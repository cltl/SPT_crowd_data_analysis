# %%
from load_data import load_experiment_data


import pandas as pd
import os
from collections import defaultdict
import datetime
import pytz
import json

# %%
# header: 
#_unit_id	_id	_worker_id	_started_at	_created_at	description	relation	concept	property	answer	Nationality	prolific_rating

# time format:
#2019-12-03 13:48:04	2019-12-03 13:47:44

# %%
# Out:
# Discarded 0.0 annotations.

# %%
input_df
# Out:
#                                    _unit_id     _id                _worker_id  \
# 0      8da635bd-d5d0-4398-9b10-236c2c4b3805  158115  5ce2cde71d1060001a811155
# 1      3625f593-6423-44b0-b344-59b14e15947c  158116  5ce2cde71d1060001a811155
# 2      97dc6704-0366-41d3-bb47-e0fece9bdd41  158117  5ce2cde71d1060001a811155
# 3      3360c8e2-6ad8-45b8-8df6-d64e8c5390ed  158118  5ce2cde71d1060001a811155
# 4      deef0a3a-0ff4-4ddc-8aec-a1a392a2d30a  158119  5ce2cde71d1060001a811155
# 5      66ddf6ea-07ba-451b-b95b-14b71a2704b6  158120  5ce2cde71d1060001a811155
# 6      6f6a4e49-850f-4ad0-9494-cf24a7645b65  158121  5ce2cde71d1060001a811155
# 7      a06e1cb4-fac6-4427-a367-874a03dfb72a  158122  5ce2cde71d1060001a811155
# 8      a29dad79-d3d8-425a-9c02-fa35041b6da7  158123  5ce2cde71d1060001a811155
# 9      ae46013e-e36c-4684-9e4a-baae8db3886e  158124  5ce2cde71d1060001a811155
# 10     a99c9159-9902-47c8-8732-2021c0aa7742  158125  5ce2cde71d1060001a811155
# 11     d60d0557-f242-4b5f-aaea-9453ce08dbe9  158126  5ce2cde71d1060001a811155
# 12     a7cf6506-30b2-4941-b26d-3f168aad5ebd  158127  5ce2cde71d1060001a811155
# 13     14d27cac-c59b-4edd-b3b0-103e4fe0584a  158128  5ce2cde71d1060001a811155
# 14     33696193-812b-4f9d-90ad-413560def92e  158129  5ce2cde71d1060001a811155
# 15     1df5d033-9de2-4ad1-93a9-407bd583fbe6  158130  5ce2cde71d1060001a811155
# 16     67dad711-ee02-438b-9128-43f8f05e9c67  158131  5ce2cde71d1060001a811155
# 17     9b911970-242a-4033-8660-e2f40657fca7  158132  5ce2cde71d1060001a811155
# 18     42f5a955-c189-4182-bea7-5275258fa961  158133  5ce2cde71d1060001a811155
# 19     cc14cba7-986d-4425-a986-1b2e914dffeb  158134  5ce2cde71d1060001a811155
# 20     5c0f85fa-52ba-4174-be30-ea3e5754dc34  158135  5ce2cde71d1060001a811155
# 21     148acff3-0c7b-47a1-88ba-d239556f4cea  158136  5ce2cde71d1060001a811155
# 22     d83af6df-8361-43c6-9919-9e295c434dad  158137  5ce2cde71d1060001a811155
# 23     61d6c2c8-fe0c-4de9-b2d4-e9b38d4bda55  158138  5ce2cde71d1060001a811155
# 24     45ee5470-c21d-42e7-ac79-e9e74f4f03df  158139  5ce2cde71d1060001a811155
# 25     60d73aa7-68ef-4716-a6a4-f20dfd9aafc3  158140  5ce2cde71d1060001a811155
# 84466  2010-01-01 11:19:36  2010-01-01 21:16:34
# 84467  2010-01-01 11:43:10  2010-01-01 21:16:37
# 84468  2010-01-01 11:28:35  2010-01-01 21:16:40
# 84469  2010-01-01 11:28:44  2010-01-01 21:16:43
# 84470  2010-01-01 11:11:50  2010-01-01 21:16:45
# 84471  2010-01-01 11:08:41  2010-01-01 21:16:47
# 84472  2010-01-01 13:03:19  2010-01-01 21:16:50
# 84473  2010-01-01 10:58:55  2010-01-01 21:16:53
# 84474  2010-01-01 11:12:33  2010-01-01 21:16:57
# 84475  2010-01-01 11:01:11  2010-01-01 21:17:00
# 84476  2010-01-01 11:14:29  2010-01-01 21:17:01
# 84477  2010-01-01 11:42:48  2010-01-01 21:17:05
# 84478  2010-01-01 11:29:36  2010-01-01 21:17:08
# 84479  2010-01-01 11:26:45  2010-01-01 21:17:11
# 84480  2010-01-01 11:16:12  2010-01-01 21:17:13
# 84481  2010-01-01 11:13:44  2010-01-01 21:17:16
# 84482  2010-01-01 13:05:25  2010-01-01 21:17:20
# 84483  2010-01-01 10:59:36  2010-01-01 21:17:22
# 84484  2010-01-01 11:12:29  2010-01-01 21:17:25
# 84485  2010-01-01 11:02:56  2010-01-01 21:17:28
# 84486  2010-01-01 11:11:49  2010-01-01 21:17:31
# 84487  2010-01-01 11:44:07  2010-01-01 21:17:35
# 84488  2010-01-01 11:24:47  2010-01-01 21:17:38
#
#                                              description             relation  \
# 0      ``Hot'' is one for the first things which come...   typical_of_concept
# 1      You can find (a/an) vehicle which has (a/an) w...     variability_open
# 2      You can find (a/an) wasp which is yellow. Yell...     variability_open
# 3      You can find (a/an) vehicle which has (a/an) w...  variability_limited
# 4      All or most  gallinule(s) can fly/be used for ...     afforded_unusual
# 5      ``Lay_eggs'' is one for the first things which...   typical_of_concept
# 6      I could say (a/an) gallinule flies/is used for...             creative
# 7      I think (a/an) groundnut can be sweet, but thi...                 rare
# 8      I know that all or most creeper(s) lay_eggs re...       afforded_usual
# 9      ``Gallinule'' is one of the first things which...  typical_of_property
# 10     All or most  creeper(s) can lay_eggs/be used f...     afforded_unusual
# 11     I think it is impossible for (a/an) creeper to...           impossible
# 12     You can find (a/an) floor which is square. Squ...  variability_limited
# 13     ``Wheels'' is one for the first things which c...   typical_of_concept
# 14     I think (a/an) vehicle can have (a/an) wheels,...                 rare
# 15     I know that (a/an) snack is hot as most or all...     implied_category
# 16     Usually, (a/an) floor is not square, but there...              unusual
# 17     Usually, (a/an) creeper cannot lay_eggs/be use...              unusual
# 18     I know that (a/an) gallinule can fly/be used f...     implied_category
# 19     I know that all or most gallinule(s) fly regul...       afforded_usual
# 20     You can find (a/an) snack which is hot. (A/an)...     variability_open
# 21     ``Floor'' is one of the first things which com...  typical_of_property
# 22     You can find (a/an) creeper which can lay_eggs...  variability_limited
# 23     Usually, (a/an) groundnut is not sweet, but th...              unusual
# 24     I think it is impossible for (a/an) snack to b...           impossible
# 25     I think it is impossible for (a/an) groundnut ...           impossible
# 26     You can find (a/an) wasp which is yellow. Yell...  variability_limited
# 27     ``Snack'' is one of the first things which com...  typical_of_property
# 28     Usually, (a/an) gallinule cannot fly/be used f...              unusual
# 29     ``Yellow'' is one for the first things which c...   typical_of_concept
# ...                                                  ...                  ...
# 84459  You can find (a/an) deal which is made_of_wood...     variability_open
# 84460  I could say (a/an) deal is made_of_wood, but I...             creative
# 84461  I know that (a/an) pigeon can fly/be used for ...     implied_category
# 84462  You can find (a/an) window which is square. Sq...  variability_limited
# 84463  I think (a/an) crease can be dangerous, but th...                 rare
# 84464  Usually, (a/an) window is not square, but ther...              unusual
# 84465  I know that (a/an) bulldog can lay_eggs/be use...     implied_category
# 84466  I know that all or most pigeon(s) fly regularl...       afforded_usual
# 84467  I know that (a/an) deal is made_of_wood as mos...     implied_category
# 84468  ``Window'' is one of the first things which co...  typical_of_property
# 84469  Usually, (a/an) football is not black, but the...              unusual
# 84470  ``Crease'' is one of the first things which co...  typical_of_property
# 84471  I think (a/an) deal can is made_of_wood, but t...                 rare
# 84472  I think (a/an) window can be square, but this ...                 rare
# 84473  I could say (a/an) freezer is hot, but I would...             creative
# 84474  I know that being made_of_wood is necessary fo...   affording_activity
# 84475  Usually, (a/an) deal is not made_of_wood, but ...              unusual
# 84476  ``Bulldog'' is one of the first things which c...  typical_of_property
# 84477  You can find (a/an) freezer which is hot. (A/a...  variability_limited
# 84478  I think there is a bulldog  which can lay_eggs...                 rare
# 84479  I think it is impossible for (a/an) football t...           impossible
# 84480  ``Fly'' is one for the first things which come...   typical_of_concept
# 84481  Usually, (a/an) bulldog cannot lay_eggs/be use...              unusual
# 84482  ``Dangerous'' is one for the first things whic...   typical_of_concept
# 84483  Usually, (a/an) crease is not dangerous, but t...              unusual
# 84484  ``Football'' is one of the first things which ...  typical_of_property
# 84485  I know that being square is necessary for many...   affording_activity
# 84486  ``Black'' is one for the first things which co...   typical_of_concept
# 84487  You can find (a/an) crease which is dangerous....  variability_limited
# 84488  I know that (a/an) football is black as most o...     implied_category
#
#          concept      property answer
# 0          snack           hot  false
# 1        vehicle        wheels  false
# 2           wasp        yellow  false
# 3        vehicle        wheels  false
# 4      gallinule           fly  false
# 5        creeper      lay_eggs   true
# 6      gallinule           fly  false
# 7      groundnut         sweet  false
# 8        creeper      lay_eggs   true
# 9      gallinule           fly   true
# 10       creeper      lay_eggs  false
# 11       creeper      lay_eggs  false
# 12         floor        square  false
# 13       vehicle        wheels   true
# 14       vehicle        wheels  false
# 15         snack           hot  false
# 16         floor        square  false
# 17       creeper      lay_eggs  false
# 18     gallinule           fly   true
# 19     gallinule           fly   true
# 20         snack           hot   true
# 21         floor        square  false
# 22       creeper      lay_eggs  false
# 23     groundnut         sweet  false
# 24         snack           hot  false
# 25     groundnut         sweet  false
# 26          wasp        yellow   true
# 27         snack           hot  false
# 28     gallinule           fly  false
# 29          wasp        yellow  false
# ...          ...           ...    ...
# 84459       deal  made_of_wood  false
# 84460       deal  made_of_wood   true
# 84461     pigeon           fly   true
# 84462     window        square   true
# 84463     crease     dangerous   true
# 84464     window        square  false
# 84465    bulldog      lay_eggs  false
# 84466     pigeon           fly   true
# 84467       deal  made_of_wood  false
# 84468     window        square   true
# 84469   football         black   true
# 84470     crease     dangerous  false
# 84471       deal  made_of_wood   true
# 84472     window        square  false
# 84473    freezer           hot   true
# 84474       deal  made_of_wood  false
# 84475       deal  made_of_wood   true
# 84476    bulldog      lay_eggs  false
# 84477    freezer           hot   true
# 84478    bulldog      lay_eggs  false
# 84479   football         black   true
# 84480     pigeon           fly   true
# 84481    bulldog      lay_eggs  false
# 84482     crease     dangerous  false
# 84483     crease     dangerous   true
# 84484   football         black  false
# 84485     window        square   true
# 84486   football         black  false
# 84487     crease     dangerous   true
# 84488   football         black  false
#
# [84489 rows x 10 columns]

# %%
import pandas as pd
import crowdtruth
from crowdtruth.configuration import DefaultConfig
import os


def create_time_series(question_dicts, day):
    """
    Create a time series from all the questions answered by a single worker.

    :param list question_dicts: List of dicts with question info
    :param str day: date information
    :return: tuples (containing time and position in original list)
    """
    # create_time_serious of question_dicts
    time_tuples = []
    #print('number of questions:', len(question_dicts))
    for n, qu in enumerate(question_dicts):
        time = qu['timestamp']
        d, time = time.split(' ')
        time = datetime.time.fromisoformat(time)
        dt = datetime.datetime.combine(day, time)
        time_tuple = (dt, n)
        time_tuples.append(time_tuple)
    return time_tuples


def add_start_end_times(time_tuples, question_dicts, start_dt_a):
    """
    Add start and end times to time series.

    :param list time tuples: List of tuples with submission time
    and original position in question_dicts (list)
    :param list question_dicts: list of all questions answered by one participant
    :param datetime.datetime: starting time (Amsterdam timezone)
    :return: list of all question dicts including time stat and end time
    """
    all_questions = []
    times = sorted(time_tuples)
    for n, time_i in enumerate(times):
        dt, i = time_i
        qu = question_dicts[i]
        if n == 0:
            time_start = start_dt_a
        else:
            time_start = time_tuples[n-1][0]
        time_finish = dt
        qu['_started_at'] = str(time_start)
        qu['_created_at'] = str(time_finish)
        all_questions.append(qu)
    return all_questions

def add_time_info(question_dicts, start_dicts=None):
    """
    Add start and end times to time series.

    :param list time tuples: List of tuples with submission time
    and original position in question_dicts (list)
    :param list question_dicts: list of all questions answered by one participant
    :return: list of all question dicts including time stat and end time
    """
    # level of a single participant within a batch
    # We have start and end time of the participant working on a batch
    if start_dicts != None:
        start = start_dicts[0]['started_datetime']
    else:
        start = '2010-01-01 00:00:00.000000'
    if type(start) == str:
        start_dt = datetime.datetime.fromisoformat(start).replace(tzinfo=pytz.timezone('Europe/London'))
        day = start_dt.date()
        start_dt_a = start_dt.astimezone(pytz.timezone('Europe/Amsterdam')).replace(tzinfo=None).replace(microsecond=0)
        time_tuples = create_time_series(question_dicts, day)
        all_questions = add_start_end_times(time_tuples, question_dicts, start_dt_a)
    else:
        # not encountered so far
        print('start not string')
        all_questions = []
    return all_questions



def create_input_df(all_question_dicts):
    """
    Create final dataframe in format expected by crowdtruth (figure8)

    :param list all_question_dicts: List of all annotated units with time info
    :return: dataframe in expected format
    """
    final_df = pd.DataFrame.from_records(all_question_dicts)
    # make name changes so the format will be recognized
    final_df.rename(columns={'quid': '_unit_id'}, inplace = True)
    final_df.rename(columns={'id': '_id'}, inplace = True)
    final_df.rename(columns={'workerid': '_worker_id'}, inplace = True)
    final_df.drop(columns = ['assignmentid',
    'completionurl', 'exampletrue', 'examplefalse', 'filename', 'hitid',
    'listnumber', 'origin', 'partid', 'questionid', 'run', 'sublist', 'timestamp'],
    inplace = True)
    checks = ['check1', 'check2', 'check3', 'check4']
    #for ch in checks:
    #    final_df.drop(final_df[final_df['_unit_id'] == ch].index, inplace = True)
    # get colums in correct order
    col_order = ['_unit_id', '_id', '_worker_id', '_started_at',\
                 '_created_at', 'description', 'relation', 'concept',
                 'property', 'answer',]
    final_df = final_df[col_order]
    return final_df

class TestConfig(DefaultConfig):
    inputColums = ['description', 'relation', 'concept', 'property']
    outputColumns = ['answer']
    annotation_separator = ','
    open_ended_task = False
    annotation_vector = ['true', 'false']

    def processJudgments(self, judgments):
        # pre-process output to match the values in annotation_vector
        for col in self.outputColumns:
            # transform to lowercase
            judgments[col] = judgments[col].apply(lambda x: str(x).lower())
        return judgments

def split_unit_annotation_score(unit_scores_df):

    col = unit_scores_df['unit_annotation_score']
    scores_true = []
    scores_false = []

    for ind, sc in col.items():
        scores_true.append(sc['true'])
        scores_false.append(sc['false'])
    unit_scores_df['unit_annotation_score_true'] = scores_true
    unit_scores_df['unit_annotation_score_false'] = scores_false
    

if __name__ == '__main__':

    run = '*'
    batch = '*'
    n_q = '*'
    group = 'experiment*'
    
    name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')

    data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
    data_dicts_time = add_time_info(data_dict_list)
    input_df = create_input_df(data_dicts_time)
    input_dir = '../analyses/crowdtruth/input/'
    input_path = f'{input_dir}{name}.csv'
    os.makedirs(input_dir, exist_ok=True)
    input_df.to_csv(input_path, index = False)
    
    res_dir = '../analyses/crowdtruth/results/'
    res_path = f'{res_dir}{name}'
    os.makedirs(res_dir, exist_ok=True)

    
    input_file = input_path
    data, config = crowdtruth.load(
        file = input_file,
        config = TestConfig()
    )
    results = crowdtruth.run(data, config)

    unit_scores = results['units']
    split_unit_annotation_score(unit_scores)
    unit_scores.to_csv(f'{res_path}-units.csv')

    worker_scores = results['workers']
    worker_scores.to_csv(f'{res_path}-workers.csv')

    annotation_scores = results["annotations"]
    annotation_scores.to_csv(f'{res_path}-annotations.csv')
# Out:
# Discarded 655.0 annotations.
