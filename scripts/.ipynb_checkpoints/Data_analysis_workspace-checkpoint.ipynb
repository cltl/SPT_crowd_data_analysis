# %% [markdown]
# # Annotation analysis
#
# This noteboook
#
# * illustrates the steps of the analysis currently implemented
# * is used to analyze and monitor workers batch by batch

# %%
from load_data import load_experiment_data
from analyze_workers import get_worker_analysis
from analyze_pairs import get_pair_analysis
from analyze_pairs import show_pairs_of_worker
from analyze_pairs import compare_runs
from calculate_iaa import get_agreement
from clean_annotations import clean_annotations

# %% [markdown]
# # Analyze worker contradictions:
#
# * Workers with highest contradiction to annotations ratio appear on top
# * use the pandas dataframe sort method to sort on other values:
#
# `df.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')`

# %% [markdown]
# ### Current batch

# %%
run = 3
batch = 24
n_q = 70
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_worker_analysis(data_dict_list, name)
df.drop(['annotations'], axis = 1, inplace=True)
df
# Out:
# creating file with uuid run3-group_experiment1/qu70-s_qu70-batch24.csv
# added unique ids - file can be found at: ../data/prolific_output_uuid/run3-group_experiment1/qu70-s_qu70-batch24.csv
# Discarded 0.0 annotations.
#                    workerid  n_annotations  n_contradictions  n_fails  \
# 6  5d87ca81c3cecc0001747172             72                24        0
# 2  5c4e2d07c401980001ab62d9             72                11        0
# 7  5dab291188b2f30017d270c0             72                 9        0
# 8  5e10836d783225755f7e673f             72                 3        0
# 5  5d6932258b1f860019e2a7e1             72                 2        0
# 4  5d593e9e44609300192e33d1             72                 1        0
# 0  59d686325606100001c25ef0             72                 0        0
# 1  5b02fe323bc9af0001909bc5             72                 0        0
# 3  5ca92e4aa110d9001971fd0a             72                 0        0
# 9  5e5987efb5420118cfd1cf6e             72                 0        0
#
#    contradiction_annotation_ratio  fail_annotation_ratio  \
# 6                        0.333333                    0.0
# 2                        0.152778                    0.0
# 7                        0.125000                    0.0
# 8                        0.041667                    0.0
# 5                        0.027778                    0.0
# 4                        0.013889                    0.0
# 0                        0.000000                    0.0
# 1                        0.000000                    0.0
# 3                        0.000000                    0.0
# 9                        0.000000                    0.0
#
#    average_time_question  (typical_of_concept, unusual)  \
# 6               1.691972                            2.0
# 2               9.104278                            3.0
# 7               4.349556                            4.0
# 8              11.076319                            1.0
# 5               8.445222                            NaN
# 4              13.106069                            NaN
# 0              14.485125                            NaN
# 1              11.831708                            NaN
# 3               7.468167                            NaN
# 9              25.311833                            NaN
#
#    (implied_category, unusual)  (affording_activity, unusual)  \
# 6                          4.0                            3.0
# 2                          3.0                            1.0
# 7                          1.0                            NaN
# 8                          NaN                            1.0
# 5                          1.0                            NaN
# 4                          NaN                            1.0
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 3                          NaN                            NaN
# 9                          NaN                            NaN
#
#    (implied_category, rare)  (rare, typical_of_concept)  \
# 6                       3.0                         1.0
# 2                       2.0                         2.0
# 7                       1.0                         1.0
# 8                       NaN                         NaN
# 5                       1.0                         NaN
# 4                       NaN                         NaN
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 3                       NaN                         NaN
# 9                       NaN                         NaN
#
#    (typical_of_property, unusual)  (affording_activity, rare)  \
# 6                             2.0                         2.0
# 2                             NaN                         NaN
# 7                             1.0                         NaN
# 8                             1.0                         NaN
# 5                             NaN                         NaN
# 4                             NaN                         NaN
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 3                             NaN                         NaN
# 9                             NaN                         NaN
#
#    (affording_activity, impossible)  (implied_category, impossible)  \
# 6                               2.0                             2.0
# 2                               NaN                             NaN
# 7                               NaN                             1.0
# 8                               NaN                             NaN
# 5                               NaN                             NaN
# 4                               NaN                             NaN
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 3                               NaN                             NaN
# 9                               NaN                             NaN
#
#    (impossible, typical_of_concept)  (rare, typical_of_property)
# 6                               2.0                          1.0
# 2                               NaN                          NaN
# 7                               NaN                          NaN
# 8                               NaN                          NaN
# 5                               NaN                          NaN
# 4                               NaN                          NaN
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 3                               NaN                          NaN
# 9                               NaN                          NaN

# %% [markdown]
# ### All annotations
#
# * Workers with highest contradiction to annotations ratio appear on top
# * use the pandas dataframe sort method to sort on other values:
# * Check how the behavior of a specific worker with many contradictions compares to other workers
#
# `df.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')`

# %%
run = '*'
batch = '*'
n_q = '*'
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_worker_analysis(data_dict_list, name)
df.drop(['annotations'], axis = 1, inplace=True)
df[:10]
# Out:
# Discarded 655.0 annotations.
#                      workerid  n_annotations  n_contradictions  n_fails  \
# 502  5d76a2dc2a476a0001ce6843             72                45        1
# 289  5e4e86b070e1ed2d6e4e3f62             72                42        1
# 294  5e7cbbbcf0a5a004b60b48f7             72                41        1
# 241  5c91321c0375460001034cb8             71                38        0
# 496  5e76ab49dec4562243b421f9             72                35        2
# 305  5ba4f45c4286a00001ea457f             72                34        1
# 15   5dc0395f2a1dd64710661ccd             71                33        0
# 192  5d4434c68225f9001642fcd3             71                30        0
# 187  5de8dc07f42a16000a301cd6             78                31        0
# 71   599aca876b939900012da2cd             71                27        0
#
#      contradiction_annotation_ratio  fail_annotation_ratio  \
# 502                        0.625000               0.013889
# 289                        0.583333               0.013889
# 294                        0.569444               0.013889
# 241                        0.535211               0.000000
# 496                        0.486111               0.027778
# 305                        0.472222               0.013889
# 15                         0.464789               0.000000
# 192                        0.422535               0.000000
# 187                        0.397436               0.000000
# 71                         0.380282               0.000000
#
#      average_time_question  (afforded_unusual, unusual)  \
# 502              16.482319                          NaN
# 289               4.293264                          NaN
# 294              11.482222                          NaN
# 241              12.942127                          2.0
# 496              18.781028                          NaN
# 305               9.803042                          NaN
# 15                3.745113                          4.0
# 192               5.209535                          1.0
# 187               4.965808                          2.0
# 71               19.589310                          1.0
#
#      (typical_of_property, unusual)  (implied_category, unusual)  ...  \
# 502                             3.0                          5.0  ...
# 289                             5.0                          5.0  ...
# 294                             2.0                          1.0  ...
# 241                             6.0                          6.0  ...
# 496                             3.0                          2.0  ...
# 305                             4.0                          4.0  ...
# 15                              5.0                          5.0  ...
# 192                             4.0                          4.0  ...
# 187                             5.0                          5.0  ...
# 71                              6.0                          7.0  ...
#
#      (impossible, typical_of_concept)  (impossible, typical_of_property)  \
# 502                               3.0                                2.0
# 289                               1.0                                2.0
# 294                               2.0                                4.0
# 241                               5.0                                5.0
# 496                               3.0                                1.0
# 305                               2.0                                2.0
# 15                                3.0                                2.0
# 192                               3.0                                3.0
# 187                               3.0                                3.0
# 71                                NaN                                NaN
#
#      (implied_category, impossible)  (affording_activity, impossible)  \
# 502                             3.0                               2.0
# 289                             2.0                               1.0
# 294                             4.0                               4.0
# 241                             4.0                               1.0
# 496                             2.0                               3.0
# 305                             2.0                               2.0
# 15                              3.0                               1.0
# 192                             3.0                               3.0
# 187                             3.0                               1.0
# 71                              NaN                               NaN
#
#      (afforded_unusual, impossible)  (afforded_usual, impossible)  \
# 502                             NaN                           NaN
# 289                             NaN                           NaN
# 294                             NaN                           NaN
# 241                             1.0                           NaN
# 496                             NaN                           NaN
# 305                             NaN                           NaN
# 15                              1.0                           1.0
# 192                             1.0                           NaN
# 187                             1.0                           1.0
# 71                              NaN                           NaN
#
#      (implied_category, rare)  (rare, typical_of_concept)  \
# 502                       5.0                         5.0
# 289                       5.0                         4.0
# 294                       5.0                         4.0
# 241                       NaN                         NaN
# 496                       2.0                         4.0
# 305                       3.0                         2.0
# 15                        NaN                         NaN
# 192                       NaN                         NaN
# 187                       NaN                         NaN
# 71                        NaN                         NaN
#
#      (rare, typical_of_property)  (affording_activity, rare)
# 502                          3.0                         5.0
# 289                          5.0                         4.0
# 294                          6.0                         6.0
# 241                          NaN                         NaN
# 496                          3.0                         4.0
# 305                          3.0                         3.0
# 15                           NaN                         NaN
# 192                          NaN                         NaN
# 187                          NaN                         NaN
# 71                           NaN                         NaN
#
# [10 rows x 23 columns]

# %% [markdown]
# ### Get all disagreements and fails of a particular worker
#
# * Check if a specfic worker continuously contradicts themselves (and fails checks)

# %%
# copy from above - worker with many disagreements in target batch
worker = '5c4e2d07c401980001ab62d9'

# df.loc[df['column_name'] == some_value]
df.loc[df['workerid'] == worker]
# Out:
#                      workerid  n_annotations  n_contradictions  n_fails  \
# 345  5c4e2d07c401980001ab62d9             72                11        0
#
#      contradiction_annotation_ratio  fail_annotation_ratio  \
# 345                        0.152778                    0.0
#
#      average_time_question  (afforded_unusual, unusual)  \
# 345               9.104278                          NaN
#
#      (typical_of_property, unusual)  (implied_category, unusual)  ...  \
# 345                             NaN                          3.0  ...
#
#      (impossible, typical_of_concept)  (impossible, typical_of_property)  \
# 345                               NaN                                NaN
#
#      (implied_category, impossible)  (affording_activity, impossible)  \
# 345                             NaN                               NaN
#
#      (afforded_unusual, impossible)  (afforded_usual, impossible)  \
# 345                             NaN                           NaN
#
#      (implied_category, rare)  (rare, typical_of_concept)  \
# 345                       2.0                         2.0
#
#      (rare, typical_of_property)  (affording_activity, rare)
# 345                          NaN                         NaN
#
# [1 rows x 23 columns]

# %% [markdown]
# # Analyze pairs
#
# * compars number of annotator contradictions among pairs

# %% [markdown]
# ### Current batch:

# %%
run = '3'
batch = '23'
n_q = '*'
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_pair_analysis(data_dict_list, name)
df.drop(['annotations_with_contradiction'], axis = 1, inplace=True)
df
# Out:
# Discarded 0.0 annotations.
#               pair  n_annotations  n_workers  n_contradictions  \
# 1    round-soursop            100         10                13
# 3    red-chocolate            100         10                 9
# 2        red-mango            100         10                 8
# 4        red-mamey            100         10                 8
# 6          red-eye            100         10                 4
# 0    round-sausage            100         10                 3
# 5     round-banana             60         10                 0
# 7  _check1-_check1             10         10                 0
# 8    _test2-_test2             10         10                 0
#
#    n_workers_contradicting  ratio_workers_contradicting  \
# 1                        3                          0.3
# 3                        1                          0.1
# 2                        3                          0.3
# 4                        4                          0.4
# 6                        1                          0.1
# 0                        2                          0.2
# 5                        0                          0.0
# 7                        0                          0.0
# 8                        0                          0.0
#
#    contradiction_annotation_ratio  average_time_pair  \
# 1                            0.13          60.055330
# 3                            0.09          60.055330
# 2                            0.08          60.055330
# 4                            0.08          60.055330
# 6                            0.04          60.055330
# 0                            0.03          60.055330
# 5                            0.00         100.092217
# 7                            0.00         600.553300
# 8                            0.00         600.553300
#
#                                workers_contradicting  \
# 1  5d87ca81c3cecc0001747172 5d9943563cc9670014523...
# 3                           5d87ca81c3cecc0001747172
# 2  5d2a471d608cc7000106fe48 5d87ca81c3cecc0001747...
# 4  59bfa457d9e6ba0001b5f2bf 5d87ca81c3cecc0001747...
# 6                           5d87ca81c3cecc0001747172
# 0  5c6b0f0dec453a00014d6a5c 5d87ca81c3cecc0001747172
# 5
# 7
# 8
#
#                            workers_not_contradicting  ...  \
# 1  59bfa457d9e6ba0001b5f2bf 5b222aff59f9620001c10...  ...
# 3  59bfa457d9e6ba0001b5f2bf 5b222aff59f9620001c10...  ...
# 2  59bfa457d9e6ba0001b5f2bf 5b222aff59f9620001c10...  ...
# 4  5b222aff59f9620001c109cb 5c6b0f0dec453a00014d6...  ...
# 6  59bfa457d9e6ba0001b5f2bf 5b222aff59f9620001c10...  ...
# 0  59bfa457d9e6ba0001b5f2bf 5b222aff59f9620001c10...  ...
# 5  59bfa457d9e6ba0001b5f2bf 5b222aff59f9620001c10...  ...
# 7  59bfa457d9e6ba0001b5f2bf 5b222aff59f9620001c10...  ...
# 8  59bfa457d9e6ba0001b5f2bf 5b222aff59f9620001c10...  ...
#
#    (rare, typical_of_concept)  (implied_category, rare)  \
# 1                         2.0                       1.0
# 3                         1.0                       NaN
# 2                         1.0                       NaN
# 4                         1.0                       2.0
# 6                         1.0                       NaN
# 0                         1.0                       1.0
# 5                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
#
#    (affording_activity, rare)  (implied_category, unusual)  \
# 1                         2.0                          2.0
# 3                         1.0                          NaN
# 2                         2.0                          NaN
# 4                         1.0                          2.0
# 6                         NaN                          NaN
# 0                         NaN                          NaN
# 5                         NaN                          NaN
# 7                         NaN                          NaN
# 8                         NaN                          NaN
#
#    (typical_of_concept, unusual)  (affording_activity, impossible)  \
# 1                            3.0                               NaN
# 3                            1.0                               1.0
# 2                            NaN                               2.0
# 4                            NaN                               NaN
# 6                            1.0                               NaN
# 0                            NaN                               NaN
# 5                            NaN                               NaN
# 7                            NaN                               NaN
# 8                            NaN                               NaN
#
#    (impossible, typical_of_concept)  (typical_of_property, unusual)  \
# 1                               NaN                             NaN
# 3                               1.0                             1.0
# 2                               1.0                             NaN
# 4                               NaN                             NaN
# 6                               NaN                             1.0
# 0                               NaN                             NaN
# 5                               NaN                             NaN
# 7                               NaN                             NaN
# 8                               NaN                             NaN
#
#    (rare, typical_of_property)  (impossible, typical_of_property)
# 1                          NaN                                NaN
# 3                          1.0                                1.0
# 2                          NaN                                NaN
# 4                          1.0                                NaN
# 6                          1.0                                NaN
# 0                          NaN                                NaN
# 5                          NaN                                NaN
# 7                          NaN                                NaN
# 8                          NaN                                NaN
#
# [9 rows x 21 columns]

# %% [markdown]
# ### Get rows with pairs annotated by specific workers:
#
# * Check if a worker in the only one contradicting or if others also had issues with the pairs

# %%
worker = '5d87ca81c3cecc0001747172'

show_pairs_of_worker(worker, df)
# Out:
# Worker 5d87ca81c3cecc0001747172 contradicted themselves in the following pairs:
#
# round-soursop 	 total workers contradicting themselves: 3
# red-chocolate 	 total workers contradicting themselves: 1
# red-mango 	 total workers contradicting themselves: 3
# red-mamey 	 total workers contradicting themselves: 4
# red-eye 	 total workers contradicting themselves: 1
# round-sausage 	 total workers contradicting themselves: 2

# %% [markdown]
# ### Compare to entire annotation set

# %%
run = '*'
batch = '*'
n_q = '*'
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_pair_analysis(data_dict_list, name)
df.drop(['annotations_with_contradiction'], axis = 1, inplace=True)
df
# Out:
# Discarded 655.0 annotations.
#                  pair  n_annotations  n_workers  n_contradictions  \
# 26       roll-spindle             50          5                22
# 231         roll-bolt             50          5                21
# 23       roll-mandrel             50          5                21
# 25          roll-pipe             50          5                19
# 227         roll-lamp             50          5                17
# ..                ...            ...        ...               ...
# 324  round-breadcrumb             50          5                 0
# 323           red-cat            142         15                 0
# 176       round-cream             50          5                 0
# 320         red-guava             50          5                 0
# 245          red-beet             35          5                 0
#
#      n_workers_contradicting  ratio_workers_contradicting  \
# 26                         4                          0.8
# 231                        5                          1.0
# 23                         5                          1.0
# 25                         4                          0.8
# 227                        4                          0.8
# ..                       ...                          ...
# 324                        0                          0.0
# 323                        0                          0.0
# 176                        0                          0.0
# 320                        0                          0.0
# 245                        0                          0.0
#
#      contradiction_annotation_ratio  average_time_pair  \
# 26                             0.44          57.711660
# 231                            0.42          85.335380
# 23                             0.42          57.711660
# 25                             0.38          57.711660
# 227                            0.34          85.335380
# ..                              ...                ...
# 324                            0.00          53.131520
# 323                            0.00          70.430573
# 176                            0.00          23.563020
# 320                            0.00          53.131520
# 245                            0.00          93.395600
#
#                                  workers_contradicting  \
# 26   5dc0395f2a1dd64710661ccd 5ddc56fbf290e7bbfa964...
# 231  5acb5910e1546900019c413a 5c5758e9efe1550001dc3...
# 23   5dc0395f2a1dd64710661ccd 5ddc56fbf290e7bbfa964...
# 25   5dc0395f2a1dd64710661ccd 5ddc56fbf290e7bbfa964...
# 227  5acb5910e1546900019c413a 5d3f14f66a8a4e0018c17...
# ..                                                 ...
# 324
# 323
# 176
# 320
# 245
#
#                              workers_not_contradicting  ...  \
# 26                            5de6be6912bcf6041b3276ba  ...
# 231                                                     ...
# 23                                                      ...
# 25                            5de6d199a23d79000bf9aef9  ...
# 227                           5c5758e9efe1550001dc31b6  ...
# ..                                                 ...  ...
# 324  5aed0f3823e2ca0001976444 5c590c02e66e510001ef0...  ...
# 323  5aed0f3823e2ca0001976444 5c590c02e66e510001ef0...  ...
# 176  59d3764946447f00011f0407 5a828ebeeea3d300016e5...  ...
# 320  5aed0f3823e2ca0001976444 5c590c02e66e510001ef0...  ...
# 245  5c8abb61e1b6910001b30615 5d8b0fb691f3e600016e6...  ...
#
#      (impossible, typical_of_property)  (implied_category, rare)  \
# 26                                 2.0                       NaN
# 231                                1.0                       NaN
# 23                                 NaN                       NaN
# 25                                 NaN                       NaN
# 227                                2.0                       NaN
# ..                                 ...                       ...
# 324                                NaN                       NaN
# 323                                NaN                       NaN
# 176                                NaN                       NaN
# 320                                NaN                       NaN
# 245                                NaN                       NaN
#
#      (rare, typical_of_property)  (affording_activity, unusual)  \
# 26                           NaN                            NaN
# 231                          NaN                            NaN
# 23                           NaN                            NaN
# 25                           NaN                            NaN
# 227                          NaN                            NaN
# ..                           ...                            ...
# 324                          NaN                            NaN
# 323                          NaN                            NaN
# 176                          NaN                            NaN
# 320                          NaN                            NaN
# 245                          NaN                            NaN
#
#      (implied_category, impossible)  (rare, typical_of_concept)  \
# 26                              2.0                         NaN
# 231                             NaN                         NaN
# 23                              NaN                         NaN
# 25                              NaN                         NaN
# 227                             1.0                         NaN
# ..                              ...                         ...
# 324                             NaN                         NaN
# 323                             NaN                         NaN
# 176                             NaN                         NaN
# 320                             NaN                         NaN
# 245                             NaN                         NaN
#
#      (affording_activity, impossible)  (afforded_unusual, impossible)  \
# 26                                NaN                             2.0
# 231                               NaN                             1.0
# 23                                NaN                             NaN
# 25                                NaN                             1.0
# 227                               NaN                             2.0
# ..                                ...                             ...
# 324                               NaN                             NaN
# 323                               NaN                             NaN
# 176                               NaN                             NaN
# 320                               NaN                             NaN
# 245                               NaN                             NaN
#
#      (afforded_usual, impossible)  (affording_activity, rare)
# 26                            2.0                         NaN
# 231                           1.0                         NaN
# 23                            NaN                         NaN
# 25                            1.0                         NaN
# 227                           1.0                         NaN
# ..                            ...                         ...
# 324                           NaN                         NaN
# 323                           NaN                         NaN
# 176                           NaN                         NaN
# 320                           NaN                         NaN
# 245                           NaN                         NaN
#
# [436 rows x 26 columns]

# %% [markdown]
# ### Compare contradictions between runs:

# %%
run = '1'
batch = '*'
n_q = '*'
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df1, filepath = get_pair_analysis(data_dict_list, name)
print(f'analysis can be found at: {filepath}')

run = '3'
batch = '*'
n_q = '*'
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df2, filepath = get_pair_analysis(data_dict_list, name)
print(f'analysis can be found at: {filepath}')

name1 = '1'
name2 = '3'
compare_runs(name1, name2, df1, df2, comp = 'all')
print()
compare_runs(name1, name2, df1, df2, comp = 'pairs')
# Out:
# Discarded 0.0 annotations.
# analysis can be found at: ../analyses/pairs/run1-group_experiment1-batch-all-.csv
# Discarded 655.0 annotations.
# analysis can be found at: ../analyses/pairs/run3-group_experiment1-batch-all-.csv
# Set 1 as a contradiction ratio of 0.26912294753704447
# Set 3 as a contradiction ratio of 0.1533487297921478
# The ratio is based on the number of workers annotating a pair.
# A worker always annotates a full set.
#
# Set 1 as a contradiction ratio of 0.19137931034482758
# Set 3 as a contradiction ratio of 0.170997920997921
# The ratio is based on the number of workers annotating a pair.
# A worker always annotates a full set.
# This analysis only includes pairs annotated in run 1 and run 3.
# (0.19137931034482758, 0.170997920997921)

# %% [markdown]
# # Inter-annotator agreement
#
# Compare both runs in original version and version without annotations in which annotators contradict themselves:

# %%
run = '3'
batch = '18'
n_q = '*'
group = 'experiment1'
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)

get_agreement(data_dict_list)

run = '1'
batch = '*'
n_q = '*'
group = 'experiment1'
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)

get_agreement(data_dict_list)
# Out:
# Discarded 20.0 annotations.
# Krippendorff's alpha: 0.2933511483129806
# Proportional agreement (pairwise): 0.684330484330484
#
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.2413329996998821
# Proportional agreement (pairwise): 0.6204625909422005

# %%
run = '1'
batch = '*'
n_q = '*'
group = 'experiment1'
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)

get_agreement(data_dict_list)
# Out:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.2413329996998821
# Proportional agreement (pairwise): 0.6204625909422005

# %%
run = '3'
batch = '*'
n_q = '*'
group = 'experiment1'

category = 'pairs_contradictions'
print(f'analyze {category}')
annotations_clean, annotations_removed = clean_annotations(run, group, n_q, batch, category)
print('agreement clean')
get_agreement(annotations_clean)
print('agreement rest')
get_agreement(annotations_removed)


category = 'worker_contradictions'
print(f'analyze {category}')
annotations_clean, annotations_removed = clean_annotations(run, group, n_q, batch, category)
print('agreement clean')
get_agreement(annotations_clean)
print('agreement rest')
get_agreement(annotations_removed)


category = 'worker_checks'
print(f'analyze {category}')
annotations_clean, annotations_removed = clean_annotations(run, group, n_q, batch, category)
print('agreement clean')
get_agreement(annotations_clean)
print('agreement rest')
get_agreement(annotations_removed)
# Out:
# analyze pairs_contradictions
# Discarded 655.0 annotations.
# Found 13633 clean annotations.
# Round 3283 to remove.
#
# agreement clean
# Krippendorff's alpha: 0.34099930456831007
# Proportional agreement (pairwise): 0.7022918102658329
#
# agreement rest
# Krippendorff's alpha: 0.08464996553294202
# Proportional agreement (pairwise): 0.40217438573602804
#
# analyze worker_contradictions
# Discarded 655.0 annotations.
# Found 6774 clean annotations.
# Round 10100 to remove.
#
# agreement clean
# Krippendorff's alpha: 0.34138322343219396
# Proportional agreement (pairwise): 0.6879524284198786
#
# agreement rest
# Krippendorff's alpha: 0.22305174148170004
# Proportional agreement (pairwise): 0.6155764495684004
#
# analyze worker_checks
# Discarded 655.0 annotations.
# Found 14345 clean annotations.
# Round 2529 to remove.
#
# agreement clean
# Krippendorff's alpha: 0.3004942691037146
# Proportional agreement (pairwise): 0.6671261731478569
#
# agreement rest
# Krippendorff's alpha: 0.11758340511071363
# Proportional agreement (pairwise): 0.47452206698530147
