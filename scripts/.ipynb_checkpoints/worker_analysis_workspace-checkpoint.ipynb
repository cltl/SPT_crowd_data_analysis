# %%
from load_data import load_experiment_data
from analyze_workers import get_worker_analysis
from analyze_iaa import get_agreement

# %% [markdown]
# # Analyze current batch [enter batch number]:
#
# * Workers with highest contradiction to annotations ratio appear on top
# * use the pandas dataframe sort method to sort on other values:
#
# `df.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')`

# %%
run = 3
batch = 13
n_q = 70
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_worker_analysis(data_dict_list, name)
df
# Out:
#                    workerid  n_annotations  n_contradictions  n_fails  \
# 5  5c8d3f8bf756d40016683868             76                25        0
# 8  5e6a3ff6a21e120a40d76a84             76                17        1
# 3  5bfe6f8c6e6cd80001bea615             76                14        0
# 1  5bae4929254aa9000189a644             76                 4        1
# 2  5bf4d30498496900016ffd14             76                 2        0
# 0  5b222aff59f9620001c109cb             76                 0        0
# 4  5c7017ac1e20530001e7ce63             76                 0        0
# 6  5dcc8459bfb31a920381996e             76                 0        0
# 7  5e6a16f0d2e99d06ad80e2a8             76                 0        0
# 9  5e7156645b050e07277c6682             76                 0        0
#
#    contradiction_annotation_ratio  fail_annotation_ratio  \
# 5                        0.328947               0.000000
# 8                        0.223684               0.013158
# 3                        0.184211               0.000000
# 1                        0.052632               0.013158
# 2                        0.026316               0.000000
# 0                        0.000000               0.000000
# 4                        0.000000               0.000000
# 6                        0.000000               0.000000
# 7                        0.000000               0.000000
# 9                        0.000000               0.000000
#
#    average_time_question  (affording_activity, rare)  \
# 5              12.950526                         NaN
# 8              27.117737                         3.0
# 3               3.578408                         2.0
# 1               8.263618                         1.0
# 2               7.567855                         1.0
# 0               8.195132                         NaN
# 4              10.231684                         NaN
# 6              13.788763                         NaN
# 7              14.573421                         NaN
# 9              13.587842                         NaN
#
#    (affording_activity, unusual)  (implied_category, rare)  \
# 5                            1.0                       3.0
# 8                            1.0                       1.0
# 3                            1.0                       1.0
# 1                            1.0                       1.0
# 2                            1.0                       NaN
# 0                            NaN                       NaN
# 4                            NaN                       NaN
# 6                            NaN                       NaN
# 7                            NaN                       NaN
# 9                            NaN                       NaN
#
#    (implied_category, unusual)  (typical_of_property, unusual)  \
# 5                          6.0                             3.0
# 8                          1.0                             1.0
# 3                          1.0                             2.0
# 1                          1.0                             NaN
# 2                          NaN                             NaN
# 0                          NaN                             NaN
# 4                          NaN                             NaN
# 6                          NaN                             NaN
# 7                          NaN                             NaN
# 9                          NaN                             NaN
#
#    (rare, typical_of_property)  (impossible, typical_of_concept)  \
# 5                          2.0                               NaN
# 8                          2.0                               1.0
# 3                          2.0                               1.0
# 1                          NaN                               NaN
# 2                          NaN                               NaN
# 0                          NaN                               NaN
# 4                          NaN                               NaN
# 6                          NaN                               NaN
# 7                          NaN                               NaN
# 9                          NaN                               NaN
#
#    (implied_category, impossible)  (affording_activity, impossible)  \
# 5                             2.0                               1.0
# 8                             1.0                               2.0
# 3                             1.0                               1.0
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 0                             NaN                               NaN
# 4                             NaN                               NaN
# 6                             NaN                               NaN
# 7                             NaN                               NaN
# 9                             NaN                               NaN
#
#    (rare, typical_of_concept)  (typical_of_concept, unusual)  \
# 5                         2.0                            4.0
# 8                         1.0                            1.0
# 3                         2.0                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 0                         NaN                            NaN
# 4                         NaN                            NaN
# 6                         NaN                            NaN
# 7                         NaN                            NaN
# 9                         NaN                            NaN
#
#    (impossible, typical_of_property)
# 5                                1.0
# 8                                2.0
# 3                                NaN
# 1                                NaN
# 2                                NaN
# 0                                NaN
# 4                                NaN
# 6                                NaN
# 7                                NaN
# 9                                NaN

# %% [markdown]
# # Compare to all annotations
#
# * Workers with highest contradiction to annotations ratio appear on top
# * use the pandas dataframe sort method to sort on other values:
#
# `df.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')`

# %%
run = '*'
batch = '*'
n_q = '*'
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_worker_analysis(data_dict_list, name)
df
# Out:
#                      workerid  n_annotations  n_contradictions  n_fails  \
# 398  5d76a2dc2a476a0001ce6843             75                45        1
# 241  5c91321c0375460001034cb8             71                38        0
# 15   5dc0395f2a1dd64710661ccd             71                33        0
# 392  5e76ab49dec4562243b421f9             79                35        2
# 192  5d4434c68225f9001642fcd3             71                30        0
# ..                        ...            ...               ...      ...
# 321  5cd74735c78b7d0001f9b364             80                 0        0
# 180  5c506148bfe6820001309a06             77                 0        0
# 319  5c542a124e2ebe0001458bf9             80                 0        0
# 188  582c280c3b081f0001510456             71                 0        0
# 206  5db2d023d76f07000b00349a             78                 0        0
#
#      contradiction_annotation_ratio  fail_annotation_ratio  \
# 398                        0.600000               0.013333
# 241                        0.535211               0.000000
# 15                         0.464789               0.000000
# 392                        0.443038               0.025316
# 192                        0.422535               0.000000
# ..                              ...                    ...
# 321                        0.000000               0.000000
# 180                        0.000000               0.000000
# 319                        0.000000               0.000000
# 188                        0.000000               0.000000
# 206                        0.000000               0.000000
#
#      average_time_question  (afforded_unusual, unusual)  \
# 398              15.823027                          NaN
# 241              12.942127                          2.0
# 15                3.745113                          4.0
# 392              17.116886                          NaN
# 192               5.209535                          1.0
# ..                     ...                          ...
# 321              23.345225                          NaN
# 180               9.666117                          NaN
# 319               7.879437                          NaN
# 188               9.955620                          NaN
# 206               9.402795                          NaN
#
#      (typical_of_property, unusual)  (implied_category, unusual)  ...  \
# 398                             3.0                          5.0  ...
# 241                             6.0                          6.0  ...
# 15                              5.0                          5.0  ...
# 392                             3.0                          2.0  ...
# 192                             4.0                          4.0  ...
# ..                              ...                          ...  ...
# 321                             NaN                          NaN  ...
# 180                             NaN                          NaN  ...
# 319                             NaN                          NaN  ...
# 188                             NaN                          NaN  ...
# 206                             NaN                          NaN  ...
#
#      (impossible, typical_of_concept)  (impossible, typical_of_property)  \
# 398                               3.0                                2.0
# 241                               5.0                                5.0
# 15                                3.0                                2.0
# 392                               3.0                                1.0
# 192                               3.0                                3.0
# ..                                ...                                ...
# 321                               NaN                                NaN
# 180                               NaN                                NaN
# 319                               NaN                                NaN
# 188                               NaN                                NaN
# 206                               NaN                                NaN
#
#      (implied_category, impossible)  (affording_activity, impossible)  \
# 398                             3.0                               2.0
# 241                             4.0                               1.0
# 15                              3.0                               1.0
# 392                             2.0                               3.0
# 192                             3.0                               3.0
# ..                              ...                               ...
# 321                             NaN                               NaN
# 180                             NaN                               NaN
# 319                             NaN                               NaN
# 188                             NaN                               NaN
# 206                             NaN                               NaN
#
#      (afforded_unusual, impossible)  (afforded_usual, impossible)  \
# 398                             NaN                           NaN
# 241                             1.0                           NaN
# 15                              1.0                           1.0
# 392                             NaN                           NaN
# 192                             1.0                           NaN
# ..                              ...                           ...
# 321                             NaN                           NaN
# 180                             NaN                           NaN
# 319                             NaN                           NaN
# 188                             NaN                           NaN
# 206                             NaN                           NaN
#
#      (implied_category, rare)  (rare, typical_of_concept)  \
# 398                       5.0                         5.0
# 241                       NaN                         NaN
# 15                        NaN                         NaN
# 392                       2.0                         4.0
# 192                       NaN                         NaN
# ..                        ...                         ...
# 321                       NaN                         NaN
# 180                       NaN                         NaN
# 319                       NaN                         NaN
# 188                       NaN                         NaN
# 206                       NaN                         NaN
#
#      (affording_activity, rare)  (rare, typical_of_property)
# 398                         5.0                          3.0
# 241                         NaN                          NaN
# 15                          NaN                          NaN
# 392                         4.0                          3.0
# 192                         NaN                          NaN
# ..                          ...                          ...
# 321                         NaN                          NaN
# 180                         NaN                          NaN
# 319                         NaN                          NaN
# 188                         NaN                          NaN
# 206                         NaN                          NaN
#
# [413 rows x 23 columns]

# %% [markdown]
# # Inter-annotator agreement
#
# Compare both runs in original version and version without annotations in which annotators contradict themselves:

# %%
run = 1
group = 'experiment1'
batch = '*'
n_q = '*'
statuses = ['original', 'clean']
print(f'--- analyzing run {run} ---')
for status in statuses:
    get_agreement(run, group, batch, n_q, status)



run = 3
group = 'experiment1'
batch = '*'
n_q = '*'
statuses = ['original', 'clean']
print(f'--- analyzing run {run} ---')
for status in statuses:
    get_agreement(run, group, batch, n_q, status)
# Out:
# --- analyzing run 1 ---
# Analyzing run 1 of experiment group experiment1 (original):
# Krippendorff's alpha: 0.2413329996998821
# Proportional agreement (pairwise): 0.6204625909422006
#
# Analyzing run 1 of experiment group experiment1 (clean):
# original number of annotations: 21257
# number of clean annotations: 14519
# number of discarded annotations: 6738
# percentage discarded: 0.316977936679682
# Krippendorff's alpha: 0.32159574124607226
# Proportional agreement (pairwise): 0.6234131462884155
#
# --- analyzing run 3 ---
# Analyzing run 3 of experiment group experiment1 (original):
# Krippendorff's alpha: 0.2509984821432901
# Proportional agreement (pairwise): 0.6384277564987105
#
# Analyzing run 3 of experiment group experiment1 (clean):
# original number of annotations: 10677
# number of clean annotations: 8545
# number of discarded annotations: 2132
# percentage discarded: 0.1996815584902126
# Krippendorff's alpha: 0.3432775073728077
# Proportional agreement (pairwise): 0.6998206909360225
