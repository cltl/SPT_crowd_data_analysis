# %%
# match annotations from run 1 and 3 and see if there are fewer contradictions

from collections import defaultdict
import csv

from utils import get_pair_dict
from utils import load_experiment_data
from utils import get_worker_pair_dict
from utils import load_contradiction_pairs
#from remove_contradictory_answers import clean_annotations

from utils import get_relation_counts
from utils import consistency_check
import pandas as pd

# %%
def get_dict_lists(list_dict, dict_list_n, k_name, v_name):
    dict_list = []
    for k, l in dict_list_n.items():
        cnt_dict = dict()
        n = len(list_dict[k])
        total = len(l)
        cnt_dict[k_name] = k
        cnt_dict[v_name] = n
        cnt_dict['total'] = total
        cnt_dict['proportion'] = n/total
        dict_list.append(cnt_dict)    
    return dict_list

def dicts_to_file(dicts, name):
    fieldnames = dicts[0].keys()
    with open(name, 'w') as outfile:
        writer = csv.DictWriter(outfile, fieldnames = fieldnames)
        writer.writeheader()
        for d in dicts:
            writer.writerow(d)
            
def collect_contradictions(worker_pair_dict, dict_list_out, contradiction_pairs, v=True):

    pair_workers_contradicting = defaultdict(list)
    pair_nworkers = defaultdict(set)
    for worker, pair_dict in worker_pair_dict.items():
        for pair, relation_vec in pair_dict.items():
            relation_counts = get_relation_counts(relation_vec, normalize = True)
            contradictions = consistency_check(contradiction_pairs, relation_counts,\
                                               thresh = 0.0)
            pair_nworkers[pair].add(worker)
            if len(contradictions) > 0:
                if v == True:
                    print('contradiction_count', worker, pair)
                pair_workers_contradicting[pair].append(worker)
    dict_list_pairs = get_dict_lists(pair_workers_contradicting,\
                                     pair_nworkers, 'pair', 'pairs_removed')
    return dict_list_pairs
        
    
    
def contradiction_analysis(run, group, n_q, batch, remove_not_val = True):
    
    dict_list_out = load_experiment_data(run, group, n_q, batch,\
                                         remove_not_val = remove_not_val)
    worker_pair_dict = get_worker_pair_dict(dict_list_out)
    dict_list_pairs = collect_contradictions(worker_pair_dict, dict_list_out,\
                                            contradiction_pairs, v = False)

    pair_cont_name = 'pairs_removed'
    filepath = f'../analyses/contradiction/{pair_cont_name}-run{run}-group_{group}.csv'
    dicts_to_file(dict_list_pairs, filepath)
    return filepath, dict_list_pairs

def get_counts_same_pairs(run_analysis_dict, factor = 'proportion'):
    
    pair_analysis_dict = defaultdict(dict)
    runs = run_analysis_dict.keys()
    for run, analysis_dicts in run_analysis_dict.items():
        for analysis_dict in analysis_dicts:
            pair = analysis_dict['pair']
            pair_analysis_dict[pair][run] = analysis_dict[factor]
        
    return pair_analysis_dict


def get_comparison_df(pair_ananlysis_dict):
    comparison_dicts = []
    for pair, analysis_dict in pair_analysis_dict.items():
        pair_dict = dict()
        if len(analysis_dict) == len(run_analysis_dict):
            pair_dict['pair'] = '-'.join(pair)
            pair_dict.update(analysis_dict)
            comparison_dicts.append(pair_dict)

    
    return comparison_dicts

# %%
# Out:
#                 pair    3    1
# 0         roll-wheel  0.0  0.2
# 1        red-balloon  0.3  0.4
# 2          red-night  0.3  0.0
# 3         round-soup  0.3  0.8
# 4       round-cheese  0.1  0.4
# 5    round-corkscrew  0.3  0.0
# 6        round-apple  0.0  0.0
# 7          roll-bike  0.0  0.2
# 8        roll-tappet  0.0  0.6
# 9         round-tray  0.4  0.0
# 10        roll-brick  0.0  0.6
# 11   _check1-_check1  0.0  0.0
# 12       red-pigweed  0.0  0.4
# 13       round-candy  0.3  0.4
# 14      red-clarinet  0.2  0.2
# 15          red-cake  0.3  0.2
# 16    red-blackberry  0.4  0.4
# 17   red-pomegranate  0.4  0.2
# 18       round-spoon  0.5  0.2
# 19  round-cantaloupe  0.0  0.0
# 20   roll-projectile  0.0  0.6
# 21      roll-leather  0.0  0.6
# 22  roll-breechblock  0.0  0.2
# 23   _check3-_check3  0.0  0.0
# 24       roll-donkey  0.0  0.1
# 25    round-cucurbit  0.2  0.4
# 26          red-oven  0.3  0.0
# 27           red-fox  0.3  0.2
# 28        round-disc  0.2  0.6
# 29        round-beet  0.0  0.0
# 30         red-onion  0.5  0.4
# 31           red-bus  0.0  0.0
# 32       round-melon  0.5  0.0
# 33    roll-vaporizer  0.0  0.6
# 34   _check2-_check2  0.0  0.0
# 35      round-pomade  0.1  0.2
# 36         red-sauce  0.1  0.2
# 37       round-scone  0.4  0.4
# 38      round-sundae  0.2  0.5
# 39     round-ketchup  0.2  0.0
# 40         red-anger  0.0  0.0
# 41         red-wheat  0.0  0.2
# 42        red-tomato  0.0  0.0
# 43        roll-dowel  0.0  0.4
# 44   _check4-_check4  0.0  0.0
# 45        red-lentil  0.3  0.6
# 46    red-grapefruit  0.6  0.4
# 47          red-crab  0.3  0.2
# 48    red-rhagoletis  0.4  0.2
# 49         red-paint  0.0  0.0
# 50        red-coffee  0.2  0.2
# 51       red-rooster  0.0  0.8
# 52     roll-pavement  0.0  0.4
# 53       roll-paddle  0.0  0.4
# 54         roll-pipe  0.0  0.8
# 55      roll-manhole  0.0  0.6
#
# run 3 0.15357142857142853
# run 1 0.27499999999999997

# %%
# test

run = 3
batch = '*'
n_q = '*'
group = 'experiment1'

dict_list_out = load_experiment_data(run, group, n_q, batch,\
                                         remove_not_val = True)


for d in dict_list_out:
    triple = d['triple']
    if 'red-pigweed' in triple:
        print(triple)
# Out:
# unusual-red-pigweed
# affording_activity-red-pigweed
# rare-red-pigweed
# typical_of_concept-red-pigweed
# creative-red-pigweed
# impossible-red-pigweed
# typical_of_property-red-pigweed
# variability_limited-red-pigweed
# implied_category-red-pigweed
# variability_open-red-pigweed
# unusual-red-pigweed
# affording_activity-red-pigweed
# rare-red-pigweed
# typical_of_concept-red-pigweed
# creative-red-pigweed
# impossible-red-pigweed
# typical_of_property-red-pigweed
# variability_limited-red-pigweed
# implied_category-red-pigweed
# variability_open-red-pigweed
# unusual-red-pigweed
# affording_activity-red-pigweed
# rare-red-pigweed
# typical_of_concept-red-pigweed
# creative-red-pigweed
# impossible-red-pigweed
# typical_of_property-red-pigweed
# variability_limited-red-pigweed
# implied_category-red-pigweed
# variability_open-red-pigweed
# unusual-red-pigweed
# affording_activity-red-pigweed
# rare-red-pigweed
# typical_of_concept-red-pigweed
# creative-red-pigweed
# impossible-red-pigweed
# typical_of_property-red-pigweed
# variability_limited-red-pigweed
# implied_category-red-pigweed
# variability_open-red-pigweed
# unusual-red-pigweed
# affording_activity-red-pigweed
# rare-red-pigweed
# typical_of_concept-red-pigweed
# creative-red-pigweed
# impossible-red-pigweed
# typical_of_property-red-pigweed
# variability_limited-red-pigweed
# implied_category-red-pigweed
# variability_open-red-pigweed
# unusual-red-pigweed
# affording_activity-red-pigweed
# rare-red-pigweed
# typical_of_concept-red-pigweed
# creative-red-pigweed
# impossible-red-pigweed
# typical_of_property-red-pigweed
# variability_limited-red-pigweed
# implied_category-red-pigweed
# variability_open-red-pigweed
# unusual-red-pigweed
# affording_activity-red-pigweed
# rare-red-pigweed
# typical_of_concept-red-pigweed
# creative-red-pigweed
# impossible-red-pigweed
# typical_of_property-red-pigweed
# variability_limited-red-pigweed
# implied_category-red-pigweed
# variability_open-red-pigweed
# unusual-red-pigweed
# affording_activity-red-pigweed
# rare-red-pigweed
# typical_of_concept-red-pigweed
# creative-red-pigweed
# impossible-red-pigweed
# typical_of_property-red-pigweed
# variability_limited-red-pigweed
# implied_category-red-pigweed
# variability_open-red-pigweed
# unusual-red-pigweed
# affording_activity-red-pigweed
# rare-red-pigweed
# typical_of_concept-red-pigweed
# creative-red-pigweed
# impossible-red-pigweed
# typical_of_property-red-pigweed
# variability_limited-red-pigweed
# implied_category-red-pigweed
# variability_open-red-pigweed
# unusual-red-pigweed
# affording_activity-red-pigweed
# rare-red-pigweed
# typical_of_concept-red-pigweed
# creative-red-pigweed
# impossible-red-pigweed
# typical_of_property-red-pigweed
# variability_limited-red-pigweed
# implied_category-red-pigweed
# variability_open-red-pigweed

# %%
# check if we have to get rid of fewer pairs in the new annotation framework



dict_list_out_run3 = load_experiment_data(run, group, n_q, batch, remove_not_val = True)


run = 1
batch = '*'
n_q = '*'
group = 'experiment1'

dict_list_out_run1 = load_experiment_data(run, group, n_q, batch, remove_not_val = True)

#worker_pair_dict = get_worker_pair_dict(dict_list_out)

# %%
run1_pair_dict = get_pair_dict(dict_list_out_run1)
run3_pair_dict = get_pair_dict(dict_list_out_run3)


pairs_in_both_runs = set(run1_pair_dict.keys()).intersection(run3_pair_dict.keys())

pair_dict_run1_clean = dict([(pair, v) for pair, v in run1_pair_dict.items() \
                  if pair in pairs_in_both_runs ])

pair_dict_run2_clean = dict([(pair, v) for pair, v in run2_pair_dict.items() \
                  if pair in pairs_in_both_runs ])


print(len(pairs_in_both_runs))
print(len(run1_pair_dict.keys()))
print(len(run3_pair_dict.keys()))
print(len(pair_dict_run1_clean))
print(len(pair_dict_run2_clean))


dict_list_clean_run1, dict_list_discard_run1 = clean_annotations(worker_pair_dict_run1_clean,\
                                                           dict_list_out_run1,\
                                                           contradiction_pairs,\
                                                            v = False)
# Out:
# 45
# 429
# 48
# 45
# 45

# %%
run = 3
batch = '*'
n_q = '*'
group = 'experiment1'

dict_list_ex3 = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
print(len(dict_list_ex3))
# Out:
# 3013

# %%
for d in pair_contradiction_dicts:
    print(d.values())
# Out:
# dict_values([('roll', 'rope'), 8])
# dict_values([('red', 'clothing'), 6])
# dict_values([('round', 'popsicle'), 0])
# dict_values([('red', 'bulgur'), 3])
# dict_values([('red', 'cowpeas'), 2])
# dict_values([('red', 'marinade'), 1])
# dict_values([('round', 'marble'), 10])
# dict_values([('_check3', '_check3'), 0])
# dict_values([('round', 'pizza'), 4])
# dict_values([('roll', 'wheel'), 4])
# dict_values([('roll', 'lever'), 4])
# dict_values([('roll', 'chimney'), 1])
# dict_values([('roll', 'polyurethane'), 0])
# dict_values([('roll', 'calliper'), 2])
# dict_values([('red', 'jam'), 4])
# dict_values([('_check2', '_check2'), 0])
# dict_values([('round', 'donut'), 12])
# dict_values([('red', 'bloodstone'), 6])
# dict_values([('red', 'lewisia'), 6])
# dict_values([('red', 'carnation'), 12])
# dict_values([('roll', 'eyelet'), 10])
# dict_values([('red', 'syrup'), 8])
# dict_values([('red', 'geranium'), 6])
# dict_values([('roll', 'bead'), 13])
# dict_values([('red', 'beetroot'), 6])
# dict_values([('round', 'dresser'), 4])
# dict_values([('red', 'lentil'), 5])
# dict_values([('round', 'bedroom'), 0])
# dict_values([('red', 'crypt'), 1])
# dict_values([('round', 'pancake'), 3])
# dict_values([('roll', 'mandrel'), 21])
# dict_values([('roll', 'ferrule'), 7])
# dict_values([('roll', 'pipe'), 19])
# dict_values([('roll', 'spindle'), 22])
# dict_values([('roll', 'noseband'), 4])
# dict_values([('red', 'flower'), 12])
# dict_values([('red', 'radish'), 9])
# dict_values([('_check1', '_check1'), 0])
# dict_values([('round', 'world'), 9])
# dict_values([('round', 'watermelon'), 10])
# dict_values([('round', 'nut'), 2])
# dict_values([('roll', 'pavement'), 2])
# dict_values([('round', 'dough'), 10])
# dict_values([('red', 'cockroach'), 10])
# dict_values([('round', 'patty'), 0])
# dict_values([('red', 'cheetah'), 0])
# dict_values([('roll', 'nut'), 16])
# dict_values([('round', 'mayonnaise'), 0])
# dict_values([('red', 'peanut'), 2])
# dict_values([('red', 'truffle'), 0])
# dict_values([('red', 'lobster'), 6])
# dict_values([('red', 'vegetable'), 3])
# dict_values([('round', 'pepperoni'), 10])
# dict_values([('red', 'pigweed'), 2])
# dict_values([('round', 'banjo'), 0])
# dict_values([('roll', 'radiator'), 8])
# dict_values([('roll', 'propeller'), 7])
# dict_values([('round', 'peanut'), 7])
# dict_values([('roll', 'brick'), 4])
# dict_values([('roll', 'driveshaft'), 5])
# dict_values([('_check4', '_check4'), 0])
# dict_values([('round', 'omelette'), 6])
# dict_values([('red', 'ketchup'), 8])
# dict_values([('round', 'coleslaw'), 0])
# dict_values([('roll', 'rail'), 4])
# dict_values([('red', 'mamey'), 3])
# dict_values([('red', 'fenugreek'), 0])
# dict_values([('red', 'chocolate'), 0])
# dict_values([('roll', 'pulley'), 14])
# dict_values([('red', 'crow'), 2])
# dict_values([('round', 'doughnut'), 13])
# dict_values([('red', 'water'), 2])
# dict_values([('round', 'syrup'), 0])
# dict_values([('round', 'baton'), 0])
# dict_values([('round', 'curd'), 13])
# dict_values([('round', 'disk'), 16])
# dict_values([('round', 'apple'), 0])
# dict_values([('red', 'fir'), 1])
# dict_values([('roll', 'chock'), 5])
# dict_values([('round', 'cantaloupe'), 0])
# dict_values([('roll', 'kickstand'), 4])
# dict_values([('red', 'brick'), 0])
# dict_values([('red', 'ageratina'), 3])
# dict_values([('round', 'cucurbit'), 10])
# dict_values([('roll', 'fireplace'), 2])
# dict_values([('roll', 'wiffle'), 4])
# dict_values([('red', 'tongue'), 2])
# dict_values([('red', 'wheat'), 3])
# dict_values([('round', 'room'), 4])
# dict_values([('roll', 'tub'), 9])
# dict_values([('round', 'ketchup'), 0])
# dict_values([('red', 'wand'), 1])
# dict_values([('round', 'frisbee'), 3])
# dict_values([('red', 'night'), 0])
# dict_values([('red', 'paint'), 0])
# dict_values([('red', 'pistachio'), 0])
# dict_values([('red', 'oven'), 0])
# dict_values([('roll', 'millstone'), 4])
# dict_values([('round', 'cake'), 3])
# dict_values([('red', 'watermelon'), 0])
# dict_values([('round', 'marshmallow'), 6])
# dict_values([('red', 'galangal'), 4])
# dict_values([('red', 'fox'), 3])
# dict_values([('round', 'beet'), 0])
# dict_values([('roll', 'wagon'), 0])
# dict_values([('round', 'chicken'), 0])
# dict_values([('red', 'garlic'), 1])
# dict_values([('round', 'ashtray'), 0])
# dict_values([('red', 'recorder'), 0])
# dict_values([('red', 'wine'), 4])
# dict_values([('roll', 'dowel'), 7])
# dict_values([('roll', 'paddle'), 2])
# dict_values([('red', 'glass'), 3])
# dict_values([('round', 'pudding'), 0])
# dict_values([('red', 'pot'), 4])
# dict_values([('round', 'soup'), 10])
# dict_values([('red', 'eye'), 5])
# dict_values([('red', 'bus'), 0])
# dict_values([('roll', 'horseshoe'), 12])
# dict_values([('red', 'mentzelia'), 16])
# dict_values([('round', 'fritter'), 7])
# dict_values([('round', 'pie'), 9])
# dict_values([('round', 'creamer'), 9])
# dict_values([('round', 'cornmeal'), 3])
# dict_values([('roll', 'surfboard'), 3])
# dict_values([('roll', 'cart'), 3])
# dict_values([('round', 'juice'), 2])
# dict_values([('red', 'couch'), 3])
# dict_values([('red', 'juice'), 6])
# dict_values([('round', 'condiment'), 1])
# dict_values([('round', 'candle'), 0])
# dict_values([('red', 'daisy'), 2])
# dict_values([('round', 'puree'), 5])
# dict_values([('red', 'clarinet'), 3])
# dict_values([('round', 'mentzelia'), 3])
# dict_values([('round', 'chive'), 8])
# dict_values([('round', 'hubcap'), 4])
# dict_values([('red', 'lime'), 4])
# dict_values([('round', 'bean'), 3])
# dict_values([('red', 'nectarine'), 7])
# dict_values([('round', 'enchiladas'), 2])
# dict_values([('round', 'cds'), 2])
# dict_values([('round', 'plunger'), 5])
# dict_values([('roll', 'shovel'), 5])
# dict_values([('round', 'corkscrew'), 0])
# dict_values([('red', 'ambulance'), 0])
# dict_values([('round', 'shape'), 5])
# dict_values([('red', 'shallot'), 0])
# dict_values([('round', 'bowl'), 0])
# dict_values([('red', 'elm'), 2])
# dict_values([('red', 'lark'), 0])
# dict_values([('red', 'lingonberry'), 10])
# dict_values([('red', 'lemon'), 1])
# dict_values([('red', 'leafs'), 2])
# dict_values([('round', 'ball'), 0])
# dict_values([('red', 'lip'), 8])
# dict_values([('roll', 'chamfer'), 2])
# dict_values([('red', 'olive'), 3])
# dict_values([('round', 'drumstick'), 2])
# dict_values([('roll', 'plastic'), 5])
# dict_values([('red', 'milk'), 1])
# dict_values([('red', 'broccoli'), 0])
# dict_values([('red', 'magpie'), 0])
# dict_values([('roll', 'grindstone'), 5])
# dict_values([('red', 'ink'), 2])
# dict_values([('round', 'custard'), 2])
# dict_values([('round', 'barrel'), 0])
# dict_values([('red', 'robin'), 2])
# dict_values([('round', 'dessert'), 2])
# dict_values([('roll', 'tile'), 3])
# dict_values([('round', 'salad'), 7])
# dict_values([('round', 'bulgur'), 1])
# dict_values([('red', 'strawberry'), 0])
# dict_values([('roll', 'lamp'), 17])
# dict_values([('round', 'cabbage'), 0])
# dict_values([('round', 'marzipan'), 16])
# dict_values([('roll', 'flywheel'), 9])
# dict_values([('roll', 'bolt'), 21])
# dict_values([('round', 'pumpkin'), 3])
# dict_values([('round', 'disc'), 15])
# dict_values([('red', 'apricot'), 7])
# dict_values([('red', 'sauce'), 6])
# dict_values([('round', 'vegetable'), 4])
# dict_values([('red', 'flame'), 11])
# dict_values([('red', 'cream'), 3])
# dict_values([('red', 'anger'), 0])
# dict_values([('roll', 'alloy'), 10])
# dict_values([('red', 'aubergine'), 2])
# dict_values([('red', 'spice'), 3])
# dict_values([('roll', 'kiln'), 7])
# dict_values([('red', 'ant'), 0])
# dict_values([('round', 'snack'), 3])
# dict_values([('roll', 'piston'), 6])
# dict_values([('round', 'chocolate'), 2])
# dict_values([('red', 'melon'), 1])
# dict_values([('roll', 'projectile'), 10])
# dict_values([('red', 'ring'), 0])
# dict_values([('round', 'egg'), 8])
# dict_values([('red', 'chive'), 0])
# dict_values([('red', 'hair'), 3])
# dict_values([('round', 'cream'), 0])
# dict_values([('round', 'fondant'), 5])
# dict_values([('round', 'samosa'), 0])
# dict_values([('red', 'coconut'), 0])
# dict_values([('round', 'matzah'), 0])
# dict_values([('red', 'chutney'), 3])
# dict_values([('red', 'currant'), 0])
# dict_values([('roll', 'pencil'), 1])
# dict_values([('roll', 'handlebar'), 6])
# dict_values([('round', 'bottle'), 0])
# dict_values([('roll', 'cartridge'), 5])
# dict_values([('round', 'spoon'), 2])
# dict_values([('roll', 'handrail'), 5])
# dict_values([('roll', 'boiler'), 4])
# dict_values([('roll', 'pin'), 0])
# dict_values([('round', 'sapodilla'), 2])
# dict_values([('red', 'miner'), 2])
# dict_values([('red', 'hazelnut'), 6])
# dict_values([('red', 'crab'), 6])
# dict_values([('red', 'celery'), 2])
# dict_values([('roll', 'acrylic'), 7])
# dict_values([('roll', 'wrench'), 3])
# dict_values([('red', 'apple'), 0])
# dict_values([('roll', 'brake'), 7])
# dict_values([('red', 'jade'), 4])
# dict_values([('roll', 'tappet'), 14])
# dict_values([('round', 'berry'), 9])
# dict_values([('roll', 'corkscrew'), 3])
# dict_values([('roll', 'lathe'), 10])
# dict_values([('red', 'limousine'), 4])
# dict_values([('round', 'mozzarella'), 6])
# dict_values([('round', 'blueberry'), 0])
# dict_values([('roll', 'bearing'), 3])
# dict_values([('red', 'sycamore'), 2])
# dict_values([('roll', 'donkey'), 1])
# dict_values([('round', 'onion'), 11])
# dict_values([('round', 'circle'), 7])
# dict_values([('round', 'bucket'), 0])
# dict_values([('round', 'table'), 3])
# dict_values([('roll', 'washer'), 6])
# dict_values([('round', 'shoe'), 6])
# dict_values([('round', 'cube'), 1])
# dict_values([('round', 'globe'), 0])
# dict_values([('red', 'quesadilla'), 1])
# dict_values([('roll', 'firebox'), 3])
# dict_values([('red', 'chicken'), 2])
# dict_values([('red', 'blueberry'), 0])
# dict_values([('round', 'pen'), 0])
# dict_values([('round', 'seedpod'), 12])
# dict_values([('roll', 'nozzle'), 8])
# dict_values([('red', 'rooster'), 13])
# dict_values([('roll', 'axle'), 11])
# dict_values([('roll', 'urethane'), 6])
# dict_values([('round', 'sauce'), 1])
# dict_values([('round', 'seasoning'), 3])
# dict_values([('round', 'cheeseburger'), 0])
# dict_values([('round', 'gourd'), 4])
# dict_values([('roll', 'bushing'), 6])
# dict_values([('roll', 'car'), 9])
# dict_values([('red', 'berry'), 0])
# dict_values([('round', 'melon'), 0])
# dict_values([('roll', 'bottle'), 4])
# dict_values([('red', 'gherkin'), 0])
# dict_values([('red', 'candy'), 2])
# dict_values([('roll', 'backboard'), 1])
# dict_values([('round', 'pineapple'), 7])
# dict_values([('roll', 'crankshaft'), 5])
# dict_values([('roll', 'slab'), 0])
# dict_values([('red', 'beet'), 0])
# dict_values([('red', 'fear'), 0])
# dict_values([('round', 'can'), 5])
# dict_values([('roll', 'vaporizer'), 4])
# dict_values([('red', 'blackberry'), 4])
# dict_values([('red', 'corncob'), 1])
# dict_values([('red', 'grape'), 6])
# dict_values([('round', 'tray'), 0])
# dict_values([('roll', 'tray'), 6])
# dict_values([('red', 'weed'), 0])
# dict_values([('roll', 'roller'), 8])
# dict_values([('round', 'pastry'), 1])
# dict_values([('roll', 'headboard'), 4])
# dict_values([('roll', 'crosshead'), 7])
# dict_values([('roll', 'hose'), 16])
# dict_values([('roll', 'plaster'), 7])
# dict_values([('round', 'sundae'), 13])
# dict_values([('round', 'pilaf'), 0])
# dict_values([('red', 'vanilla'), 2])
# dict_values([('round', 'vinaigrette'), 0])
# dict_values([('round', 'football'), 0])
# dict_values([('red', 'ladybird'), 0])
# dict_values([('red', 'gorilla'), 0])
# dict_values([('roll', 'plunger'), 4])
# dict_values([('red', 'herring'), 3])
# dict_values([('round', 'planet'), 0])
# dict_values([('red', 'banana'), 0])
# dict_values([('red', 'carrot'), 0])
# dict_values([('red', 'pignut'), 6])
# dict_values([('red', 'cherry'), 14])
# dict_values([('roll', 'hammer'), 16])
# dict_values([('roll', 'hubcap'), 9])
# dict_values([('red', 'football'), 3])
# dict_values([('round', 'tart'), 12])
# dict_values([('roll', 'candle'), 0])
# dict_values([('roll', 'fusee'), 5])
# dict_values([('roll', 'caber'), 9])
# dict_values([('red', 'heart'), 4])
# dict_values([('red', 'egg'), 5])
# dict_values([('red', 'cake'), 4])
# dict_values([('round', 'pomade'), 4])
# dict_values([('red', 'cucurbit'), 8])
# dict_values([('round', 'pasta'), 3])
# dict_values([('red', 'fern'), 1])
# dict_values([('round', 'atole'), 0])
# dict_values([('red', 'honey'), 2])
# dict_values([('round', 'butter'), 1])
# dict_values([('red', 'sand'), 1])
# dict_values([('red', 'mango'), 4])
# dict_values([('roll', 'quoit'), 2])
# dict_values([('roll', 'gearshift'), 4])
# dict_values([('red', 'frog'), 4])
# dict_values([('red', 'cinnamon'), 3])
# dict_values([('red', 'chili'), 12])
# dict_values([('roll', 'grip'), 7])
# dict_values([('roll', 'shoe'), 11])
# dict_values([('red', 'dogwood'), 1])
# dict_values([('red', 'slug'), 1])
# dict_values([('roll', 'windowpane'), 3])
# dict_values([('roll', 'glass'), 4])
# dict_values([('red', 'lipstick'), 7])
# dict_values([('roll', 'pen'), 0])
# dict_values([('red', 'peony'), 5])
# dict_values([('round', 'box'), 1])
# dict_values([('roll', 'tire'), 7])
# dict_values([('roll', 'shaft'), 2])
# dict_values([('red', 'artichoke'), 3])
# dict_values([('roll', 'leather'), 8])
# dict_values([('roll', 'wheelbarrow'), 0])
# dict_values([('roll', 'windscreen'), 2])
# dict_values([('red', 'rhino'), 0])
# dict_values([('red', 'cabbage'), 0])
# dict_values([('round', 'cheese'), 4])
# dict_values([('red', 'barn'), 0])
# dict_values([('red', 'custard'), 2])
# dict_values([('red', 'guava'), 0])
# dict_values([('red', 'dog'), 1])
# dict_values([('round', 'almond'), 4])
# dict_values([('red', 'cat'), 0])
# dict_values([('round', 'breadcrumb'), 0])
# dict_values([('red', 'balloon'), 7])
# dict_values([('round', 'coconut'), 8])
# dict_values([('roll', 'peg'), 9])
# dict_values([('round', 'lolly'), 3])
# dict_values([('round', 'tomato'), 6])
# dict_values([('round', 'pecan'), 6])
# dict_values([('round', 'orange'), 6])
# dict_values([('red', 'vine'), 1])
# dict_values([('red', 'potato'), 2])
# dict_values([('roll', 'tyre'), 4])
# dict_values([('red', 'squirrel'), 3])
# dict_values([('red', 'ruby'), 0])
# dict_values([('red', 'vinegar'), 0])
# dict_values([('red', 'chameleon'), 2])
# dict_values([('roll', 'cloth'), 1])
# dict_values([('red', 'tiger'), 2])
# dict_values([('round', 'scone'), 7])
# dict_values([('roll', 'cylinder'), 4])
# dict_values([('red', 'ginger'), 4])
# dict_values([('red', 'echinocereus'), 0])
# dict_values([('round', 'banana'), 0])
# dict_values([('round', 'popcorn'), 5])
# dict_values([('red', 'car'), 4])
# dict_values([('red', 'pansy'), 8])
# dict_values([('red', 'mangifera'), 8])
# dict_values([('roll', 'paint'), 9])
# dict_values([('roll', 'skateboard'), 8])
# dict_values([('red', 'blackboard'), 4])
# dict_values([('round', 'soursop'), 8])
# dict_values([('red', 'rhubarb'), 2])
# dict_values([('red', 'grapefruit'), 4])
# dict_values([('roll', 'ball'), 5])
# dict_values([('red', 'pomegranate'), 2])
# dict_values([('red', 'jeep'), 0])
# dict_values([('roll', 'breechblock'), 4])
# dict_values([('round', 'quesadilla'), 8])
# dict_values([('round', 'basketball'), 0])
# dict_values([('round', 'biscuit'), 0])
# dict_values([('red', 'tomato'), 0])
# dict_values([('round', 'sausage'), 0])
# dict_values([('roll', 'bucket'), 9])
# dict_values([('round', 'potato'), 11])
# dict_values([('round', 'sphere'), 3])
# dict_values([('roll', 'barrel'), 16])
# dict_values([('red', 'raspberry'), 11])
# dict_values([('roll', 'manhole'), 6])
# dict_values([('round', 'bracelet'), 0])
# dict_values([('round', 'cheesecloth'), 3])
# dict_values([('red', 'raisin'), 3])
# dict_values([('red', 'onion'), 7])
# dict_values([('round', 'baseball'), 4])
# dict_values([('red', 'pineapple'), 0])
# dict_values([('red', 'avocado'), 0])
# dict_values([('roll', 'blade'), 6])
# dict_values([('red', 'yogurt'), 1])
# dict_values([('round', 'fruit'), 3])
# dict_values([('red', 'pit'), 2])
# dict_values([('round', 'casserole'), 1])
# dict_values([('red', 'fruit'), 2])
# dict_values([('roll', 'ski'), 2])
# dict_values([('roll', 'bike'), 5])
# dict_values([('roll', 'saw'), 1])
# dict_values([('roll', 'sprocket'), 5])
# dict_values([('round', 'button'), 3])
# dict_values([('roll', 'rifling'), 3])
# dict_values([('red', 'pepper'), 2])
# dict_values([('red', 'shiitake'), 3])
# dict_values([('red', 'cereal'), 2])
# dict_values([('round', 'cherry'), 15])
# dict_values([('roll', 'footrest'), 0])
# dict_values([('round', 'cookie'), 2])
# dict_values([('red', 'cilantro'), 0])
# dict_values([('round', 'lemon'), 0])
# dict_values([('round', 'candy'), 7])
# dict_values([('red', 'coffee'), 4])
# dict_values([('round', 'bread'), 0])
# dict_values([('round', 'tortilla'), 3])
# dict_values([('roll', 'bumper'), 8])
# dict_values([('red', 'allspice'), 0])
# dict_values([('roll', 'pig'), 4])
# dict_values([('red', 'rhagoletis'), 3])
