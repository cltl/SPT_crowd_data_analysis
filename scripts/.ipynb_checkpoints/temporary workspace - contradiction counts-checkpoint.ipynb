# %% [markdown]
# # Data analysis
#
#
# **To do:**
#
# * Agreement:
#     * collapse annotations with respect to (1) levels and (2) hypotheses
#     * only keep high quality annotations
#
# * Contradiction analysis
#     * change rate to n contradictions/n possible contradictions
#     * look for patterns (1) for workers and (2) pairs
#
# * Distribution of answers
#     * plot histograms
#     * see if we have clear normal distributions
#     * possibly adapt ideas about Gaussian vs Gaussian mixture models (Pavlick & Kwiatkowski 2019)
#
# * Weighing annotations to establish ambiguity, difficulty and worker quality
#     * ideas:
#         * Annotations of coder with few contradictions should carry more weight
#         * Get common distriubtions of pairs
#         * Get pair difficulty score:
#             * count number of contradictions / number of annotations per worker
#             * weigh by total worker score
#         * Possibly use the outcome to update worker scores:
#             * count number of contradictions over pairs
#             * weigh by pair difficulty

# %% [markdown]
# # Contradiction analysis
#
#
# * change rate in worker analysis - **done**
# * change rate in pair analysis - **done**
# * look for patterns
#
# Idea implemented below:
#
# check which pairs lie outside the standard deviation - more contradictions than expected
#
# Tomorrow: check if we can do this for workers (check crowd sourcing paper White or smth)
#
#
# ### Worker analysis:
#
# Fine-grained contradiction analysis
#
# * Per contradiction type, check if number of contradictions by a worker is higher than mean + sd for that particular contradiction type.
# * Calculate contradiction rate based on only those contradictions.
#
#
# TO DO: check iaa if removing workers based in this rate
#
#
# ### Pair analysis
#
# * Get worker contradiction types which are outliers
# * Remove those annotations from pairs annotated by the worker
# * Calculate iaa

# %%
# generate correct contradiction pairs
import csv
from collections import defaultdict

def load_relations():
    with open('../scheme/relation_overview_run3.csv') as infile:
        dict_list = list(csv.DictReader(infile))
    level_dict = defaultdict(set)
    for d in dict_list:
        level_dict[d['level']].add(d['relation'])
    return level_dict

def gen_conts():
    level_dict = load_relations()
    # we do not want contradictions between all and few
    rel_all = level_dict['all']
    rel_few = level_dict['few']
    pairs = []
    
    for r1 in rel_all:
        for r2 in rel_few:
            pair = set([r1, r2])
            if pair not in pairs:
                pairs.append(pair)
    conts = [tuple(sorted(pair)) for pair in pairs]
    
    with open('../scheme/contradictions.csv', 'w') as outfile:
        for c in conts:
            outfile.write(','.join(c)+'\n')
    print('Contradictions written to: ../scheme/contradictions.csv')
    return conts

        
conts = gen_conts()
for c in conts:
    print(c)
# Out:
# ('afforded_usual', 'rare')
# ('afforded_usual', 'unusual')
# ('afforded_usual', 'impossible')
# ('rare', 'typical_of_property')
# ('typical_of_property', 'unusual')
# ('impossible', 'typical_of_property')
# ('afforded_unusual', 'rare')
# ('afforded_unusual', 'unusual')
# ('afforded_unusual', 'impossible')
# ('rare', 'typical_of_concept')
# ('typical_of_concept', 'unusual')
# ('impossible', 'typical_of_concept')
# ('implied_category', 'rare')
# ('implied_category', 'unusual')
# ('implied_category', 'impossible')
# ('affording_activity', 'rare')
# ('affording_activity', 'unusual')
# ('affording_activity', 'impossible')

# %%
from utils_analysis import load_analysis
from utils_analysis import sort_by_key
from utils_analysis import collect_contradictions
from utils_analysis import load_contradiction_pairs
from load_data import load_experiment_data
import numpy as np
from collections import Counter
import pandas as pd

def str_to_tuple(tuple_string):
    t = tuple(tuple_string.replace('(', '').replace(')', '').replace("'", "").replace(' ', '').split(','))
    return t


def get_pair_workers_df(pair_dicts, worker_dicts, data_dicts):
    pair_worker_dicts = []
    contradictions = load_contradiction_pairs()
    data_dicts_by_pairs = sort_by_key(data_dicts, ['property', 'concept'])
    pair_dicts_by_pairs = sort_by_key(pair_dicts, ['pair'])
    worker_dicts_by_worker = sort_by_key(worker_dicts, ['workerid'])
    for pair, dl in data_dicts_by_pairs.items():
        dl_by_workers = sort_by_key(dl, ['workerid'])
        for worker, dl_worker_pair in dl_by_workers.items():
            cont_worker_pair =  collect_contradictions(dl_worker_pair,\
                                                       contradictions, threshold = 0)
            cont_cnt = Counter()
            cont_cnt.update(cont_worker_pair)
            pair_worker_dict = dict()
            pair_worker_dict['pair'] = pair
            pair_worker_dict['workerid'] = worker
            pair_worker_dict.update(cont_cnt)
            worker_dict = worker_dicts_by_worker[worker][0]
            worker_tendencies = worker_dict['outlier_contradictions']
            if str(worker_tendencies) != 'nan':
                w_t_list = [str_to_tuple(s) for s in worker_tendencies.split(') (')]
                pair_worker_dict['worker_outliers']  = w_t_list
            else:
                w_t_list = []
                
            pair_conts = set(cont_worker_pair)
            worker_tends = set(w_t_list)
         
            overlap = pair_conts.intersection(worker_tends)
            if len(overlap) > 0:
                remove = True
            else:
                remove = False
            pair_worker_dict['tendency in contradictions'] = remove
            pair_worker_dicts.append(pair_worker_dict)
    df = pd.DataFrame.from_records(pair_worker_dicts)
    return df
            # check how many of the contradictions are also general tendencies of the worker
            #overlap_cont_tend

run = '*'
exp_name = 'experiment1'
batch = '*'
n_q = '*'
df_workers = load_analysis('outliers_workers', run, exp_name, batch)
worker_dicts = df_workers.to_dict('records')
df_pairs = load_analysis('pairs', run, exp_name, batch)
pair_dicts = df_pairs.to_dict('records')

data_dicts = load_experiment_data(run, exp_name, n_q, batch, remove_not_val = True)


data_by_pair = sort_by_key(data_dicts, ['property', 'concept'])
pair_annotations = data_by_pair['roll-rope']
df = get_pair_workers_df(pair_dicts, worker_dicts, data_dicts)
# Out:
# Discarded 655.0 annotations.

# %%
df
# Out:
#            pair                  workerid  tendency in contradictions  \
# 0     roll-rope  5bec28bf65c4360001e8590c                       False
# 1     roll-rope  5c28f3efdfe7fc0001cd8b28                       False
# 2     roll-rope  5cfa7e66b131cd001aa86c44                        True
# 3     roll-rope  5d025e0959967a0019b3db84                       False
# 4     roll-rope  5d1e2045a37a4d001a1fc2cb                       False
# ...         ...                       ...                         ...
# 7841  red-dress  5b6e33e4a4666d0001c79e62                       False
# 7842  red-dress  5c2bd5f88c234c00018b91f8                        True
# 7843  red-dress  5c82f2e2d6a4d0000164091e                        True
# 7844  red-dress  5dee62c0770a434f62147de2                       False
# 7845  red-dress  5e701697bb8f8a0b89b86434                       False
#
#                        worker_outliers  (afforded_usual, unusual)  \
# ...

# %% [markdown]
# # Analyze answer distributions
#
# * Inspiration:
#
# Pavlick, Ellie, and Tom Kwiatkowski. "Inherent Disagreements in Human Textual Inferences." Transactions of the Association for Computational Linguistics 7 (2019): 677-694.
#
# * Idea: do the responses follow a normal distribution or rather a multimodal distribution or no clear distribution at all?
#
# * Step (1): see if we can plot the distributions using a histogram
#
# * Step (2): can we also apply the idea of Gaussian and Gaussian Mixture models here? Possibly not enough data.
#
# [Code below was used to play with the data - possibly useful]

# %%
from load_data import load_experiment_data
from utils_analysis import sort_by_key
from utils_analysis import get_relation_cnt

import pandas as pd

# %%
# Distribution of answers

from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
from calculate_iaa import load_rel_level_mapping


def get_all_relations():
    with open('../scheme/relations.txt') as infile:
        relations = infile.read().split('\n')
    relations = [rel.strip() for rel in relations]
    return relations


def get_relation_vec(wpds, relations, mapping = None):
    dicts_by_relation = sort_by_key(wpds, ['relation'])
    
    if mapping != None: #mapping.startswith('levels'):
        levels = ['all', 'some', 'few', 'creative']
        cats = levels
        vec = []
        mapping_dict = load_rel_level_mapping()
        level_rel_dict = defaultdict(list)
        for r, l in mapping_dict.items():
            level_rel_dict[l].append(r)
        for l in levels:
            l_cnt = 0
            rels = level_rel_dict[l]
            for rel in rels:
                if rel in dicts_by_relation:
                    d = dicts_by_relation[rel][0]
                    answer = d['answer']
                    if answer == 'true':
                        val = 1
                    else:
                        val = 0
                else:
                    answer = None
                    val = 0
                l_cnt += val
            if mapping == 'levels_sum':
                l_cnt_norm = l_cnt/len(rels)
            elif mapping == 'levels_bin':
                if l_cnt > 0:
                    l_cnt_norm = 1
                else:
                    l_cnt_norm = 0
            vec.append(l_cnt_norm)
                      
    else:
        vec = []
        cats = relations
        for rel in relations:
            if rel in dicts_by_relation:
                d = dicts_by_relation[rel][0]
                answer = d['answer']
                if answer == 'true':
                    val = 1
                else:
                    val = 0
            else:
                answer = None
                val = 0
            vec.append(val)
    return vec, cats


def get_pair_vecs(dict_list_out, dict_list_workers, weight = False, mapping = None):
    pair_vec_dicts = []
    dict_list_by_pair = sort_by_key(dict_list_out, ['property', 'concept'])
    relations = get_all_relations()
    worker_dicts_by_worker = sort_by_key(dict_list_workers, ['workerid'])
    n = 0
    for pair, dicts in dict_list_by_pair.items():
        worker_vecs = defaultdict(list)
        dicts_by_worker = sort_by_key(dicts, ['workerid'])
        pair_vecs = []
        for worker, wpds in dicts_by_worker.items():
            worker_d = worker_dicts_by_worker[worker][0]
            cont = worker_d['contradiction_annotation_ratio']
            fails = worker_d['n_fails']
            score = 1-cont
            vec, cats = get_relation_vec(wpds, relations, mapping = mapping)
            vec = np.array(vec)
            if weight == True:
                vec = vec * score
            pair_vecs.append(vec)
        pair_m = np.array(pair_vecs)
        n_workers =  pair_m.shape[0]
        pair_vec = pair_m.sum(axis = 0) / n_workers
        rel_dict = dict()
        rel_dict['pair'] = pair
        rel_dict.update(dict(list(zip(cats, pair_vec))))
        pair_vec_dicts.append(rel_dict)
    return pair_vec_dicts

def plot_pair_distributions(pair_vec_dicts, target_prop = None):
    print(f'Analyzing {len(pair_vec_dicts)} pairs')
    relations = list(pair_vec_dicts[0].keys())[1:]
    for d in pair_vec_dicts:
        pair = d['pair']
        if target_prop == None:
            if 'test' not in pair and 'check' not in pair:
                vec =  [v for v in d.values()][1:]
                plt.plot(vec)
        else:
            prop = pair.split('-')[0]
            if target_prop == prop:
                vec =  [v for v in d.values()][1:]
                plt.plot(vec)
    plt.xticks(np.arange(len(relations)), relations, rotation=90)           
    plt.show()
    

    
def get_matrix(pair_vec_dicts, target_prop = None):
    matrix = []
    pairs = []
    pair_ind_dict = dict()
    i = 0
    for d in pair_vec_dicts:
        pair = d['pair']
        if target_prop == None:
            if 'test' not in pair and 'check' not in pair:
                vec = [val for val in d.values()][1:]
                matrix.append(vec)
                pairs.append(pair)
                pair_ind_dict[pair] = i
                i += 1
        else:
            prop = pair.split('-')[0]
            if prop == target_prop:
                vec = [val for val in d.values()][1:]
                matrix.append(vec)
                pairs.append(pair)
                pair_ind_dict[pair] = i
                i += 1             
    return matrix, pairs, pair_ind_dict

# %%
run = 3
group = 'experiment1'
batch = '16'
n_q = '*'
print(f'--- analyzing run {run} ---')
dict_list_out = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
worker_path = '../analyses/workers/run-all--group_experiment1-batch-all-.csv'
dict_list_workers = pd.read_csv(worker_path).to_dict('records')



pair_vec_dicts = get_pair_vecs(dict_list_out, dict_list_workers,\
                               mapping = 'levels_bin', weight = True)
plot_pair_distributions(pair_vec_dicts, target_prop = None)

   
    
pair_vec_dicts = get_pair_vecs(dict_list_out, dict_list_workers,\
                               mapping = 'levels_sum', weight = True)
plot_pair_distributions(pair_vec_dicts, target_prop = None)



pair_vec_dicts = get_pair_vecs(dict_list_out, dict_list_workers,\
                                mapping = None, weight = True)
plot_pair_distributions(pair_vec_dicts, target_prop = None)
# Out:
# --- analyzing run 3 ---
# Discarded 10.0 annotations.
# Analyzing 10 pairs
# Analyzing 10 pairs
# Analyzing 10 pairs

# %%
# K means experiment
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

run = 3
group = 'experiment1'
batch = '*'
n_q = '*'
print(f'--- analyzing run {run} ---')
dict_list_out = load_experiment_data(run, group, n_q, batch, remove_not_val = True)

 

worker_path = '../analyses/workers/run-all--group_experiment1-batch-all-.csv'
dict_list_workers = pd.read_csv(worker_path).to_dict('records')
pair_vec_dicts = get_pair_vecs(dict_list_out, dict_list_workers,\
                               mapping = 'levels_bin', weight = True)


matrix, pairs, pair_ind_dict = get_matrix(pair_vec_dicts, target_prop = 'round')
matrix = np.array(matrix)
print(len(matrix), len(pairs), len(pair_ind_dict))

scores_n = []
for n in range(2, 20):
    kmeans = KMeans(n_clusters=n)
    y_kmeans = kmeans.fit_predict(matrix)
    silhouette_avg = silhouette_score(matrix, y_kmeans, metric='euclidean')
    scores_n.append((silhouette_avg, n))

for s, n in sorted(scores_n, reverse = True):
    print(s, n)
#plt.scatter(matrix[:, 0], matrix[:, 3], c=y_kmeans5, cmap = 'rainbow')
# Out:
# --- analyzing run 3 ---
# Discarded 655.0 annotations.
# 125 125 125
# 0.4390829638499323 2
# 0.33442319622099315 4
# 0.3180656267042412 3
# 0.27702810985578424 11
# 0.2732939776036116 10
# 0.2732408170236828 9
# 0.27195035149784347 13
# 0.27076047194716696 14
# 0.26891447190610607 8
# 0.2676011922180514 7
# 0.26073560171718324 5
# 0.2598191626207755 12
# 0.25607764560030594 6
# 0.2544708396358169 15
# 0.24738767524781016 16
# 0.24688580527634993 19
# 0.24537918547773171 18
# 0.24152558349644374 17

# %%
best_n = 2
kmeans = KMeans(n_clusters=best_n)
y_kmeans = kmeans.fit_predict(matrix)
silhouette_avg = silhouette_score(matrix, y_kmeans, metric='euclidean')

plt.scatter(matrix[:, 0], matrix[:, 1], c=y_kmeans, cmap = 'rainbow')

label_pairs_dict = defaultdict(list)
for pair, l in zip(pairs,y_kmeans):
    label_pairs_dict[l].append(pair)

for l, pairs in label_pairs_dict.items():
    print(l)
    print(pairs)
    print()
# Out:
# 0
# ...
