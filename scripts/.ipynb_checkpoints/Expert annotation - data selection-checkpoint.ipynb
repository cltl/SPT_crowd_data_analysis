# %% [markdown]
# # Select:
#
#
# * Pairs with high agreement/few contradictions
# * Pairs with low agreement/few contradictions (if possible)
# * Pairs with high agrement/many contradictions
# * Pairs with low agreement/many contradictions
#
# Try to spread over property types
#
#
# # Annotate:
#
# * New run
# * Define new experiment group somehow
#
# # Ideas:
#
# * Low agreement, low contradiction rate: knowledge issue (some people know, some don't)
# * Low agreement, high contradiction rate: ambiguity
#
#
#
# # Implementation plan:
#
# * sort according to agreement
# * sort according to contradiction rate
# * get top pairs (top 5 or so)
# * get intersections:
#     * most problematic: low agreement - high contradiction
#     * problematic: low agreement - low contradiction
#     * interesting: high agreement - high contradiction (multiple interpretations?)
#     * clear: high agreement - low contradiction

# %%
from load_data import load_experiment_data
from calculate_iaa import get_agreement
from utils_analysis import load_contradiction_pairs
from utils_analysis import collect_contradictions
from utils_analysis import sort_by_key
from utils_analysis import get_annotation_ids
from utils_analysis import load_analysis

from collections import Counter, defaultdict
import pandas as pd
from scipy.stats import spearmanr


def get_agreement_by_property(data_dict_list):

    agreement_prop_dict = dict()
    data_by_pair = sort_by_key(data_dict_list, ['property', 'concept'])
    for pair, dl_prop in data_by_pair.items():
        agreement_prop_dict[pair] = get_agreement(dl_prop, v=False, disable_kappa=True)
    return agreement_prop_dict


def get_pairs_by_day(data_dict_list):
    data_by_date = sort_by_key(data_dict_list, ['timestamp'])
    day_by_pair = dict()
    for d, data in data_by_date.items():
        day = d.split(' ')[0]
        pairs = sort_by_key(data, ['property', 'concept']).keys()
        for pair in pairs:
            day_by_pair[pair] = day
    return day_by_pair


def get_agreement_contradiction_data(run, group, batch, n_q):
    data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
    print(run, group, batch, n_q)
    #data_by_pair = sort_by_key(data_dict_list, ['property', 'concept'])
    analysis_type = 'pairs'
    df = load_analysis(analysis_type, run, group, batch)
    pair_dicts = df.to_dict('records') 
    pair_dicts_by_pair = sort_by_key(pair_dicts, ['pair'])
    ag_pair_dict = get_agreement_by_property(data_dict_list)
    # get dates
    day_by_pair = get_pairs_by_day(data_dict_list)
    print(day_by_pair['round-fruit'])
    agreement_dict = Counter()
    for pair, ag in ag_pair_dict.items():
        agreement_dict[pair] =  ag['Krippendorff']

    ag_cont_dicts = []
    for pair, ag in agreement_dict.most_common():
        print(pair)
        date = day_by_pair(pair)
        if 'test' not in pair and 'check' not in pair: 
            d = pair_dicts_by_pair[pair]
            if len(d) == 1:
                new_dict = dict()
                d = d[0]
                #print(d.keys())
                cont = d['contradiction_poss_contradiction_ratio']
                new_dict['pair'] = pair
                new_dict['agreement'] = ag
                new_dict['contradiction_rate'] = cont
                new_dict['date'] = date
                ag_cont_dicts.append(new_dict)

            else:
                print('unexpected length:', len(d), 'for pair', pair)
        else:
            print('test pair:', pair)
        #d = data_by_pair[pair]
    df_ag_cont = pd.DataFrame(ag_cont_dicts)
    return df_ag_cont

# %%
run = "*"
group = 'experiment*'
batch = '*'
n_q = '*'

df_cont_ag = get_agreement_contradiction_data(run, group, batch, n_q)
# Out:
# Discarded 655.0 annotations.
# * experiment* * *
# 23-Mar-2020
# yellow-radish
# fly-velocipede
# yellow-boot
# yellow-mango
# fly-shark
# yellow-huckleberry
# fly-marabou
# fly-penguin
# yellow-piano
# fly-plane
# yellow-grape
# yellow-bean
# _check4-_check4
# _test2-_test2
# hot-soup
# yellow-chocolate
# dangerous-fork
# black-woodpecker
# fly-ship
# sweet-peach
# lay_eggs-rattlesnake
# made_of_wood-ruler
# square-bracelet
# wheels-trawler
# yellow-salad
# _check2-_check2
# _test1-_test1
# sweet-soup
# hot-fire
# fly-lemur
# made_of_wood-lumber
# dangerous-buckshot
# yellow-juice
# square-laundry
# black-satire
# wheels-jeep
# fly-hen
# sweet-gift
# hot-fume
# yellow-brick
# made_of_wood-dowel
# lay_eggs-capybara
# square-biscuit
# black-millipede
# wheels-bus
# yellow-herb
# lay_eggs-cow
# fly-owl
# made_of_wood-pulley
# hot-chocolate
# square-photocopier
# sweet-pip
# black-peacock
# _test4-_test
# sweet-fry
# made_of_wood-sword
# black-dogbane
# dangerous-flack
# square-hardware
# lay_eggs-cock
# fly-giraffe
# _test3-_test
# square-computer
# dangerous-shaft
# hot-firebox
# lay_eggs-felid
# black-sand
# yellow-lime
# sweet-pod
# made_of_wood-railing
# _check3-_check3
# yellow-bee
# hot-igniter
# square-tart
# dangerous-conspiracy
# fly-damselfish
# lay_eggs-trout
# black-dress
# wheels-oxcart
# dangerous-bucket
# sweet-sorrel
# hot-oven
# lay_eggs-bonobo
# wheels-sleigh
# square-floppy
# yellow-peanut
# fly-bunting
# black-sapsucker
# yellow-daffodil
# hot-icicle
# black-snake
# dangerous-punk
# square-book
# made_of_wood-binnacle
# sweet-currant
# lay_eggs-wrymouth
# lay_eggs-micropterus
# yellow-car
# square-file
# made_of_wood-wood
# sweet-freestone
# hot-jungle
# black-tar
# fly-stallion
# fly-crane
# lay_eggs-ibex
# hot-bottle
# sweet-onion
# square-snack
# black-hair
# dangerous-traitor
# yellow-cheetah
# made_of_wood-rafter
# fly-phaeton
# yellow-berry
# sweet-scallop
# dangerous-racketeer
# lay_eggs-bronc
# hot-pudding
# wheels-motorcycle
# made_of_wood-ladle
# fly-vulture
# dangerous-tuck
# sweet-grapefruit
# made_of_wood-bedstead
# black-radish
# yellow-jam
# wheels-streamliner
# lay_eggs-linnet
# _check1-_check1
# dangerous-turtle
# sweet-date
# fly-woodpecker
# made_of_wood-wire
# yellow-clarinet
# lay_eggs-gyrfalcon
# black-gown
# square-mainframe
# hot-summertime
# yellow-frog
# fly-helicopter
# yellow-dogwood
# sweet-cake
# yellow-umbellifer
# yellow-shiitake
# sweet-cucumber
# yellow-umbrella
# fly-chow
# yellow-emerald
# fly-ostrich
# yellow-hair
# yellow-slug
# yellow-cucurbit
# yellow-serviceberry
# yellow-couch
# made_of_wood-grommet
# square-pantry
# lay_eggs-timaliidae
# black-recorder
# yellow-cricket
# hot-tile
# fly-mammal
# dangerous-hornbill
# sweet-soy
# dangerous-fire
# fly-watchdog
# wheels-minivan
# yellow-walnut
# sweet-flavoring
# made_of_wood-rock
# black-tyre
# lay_eggs-icteridae
# square-tortilla
# wheels-sidecar
# made_of_wood-pencil
# yellow-bus
# lay_eggs-egret
# square-rom
# hot-hearth
# dangerous-bayonet
# fly-quail
# sweet-corn
# fly-autogyro
# lay_eggs-apodidae
# made_of_wood-plywood
# wheels-chassis
# hot-toilet
# square-barrel
# yellow-cactus
# black-combretum
# fly-clarence
# lay_eggs-ichthyosaur
# made_of_wood-paddle
# dangerous-gentamicin
# black-weed
# yellow-orange
# hot-pancake
# wheels-tram
# yellow-peacock
# square-bookmark
# fly-groundhog
# sweet-pumpkin
# black-acaridae
# made_of_wood-soffit
# dangerous-mafioso
# hot-sauna
# fly-crow
# dangerous-crowbar
# sweet-saskatoon
# lay_eggs-smallmouth
# wheels-wagon
# made_of_wood-hardboard
# square-disk
# black-pupil
# dangerous-plot
# wheels-truck
# black-fox
# lay_eggs-torpedo
# sweet-olive
# fly-lion
# yellow-crassula
# square-restroom
# yellow-pumpkin
# fly-tiger
# made_of_wood-chimney
# wheels-backhoe
# sweet-carrot
# dangerous-gutter
# lay_eggs-tortoise
# square-typewriter
# made_of_wood-board
# black-pit
# fly-toy
# sweet-jack
# dangerous-adze
# hot-griddle
# wheels-heap
# yellow-orchid
# fly-loon
# lay_eggs-crow
# sweet-pear
# dangerous-mallet
# made_of_wood-trestle
# black-currawong
# square-gameboard
# lay_eggs-turtle
# black-glass
# fly-saloon
# made_of_wood-transom
# sweet-buckeye
# square-workroom
# yellow-fruit
# dangerous-clipper
# yellow-water
# dangerous-hijacker
# wheels-windshield
# sweet-desert
# hot-fondue
# square-shelf
# lay_eggs-neritidae
# black-rat
# lay_eggs-redstart
# square-card
# wheels-schooner
# fly-steamer
# sweet-yogurt
# yellow-ring
# made_of_wood-pen
# black-supermarket
# hot-vaporizer
# dangerous-rod
# yellow-fir
# sweet-mango
# fly-sausage
# lay_eggs-drum
# yellow-pansy
# yellow-bottle
# yellow-flower
# yellow-ginger
# yellow-gherkin
# yellow-apricot
# yellow-photinia
# sweet-peanut
# sweet-wintergreen
# made_of_wood-clapboard
# fly-forklift
# black-cloud
# lay_eggs-chow
# yellow-drupe
# dangerous-coyote
# hot-tub
# fly-trumpeter
# black-balloon
# made_of_wood-chock
# lay_eggs-hackney
# hot-jug
# yellow-lobster
# wheels-train
# sweet-sardine
# black-market
# dangerous-malaria
# sweet-almond
# yellow-cream
# fly-wren
# made_of_wood-outrigger
# hot-winter
# square-bookshelf
# lay_eggs-stag
# lay_eggs-malinois
# dangerous-war
# yellow-thundercloud
# made_of_wood-chamfer
# black-heart
# wheels-racer
# square-desk
# hot-heat
# sweet-avocado
# fly-craft
# made_of_wood-stringer
# lay_eggs-utahraptor
# black-dolphin
# yellow-corn
# sweet-veg
# wheels-piton
# square-washroom
# sweet-loquat
# yellow-lemonade
# dangerous-bit
# made_of_wood-eyelet
# hot-tortilla
# wheels-stanhope
# square-luggage
# lay_eggs-flounder
# lay_eggs-deer
# wheels-phaeton
# hot-space
# sweet-parsnip
# black-weasel
# made_of_wood-barrel
# yellow-seaweed
# dangerous-beetle
# dangerous-bow
# black-frog
# yellow-citrus
# lay_eggs-jade
# made_of_wood-bow
# fly-puffin
# sweet-blueberry
# wheels-motor
# sweet-lemonade
# yellow-allspice
# wheels-bike
# black-cherry
# fly-bomber
# square-locker
# hot-shower
# lay_eggs-whiff
# black-avocado
# sweet-edda
# fly-butterfly
# square-screen
# yellow-eucalyptus
# lay_eggs-beaver
# hot-quesadilla
# wheels-auto
# made_of_wood-fence
# fly-pheasant
# black-night
# made_of_wood-ferrule
# sweet-spinach
# yellow-jade
# hot-flatbread
# wheels-bicycle
# dangerous-typhlopidae
# made_of_wood-centreboard
# hot-boiler
# wheels-ship
# sweet-soursop
# lay_eggs-painter
# fly-minesweeper
# black-lime
# yellow-night
# square-doorbell
# fly-tractor
# hot-puree
# black-coatis
# dangerous-poison
# yellow-mustard
# made_of_wood-chisel
# wheels-lorry
# sweet-pulse
# made_of_wood-corkscrew
# black-beetle
# yellow-plum
# lay_eggs-sardine
# fly-budgie
# sweet-grape
# wheels-wheelbase
# dangerous-terrorism
# hot-syrup
# hot-candle
# black-human
# lay_eggs-procellariidae
# sweet-chipotle
# made_of_wood-roof
# wheels-diesel
# fly-hobby
# hot-popcorn
# fly-minnow
# sweet-cottonseed
# yellow-gooseberry
# dangerous-tegu
# made_of_wood-stock
# black-onion
# lay_eggs-hind
# yellow-cherry
# sweet-fruit
# fly-kite
# lay_eggs-currawong
# fly-cock
# fly-schooner
# sweet-gesture
# yellow-palaquium
# fly-yellowhammer
# made_of_wood-spade
# dangerous-tiger
# hot-ice
# square-countertop
# sweet-chilli
# yellow-spinach
# fly-coupe
# black-opossum
# made_of_wood-deal
# lay_eggs-bulldog
# dangerous-crease
# black-football
# fly-pigeon
# square-window
# hot-freezer
# square-kitchenette
# fly-gnu
# made_of_wood-clock
# sweet-pepperoni
# lay_eggs-fringillidae
# dangerous-thief
# yellow-crane
# hot-spiciness
# black-suit
# sweet-windfall
# wheels-ambulance
# square-bedroom
# lay_eggs-albatross
# made_of_wood-kayak
# hot-pot
# lay_eggs-avocet
# square-notebook
# fly-moorcock
# black-miner
# yellow-herring
# hot-kitchen
# made_of_wood-aerator
# dangerous-pistol
# black-rice
# dangerous-hippopotamus
# yellow-pepper
# fly-sunfish
# made_of_wood-plunger
# wheels-hearse
# lay_eggs-bushbaby
# square-subdirectory
# square-room
# lay_eggs-phalacrocorax
# sweet-oilseed
# hot-nose
# dangerous-methamphetamine
# made_of_wood-toothpick
# fly-amberjack
# black-pig
# fly-snowbird
# made_of_wood-scabbard
# black-cat
# hot-dessert
# lay_eggs-armadillo
# dangerous-club
# yellow-custard
# square-console
# sweet-tabasco
# fly-carrier
# yellow-cannon
# lay_eggs-stickleback
# sweet-beetroot
# fly-turtle
# lay_eggs-platypus
# sweet-cheese
# sweet-achene
# yellow-calf
# yellow-lemon
# hot-cupcake
# black-fir
# fly-jalopy
# sweet-tamarind
# wheels-streetcar
# lay_eggs-acaridae
# made_of_wood-rake
# dangerous-isoniazid
# wheels-machine
# sweet-breadfruit
# fly-bobcat
# yellow-apple
# square-egg
# black-echinocereus
# hot-vegetable
# lay_eggs-yellowthroat
# sweet-cider
# black-honey
# fly-sky
# dangerous-cardinalate
# square-desktop
# hot-pastry
# yellow-geranium
# fly-tropicbird
# made_of_wood-chair
# hot-juice
# lay_eggs-giraffe
# sweet-allspice
# square-cupboard
# black-viscacha
# dangerous-weapon
# made_of_wood-truss
# fly-lynx
# yellow-lavandula
# square-diskette
# black-butter
# wheels-dumper
# hot-water
# fly-nightingale
# made_of_wood-beam
# wheels-van
# black-monkey
# sweet-cabbage
# dangerous-gang
# lay_eggs-bull
# lay_eggs-leatherback
# dangerous-file
# sweet-strawberry
# square-keypad
# yellow-buttercup
# hot-vapor
# fly-bark
# wheels-cat
# lay_eggs-lepomis
# made_of_wood-plank
# square-mug
# yellow-blossom
# sweet-iceberg
# black-ketchup
# fly-ass
# dangerous-hoe
# hot-coffee
# wheels-cabriolet
# dangerous-sulfonamide
# yellow-lion
# hot-bathtub
# wheels-tugboat
# sweet-doughnut
# fly-boat
# lay_eggs-tanager
# made_of_wood-floorboard
# square-classroom
# square-ashtray
# fly-bearcat
# wheels-winch
# dangerous-lister
# sweet-nut
# yellow-cereal
# made_of_wood-spindle
# hot-ingredient
# black-toucanet
# hot-snack
# yellow-wasp
# lay_eggs-creeper
# black-beet
# sweet-groundnut
# square-floor
# fly-gallinule
# wheels-vehicle
# yellow-toadflax
# fly-stork
# made_of_wood-stool
# wheels-rim
# sweet-tangerine
# black-bus
# lay_eggs-cob
# square-ball
# hot-lampshade
# black-giraffe
# made_of_wood-pintle
# fly-whitethroat
# square-blackboard
# sweet-linseed
# yellow-lemongrass
# hot-bath
# wheels-runabout
# yellow-nectarine
# made_of_wood-rudder
# lay_eggs-basilisk
# fly-skimmer
# sweet-pistachio
# dangerous-killer
# square-cabinet
# wheels-trailer
# dangerous-venom
# yellow-giraffe
# lay_eggs-halibut
# sweet-spike
# fly-skylark
# black-parrot
# made_of_wood-shaft
# square-rack
# hot-pomade
# fly-paridae
# lay_eggs-curlew
# made_of_wood-bagpipe
# square-sphere
# dangerous-scimitar
# yellow-honey
# sweet-chocolate
# square-recliner
# yellow-colocasia
# made_of_wood-stick
# sweet-fennel
# dangerous-pusher
# hot-bathroom
# wheels-coach
# fly-basset
# lay_eggs-cony
# fly-jet
# made_of_wood-bamboo
# wheels-automobile
# hot-problem
# black-truffle
# yellow-daisy
# square-server
# sweet-satsuma
# hot-enchiladas
# lay_eggs-trogon
# dangerous-stamper
# square-apartment
# black-jade
# fly-hind
# fly-balloon
# yellow-sunbeam
# hot-toaster
# lay_eggs-marabout
# dangerous-jack
# made_of_wood-deck
# wheels-tramcar
# sweet-lime
# dangerous-prelacy
# lay_eggs-pompon
# made_of_wood-staysail
# fly-bream
# yellow-melon
# black-hornet
# sweet-juice
# square-hallway
# fly-mangabey
# wheels-boat
# lay_eggs-clupeidae
# made_of_wood-rope
# sweet-pineapple
# black-raccoon
# square-couch
# hot-butter
# made_of_wood-wheelbarrow
# yellow-gentianella
# fly-lorry
# lay_eggs-halfbeak
# sweet-rhubarb
# dangerous-blunderbuss
# hot-moon
# black-crassula
# black-pea
# hot-fireplace
# made_of_wood-strake
# fly-babbler
# sweet-tater
# dangerous-alligator
# square-kitchen
# fly-wherry
# yellow-corncob
# hot-chutney
# made_of_wood-brush
# lay_eggs-mouser
# black-paint
# wheels-equipage
# sweet-soybean
# made_of_wood-kickstand
# black-hose
# fly-icteridae
# dangerous-sword
# wheels-snowplow
# square-parlor
# lay_eggs-bass
# sweet-oyster
# black-olive
# dangerous-freebooter
# hot-flowerpot
# square-sideboard
# sweet-grain
# fly-roebuck
# lay_eggs-redhorse
# lay_eggs-charadrius
# yellow-beer
# sweet-cherry
# fly-deer
# square-button
# black-cockroach
# wheels-garage
# hot-soot
# wheels-driver
# made_of_wood-oak
# sweet-chicken
# fly-rudd
# lay_eggs-chicken
# square-tape
# hot-vinaigrette
# black-paridae
# made_of_wood-armrest
# square-cube
# lay_eggs-salmon
# fly-heap
# sweet-bulgur
# yellow-tank
# hot-drink
# dangerous-handgun
# lay_eggs-char
# sweet-pea
# made_of_wood-blade
# fly-twinjet
# yellow-pyramid
# black-lantern
# square-bucket
# wheels-footrest
# lay_eggs-pachyderm
# fly-rabbit
# sweet-rice
# hot-tray
# black-bat
# wheels-brake
# dangerous-iodine
# made_of_wood-tray
# lay_eggs-hen
# sweet-hip
# black-tomato
# dangerous-nightstick
# yellow-loquat
# square-door
# hot-condiment
# hot-pie
# yellow-hornet
# black-umbrella
# lay_eggs-lynx
# made_of_wood-centerboard
# sweet-artichoke
# dangerous-phencyclidine
# fly-trailer
# yellow-pineapple
# lay_eggs-stockfish
# fly-hog
# square-workspace
# black-insect
# wheels-car
# made_of_wood-broom
# sweet-apple
# square-foyer
# sweet-vinaigrette
# hot-vinyl
# fly-emu
# dangerous-snake
# wheels-unicycle
# lay_eggs-motacilla
# black-bottle
# made_of_wood-gun
# sweet-beet
# black-raspberry
# lay_eggs-hobby
# yellow-insect
# dangerous-buffer
# wheels-tank
# fly-arrow
# hot-geyser
# hot-sandwich
# black-grape
# made_of_wood-plough
# fly-wing
# square-laptop
# sweet-bacca
# dangerous-hack
# yellow-milk
# made_of_wood-fuselage
# yellow-pigweed
# sweet-chickpea
# lay_eggs-bay
# dangerous-pentobarbital
# hot-tea
# black-gherkin
# fly-shell
# black-blackboard
# hot-fruitcake
# made_of_wood-rail
# dangerous-sniper
# sweet-asparagus
# square-sunroom
# lay_eggs-plaice
# fly-grosbeak
# dangerous-blade
# hot-countertop
# lay_eggs-whippet
# black-parka
# sweet-salad
# wheels-motorbike
# made_of_wood-noseband
# lay_eggs-chamois
# hot-laundry
# fly-flicker
# square-box
# black-crypt
# made_of_wood-trumpet
# sweet-condiment
# yellow-yolk
# hot-tandoor
# sweet-ketchup
# fly-titi
# square-table
# black-eye
# dangerous-businessman
# yellow-skunk
# made_of_wood-bookcase
# black-owl
# made_of_wood-flatcar
# hot-toe
# fly-interceptor
# dangerous-virus
# wheels-bogie
# yellow-butter
# sweet-cinnamon
# made_of_wood-axe
# black-mentzelia
# fly-phalacrocorax
# dangerous-reduviidae
# square-cds
# sweet-sultana
# hot-kerosene
# black-forepaw
# hot-fridge
# made_of_wood-modillion
# lay_eggs-whitethroat
# fly-capsule
# sweet-flageolet
# wheels-diner
# square-stairwell
# lay_eggs-leopard
# wheels-packhorse
# yellow-leopard
# sweet-honey
# black-sheep
# fly-ferry
# made_of_wood-window
# hot-outfit
# sweet-broccoli
# hot-charcoal
# fly-pussy
# lay_eggs-layer
# square-marble
# black-sky
# wheels-dray
# hot-seasoning
# made_of_wood-washtub
# dangerous-naproxen
# wheels-toboggan
# fly-flycatcher
# black-mussel
# lay_eggs-humankind
# sweet-coffee
# lay_eggs-hare
# yellow-kingfisher
# sweet-lentil
# black-ladybird
# wheels-pedicab
# fly-duck
# dangerous-bill
# hot-kettle
# black-wine
# sweet-litchi
# wheels-wheel
# dangerous-acaridae
# fly-armadillo
# square-circle
# hot-mug
# hot-heater
# fly-ounce
# dangerous-revolver
# sweet-tea
# black-lion
# lay_eggs-human
# wheels-pram
# fly-ratite
# yellow-saffron
# lay_eggs-addax
# dangerous-goat
# hot-lamp
# made_of_wood-girder
# sweet-plantain
# square-armrest
# square-refrigerator
# wheels-stagecoach
# dangerous-nursing
# yellow-sheep
# fly-hawk
# lay_eggs-roach
# sweet-sugar
# hot-cooker
# hot-lava
# dangerous-grenade
# fly-lizardfish
# black-rhino
# made_of_wood-strap
# sweet-mussel
# square-playroom
# sweet-ginger
# black-skunk
# dangerous-attack
# fly-pelican
# hot-garlic
# square-drawer
# lay_eggs-blackbuck
# wheels-luggage
# square-footrest
# sweet-puree
# made_of_wood-headstock
# wheels-trap
# black-car
# fly-monkey
# hot-pasta
# fly-chinook
# hot-grill
# lay_eggs-calidris
# made_of_wood-lath
# yellow-actinidia
# sweet-vegetable
# black-lizard
# dangerous-looter
# fly-wheeler
# sweet-jam
# wheels-snowmobile
# dangerous-doodlebug
# black-pelican
# yellow-flame
# lay_eggs-whiteface
# made_of_wood-rod
# fly-mola
# yellow-cheese
# hot-utensil
# dangerous-nitrazepam
# square-dresser
# lay_eggs-duck
# black-lobster
# wheels-cart
# hot-meat
# black-pear
# yellow-oven
# dangerous-shotgun
# made_of_wood-crosshead
# wheels-passenger
# lay_eggs-quail
# square-macintosh
# square-basement
# hot-firewood
# yellow-crow
# sweet-hackberry
# made_of_wood-fir
# lay_eggs-syngnathidae
# black-civet
# dangerous-arrow
# lay_eggs-cotingidae
# fly-howler
# square-globe
# sweet-lychee
# yellow-pecan
# hot-cake
# made_of_wood-pin
# black-coal
# square-bathroom
# made_of_wood-holster
# yellow-barley
# fly-cart
# hot-noodle
# sweet-dewberry
# black-alligator
# wheels-cruiser
# dangerous-menthol
# lay_eggs-permit
# made_of_wood-pedal
# fly-car
# wheels-hack
# hot-percolator
# square-sharpener
# sweet-cookie
# dangerous-marlinspike
# square-fireplace
# sweet-taro
# lay_eggs-muskrat
# wheels-taxicab
# black-ring
# made_of_wood-gunwale
# dangerous-conspirator
# wheels-motorbus
# yellow-tomato
# fly-robin
# hot-wok
# black-dog
# sweet-plum
# lay_eggs-howler
# square-dining
# dangerous-unction
# wheels-railcar
# dangerous-plane
# dangerous-opener
# wheels-rig
# wheels-stage
# dangerous-bar
# fly-submarine
# black-rhagoletis
# yellow-cloak
# square-phone
# sweet-rye
# wheels-motorcar
# hot-flame
# dangerous-dip
# lay_eggs-toadfish
# made_of_wood-fingerboard
# fly-machine
# hot-puzzle
# sweet-kale
# dangerous-bootlegger
# square-doorknob
# yellow-potato
# wheels-suv
# made_of_wood-oar
# wheels-engine
# black-cucumber
# sweet-biscuit
# fly-ape
# yellow-garlic
# lay_eggs-turkey
# square-cubicle
# sweet-radish
# square-text
# fly-bogie
# dangerous-scalpel
# made_of_wood-windshield
# black-bean
# lay_eggs-skate
# wheels-coupe
# yellow-mamey
# hot-cookware
# wheels-carrier
# made_of_wood-ladder
# hot-barbecue
# lay_eggs-pointer
# fly-haddock
# sweet-shiitake
# dangerous-raper
# made_of_wood-guitar
# lay_eggs-hack
# fly-towhee
# dangerous-torpedo
# sweet-crab
# hot-sundae
# wheels-saloon
# square-pew
# lay_eggs-drill
# wheels-flatcar
# black-zebra
# sweet-muscat
# yellow-plumeria
# hot-yogurt
# dangerous-colchicine
# made_of_wood-carabiner
# made_of_wood-button
# wheels-cab
# dangerous-arm
# sweet-candy
# hot-roast
# black-frogmouth
# lay_eggs-typhlopidae
# lay_eggs-paridae
# yellow-plantain
# fly-cob
# hot-atole
# square-page
# dangerous-firearm
# sweet-lobster
# black-thornbill
# sweet-hazelnut
# hot-candy
# made_of_wood-timber
# wheels-carriage
# lay_eggs-eland
# yellow-vanilla
# black-pipefish
# fly-nuthatch
# wheels-hackney
# fly-grouper
# black-carnation
# yellow-grapefruit
# lay_eggs-bunting
# hot-basement
# square-pen
# dangerous-mop
# sweet-emperor
# made_of_wood-fireplace
# fly-seagull
# lay_eggs-mangabey
# black-bear
# yellow-truffle
# sweet-cauliflower
# made_of_wood-joist
# dangerous-plier
# wheels-warship
# hot-steam
# sweet-bacon
# wheels-caravan
# yellow-gorilla
# dangerous-soup
# made_of_wood-saxophone
# lay_eggs-lark
# fly-razorback
# hot-people
# black-lark
# made_of_wood-mop
# yellow-locust
# sweet-acorn
# hot-refrigerator
# fly-knot
# black-gorilla
# lay_eggs-packhorse
# dangerous-tap
# yellow-dogbane
# sweet-pork
# fly-whistler
# lay_eggs-grade
# made_of_wood-bass
# black-milk
# hot-anger
# dangerous-remedy
# yellow-aubergine
# yellow-lagoon
# made_of_wood-anchor
# dangerous-spud
# wheels-bodywork
# hot-campfire
# sweet-peeler
# fly-tit
# yellow-syrup
# lay_eggs-robin
# made_of_wood-pine
# square-frisbee
# black-aubergine
# dangerous-bolo
# lay_eggs-stork
# square-clipboard
# wheels-handcart
# hot-lemonade
# made_of_wood-arrow
# sweet-apricot
# wheels-trolley
# hot-pizza
# dangerous-mandrill
# lay_eggs-cuscus
# black-pot
# made_of_wood-wheel
# fly-sharpie
# wheels-limousine
# black-magpie
# hot-casserole
# square-planet
# made_of_wood-cushion
# fly-junk
# dangerous-saxitoxin
# lay_eggs-coypu
# fly-avocet
# yellow-sun
# made_of_wood-boat
# hot-furnace
# dangerous-hammer
# lay_eggs-pickerel
# black-humor
# sweet-raspberry
# wheels-undercarriage
# made_of_wood-bridge
# square-dumbwaiter
# fly-scull
# dangerous-ointment
# sweet-nectarine
# hot-cheesecloth
# black-apple
# lay_eggs-mole
# sweet-cob
# yellow-jean
# lay_eggs-roebuck
# fly-fryer
# made_of_wood-hutch
# dangerous-blender
# black-sun
# fly-merganser
# yellow-budgie
# yellow-antennaria
# sweet-lingonberry
# square-toilet
# lay_eggs-mankind
# black-brick
# fly-pinniped
# made_of_wood-flute
# dangerous-henchman
# hot-coal
# fly-tramcar
# wheels-battleship
# sweet-serviceberry
# dangerous-pestle
# yellow-raspberry
# hot-beer
# black-calf
# lay_eggs-haddock
# made_of_wood-tappet
# sweet-aniseed
# fly-mouse
# lay_eggs-viscacha
# yellow-guava
# made_of_wood-cannon
# yellow-football
# yellow-ageratina
# yellow-soursop
# fly-catfish
# yellow-carrot
# fly-tortoise
# sweet-huckleberry
# lay_eggs-gnu
# fly-airship
# made_of_wood-peg
# black-leopard
# yellow-vegetable
# square-armoire
# sweet-raisin
# dangerous-morphine
# sweet-zucchini
# fly-plaice
# square-wheel
# lay_eggs-psittacula
# wheels-rickshaw
# yellow-pawpaw
# made_of_wood-microtome
# black-pansy
# black-starling
# sweet-pie
# fly-shunter
# yellow-willow
# dangerous-ciprofloxacin
# square-wallpaper
# wheels-charabanc
# made_of_wood-drum
# hot-toast
# square-balcony
# yellow-taxi
# black-penguin
# fly-goldcrest
# sweet-orange
# made_of_wood-spear
# wheels-gondola
# dangerous-gun
# square-lavatory
# sweet-spud
# lay_eggs-pleuronectidae
# black-nightmare
# yellow-sandpaper
# hot-cooler
# made_of_wood-date
# fly-fowl
# lay_eggs-grackle
# square-lounge
# fly-caracara
# dangerous-knife
# sweet-donut
# made_of_wood-breechblock
# wheels-airplane
# yellow-pistachio
# fly-poacher
# made_of_wood-fipple
# yellow-miner
# sweet-butter
# black-cider
# wheels-vessel
# hot-dish
# square-cafeteria
# lay_eggs-equine
# sweet-baby
# lay_eggs-sheep
# fly-stock
# yellow-platanthera
# hot-skillet
# dangerous-starter
# square-dongle
# made_of_wood-footrest
# lay_eggs-tropicbird
# sweet-dessert
# yellow-human
# fly-albatross
# made_of_wood-knife
# dangerous-toad
# black-rain
# yellow-paint
# fly-toadfish
# yellow-cider
# fly-goatfish
# hot-custard
# yellow-sunflower
# black-bra
# made_of_wood-table
# sweet-melon
# lay_eggs-puss
# dangerous-neurotoxin
# wheels-frigate
# made_of_wood-turnbuckle
# fly-tower
# lay_eggs-whale
# sweet-rutabaga
# yellow-champagne
# dangerous-slice
# wheels-yacht
# black-day
# hot-sauce
# sweet-squash
# fly-glutton
# dangerous-scorpion
# hot-stove
# black-pyramid
# lay_eggs-emberizidae
# wheels-axle
# made_of_wood-houseboat
# sweet-mangosteen
# black-raisin
# lay_eggs-strigidae
# hot-bread
# yellow-millipede
# square-workstation
# dangerous-gunman
# fly-van
# square-folder
# lay_eggs-pipefish
# sweet-mast
# hot-can
# dangerous-dose
# black-buttercup
# yellow-alligator
# dangerous-harpoon
# hot-burner
# sweet-fenugreek
# black-bird
# made_of_wood-harp
# fly-jade
# lay_eggs-moose
# dangerous-elixir
# hot-smoke
# fly-motacilla
# sweet-amaranth
# made_of_wood-club
# wheels-tractor
# square-closet
# black-corn
# square-orange
# hot-jar
# sweet-walnut
# fly-silverback
# lay_eggs-pintail
# dangerous-mattock
# made_of_wood-trowel
# lay_eggs-crocodile
# fly-emberizidae
# black-housefly
# sweet-banana
# yellow-peach
# hot-bikini
# dangerous-missile
# yellow-quesadilla
# fly-potoroo
# lay_eggs-crane
# sweet-flavor
# dangerous-langur
# made_of_wood-screw
# hot-chimney
# black-coffee
# yellow-dandelion
# fly-chick
# fly-yawl
# yellow-meconopsis
# dangerous-penicillin
# lay_eggs-tabby
# sweet-yoghurt
# hot-marinade
# made_of_wood-handrail
# black-elm
# yellow-echinocereus
# sweet-watermelon
# lay_eggs-collie
# fly-sheepshead
# black-crow
# hot-happiness
# dangerous-grapeshot
# made_of_wood-steerer
# wheels-sedan
# made_of_wood-violin
# yellow-tire
# black-jean
# made_of_wood-bell
# lay_eggs-mosquitofish
# dangerous-fusil
# sweet-pepper
# fly-seal
# square-bookcase
# hot-heating
# lay_eggs-pig
# fly-taxi
# square-apple
# sweet-bean
# hot-glass
# yellow-fox
# black-oven
# made_of_wood-puppet
# wheels-chaise
# made_of_wood-forepaw
# square-tray
# hot-kiln
# dangerous-aspirin
# sweet-pomegranate
# yellow-candy
# black-crocodile
# fly-sloop
# black-cow
# sweet-coconut
# fly-barnacle
# square-suite
# made_of_wood-cello
# lay_eggs-world
# yellow-dog
# wheels-underframe
# black-rabbit
# sweet-lemon
# made_of_wood-mandrel
# lay_eggs-haliaeetus
# dangerous-laxative
# fly-buffalo
# wheels-scooter
# hot-lightning
# made_of_wood-saw
# hot-bulb
# lay_eggs-laridae
# sweet-wine
# fly-titmouse
# black-flower
# yellow-chameleon
# dangerous-glove
# square-carrel
# wheels-roadster
# yellow-chive
# dangerous-warhead
# made_of_wood-weatherboard
# hot-cream
# black-potoroo
# sweet-pome
# fly-gull
# black-stocking
# lay_eggs-lemming
# sweet-tomato
# wheels-locomotive
# fly-zebra
# yellow-goldfish
# hot-dough
# made_of_wood-soundbox
# black-death
# fly-thrush
# lay_eggs-merganser
# sweet-berry
# yellow-marigold
# wheels-freighter
# made_of_wood-laptop
# dangerous-rabbit
# hot-table
# fly-ouzel
# made_of_wood-cymbal
# lay_eggs-merino
# hot-argument
# fly-truck
# made_of_wood-trave
# sweet-legume
# yellow-banana
# dangerous-cure
# wheels-buggy
# square-newspaper
# roll-rope
# red-clothing
# round-popsicle
# red-bulgur
# red-cowpeas
# red-marinade
# round-marble
# round-pizza
# roll-wheel
# roll-lever
# roll-chimney
# roll-polyurethane
# roll-calliper
# red-jam
# roll-bead
# red-beetroot
# round-dresser
# red-lentil
# round-bedroom
# red-crypt
# round-pancake
# roll-mandrel
# roll-ferrule
# roll-pipe
# roll-spindle
# roll-noseband
# red-flower
# red-radish
# round-world
# round-watermelon
# round-nut
# roll-pavement
# round-dough
# red-cockroach
# round-patty
# red-cheetah
# roll-nut
# round-mayonnaise
# red-peanut
# red-truffle
# red-lobster
# red-vegetable
# round-omelette
# red-ketchup
# round-coleslaw
# roll-rail
# red-mamey
# red-fenugreek
# red-chocolate
# roll-pulley
# red-crow
# round-doughnut
# red-water
# round-syrup
# round-baton
# round-curd
# round-disk
# round-apple
# red-fir
# roll-chock
# round-cantaloupe
# roll-kickstand
# red-brick
# red-ageratina
# round-cucurbit
# roll-fireplace
# roll-wiffle
# red-tongue
# red-wheat
# round-room
# roll-tub
# round-ketchup
# red-wand
# round-frisbee
# red-night
# red-paint
# red-pistachio
# red-oven
# roll-millstone
# round-cake
# round-ashtray
# red-recorder
# red-wine
# roll-dowel
# roll-paddle
# red-glass
# round-pudding
# red-pot
# round-soup
# red-eye
# red-bus
# roll-horseshoe
# red-mentzelia
# round-fritter
# round-pie
# round-creamer
# round-cornmeal
# roll-surfboard
# roll-cart
# round-juice
# red-couch
# red-juice
# round-condiment
# round-candle
# round-donut
# red-bloodstone
# red-lewisia
# red-carnation
# roll-eyelet
# red-syrup
# red-geranium
# red-daisy
# round-puree
# red-clarinet
# round-mentzelia
# round-chive
# round-hubcap
# red-lime
# round-bean
# red-nectarine
# round-enchiladas
# round-cds
# round-plunger
# roll-shovel
# round-corkscrew
# round-pepperoni
# red-pigweed
# round-banjo
# roll-radiator
# roll-propeller
# round-peanut
# roll-brick
# roll-driveshaft
# red-ambulance
# round-shape
# red-shallot
# round-bowl
# red-elm
# red-lark
# red-lingonberry
# red-lemon
# red-leafs
# round-ball
# red-lip
# roll-chamfer
# red-olive
# round-drumstick
# roll-plastic
# red-milk
# red-broccoli
# red-magpie
# roll-grindstone
# red-ink
# round-custard
# round-barrel
# red-robin
# round-dessert
# roll-tile
# round-pumpkin
# round-disc
# red-apricot
# red-sauce
# round-vegetable
# red-flame
# red-cream
# red-anger
# red-melon
# roll-projectile
# red-ring
# round-egg
# red-chive
# red-hair
# round-cream
# roll-handlebar
# round-bottle
# roll-cartridge
# round-spoon
# roll-handrail
# roll-boiler
# roll-pin
# round-sapodilla
# red-miner
# red-hazelnut
# red-crab
# red-celery
# roll-acrylic
# roll-wrench
# red-apple
# roll-brake
# red-jade
# roll-tappet
# round-berry
# roll-corkscrew
# roll-lathe
# red-limousine
# round-mozzarella
# round-blueberry
# roll-bearing
# red-sycamore
# roll-donkey
# round-onion
# round-circle
# round-bucket
# round-table
# roll-washer
# round-shoe
# round-cube
# round-globe
# red-quesadilla
# roll-firebox
# red-chicken
# red-blueberry
# round-pen
# round-seedpod
# roll-nozzle
# red-rooster
# roll-axle
# roll-urethane
# round-sauce
# round-seasoning
# round-salad
# round-bulgur
# red-strawberry
# roll-lamp
# round-cabbage
# round-marzipan
# roll-flywheel
# roll-bolt
# round-cheeseburger
# round-gourd
# roll-bushing
# roll-car
# red-berry
# round-melon
# roll-bottle
# red-gherkin
# red-candy
# roll-backboard
# round-pineapple
# roll-crankshaft
# roll-slab
# red-beet
# red-fear
# round-can
# roll-vaporizer
# red-blackberry
# red-corncob
# red-grape
# round-tray
# roll-tray
# red-weed
# roll-roller
# round-pastry
# roll-headboard
# roll-crosshead
# roll-hose
# roll-plaster
# round-sundae
# round-pilaf
# red-vanilla
# round-vinaigrette
# round-football
# red-ladybird
# red-gorilla
# roll-plunger
# red-herring
# round-planet
# red-banana
# red-carrot
# red-pignut
# red-cherry
# roll-hammer
# roll-hubcap
# red-football
# round-tart
# roll-candle
# roll-fusee
# roll-caber
# red-heart
# red-egg
# red-cake
# round-pomade
# red-cucurbit
# round-pasta
# red-fern
# round-atole
# red-honey
# round-butter
# red-sand
# red-mango
# roll-quoit
# roll-gearshift
# red-frog
# red-cinnamon
# red-chili
# roll-grip
# roll-shoe
# red-dogwood
# red-slug
# roll-windowpane
# roll-glass
# red-lipstick
# roll-pen
# red-peony
# round-box
# roll-tire
# roll-shaft
# red-artichoke
# roll-leather
# roll-wheelbarrow
# roll-windscreen
# red-rhino
# red-cabbage
# round-cheese
# red-barn
# red-custard
# red-guava
# red-dog
# round-almond
# red-cat
# round-breadcrumb
# red-balloon
# round-coconut
# roll-peg
# round-lolly
# round-tomato
# round-pecan
# round-orange
# red-vine
# red-potato
# roll-tyre
# red-squirrel
# red-ruby
# red-vinegar
# red-chameleon
# roll-cloth
# red-tiger
# round-scone
# roll-cylinder
# red-ginger
# red-echinocereus
# round-banana
# round-popcorn
# red-car
# red-watermelon
# round-marshmallow
# red-galangal
# red-fox
# round-beet
# roll-wagon
# round-chicken
# red-garlic
# red-pansy
# red-mangifera
# roll-paint
# roll-skateboard
# red-blackboard
# round-soursop
# red-rhubarb
# round-fondant
# round-samosa
# red-coconut
# round-matzah
# red-chutney
# red-currant
# roll-pencil
# round-biscuit
# red-tomato
# round-sausage
# roll-bucket
# round-potato
# round-sphere
# roll-barrel
# red-raspberry
# roll-manhole
# round-bracelet
# round-cheesecloth
# red-raisin
# red-onion
# round-baseball
# red-pineapple
# red-avocado
# roll-blade
# red-yogurt
# round-fruit
# red-pit
# round-casserole
# red-fruit
# roll-ski
# roll-bike
# roll-saw
# roll-sprocket
# round-button
# roll-rifling
# red-pepper
# red-shiitake
# roll-alloy
# red-aubergine
# red-spice
# roll-kiln
# red-ant
# round-snack
# roll-piston
# round-chocolate
# red-grapefruit
# roll-ball
# red-pomegranate
# red-jeep
# roll-breechblock
# round-quesadilla
# round-basketball
# red-cereal
# round-cherry
# roll-footrest
# round-cookie
# red-cilantro
# round-lemon
# round-candy
# red-coffee
# round-bread
# round-tortilla
# roll-bumper
# red-allspice
# roll-pig
# red-rhagoletis
# round-nutlet
# roll-marble
# roll-headstock
# _test4-_test4
# roll-screw
# roll-carabiner
# _test3-_test3
# roll-windshield
# round-wheel
# red-spinach
# red-dress
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-e72e9558d1bb> in <module>
#       4 n_q = '*'
#       5
# ----> 6 df_cont_ag = get_agreement_contradiction_data(run, group, batch, n_q)
#
# <ipython-input-41-d31943796513> in get_agreement_contradiction_data(run, group, batch, n_q)
#      51     ag_cont_dicts = []
#      52     for pair, ag in agreement_dict.most_common():
# ---> 53         date = day_by_pair(pair)
#      54         if 'test' not in pair and 'check' not in pair:
#      55             d = pair_dicts_by_pair[pair]
#
# TypeError: 'dict' object is not callable

# %%
#data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
#data_by_day = get_pairs_by_day(data_dict_list)

# %%
# High agreement

df_ag_sorted = df_cont_ag.sort_values('agreement', axis = 0, ascending=False, inplace=False)
top_ag = df_ag_sorted[:30]
print(f'Total number of pairs: {len(df_ag_sorted)}')
top_ag

# %%
# Low agreement

df_ag_sorted = df_cont_ag.sort_values('agreement', axis = 0, ascending=False, inplace=False)
bottom_ag = df_ag_sorted[-30:-1]
bottom_ag
# Out:
#       agreement  contradiction_rate                    pair
# 1709  -0.038033            0.081250         round-corkscrew
# 1710  -0.040621            0.000000       yellow-gooseberry
# 1711  -0.041397            0.000000            sweet-desert
# 1712  -0.045636            0.000000              red-carrot
# 1713  -0.045977            0.000000            yellow-drupe
# 1714  -0.047068            0.000000          dangerous-fire
# 1715  -0.047619            0.000000            yellow-night
# 1716  -0.049383            0.000000         wheels-schooner
# 1717  -0.049601            0.186667          lay_eggs-hobby
# 1718  -0.049689            0.060000      lay_eggs-whiteface
# 1719  -0.050434            0.000000    dangerous-freebooter
# 1720  -0.051610            0.000000        yellow-buttercup
# 1721  -0.052126            0.000000             square-book
# 1722  -0.052632            0.000000           yellow-potato
# 1723  -0.052856            0.000000           wheels-sleigh
# 1724  -0.053467            0.000000    made_of_wood-trumpet
# 1725  -0.059701            0.033333          wheels-cruiser
# 1726  -0.060764            0.000000             square-ball
# 1727  -0.061292            0.000000          wheels-warship
# 1728  -0.062434            0.000000            yellow-honey
# 1729  -0.062548            0.000000             square-text
# 1730  -0.068208            0.158333  made_of_wood-carabiner
# 1731  -0.069830            0.000000          yellow-saffron
# 1732  -0.071169            0.000000            black-satire
# 1733  -0.071429            0.000000           yellow-peanut
# 1734  -0.072391            0.000000        yellow-lavandula
# 1735  -0.083333            0.000000          yellow-blossom
# 1736  -0.094090            0.062500          round-coleslaw
# 1737  -0.094595            0.000000                roll-pin

# %%
# middle

df_ag_sorted = df_cont_ag.sort_values('agreement', axis = 0, ascending=False, inplace=False)
bottom_ag = df_ag_sorted[-725:-725+30]
bottom_ag
# Out:
#      agreement  contradiction_rate                    pair
# 813   0.227415            0.084416               red-onion
# 814   0.227006            0.112500                red-frog
# 815   0.226562            0.000000         black-aubergine
# 816   0.226080            0.000000              yellow-bee
# 817   0.225874            0.075000           round-dessert
# 818   0.225649            0.000000           black-dolphin
# 819   0.225600            0.183333        dangerous-killer
# 820   0.225555            0.115000               roll-tile
# 821   0.225490            0.016667  made_of_wood-kickstand
# 822   0.225490            0.058333        dangerous-iodine
# 823   0.225418            0.000000            hot-cookware
# 824   0.225198            0.016667         black-crocodile
# 825   0.224717            0.062500            round-tomato
# 826   0.224495            0.000000         black-cockroach
# 827   0.224231            0.013333            fly-clarence
# 828   0.224231            0.000000          black-toucanet
# 829   0.223958            0.085000           roll-flywheel
# 830   0.223582            0.058333        square-wallpaper
# 831   0.223317            0.125000            wheels-stage
# 832   0.223037            0.006667          lay_eggs-felid
# 833   0.222454            0.093750           red-carnation
# 834   0.222453            0.033333              hot-butter
# 835   0.222222            0.000000           black-avocado
# 836   0.222222            0.300000               red-chili
# 837   0.222222            0.000000             round-baton
# 838   0.222222            0.000000          square-luggage
# 839   0.222152            0.085000            roll-chamfer
# 840   0.222013            0.065000               roll-slab
# 841   0.221928            0.075000             red-chicken
# 842   0.221507            0.016667               black-sky

# %%
def pairs_to_file(name, pairs):
    path = f'../analyses/{name}.txt'
    with open(path, 'w') as outfile:
        for p in pairs:
            outfile.write(p+'\n')
    print(f'Written pairs to {path}')

# %% [markdown]
# # Selecting data
#
# * from high, low and medium agreement
# * pairs workers have commented on
#
#
# ## Worker comments:
#
# * Dangerous - guttering
# * fly-trumpeter
# * lay_eggs - hackney
# * Yellow - Corn on the cob
# * Made from wood - brush
# * Hot - chutney
# * Has_wheels - equipment
# * sweet - desert (mistaken for dessert)

# %%
# Selection for a trial round:

pair_dict = dict()
all_pairs = []

pair_dict['expert_inspection1'] = ['fly-arrow', 'roll-pin', 'yellow-buttercup',
                                   'hot-vineigrette', 'roll-tire']
pair_dict['expert_inspection2'] = ['roll-shovel', 'dangerous-freebooter',
                                   'yellow-pineapple', 'red-carrot', 'red-wine']
pair_dict['expert_inspection3'] = ['square-recliner', 'yellow-leopard', 
                                   'round-pen', 'roll-washer', 'lay_eggs-plaice']
pair_dict['expert_inspection4'] = ['dangerous-guttering','fly-trumpeter', 'lay_eggs-hackney', 
                                   'yellow-corn_on_the_cob','made_from_wood-brush', 'hot-chutney']


all_pairs = []
for name, pairs in pair_dict.items():
    if any([p in all_pairs for p in pairs]):
        print(f'Attention! Duplicate pair in {name}')
    else:
        all_pairs.extend(pairs)
        pairs_to_file(name, pairs)
# Out:
# Written pairs to ../analyses/expert_inspection1.txt
# Written pairs to ../analyses/expert_inspection2.txt
# Written pairs to ../analyses/expert_inspection3.txt
# Written pairs to ../analyses/expert_inspection4.txt
