# %% [markdown]
# # Select:
#
#
# * Pairs with high agreement/few contradictions
# * Pairs with low agreement/few contradictions (if possible)
# * Pairs with high agrement/many contradictions
# * Pairs with low agreement/many contradictions
#
# Try to spread over property types
#
#
# # Annotate:
#
# * New run
# * Define new experiment group somehow
#
# # Ideas:
#
# * Low agreement, low contradiction rate: knowledge issue (some people know, some don't)
# * Low agreement, high contradiction rate: ambiguity

# %%
from load_data import load_experiment_data
from calculate_iaa import get_agreement
from utils_analysis import load_contradiction_pairs
from utils_analysis import collect_contradictions
from utils_analysis import sort_by_key
from utils_analysis import get_annotation_ids
from utils_analysis import load_analysis

from collections import Counter, defaultdict
import pandas as pd


def get_agreement_by_property(data_dict_list):

    agreement_prop_dict = dict()
    data_by_prop = sort_by_key(data_dict_list, ['property', 'concept'])
    for prop, dl_prop in data_by_prop.items():
        agreement_prop_dict[prop] = get_agreement(dl_prop, v=False)
    return agreement_prop_dict


run = "4"
group = 'experiment2'
batch = '*'
n_q = '*'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
#data_by_pair = sort_by_key(data_dict_list, ['property', 'concept'])
analysis_type = 'pairs'
df = load_analysis(analysis_type, run, group, batch)
pair_dicts = df.to_dict('records') 
pair_dicts_by_pair = sort_by_key(pair_dicts, ['pair'])
ag_prop_dict = get_agreement_by_property(data_dict_list)

agreement_dict = Counter()
for prop, ag in ag_prop_dict.items():
    agreement_dict[prop] =  ag['Krippendorff']
 

n = 0

ag_cont_dicts = []
for pair, ag in agreement_dict.most_common():
    d = pair_dicts_by_pair[pair]
    if len(d) == 1:
        new_dict = dict()
        d = d[0]
        #print(d.keys())
        cont = d['contradiction_poss_contradiction_ratio']
        new_dict['pair'] = pair
        new_dict['agreement'] = ag
        new_dict['contradiction_rate'] = cont
        ag_cont_dicts.append(new_dict)
        print(pair, ag)
        n += 1
        #if n == 5:
         #   break
    else:
        print('unexpected length:', len(d), 'for pair', pair)
    #d = data_by_pair[pair]
df_ag_cont = pd.DataFrame(ag_cont_dicts)
# Out:
# Discarded 0.0 annotations.
# _check3-_check3 1
# _check1-_check1 1
# made_of_wood-oak 0.7746923076923077
# sweet-honey 0.7267628205128205
# sweet-cherry 0.7070754716981131
# fly-robin 0.7027027027027026
# sweet-candy 0.6225713104588673
# hot-grill 0.6215999999999999
# wheels-taxicab 0.6171477079796266
# fly-deer 0.5998556998556999
# fly-wing 0.562826174227218
# fly-ferry 0.5512820512820513
# lay_eggs-humankind 0.547945205479452
# fly-pussy 0.54625
# hot-vinaigrette 0.5168402777777777
# sweet-jam 0.5098354074668807
# wheels-cab 0.5010036130068245
# made_of_wood-lath 0.4887820512820513
# lay_eggs-leopard 0.47786666666666666
# fly-nightingale 0.47705663497312933
# wheels-van 0.47619047619047605
# lay_eggs-mouser 0.4746376811594203
# black-paint 0.4743859649122807
# hot-geyser 0.4732142857142857
# lay_eggs-charadrius 0.46501831501831503
# hot-barbecue 0.4623397435897436
# lay_eggs-hare 0.4598214285714286
# yellow-milk 0.45833333333333326
# hot-kettle 0.4480128462464874
# sweet-broccoli 0.44395604395604393
# dangerous-bar 0.4282744282744283
# hot-wok 0.4243156199677939
# hot-fruitcake 0.4199353500265356
# wheels-motorbus 0.4129720853858785
# hot-fireplace 0.4038538739462063
# wheels-car 0.39914880680954556
# yellow-corncob 0.39441860465116296
# made_of_wood-gunwale 0.1552
# fly-pelican 0.15106732348111673
# black-forepaw 0.14646381578947376
# wheels-garage 0.14492583918813418
# fly-chinook 0.14091680814940577
# wheels-dray 0.14055394791236053
# lay_eggs-drill 0.13809027777777771
# lay_eggs-eland 0.1378669639539205
# fly-hog 0.13760000000000006
# made_of_wood-rail 0.1363885662666151
# sweet-pistachio 0.1353509878100042
# hot-seasoning 0.12916666666666665
# sweet-asparagus 0.12259070294784569
# sweet-chicken 0.12121212121212122
# dangerous-unction 0.12
# square-sunroom 0.11705069124423961
# yellow-nectarine 0.11638853230637558
# black-monkey 0.11529352481733435
# made_of_wood-rod 0.11516483516483533
# fly-basset 0.11494252873563215
# wheels-driver 0.11402116402116402
# fly-duck 0.11326994625878439
# black-grape 0.1126331811263318
# sweet-puree 0.11083333333333345
# sweet-lentil 0.10810810810810823
# sweet-beet 0.10689514483884122
# square-fireplace 0.10591133004926112
# dangerous-colchicine 0.10222222222222221
# yellow-kingfisher 0.09876543209876543
# square-footrest 0.0980392156862745
# wheels-cat 0.09668174962292608
# wheels-equipage 0.09507024265644959
# lay_eggs-leatherback 0.09488484848484835
# made_of_wood-modillion 0.09246432579765906
# dangerous-attack 0.09037745879851156
# wheels-snowmobile 0.09007352941176494
# sweet-ginger 0.08976157082748937
# made_of_wood-rudder 0.0891130727196301
# dangerous-arm 0.08888888888888902
# made_of_wood-window 0.08857142857142852
# hot-bathroom 0.08784893267651872
# sweet-hazelnut 0.08730158730158721
# fly-bark 0.08538961038961046
# made_of_wood-stick 0.08003201280512195
# black-frogmouth 0.07996736026111773
# fly-babbler 0.07986548970155516
# square-dining 0.0791476407914764
# hot-garlic 0.0757649344341913
# black-ladybird 0.07451923076923073
# fly-capsule 0.07019696969696965
# dangerous-hack 0.06720000000000004
# black-mentzelia 0.06681318681318693
# square-workspace 0.06423611111111105
# wheels-carriage 0.06349206349206338
# dangerous-buffer 0.06222222222222218
# fly-skimmer 0.06201550387596899
# lay_eggs-howler 0.059701492537313494
# wheels-toboggan 0.0551378446115286
# hot-chutney 0.048327854481700516
# wheels-coach 0.04481792717086841
# lay_eggs-stockfish 0.03980099502487555
# made_of_wood-plough 0.03749999999999987
# made_of_wood-strake 0.03601440576230497
# sweet-muscat 0.03373878536922015
# dangerous-pusher 0.030448717948718063
# square-marble 0.02833333333333321
# sweet-tater 0.027210884353741305
# fly-flycatcher 0.02678571428571408
# lay_eggs-muskrat 0.0257142857142858
# lay_eggs-layer 0.018461538461538418
# lay_eggs-pointer 0.017765310892940755
# dangerous-doodlebug 0.01649305555555547
# yellow-colocasia 0.011695906432748537
# lay_eggs-basilisk 0.011656143759106397
# square-laptop 0.004960317460317332
# made_of_wood-axe 0.004290004290004146
# _check2-_check2 0.0
# sweet-strawberry 0.0
# _test2-_test2 0.0
# _check4-_check4 0.0
# _test3-_test 0.0
# _test4-_test 0.0
# yellow-flame 0.0
# _test1-_test1 -2.220446049250313e-16
# hot-outfit -0.0003292181069958211
# made_of_wood-beam -0.000760709361479428
# fly-wheeler -0.0032000000000000917
# wheels-tank -0.005148005148005508
# wheels-rig -0.005148005148005508
# yellow-pineapple -0.013595352861203835
# lay_eggs-plaice -0.01595959595959595
# fly-arrow -0.016806722689075793
# sweet-fennel -0.01750000000000007
# sweet-shiitake -0.020219780219780104
# yellow-leopard -0.02314814814814814
# square-recliner -0.03555555555555534
# lay_eggs-hobby -0.049600672551492364
# lay_eggs-whiteface -0.049689440993789136
# yellow-buttercup -0.05160997732426287
# made_of_wood-carabiner -0.06820768759303064

# %%
# worker_df.sort_values('contradiction_poss_contradiction_ratio', axis=0, ascending=False, inplace=True)
pd.set_option('display.float_format', lambda x: '%.5f' % x)
df_ag_cont.sort_values('agreement', axis = 0, ascending=False, inplace=True)
df_ag_cont
# Out:
#      agreement  contradiction_rate                    pair
# 1      1.00000             0.00000         _check1-_check1
# 0      1.00000             0.00000         _check3-_check3
# 2      0.77469             0.00893        made_of_wood-oak
# 3      0.72676             0.03333             sweet-honey
# 4      0.70708             0.00000            sweet-cherry
# 5      0.70270             0.00000               fly-robin
# 6      0.62257             0.10000             sweet-candy
# 7      0.62160             0.02500               hot-grill
# 8      0.61715             0.01667          wheels-taxicab
# 9      0.59986             0.00741                fly-deer
# 10     0.56283             0.05333                fly-wing
# 11     0.55128             0.00000               fly-ferry
# 12     0.54795             0.02000      lay_eggs-humankind
# 13     0.54625             0.01333               fly-pussy
# 14     0.51684             0.00000         hot-vinaigrette
# 15     0.50984             0.03333               sweet-jam
# 16     0.50100             0.05000              wheels-cab
# 17     0.48878             0.01667       made_of_wood-lath
# 18     0.47787             0.04000        lay_eggs-leopard
# 19     0.47706             0.06000         fly-nightingale
# 20     0.47619             0.09167              wheels-van
# 21     0.47464             0.00667         lay_eggs-mouser
# 22     0.47439             0.00000             black-paint
# 23     0.47321             0.02500              hot-geyser
# 24     0.46502             0.03704     lay_eggs-charadrius
# 25     0.46234             0.12500            hot-barbecue
# 26     0.45982             0.02667           lay_eggs-hare
# 27     0.45833             0.00000             yellow-milk
# 28     0.44801             0.10833              hot-kettle
# 29     0.44396             0.00000          sweet-broccoli
# ..         ...                 ...                     ...
# 200    0.01777             0.10667        lay_eggs-pointer
# 201    0.01649             0.06667     dangerous-doodlebug
# 202    0.01170             0.00000        yellow-colocasia
# 203    0.01166             0.09333       lay_eggs-basilisk
# 204    0.00496             0.00000           square-laptop
# 205    0.00429             0.04167        made_of_wood-axe
# 209    0.00000             0.00000         _check4-_check4
# 208    0.00000             0.00000           _test2-_test2
# 207    0.00000             0.00000        sweet-strawberry
# 210    0.00000             0.00000            _test3-_test
# 212    0.00000             0.00000            yellow-flame
# 211    0.00000             0.00000            _test4-_test
# 206    0.00000             0.00000         _check2-_check2
# 213   -0.00000             0.00000           _test1-_test1
# 214   -0.00033             0.00000              hot-outfit
# 215   -0.00076             0.01754       made_of_wood-beam
# 216   -0.00320             0.04667             fly-wheeler
# 218   -0.00515             0.04167              wheels-rig
# 217   -0.00515             0.10000             wheels-tank
# 219   -0.01360             0.00000        yellow-pineapple
# 220   -0.01596             0.06612         lay_eggs-plaice
# 221   -0.01681             0.22667               fly-arrow
# 222   -0.01750             0.11667            sweet-fennel
# 223   -0.02022             0.06667          sweet-shiitake
# 224   -0.02315             0.00000          yellow-leopard
# 225   -0.03556             0.20000         square-recliner
# 226   -0.04960             0.18667          lay_eggs-hobby
# 227   -0.04969             0.06000      lay_eggs-whiteface
# 228   -0.05161             0.00000        yellow-buttercup
# 229   -0.06821             0.15833  made_of_wood-carabiner
#
# [230 rows x 3 columns]
