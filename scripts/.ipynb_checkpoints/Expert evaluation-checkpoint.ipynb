# %% [markdown]
# # Evaluation of different crowd analysis metrics
#
#
# (1) Dataset filtering:
#
# * Exclude workers based on:
#     - contradiction ration (absolut thresh, batch stdv, pair stdv, total stdv)
#     - worker quality score (thresholds)
#     - attention check fails
#
# (2) Label aggregation:
#
# * Majority vote
# * Top vote
# * CT unit-label score (tresholds)

# %%
# Test crowd truth aggregation here 

from clean_annotations import clean_workers
from load_data import load_experiment_data, load_expert_data, load_gold_data
from aggregation import aggregate_binary_labels
from calculate_iaa import  get_collapsed_relations
from utils_analysis import sort_by_key
from utils_analysis import load_analysis, load_ct

from sklearn.metrics import precision_recall_fscore_support as p_r_f1
# load expert data    
#run = '4'
#group = 'expert_inspection1'
#n_q = '*'
#batch = '*'
#data_dict_list_exp = load_expert_data(run, group, n_q, batch)

run = '*'
group = 'experiment*'
n_q = '*'
batch = '*'



crowd = load_experiment_data(run, group, n_q, batch)
#crowd_coll = get_collapsed_relations(data_dict_list_crowd,
                                                        #  mapping='negative_relations',
                                                        # answer_name = 'answer')
print(len(crowd))
# Out:
# Discarded 655.0 annotations.
# 200723

# %%
# Test load expert data

# load expert data    
run = '4'
group = 'expert_inspection1'
n_q = '30'
batch = '1'
gold = load_gold_data(run, group, n_q, batch)


gold_coll = get_collapsed_relations(gold, mapping='negative_relations',
                                                         answer_name = 'answer')

print(gold[0]['answer'])
print()
print(gold_coll[0]['answer'])
print()
print(len(gold))
print(len(gold_coll))
# Out:
# true
#
# True
#
# 30
# 24

# %%
def get_evaluation_instances(crowd, gold):
    triples_gold = sort_by_key(gold, ['relation', 'property', 'concept'])
    triples_crowd = sort_by_key(crowd, ['relation', 'property', 'concept'])
    evaluation_instances_crowd = []
    for t, gold_data in triples_gold.items():
        evaluation_instances_crowd.extend(triples_crowd[t])
    return evaluation_instances_crowd


def evaluate(gold, crowd, vote):
    crowd_by_triple = sort_by_key(crowd, ['relation', 'property', 'concept'])
    gold_by_triple = sort_by_key(gold, ['relation', 'property', 'concept'])
    total = []
    labels_gold = []
    labels_crowd = []
    for t, gold_data in gold_by_triple.items():
        crowd_data = crowd_by_triple[t]
        if len(crowd_data) == 1:
    
            gold_answer = gold_data[0]['answer']
            crowd_answer = crowd_data[0][vote]
            gold_answer = str(gold_answer).lower()
            crowd_answer = str(crowd_answer).lower()
            labels_gold.append(gold_answer)
            labels_crowd.append(crowd_answer)
        else:
            print('irregularities in data:', t, len(crowd_data))
            #pass

    p, r, f1, support = p_r_f1(labels_gold, labels_crowd, average = 'weighted')
    results_dict = dict()
    results_dict['f1'] = f1
    results_dict['p'] = p
    results_dict['r'] = r
    return results_dict


def evaluate_all_versions(gold, crowd_eval_agg, vote):
    versions = ['relations', 'levels', 'negative_relations']
    results_dict = dict()
    for v in versions:
      
        if v != 'relations':
            gold_coll = get_collapsed_relations(gold, 
                                    mapping=v, answer_name = 'answer')
            crowd_eval_agg_coll = get_collapsed_relations(crowd_eval_agg, 
                                    mapping=v, answer_name = vote) 
        else:
            crowd_eval_agg_coll = crowd_eval_agg
            gold_coll = gold
        res = evaluate(gold_coll, crowd_eval_agg_coll, vote=vote)
        results_dict[v] = res
    return results_dict
        
        
        
        
        
crowd_eval = get_evaluation_instances(crowd, gold)
ct_units = load_ct('*', 'experiment*', '*', 'units', as_dict=True)
crowd_eval_agg = aggregate_binary_labels(crowd_eval, ct_units)
vote='majority_vote'
results_dict = evaluate_all_versions(gold, crowd_eval_agg, vote)
for version, results in results_dict.items():
    print(version)
    for k, v in results.items():
        print(k, v)
    print()
    


group = 'experiment*'
n_q = '*'
batch = '*'

n_stdv = 0.5
unit = 'batch'
metric = 'contradictions'
crowd_eval = get_evaluation_instances(crowd, gold)
crowd_eval_clean = clean_workers(crowd_eval, run, group, 
                                               batch, metric, unit, n_stdv)
# Out:
# relations
# f1 0.8733333333333334
# p 0.9111111111111111
# r 0.8666666666666667
#
# levels
# f1 0.9201680672268907
# p 0.9375
# r 0.9166666666666666
#
# negative_relations
# f1 0.8380952380952381
# p 0.8888888888888888
# r 0.8333333333333334

# %%
# Out:
# 30

# %% [markdown]
# # Aggregate labels and evaluate against gold

# %%
import pandas as pd

from evaluation import evaluate 
from aggregation import aggregate_binary_labels, get_expert_labels
from load_data import load_expert_data
from load_data import load_experiment_data
from clean_annotations import clean_workers
from calculate_iaa import get_agreement 

def get_performance_overview(data_dict_list_exp, run, group, n_q, batch):
    crowd_raw = load_experiment_data(run, group, n_q, batch)
    
    # raw crowd aggregation 
    #iaa_raw = get_agreement(data_dict_list_crowd, 
                              #  collapse_relations = False, v=False, disable_kappa = True)
    #iaa_levels = get_agreement(data_dict_list_crowd, 
                               # collapse_relations = 'levels', v=False, disable_kappa = True)
    
    
    units = [ 'raw']#, 'pair', 'batch', 'total']
    stds = ['raw']#, 0.5, 1, 1.5, 2]
    metrics = ['contradictions', 'crowdtruth']
    votes = ['majority_vote']#, 'top_vote', 'ct_vote_0.5', 'ct_vote_0.6']#,
             #'ct_vote_0.7', 'ct_vote_0.8', 'ct_vote_0.9', 
             #'top_vote_ct_0.5', 'top_vote_ct_0.6','top_vote_ct_0.7',
             #'top_vote_ct_0.8', 'top_vote_ct_0.9']
    overview_dicts = []
    gold = get_expert_labels(data_dict_list_exp)
    gold_levels = get_collapsed_relations(gold,
                                                mapping='levels',
                                                answer_name = 'answer')
    gold_neg_collapsed = get_collapsed_relations(gold,
                                                mapping='negative_relation',
                                                answer_name = 'answer')
    
    for v in votes:
        print(v)
        if v.startswith('ct_vote') or v.startswith('top_vote_ct'):
            unit = 'raw'
            n_stdv = 'raw'
            crowd_bin_raw  = aggregate_binary_labels(data_dict_list_crowd)
            crowd_bin_raw_levels = get_collapsed_relations(crowd_,
                                                mapping='levels',
                                                answer_name = vote)
            crowd_bin_raw_coll_neg = get_collapsed_relations(gold_data,
                                                mapping='negative_relation',
                                                answer_name = vote)
        
            results_dict_rel = evaluate(expert_bin_labels, crowd_bin_raw,\
                                        vote=v, label = 'relation')
            results_dict_level = evaluate(expert_bin_labels, crowd_bin_labels_clean,\
                                        vote=v, label = 'level')
            
            results_dict_level = evaluate(expert_bin_labels, crowd_bin_labels_clean,\
                                        vote=v, label = 'negative-relations')
            d = dict()
            d['cleaning'] = f'{unit}_{n_stdv}'
            d['aggregation'] = v
            d['f1_relation'] = results_dict_rel['f1']
            d['p_relation'] = results_dict_rel['p']
            d['r_relation'] = results_dict_rel['r']
            d['f1_level'] = results_dict_level['f1']
            d['iaa'] = iaa['Krippendorff']
            d['iaa_levels'] = iaa_levels['Krippendorff']
            overview_dicts.append(d)
        else:
            for unit in units: 
                for n_stdv in stds:
                    if unit == str(n_stdv) == 'raw':
                        data_dict_list_crowd_clean = data_dict_list_crowd
                        crowd_bin_labels_clean  = aggregate_binary_labels(data_dict_list_crowd_clean)
                    elif 'raw' not in [unit, n_stdv]:
                        for metric in metrics:
                            print(v, metric, unit, n_stdv)
                            data_dict_list_crowd_clean = clean_workers(data_dict_list_crowd, run, group, 
                                               batch, metric, unit, n_stdv)
                            crowd_bin_labels_clean  = aggregate_binary_labels(
                                                        data_dict_list_crowd_clean)
                            iaa = get_agreement(data_dict_list_crowd_clean, 
                                            collapse_relations = False, v=False, disable_kappa = True)
                            iaa_levels = get_agreement(data_dict_list_crowd_clean,
                                                       collapse_relations = 'levels', v=False, disable_kappa = True)

                            #print(v)
                            results_dict_rel = evaluate(expert_bin_labels, crowd_bin_labels_clean,\
                                                    vote=v, label = 'relation')
                            results_dict_level = evaluate(expert_bin_labels, crowd_bin_labels_clean,\
                                                    vote=v, label = 'level')
                            # missing: write function to get iaa of selected labels only 
                            d = dict()
                            d['cleaning'] = f'{metric}_{unit}_{n_stdv}'
                            d['aggregation'] = v
                            d['f1_relation'] = results_dict_rel['f1']
                            d['p_relation'] = results_dict_rel['p']
                            d['r_relation'] = results_dict_rel['r']
                            d['f1_level'] = results_dict_level['f1']
                            d['iaa'] = iaa['Krippendorff']
                            d['iaa_levels'] = iaa_levels['Krippendorff']
                            overview_dicts.append(d)
                        else:
                            continue                  
    return overview_dicts

# load expert data    
run = '4'
group = 'expert_inspection1'
n_q = '30'
batch = '1'
data_dict_list_gold = load_gold_data(run, group, n_q, batch)

run = '*'
group = 'experiment*'
n_q = '*'
batch = '*'

# evaluate:
overview_dicts = get_performance_overview(data_dict_list_gold, run, group, n_q, batch)
df = pd.DataFrame(overview_dicts)
# Out:
# Discarded 655.0 annotations.
# majority_vote
# majority_vote contradictions pair 0.5
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# majority_vote crowdtruth pair 0.5
# majority_vote contradictions pair 1
# majority_vote crowdtruth pair 1
# majority_vote contradictions pair 1.5
# majority_vote crowdtruth pair 1.5
# majority_vote contradictions pair 2
# majority_vote crowdtruth pair 2
# majority_vote contradictions batch 0.5
# majority_vote crowdtruth batch 0.5
# majority_vote contradictions batch 1
# majority_vote crowdtruth batch 1
# majority_vote contradictions batch 1.5
# majority_vote crowdtruth batch 1.5
# majority_vote contradictions batch 2
# majority_vote crowdtruth batch 2
# majority_vote contradictions total 0.5
# majority_vote crowdtruth total 0.5
# ...

# %%
from sklearn.metrics import precision_recall_fscore_support as p_r_f1


from load_data import load_expert_data
from load_data import load_experiment_data
from utils_analysis import load_analysis
from utils_analysis import sort_by_key
from aggregation import aggregate_binary_labels
from clean_annotations import remove_contradicting_workers


from sklearn.metrics import precision_recall_fscore_support as p_r_f1


from load_data import load_expert_data
from load_data import load_experiment_data
from utils_analysis import load_analysis
from utils_analysis import sort_by_key
from aggregation import aggregate_binary_labels, get_expert_labels
from clean_annotations import remove_contradicting_workers





def main():

    # load expert data
    run = 4
    group = 'expert_inspection*'
    n_q = '*'
    batch = '*'
    data_dict_list = load_expert_data(run, group, n_q, batch)

    # load crowd data:
    run = '*'
    group = 'experiment*'
    n_q = '*'
    batch = '*'
    data_dict_list_crowd = load_experiment_data(run, group, n_q, batch)
    # clean in preferred way:
    unit = 'pair'
    n_stds = 0.5
    if unit == 'total':
        analysis_type = 'workers'
    else:
        analysis_type = f'workers_by_{unit}'
    dict_list_workers = load_analysis(analysis_type, run, group, batch, as_dict = True)
    data_dict_list_crowd_clean= remove_contradicting_workers(data_dict_list_crowd, dict_list_workers, unit,  n_stds)

    # aggregate binary labels
    expert_bin_labels = aggregate_binary_labels(data_dict_list)
    crowd_bin_labels_raw  = aggregate_binary_labels(data_dict_list_crowd)
    crowd_bin_labels_clean  = aggregate_binary_labels(data_dict_list_crowd_clean)


    # with clean data
    results_dict = evaluate(expert_bin_labels, crowd_bin_labels_clean, vote='majority_vote')
    print(results_dict)

    #with raw data
    results_dict = evaluate(expert_bin_labels, crowd_bin_labels_raw, vote='majority_vote')
    print(results_dict)

if __name__ == '__main__':
    main()

# %%
results_dict_rel = evaluate(gold, crowd_bin_raw,\
                                        vote=v, label = 'relation')
results_dict_level = evaluate(expert_bin_labels, crowd_bin_labels_clean,\
                                        vote=v, label = 'level')         
results_dict_collapse_neg = evaluate(expert_bin_labels, crowd_bin_labels_clean,\
                                        vote=v, label = 'negative-relations')

# %%
df = df.sort_values('f1_relation', ascending = False).round(2)
df
# Out:
#         aggregation                  cleaning  f1_level  f1_relation   iaa  \
# 49      ct_vote_0.6                   raw_raw      1.00         0.90  0.33
# 50      ct_vote_0.7                   raw_raw      0.91         0.89  0.33
# 54  top_vote_ct_0.6                   raw_raw      0.92         0.86  0.33
# 53  top_vote_ct_0.5                   raw_raw      0.92         0.86  0.33
# 57  top_vote_ct_0.9                   raw_raw      0.92         0.86  0.33
# 55  top_vote_ct_0.7                   raw_raw      0.92         0.86  0.33
# 56  top_vote_ct_0.8                   raw_raw      0.92         0.86  0.33
# 51      ct_vote_0.8                   raw_raw      0.80         0.85  0.33
# 48      ct_vote_0.5                   raw_raw      0.92         0.84  0.33
# 52      ct_vote_0.9                   raw_raw      0.80         0.80  0.33
# 18    majority_vote    contradictions_total_1      0.64         0.62  0.35
# ...

# %%
print(df.to_latex(index=False))
# Out:
# \begin{tabular}{llrrrrrr}
# \toprule
#      aggregation &             cleaning &  f1\_level &  f1\_relation &   iaa &  iaa\_levels &  p\_relation &  r\_relation \\
# \midrule
#    majority\_vote &  cont\_rate\_total\_1.5 &      1.00 &         0.97 &  0.33 &        0.52 &        0.97 &        0.97 \\
#    majority\_vote &  cont\_rate\_total\_0.5 &      1.00 &         0.97 &  0.35 &        0.56 &        0.97 &        0.97 \\
#    majority\_vote &  cont\_rate\_batch\_0.5 &      1.00 &         0.97 &  0.36 &        0.60 &        0.97 &        0.97 \\
#    majority\_vote &    cont\_rate\_total\_1 &      1.00 &         0.97 &  0.34 &        0.54 &        0.97 &        0.97 \\
#    majority\_vote &     cont\_rate\_pair\_1 &      0.92 &         0.94 &  0.36 &        0.60 &        0.95 &        0.93 \\
#    majority\_vote &   cont\_rate\_pair\_0.5 &      0.92 &         0.90 &  0.37 &        0.60 &        0.91 &        0.90 \\
# ...

# %% [markdown]
# # Evaluate individual workers
