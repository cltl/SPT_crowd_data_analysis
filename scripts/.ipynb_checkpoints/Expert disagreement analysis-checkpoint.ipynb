# %%
from load_data import load_expert_data
from utils_analysis import sort_by_key
import pandas as pd
import csv



def get_overview_table(expert_data):
    row_dicts = []
    data_by_triple = sort_by_key(expert_data, ['relation', 'concept', 'property'])
    #all_workers = data_by_worker.keys()
    #all_workers = set([d['workerid'] for d in expert_data])
    workers_exclude = set(['pia_test1'])
    for t, data in data_by_triple.items():
        triple_dict = dict()
        triple_dict['triple'] = t
        for d in data:
            w = d['workerid']
            if 'answer' in d and w not in workers_exclude:
                a = d['answer']
                expected_disagreements = []
                for k, v in d.items():
                    if k.startswith('disagreement_') and v == 'true':
                        expected_disagreements.append(k)
                triple_dict[f'answer-{w}'] = a
                triple_dict[f'expected_behavior-{w}'] = '-'.join(sorted(expected_disagreements))
                if 'reason' in d:
                    triple_dict[f'reason-{w}'] = d['reason']
                if 'comment' in d:
                    triple_dict[f'comment-{w}'] = d['comment']
        row_dicts.append(triple_dict)
    return row_dicts

def prepare_discussion(expert_rows):
    
    agree_all = []
    agree_label = []
    agree_behavior = []
    disagree = []
    
    for r in expert_rows[:5]:
        answers = [v for k, v in r.items() if k.startswith('answer-')]
        print(answers)
    
    
       
        
        



run = 4
n_q = '*'
batch = '1'
group = 'reason_agreement_expert_inspection4'
expert_data = load_expert_data(run, group, n_q, batch)
expert_rows = get_overview_table(expert_data)

overview_df = pd.DataFrame(expert_rows)
overview_df.to_csv(f'../analyses/expert_annotations/{group}-overview.csv')

#overview_df


name = f'run{run}-group_{group}-batch{batch}.csv'.replace('*', '-all-')


overview_df
# Out:
# run4-group_reason_agreement_expert_inspection4/qu44-s_qu44-batch1.csv
# no summary data
#    answer-antske answer-antske_2 answer-pia_run1 answer-piek  \
# 0            NaN           false           false       false
# 1            NaN           false           false       false
# 2            NaN           false           false       false
# 3            NaN           false           false        true
# 4            NaN           false           false       false
# 5            NaN           false           false       false
# 6            NaN           false           false       false
# 7            NaN            true            true       false
# 8            NaN            true            true       false
# 9            NaN           false           false       false
# 10           NaN            true            true       false
# 11           NaN           false           false       false
# 12           NaN           false           false       false
# 13           NaN           false           false       false
# 14           NaN           false           false       false
# 15           NaN           false           false       false
# 16           NaN             NaN           false       false
# 17           NaN           false           false        true
# 18          true            true           false        true
# 19           NaN           false            true       false
# 20           NaN           false           false       false
# 21           NaN           false            true        true
# 22           NaN           false           false       false
# 23           NaN           false            true       false
# 24           NaN           false            true        true
# 25           NaN           false           false       false
# 26           NaN           false           false       false
# 27           NaN           false           false       false
# 28           NaN            true           false       false
# 29           NaN           false           false       false
# 30           NaN           false           false       false
# 31           NaN           false           false       false
# 32           NaN           false           false       false
# 33           NaN           false           false        true
# 34           NaN           false           false        true
# 35           NaN            true            true        true
# 36           NaN           false           false       false
# 37           NaN           false           false       false
# 38           NaN           false            true       false
# 39           NaN           false           false       false
# 40         false           false           false       false
# 41           NaN            true           false       false
# 42           NaN            true           false       false
# 43           NaN           false           false       false
#
#                                      comment-pia_run1  \
# 0                                                 NaN
# 1   "Acaridae are a type of mites and most mites a...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  "stock (stock market) and stock (live stock) c...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  "Cruiser can mean car or boat/ship. I went wit...
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
#
#                                          comment-piek  \
# 0   "If I say this I mean it literally but they ar...
# 1                  "Does not follow from the category
# 2                                                 NaN
# 3   "They are mildly dangerous as they cause aller...
# 4           "They cannot help that we have allergies.
# 5   "Being dangerous is scalar and vague so I disa...
# 6      "This does not vary. It is either true or not.
# 7   "They can cause allergies but people may not k...
# 8   "not clear if people see allergies as dangerou...
# 9                               "they cause allergies
# 10  "If I say it I mean it literally but still we ...
# 11  "Only true for stock of birds and mostly they ...
# 12                                                NaN
# 13  "only birds as stock fly but as stock you do n...
# 14       "even stock as birds are not kept for flying
# 15        "even if birds they are not kept for flying
# 16  "multiple meanings and odd question even for t...
# 17  "stock is a group animals, if they are birds t...
# 18    "stock of birds is kept but they could fly away
# 19  "stock of birds (goose, chicken with their win...
# 20                                                NaN
# 21                                                NaN
# 22  "Cruiser is too specific and other things come...
# 23                     "other wheel things come first
# 24                                                NaN
# 25    "always wheels as a hyponym of wheeled vehicles
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                         "I would mean it literally
# 31  "They can be grey and black and there is no ca...
# 32                                                NaN
# 33                                                NaN
# 34                         "Dark colour protects them
# 35                                                NaN
# 36                "black and grey (perhaps an albino)
# 37                           "grey or black is common
# 38                                     "black or grey
# 39                                                NaN
# 40                                                NaN
# 41  "They can be made of various materials but als...
# 42  "Usually plastic or metal but it is not so unu...
# 43                            "although a bit unusual
#
#                          expected_behavior-antske  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18  disagreement_odd_pair-disagreement_odd_triple
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# 30                                            NaN
# 31                                            NaN
# 32                                            NaN
# 33                                            NaN
# 34                                            NaN
# 35                                            NaN
# 36                                            NaN
# 37                                            NaN
# 38                                            NaN
# 39                                            NaN
# 40                         disagreement_agreement
# 41                                            NaN
# 42                                            NaN
# 43                                            NaN
#
#                            expected_behavior-antske_2  \
# 0                            disagreement_imagination
# 1                              disagreement_agreement
# 2                              disagreement_agreement
# 3                              disagreement_agreement
# 4                              disagreement_agreement
# 5                              disagreement_agreement
# 6                              disagreement_agreement
# 7                  disagreement_specialized_knowledge
# 8                  disagreement_specialized_knowledge
# 9                  disagreement_specialized_knowledge
# 10                           disagreement_imagination
# 11  disagreement_ambiguous_concept-disagreement_od...
# 12  disagreement_agreement-disagreement_ambiguous_...
# 13  disagreement_agreement-disagreement_ambiguous_...
# 14  disagreement_agreement-disagreement_ambiguous_...
# 15       disagreement_agreement-disagreement_odd_pair
# 16                                                NaN
# 17  disagreement_ambiguous_concept-disagreement_od...
# 18                              disagreement_odd_pair
# 19  disagreement_ambiguous_concept-disagreement_od...
# 20  disagreement_agreement-disagreement_ambiguous_...
# 21  disagreement_ambiguous_concept-disagreement_am...
# 22  disagreement_agreement-disagreement_ambiguous_...
# 23  disagreement_agreement-disagreement_ambiguous_...
# 24                    disagreement_ambiguous_property
# 25  disagreement_agreement-disagreement_ambiguous_...
# 26  disagreement_ambiguous_concept-disagreement_am...
# 27  disagreement_ambiguous_concept-disagreement_am...
# 28  disagreement_agreement-disagreement_ambiguous_...
# 29  disagreement_ambiguous_concept-disagreement_am...
# 30                                 disagreement_vague
# 31                             disagreement_agreement
# 32          disagreement_agreement-disagreement_vague
# 33                                 disagreement_vague
# 34                             disagreement_agreement
# 35                                 disagreement_vague
# 36                             disagreement_agreement
# 37          disagreement_agreement-disagreement_vague
# 38        disagreement_imagination-disagreement_vague
# 39                                 disagreement_vague
# 40                             disagreement_agreement
# 41                             disagreement_agreement
# 42
# 43                             disagreement_agreement
#
#                            expected_behavior-pia_run1  \
# 0                  disagreement_specialized_knowledge
# 1   disagreement_agreement-disagreement_specialize...
# 2                              disagreement_agreement
# 3                  disagreement_specialized_knowledge
# 4                  disagreement_specialized_knowledge
# 5                  disagreement_specialized_knowledge
# 6                  disagreement_specialized_knowledge
# 7                  disagreement_specialized_knowledge
# 8                  disagreement_specialized_knowledge
# 9                  disagreement_specialized_knowledge
# 10  disagreement_ambiguous_concept-disagreement_im...
# 11  disagreement_ambiguous_concept-disagreement_od...
# 12  disagreement_ambiguous_concept-disagreement_od...
# 13  disagreement_ambiguous_concept-disagreement_od...
# 14  disagreement_ambiguous_concept-disagreement_od...
# 15  disagreement_ambiguous_concept-disagreement_od...
# 16  disagreement_ambiguous_concept-disagreement_od...
# 17  disagreement_ambiguous_concept-disagreement_od...
# 18  disagreement_ambiguous_concept-disagreement_od...
# 19  disagreement_ambiguous_concept-disagreement_od...
# 20  disagreement_ambiguous_concept-disagreement_im...
# 21                     disagreement_ambiguous_concept
# 22                             disagreement_agreement
# 23                     disagreement_ambiguous_concept
# 24                     disagreement_ambiguous_concept
# 25                     disagreement_ambiguous_concept
# 26                     disagreement_ambiguous_concept
# 27                     disagreement_ambiguous_concept
# 28                     disagreement_ambiguous_concept
# 29  disagreement_ambiguous_concept-disagreement_im...
# 30    disagreement_agreement-disagreement_imagination
# 31                             disagreement_agreement
# 32                             disagreement_agreement
# 33                             disagreement_agreement
# 34                             disagreement_agreement
# 35  disagreement_specialized_knowledge-disagreemen...
# 36                             disagreement_agreement
# 37  disagreement_specialized_knowledge-disagreemen...
# 38                             disagreement_agreement
# 39                             disagreement_agreement
# 40                             disagreement_agreement
# 41                             disagreement_agreement
# 42                             disagreement_agreement
# 43                             disagreement_agreement
#
#                                expected_behavior-piek  \
# 0                              disagreement_agreement
# 1                      disagreement_conceptualization
# 2                              disagreement_agreement
# 3                                  disagreement_vague
# 4                  disagreement_specialized_knowledge
# 5   disagreement_conceptualization-disagreement_sp...
# 6                  disagreement_specialized_knowledge
# 7   disagreement_conceptualization-disagreement_sp...
# 8   disagreement_specialized_knowledge-disagreemen...
# 9                  disagreement_specialized_knowledge
# 10                     disagreement_conceptualization
# 11                     disagreement_conceptualization
# 12                             disagreement_agreement
# 13  disagreement_conceptualization-disagreement_vague
# 14  disagreement_conceptualization-disagreement_vague
# 15                                 disagreement_vague
# 16  disagreement_ambiguous_property-disagreement_o...
# 17                            disagreement_odd_triple
# 18                     disagreement_conceptualization
# 19                     disagreement_conceptualization
# 20                             disagreement_agreement
# 21                             disagreement_agreement
# 22                             disagreement_agreement
# 23                             disagreement_agreement
# 24                             disagreement_agreement
# 25                             disagreement_agreement
# 26                             disagreement_agreement
# 27                             disagreement_agreement
# 28                             disagreement_agreement
# 29                             disagreement_agreement
# 30                             disagreement_agreement
# 31                     disagreement_conceptualization
# 32                             disagreement_agreement
# 33                             disagreement_agreement
# 34                             disagreement_agreement
# 35                             disagreement_agreement
# 36                             disagreement_agreement
# 37                             disagreement_agreement
# 38                             disagreement_agreement
# 39                             disagreement_agreement
# 40                             disagreement_agreement
# 41                             disagreement_agreement
# 42                            disagreement_odd_triple
# 43                             disagreement_agreement
#
#                              reason-antske  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18  "depends on what the stock consists of
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN
# 30                                     NaN
# 31                                     NaN
# 32                                     NaN
# 33                                     NaN
# 34                                     NaN
# 35                                     NaN
# 36                                     NaN
# 37                                     NaN
# 38                                     NaN
# 39                                     NaN
# 40                                     NaN
# 41                                     NaN
# 42                                     NaN
# 43                                     NaN
#
#                                       reason-antske_2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                           "flying over the counter
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19             "depends on what the stock consists of
# 20                                                NaN
# 21                    "steering wheel or other wheel?
# 22                                                NaN
# 23                                                NaN
# 24                                    "steering wheel
# 25         "wheels (plural) does seem to disambiguate
# 26                                                NaN
# 27          "other form: just rare or extremely rare?
# 28                                                NaN
# 29                                                NaN
# 30  "One could imagine someone seeing the fact tha...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                      "high unusual or just unusual
# 43                                                NaN
#
#                                     triple
# 0              creative-acaridae-dangerous
# 1      implied_category-acaridae-dangerous
# 2   typical_of_property-acaridae-dangerous
# 3    typical_of_concept-acaridae-dangerous
# 4    affording_activity-acaridae-dangerous
# 5   variability_limited-acaridae-dangerous
# 6      variability_open-acaridae-dangerous
# 7                  rare-acaridae-dangerous
# 8               unusual-acaridae-dangerous
# 9            impossible-acaridae-dangerous
# 10                      creative-stock-fly
# 11              implied_category-stock-fly
# 12           typical_of_property-stock-fly
# 13            typical_of_concept-stock-fly
# 14              afforded_unusual-stock-fly
# 15                afforded_usual-stock-fly
# 16           variability_limited-stock-fly
# 17                          rare-stock-fly
# 18                       unusual-stock-fly
# 19                    impossible-stock-fly
# 20                 creative-cruiser-wheels
# 21         implied_category-cruiser-wheels
# 22      typical_of_property-cruiser-wheels
# 23       typical_of_concept-cruiser-wheels
# 24       affording_activity-cruiser-wheels
# 25      variability_limited-cruiser-wheels
# 26         variability_open-cruiser-wheels
# 27                     rare-cruiser-wheels
# 28                  unusual-cruiser-wheels
# 29               impossible-cruiser-wheels
# 30                    creative-rhino-black
# 31            implied_category-rhino-black
# 32         typical_of_property-rhino-black
# 33          typical_of_concept-rhino-black
# 34          affording_activity-rhino-black
# 35         variability_limited-rhino-black
# 36            variability_open-rhino-black
# 37                        rare-rhino-black
# 38                     unusual-rhino-black
# 39                  impossible-rhino-black
# 40               creative-pen-made_of_wood
# 41                   rare-pen-made_of_wood
# 42                unusual-pen-made_of_wood
# 43             impossible-pen-made_of_wood
