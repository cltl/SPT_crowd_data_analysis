# %% [markdown]
# # Evaluation of different crowd analysis metrics
#
#
# (1) Dataset filtering:
#
# * Exclude workers based on:
#     - contradiction ration (absolut thresh, batch stdv, pair stdv, total stdv)
#     - worker quality score (thresholds)
#     - attention check fails
#
# (2) Label aggregation:
#
# * Majority vote
# * Top vote
# * CT unit-label score (tresholds)

# %%
from clean_annotations import clean_workers
from load_data import load_experiment_data, load_expert_data, load_gold_data
from aggregation import aggregate_binary_labels

from load_data import load_experiment_data
from calculate_iaa import get_agreement
from utils_analysis import sort_by_key
from utils_analysis import load_analysis, load_ct

from sklearn.metrics import precision_recall_fscore_support as p_r_f1
from collections import defaultdict


def iaa_dis_agreement(data_dict_list, expert_unit_agreement_dict):
    
    data_by_agreement = defaultdict(list)
    data_by_triple = sort_by_key(data_dict_list, ['relation', 'property', 'concept'])
    
    for t, gold_expect in expert_unit_agreement_dict.items():
        data = data_by_triple[t]
        data_by_agreement[gold_expect].extend(data)
        
    for exp, data in data_by_agreement.items():
        agreement = get_agreement(data, v=False)
        print(exp, agreement['Krippendorff'])
        

def get_expert_agreement_labels(expert_annotations):
    expert_annotations_by_unit = sort_by_key(expert_annotations, ['relation',
                                                              'property', 'concept'])
    unit_agreement_dict = dict()
    for unit, data in expert_annotations_by_unit.items():
        agreements = []
        for d in data:
            w = d['workerid']
            if not w.endswith('_test1'):
                for k in d.keys():
                    #print(k)
                    if k.startswith('disagreement_'):
                        agreements.append(k)
        n_agreement_annotations = len(agreements)
        n_agree = agreements.count('disagreement_agreement')
        prop_agreement = n_agree/n_agreement_annotations

        if prop_agreement == 1.0:
            unit_agreement_dict[unit] = 'agreement'
        elif 'disagreement_agreement' in agreements:
            unit_agreement_dict[unit] = 'possible_disagreement'
        else:
            unit_agreement_dict[unit] = 'disagreement'
    return unit_agreement_dict




def get_gold_dis_agreement(gold, agreement_labels):
    
    gold_agree = defaultdict(list)
    
    for d in gold:
        t = f"{d['relation']}-{d['property']}-{d['concept']}"
        label = agreement_labels[t]
        gold_agree[label].append(d)
    return gold_agree

# %% [markdown]
# # Total evaluation

# %%
from load_data import load_experiment_data, load_gold_data
from evaluation import evaluate_configs

import pandas as pd

# %%
# load gold
group = 'reason_agreement*_expert_inspection*'
run = 4
gold = load_gold_data(run, group)
for d in gold:
    if 'answer' not in d:
        print(d)
print('number of gold instances: ', len(gold))

# load crowd:
run = '*'
group = 'experiment*'
n_q = '*'
batch = '*'
crowd = load_experiment_data(run, group, n_q, batch)
# Out:
# number of gold instances:  154
# Discarded 655.0 annotations.

# %%
overview_dicts = evaluate_configs(gold, crowd)
df =  pd.DataFrame(overview_dicts) 
df = df.sort_values(by=['relations-f1'], ascending=False)[['filtering',
                                                           'aggregation',
                                                            'relations-f1',
                                                            'relations-p',
                                                           'relations-r',
                                                           'alpha', 'coverage']]
df.round(2).to_csv('../analyses/evaluation_accuracy_full.csv')
df
# Out:
# ----Label distribution----
# True: 30
# False 124
# ----------------------------
# 154 17917 1743
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# clean all contradictory annotations
#                             filtering    aggregation  relations-f1  \
# 28           batch-contradictions-0.5  majority_vote      0.829942
# 52           total-contradictions-1.5  majority_vote      0.821906
# 48             total-contradictions-1  majority_vote      0.821906
# 36           batch-contradictions-1.5  majority_vote      0.813515
# 44           total-contradictions-0.5  majority_vote      0.813407
# 32             batch-contradictions-1  majority_vote      0.812352
# 16              pair-contradictions-1  majority_vote      0.804241
# 56             total-contradictions-2  majority_vote      0.793501
# 2                                none        uqs-0.5      0.789453
# 5                                none       uqs-0.65      0.788171
# 20            pair-contradictions-1.5  majority_vote      0.788139
# 3                                none       uqs-0.55      0.786678
# 12            pair-contradictions-0.5  majority_vote      0.786519
# 40             batch-contradictions-2  majority_vote      0.785202
# 45           total-contradictions-0.5       top_vote      0.784329
# 4                                none        uqs-0.6      0.784310
# 24              pair-contradictions-2  majority_vote      0.782780
# 37           batch-contradictions-1.5       top_vote      0.781356
# 41             batch-contradictions-2       top_vote      0.781356
# 50                     total-ct_wqs-1  majority_vote      0.777422
# 46                   total-ct_wqs-0.5  majority_vote      0.777422
# 34                     batch-ct_wqs-1  majority_vote      0.777422
# 38                   batch-ct_wqs-1.5  majority_vote      0.777422
# 30                   batch-ct_wqs-0.5  majority_vote      0.777422
# 26                      pair-ct_wqs-2  majority_vote      0.777422
# 0                                none  majority_vote      0.777422
# 42                     batch-ct_wqs-2  majority_vote      0.777422
# 60  exclude_contradictory_annotations  majority_vote      0.777422
# 22                    pair-ct_wqs-1.5  majority_vote      0.777422
# 18                      pair-ct_wqs-1  majority_vote      0.777422
# ..                                ...            ...           ...
# 58                     total-ct_wqs-2  majority_vote      0.777422
# 33             batch-contradictions-1       top_vote      0.776747
# 53           total-contradictions-1.5       top_vote      0.776297
# 49             total-contradictions-1       top_vote      0.776297
# 57             total-contradictions-2       top_vote      0.773088
# 13            pair-contradictions-0.5       top_vote      0.768105
# 6                                none        uqs-0.7      0.766212
# 51                     total-ct_wqs-1       top_vote      0.763138
# 59                     total-ct_wqs-2       top_vote      0.763138
# 47                   total-ct_wqs-0.5       top_vote      0.763138
# 55                   total-ct_wqs-1.5       top_vote      0.763138
# 31                   batch-ct_wqs-0.5       top_vote      0.763138
# 43                     batch-ct_wqs-2       top_vote      0.763138
# 27                      pair-ct_wqs-2       top_vote      0.763138
# 15                    pair-ct_wqs-0.5       top_vote      0.763138
# 39                   batch-ct_wqs-1.5       top_vote      0.763138
# 23                    pair-ct_wqs-1.5       top_vote      0.763138
# 19                      pair-ct_wqs-1       top_vote      0.763138
# 1                                none       top_vote      0.763138
# 35                     batch-ct_wqs-1       top_vote      0.763138
# 61  exclude_contradictory_annotations       top_vote      0.763138
# 29           batch-contradictions-0.5       top_vote      0.761223
# 25              pair-contradictions-2       top_vote      0.760838
# 21            pair-contradictions-1.5       top_vote      0.760838
# 17              pair-contradictions-1       top_vote      0.760838
# 8                                none        uqs-0.8      0.759221
# 7                                none       uqs-0.75      0.756111
# 10                               none        uqs-0.9      0.740523
# 9                                none       uqs-0.85      0.740523
# 11                               none          uqs-1      0.718303
#
#     relations-p  relations-r     alpha  coverage
# 28     0.855785     0.818182  0.197202       1.0
# 52     0.840843     0.811688  0.199057       1.0
# 48     0.840843     0.811688  0.208858       1.0
# 36     0.847849     0.798701  0.195085       1.0
# 44     0.826243     0.805195  0.226988       1.0
# 32     0.841336     0.798701  0.189528       1.0
# 16     0.826067     0.792208  0.196745       1.0
# 56     0.820543     0.779221  0.196364       1.0
# 2      0.824509     0.772727  0.183774       1.0
# 5      0.781579     0.798701  0.183774       1.0
# 20     0.817904     0.772727  0.189510       1.0
# 3      0.811477     0.772727  0.183774       1.0
# 12     0.796243     0.779221  0.208847       1.0
# 40     0.828971     0.766234  0.190307       1.0
# 45     0.783015     0.785714  0.226988       1.0
# 4      0.790489     0.779221  0.183774       1.0
# 24     0.815338     0.766234  0.189027       1.0
# 37     0.777653     0.785714  0.195085       1.0
# 41     0.777653     0.785714  0.190307       1.0
# 50     0.812839     0.759740  0.183774       1.0
# 46     0.812839     0.759740  0.183774       1.0
# 34     0.812839     0.759740  0.183774       1.0
# 38     0.812839     0.759740  0.183774       1.0
# 30     0.812839     0.759740  0.183774       1.0
# 26     0.812839     0.759740  0.183774       1.0
# 0      0.812839     0.759740  0.183774       1.0
# 42     0.812839     0.759740  0.183774       1.0
# 60     0.812839     0.759740  0.361085       1.0
# 22     0.812839     0.759740  0.183774       1.0
# 18     0.812839     0.759740  0.183774       1.0
# ..          ...          ...       ...       ...
# 58     0.812839     0.759740  0.183774       1.0
# 33     0.781367     0.772727  0.189528       1.0
# 53     0.773655     0.779221  0.199057       1.0
# 49     0.773655     0.779221  0.208858       1.0
# 57     0.768091     0.779221  0.196364       1.0
# 13     0.764098     0.772727  0.208847       1.0
# 6      0.756001     0.785714  0.183774       1.0
# 51     0.760307     0.766234  0.183774       1.0
# 59     0.760307     0.766234  0.183774       1.0
# 47     0.760307     0.766234  0.183774       1.0
# 55     0.760307     0.766234  0.183774       1.0
# 31     0.760307     0.766234  0.183774       1.0
# 43     0.760307     0.766234  0.183774       1.0
# 27     0.760307     0.766234  0.183774       1.0
# 15     0.760307     0.766234  0.183774       1.0
# 39     0.760307     0.766234  0.183774       1.0
# 23     0.760307     0.766234  0.183774       1.0
# 19     0.760307     0.766234  0.183774       1.0
# 1      0.760307     0.766234  0.183774       1.0
# 35     0.760307     0.766234  0.183774       1.0
# 61     0.760307     0.766234  0.361085       1.0
# 29     0.762770     0.759740  0.197202       1.0
# 25     0.752346     0.772727  0.189027       1.0
# 21     0.752346     0.772727  0.189510       1.0
# 17     0.752346     0.772727  0.196745       1.0
# 8      0.752974     0.798701  0.183774       1.0
# 7      0.744090     0.785714  0.183774       1.0
# 10     0.729341     0.792208  0.183774       1.0
# 9      0.729341     0.792208  0.183774       1.0
# 11     0.648339     0.805195  0.183774       1.0
#
# [62 rows x 7 columns]

# %%
print(df.round(2).to_latex(index=False))
# Out:
# \begin{tabular}{llrrrrr}
# \toprule
#                          filtering &    aggregation &  relations-f1 &  relations-p &  relations-r &  alpha &  coverage \\
# \midrule
#           batch-contradictions-0.5 &  majority\_vote &          0.83 &         0.86 &         0.82 &   0.20 &       1.0 \\
#           total-contradictions-1.5 &  majority\_vote &          0.82 &         0.84 &         0.81 &   0.20 &       1.0 \\
#             total-contradictions-1 &  majority\_vote &          0.82 &         0.84 &         0.81 &   0.21 &       1.0 \\
#           batch-contradictions-1.5 &  majority\_vote &          0.81 &         0.85 &         0.80 &   0.20 &       1.0 \\
#           total-contradictions-0.5 &  majority\_vote &          0.81 &         0.83 &         0.81 &   0.23 &       1.0 \\
#             batch-contradictions-1 &  majority\_vote &          0.81 &         0.84 &         0.80 &   0.19 &       1.0 \\
#              pair-contradictions-1 &  majority\_vote &          0.80 &         0.83 &         0.79 &   0.20 &       1.0 \\
#             total-contradictions-2 &  majority\_vote &          0.79 &         0.82 &         0.78 &   0.20 &       1.0 \\
#                               none &        uqs-0.5 &          0.79 &         0.82 &         0.77 &   0.18 &       1.0 \\
#                               none &       uqs-0.65 &          0.79 &         0.78 &         0.80 &   0.18 &       1.0 \\
#            pair-contradictions-1.5 &  majority\_vote &          0.79 &         0.82 &         0.77 &   0.19 &       1.0 \\
#                               none &       uqs-0.55 &          0.79 &         0.81 &         0.77 &   0.18 &       1.0 \\
#            pair-contradictions-0.5 &  majority\_vote &          0.79 &         0.80 &         0.78 &   0.21 &       1.0 \\
#             batch-contradictions-2 &  majority\_vote &          0.79 &         0.83 &         0.77 &   0.19 &       1.0 \\
#           total-contradictions-0.5 &       top\_vote &          0.78 &         0.78 &         0.79 &   0.23 &       1.0 \\
#                               none &        uqs-0.6 &          0.78 &         0.79 &         0.78 &   0.18 &       1.0 \\
#              pair-contradictions-2 &  majority\_vote &          0.78 &         0.82 &         0.77 &   0.19 &       1.0 \\
#           batch-contradictions-1.5 &       top\_vote &          0.78 &         0.78 &         0.79 &   0.20 &       1.0 \\
#             batch-contradictions-2 &       top\_vote &          0.78 &         0.78 &         0.79 &   0.19 &       1.0 \\
#                     total-ct\_wqs-1 &  majority\_vote &          0.78 &         0.81 &         0.76 &   0.18 &       1.0 \\
#                   total-ct\_wqs-0.5 &  majority\_vote &          0.78 &         0.81 &         0.76 &   0.18 &       1.0 \\
#                     batch-ct\_wqs-1 &  majority\_vote &          0.78 &         0.81 &         0.76 &   0.18 &       1.0 \\
#                   batch-ct\_wqs-1.5 &  majority\_vote &          0.78 &         0.81 &         0.76 &   0.18 &       1.0 \\
#                   batch-ct\_wqs-0.5 &  majority\_vote &          0.78 &         0.81 &         0.76 &   0.18 &       1.0 \\
#                      pair-ct\_wqs-2 &  majority\_vote &          0.78 &         0.81 &         0.76 &   0.18 &       1.0 \\
#                               none &  majority\_vote &          0.78 &         0.81 &         0.76 &   0.18 &       1.0 \\
#                     batch-ct\_wqs-2 &  majority\_vote &          0.78 &         0.81 &         0.76 &   0.18 &       1.0 \\
#  exclude\_contradictory\_annotations &  majority\_vote &          0.78 &         0.81 &         0.76 &   0.36 &       1.0 \\
#                    pair-ct\_wqs-1.5 &  majority\_vote &          0.78 &         0.81 &         0.76 &   0.18 &       1.0 \\
#                      pair-ct\_wqs-1 &  majority\_vote &          0.78 &         0.81 &         0.76 &   0.18 &       1.0 \\
#                   total-ct\_wqs-1.5 &  majority\_vote &          0.78 &         0.81 &         0.76 &   0.18 &       1.0 \\
#                    pair-ct\_wqs-0.5 &  majority\_vote &          0.78 &         0.81 &         0.76 &   0.18 &       1.0 \\
#                     total-ct\_wqs-2 &  majority\_vote &          0.78 &         0.81 &         0.76 &   0.18 &       1.0 \\
#             batch-contradictions-1 &       top\_vote &          0.78 &         0.78 &         0.77 &   0.19 &       1.0 \\
#           total-contradictions-1.5 &       top\_vote &          0.78 &         0.77 &         0.78 &   0.20 &       1.0 \\
#             total-contradictions-1 &       top\_vote &          0.78 &         0.77 &         0.78 &   0.21 &       1.0 \\
#             total-contradictions-2 &       top\_vote &          0.77 &         0.77 &         0.78 &   0.20 &       1.0 \\
#            pair-contradictions-0.5 &       top\_vote &          0.77 &         0.76 &         0.77 &   0.21 &       1.0 \\
#                               none &        uqs-0.7 &          0.77 &         0.76 &         0.79 &   0.18 &       1.0 \\
#                     total-ct\_wqs-1 &       top\_vote &          0.76 &         0.76 &         0.77 &   0.18 &       1.0 \\
#                     total-ct\_wqs-2 &       top\_vote &          0.76 &         0.76 &         0.77 &   0.18 &       1.0 \\
#                   total-ct\_wqs-0.5 &       top\_vote &          0.76 &         0.76 &         0.77 &   0.18 &       1.0 \\
#                   total-ct\_wqs-1.5 &       top\_vote &          0.76 &         0.76 &         0.77 &   0.18 &       1.0 \\
#                   batch-ct\_wqs-0.5 &       top\_vote &          0.76 &         0.76 &         0.77 &   0.18 &       1.0 \\
#                     batch-ct\_wqs-2 &       top\_vote &          0.76 &         0.76 &         0.77 &   0.18 &       1.0 \\
#                      pair-ct\_wqs-2 &       top\_vote &          0.76 &         0.76 &         0.77 &   0.18 &       1.0 \\
#                    pair-ct\_wqs-0.5 &       top\_vote &          0.76 &         0.76 &         0.77 &   0.18 &       1.0 \\
#                   batch-ct\_wqs-1.5 &       top\_vote &          0.76 &         0.76 &         0.77 &   0.18 &       1.0 \\
#                    pair-ct\_wqs-1.5 &       top\_vote &          0.76 &         0.76 &         0.77 &   0.18 &       1.0 \\
#                      pair-ct\_wqs-1 &       top\_vote &          0.76 &         0.76 &         0.77 &   0.18 &       1.0 \\
#                               none &       top\_vote &          0.76 &         0.76 &         0.77 &   0.18 &       1.0 \\
#                     batch-ct\_wqs-1 &       top\_vote &          0.76 &         0.76 &         0.77 &   0.18 &       1.0 \\
#  exclude\_contradictory\_annotations &       top\_vote &          0.76 &         0.76 &         0.77 &   0.36 &       1.0 \\
#           batch-contradictions-0.5 &       top\_vote &          0.76 &         0.76 &         0.76 &   0.20 &       1.0 \\
#              pair-contradictions-2 &       top\_vote &          0.76 &         0.75 &         0.77 &   0.19 &       1.0 \\
#            pair-contradictions-1.5 &       top\_vote &          0.76 &         0.75 &         0.77 &   0.19 &       1.0 \\
#              pair-contradictions-1 &       top\_vote &          0.76 &         0.75 &         0.77 &   0.20 &       1.0 \\
#                               none &        uqs-0.8 &          0.76 &         0.75 &         0.80 &   0.18 &       1.0 \\
#                               none &       uqs-0.75 &          0.76 &         0.74 &         0.79 &   0.18 &       1.0 \\
#                               none &        uqs-0.9 &          0.74 &         0.73 &         0.79 &   0.18 &       1.0 \\
#                               none &       uqs-0.85 &          0.74 &         0.73 &         0.79 &   0.18 &       1.0 \\
#                               none &          uqs-1 &          0.72 &         0.65 &         0.81 &   0.18 &       1.0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
#  # Evaluation with respect to expected worker behavior

# %%
from utils_analysis import sort_by_key

# get agreement data

run = "4"
#group1 = 'reason_agreement_expert_inspection1'
group = 'reason_agreement*_expert_inspection*'
batch = '*'
n_q = '*'

#run4-group_reason_agreement_expert_inspection1
#expert_annotations = load_expert_data(run, group, n_q, batch)
#expert_annotations2 = load_expert_data(run, group2, n_q, batch)
#expert_annotations = expert_annotations1 + expert_annotations2
#expert_unit_agreement_dict = get_expert_agreement_labels(expert_annotations)
#agreement_labels = get_expert_agreement_labels(expert_annotations)

gold_by_agreement = sort_by_key(gold, ['expected_agreement'])
print('\n--- agreement categories---')
for l, data in gold_by_agreement.items():
    print(l, len(data))
# Out:
# --- agreement categories---
# possible_disagreement 86
# disagreement 9
# agreement 59

# %%
# evaluate agree category:
gold_agree = gold_by_agreement['agreement']
gold_poss_disagree = gold_by_agreement['possible_disagreement']
gold_disagree = gold_by_agreement['disagreement']
print(len(gold_agree))
print(len(gold_poss_disagree))
print(len(gold_disagree))
# Out:
# 59
# 86
# 9

# %%
# agree

overview_dicts_total = evaluate_configs(gold_agree, crowd)
for d in overview_dicts_total:
    d['exp. behavior'] = 'agreement'
    
gold_disagree_all = []
gold_disagree_all.extend(gold_poss_disagree)
gold_disagree_all.extend(gold_disagree)
#gold_poss_disagree + gold_disagree

overview_dicts = evaluate_configs(gold_disagree_all, crowd)
for d in overview_dicts:
    d['exp. behavior'] = 'possible disagreement'
    overview_dicts_total.append(d)
df =  pd.DataFrame(overview_dicts_total) 
df = df.sort_values(by=['relations-f1'], ascending=False)[['exp. behavior', 'filtering',
                                                           'aggregation',
                                                           'relations-f1',
                                                            'relations-p',
                                                           'relations-r',
                                                             'alpha',
                                                           'coverage']]
df.round(2).to_csv('../analyses/evaluation_accuracy_agree.csv')
df
# Out:
# ----Label distribution----
# True: 7
# False 52
# ----------------------------
# 59 17917 714
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# clean all contradictory annotations
# ----Label distribution----
# True: 23
# False 72
# ----------------------------
# 95 17917 1029
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# clean all contradictory annotations
#              exp. behavior                          filtering    aggregation  \
# 5                agreement                               none       uqs-0.65
# 6                agreement                               none        uqs-0.7
# 7                agreement                               none       uqs-0.75
# 8                agreement                               none        uqs-0.8
# 44               agreement           total-contradictions-0.5  majority_vote
# 12               agreement            pair-contradictions-0.5  majority_vote
# 48               agreement             total-contradictions-1  majority_vote
# 52               agreement           total-contradictions-1.5  majority_vote
# 4                agreement                               none        uqs-0.6
# 28               agreement           batch-contradictions-0.5  majority_vote
# 10               agreement                               none        uqs-0.9
# 9                agreement                               none       uqs-0.85
# 36               agreement           batch-contradictions-1.5  majority_vote
# 16               agreement              pair-contradictions-1  majority_vote
# 3                agreement                               none       uqs-0.55
# 24               agreement              pair-contradictions-2  majority_vote
# 2                agreement                               none        uqs-0.5
# 20               agreement            pair-contradictions-1.5  majority_vote
# 32               agreement             batch-contradictions-1  majority_vote
# 42               agreement                     batch-ct_wqs-2  majority_vote
# 38               agreement                   batch-ct_wqs-1.5  majority_vote
# 40               agreement             batch-contradictions-2  majority_vote
# 0                agreement                               none  majority_vote
# 46               agreement                   total-ct_wqs-0.5  majority_vote
# 50               agreement                     total-ct_wqs-1  majority_vote
# 30               agreement                   batch-ct_wqs-0.5  majority_vote
# 58               agreement                     total-ct_wqs-2  majority_vote
# 60               agreement  exclude_contradictory_annotations  majority_vote
# 54               agreement                   total-ct_wqs-1.5  majority_vote
# 34               agreement                     batch-ct_wqs-1  majority_vote
# ..                     ...                                ...            ...
# 99   possible disagreement           batch-contradictions-1.5       top_vote
# 103  possible disagreement             batch-contradictions-2       top_vote
# 87   possible disagreement              pair-contradictions-2       top_vote
# 83   possible disagreement            pair-contradictions-1.5       top_vote
# 109  possible disagreement                   total-ct_wqs-0.5       top_vote
# 113  possible disagreement                     total-ct_wqs-1       top_vote
# 117  possible disagreement                   total-ct_wqs-1.5       top_vote
# 105  possible disagreement                     batch-ct_wqs-2       top_vote
# 121  possible disagreement                     total-ct_wqs-2       top_vote
# 97   possible disagreement                     batch-ct_wqs-1       top_vote
# 123  possible disagreement  exclude_contradictory_annotations       top_vote
# 101  possible disagreement                   batch-ct_wqs-1.5       top_vote
# 89   possible disagreement                      pair-ct_wqs-2       top_vote
# 77   possible disagreement                    pair-ct_wqs-0.5       top_vote
# 63   possible disagreement                               none       top_vote
# 85   possible disagreement                    pair-ct_wqs-1.5       top_vote
# 81   possible disagreement                      pair-ct_wqs-1       top_vote
# 93   possible disagreement                   batch-ct_wqs-0.5       top_vote
# 66   possible disagreement                               none        uqs-0.6
# 75   possible disagreement            pair-contradictions-0.5       top_vote
# 74   possible disagreement            pair-contradictions-0.5  majority_vote
# 91   possible disagreement           batch-contradictions-0.5       top_vote
# 95   possible disagreement             batch-contradictions-1       top_vote
# 67   possible disagreement                               none       uqs-0.65
# 68   possible disagreement                               none        uqs-0.7
# 69   possible disagreement                               none       uqs-0.75
# 71   possible disagreement                               none       uqs-0.85
# 72   possible disagreement                               none        uqs-0.9
# 70   possible disagreement                               none        uqs-0.8
# 73   possible disagreement                               none          uqs-1
#
#      relations-f1  relations-p  relations-r     alpha  coverage
# 5        0.907571     0.927709     0.898305  0.253746       1.0
# 6        0.903664     0.912015     0.898305  0.253746       1.0
# 7        0.898305     0.898305     0.898305  0.253746       1.0
# 8        0.898305     0.898305     0.898305  0.253746       1.0
# 44       0.896849     0.940678     0.881356  0.342014       1.0
# 12       0.896849     0.940678     0.881356  0.323356       1.0
# 48       0.896849     0.940678     0.881356  0.302838       1.0
# 52       0.883410     0.936723     0.864407  0.291210       1.0
# 4        0.883410     0.936723     0.864407  0.253746       1.0
# 28       0.870077     0.933263     0.847458  0.302973       1.0
# 10       0.866840     0.860555     0.881356  0.253746       1.0
# 9        0.866840     0.860555     0.881356  0.253746       1.0
# 36       0.856804     0.930209     0.830508  0.272882       1.0
# 16       0.856804     0.930209     0.830508  0.287787       1.0
# 3        0.843550     0.927495     0.813559  0.253746       1.0
# 24       0.843550     0.927495     0.813559  0.269930       1.0
# 2        0.843550     0.927495     0.813559  0.253746       1.0
# 20       0.843550     0.927495     0.813559  0.275389       1.0
# 32       0.841205     0.905351     0.813559  0.281476       1.0
# 42       0.830282     0.925067     0.796610  0.253746       1.0
# 38       0.830282     0.925067     0.796610  0.253746       1.0
# 40       0.830282     0.925067     0.796610  0.267163       1.0
# 0        0.830282     0.925067     0.796610  0.253746       1.0
# 46       0.830282     0.925067     0.796610  0.253746       1.0
# 50       0.830282     0.925067     0.796610  0.253746       1.0
# 30       0.830282     0.925067     0.796610  0.253746       1.0
# 58       0.830282     0.925067     0.796610  0.253746       1.0
# 60       0.830282     0.925067     0.796610  0.361322       1.0
# 54       0.830282     0.925067     0.796610  0.253746       1.0
# 34       0.830282     0.925067     0.796610  0.253746       1.0
# ..            ...          ...          ...       ...       ...
# 99       0.726316     0.726316     0.726316  0.141405       1.0
# 103      0.726316     0.726316     0.726316  0.136848       1.0
# 87       0.721970     0.718269     0.726316  0.134231       1.0
# 83       0.721970     0.718269     0.726316  0.131840       1.0
# 109      0.721466     0.728516     0.715789  0.136073       1.0
# 113      0.721466     0.728516     0.715789  0.136073       1.0
# 117      0.721466     0.728516     0.715789  0.136073       1.0
# 105      0.721466     0.728516     0.715789  0.136073       1.0
# 121      0.721466     0.728516     0.715789  0.136073       1.0
# 97       0.721466     0.728516     0.715789  0.136073       1.0
# 123      0.721466     0.728516     0.715789  0.292349       1.0
# 101      0.721466     0.728516     0.715789  0.136073       1.0
# 89       0.721466     0.728516     0.715789  0.136073       1.0
# 77       0.721466     0.728516     0.715789  0.136073       1.0
# 63       0.721466     0.728516     0.715789  0.136073       1.0
# 85       0.721466     0.728516     0.715789  0.136073       1.0
# 81       0.721466     0.728516     0.715789  0.136073       1.0
# 93       0.721466     0.728516     0.715789  0.136073       1.0
# 66       0.716982     0.710249     0.726316  0.136073       1.0
# 75       0.713612     0.711588     0.715789  0.135236       1.0
# 74       0.713612     0.711588     0.715789  0.135236       1.0
# 91       0.707097     0.726478     0.694737  0.126860       1.0
# 95       0.707097     0.726478     0.694737  0.126006       1.0
# 67       0.704827     0.694409     0.736842  0.136073       1.0
# 68       0.671575     0.652198     0.715789  0.136073       1.0
# 69       0.660435     0.635481     0.715789  0.136073       1.0
# 71       0.659587     0.635194     0.736842  0.136073       1.0
# 72       0.659587     0.635194     0.736842  0.136073       1.0
# 70       0.659587     0.635194     0.736842  0.136073       1.0
# 73       0.653514     0.574404     0.757895  0.136073       1.0
#
# [124 rows x 8 columns]

# %%
print(df.round(2).to_latex(index=False))
# Out:
# \begin{tabular}{lllrrrrr}
# \toprule
#          exp. behavior &                          filtering &    aggregation &  relations-f1 &  relations-p &  relations-r &  alpha &  coverage \\
# \midrule
#              agreement &                               none &       uqs-0.65 &          0.91 &         0.93 &         0.90 &   0.25 &       1.0 \\
#              agreement &                               none &        uqs-0.7 &          0.90 &         0.91 &         0.90 &   0.25 &       1.0 \\
#              agreement &                               none &       uqs-0.75 &          0.90 &         0.90 &         0.90 &   0.25 &       1.0 \\
#              agreement &                               none &        uqs-0.8 &          0.90 &         0.90 &         0.90 &   0.25 &       1.0 \\
#              agreement &           total-contradictions-0.5 &  majority\_vote &          0.90 &         0.94 &         0.88 &   0.34 &       1.0 \\
#              agreement &            pair-contradictions-0.5 &  majority\_vote &          0.90 &         0.94 &         0.88 &   0.32 &       1.0 \\
#              agreement &             total-contradictions-1 &  majority\_vote &          0.90 &         0.94 &         0.88 &   0.30 &       1.0 \\
#              agreement &           total-contradictions-1.5 &  majority\_vote &          0.88 &         0.94 &         0.86 &   0.29 &       1.0 \\
#              agreement &                               none &        uqs-0.6 &          0.88 &         0.94 &         0.86 &   0.25 &       1.0 \\
#              agreement &           batch-contradictions-0.5 &  majority\_vote &          0.87 &         0.93 &         0.85 &   0.30 &       1.0 \\
#              agreement &                               none &        uqs-0.9 &          0.87 &         0.86 &         0.88 &   0.25 &       1.0 \\
#              agreement &                               none &       uqs-0.85 &          0.87 &         0.86 &         0.88 &   0.25 &       1.0 \\
#              agreement &           batch-contradictions-1.5 &  majority\_vote &          0.86 &         0.93 &         0.83 &   0.27 &       1.0 \\
#              agreement &              pair-contradictions-1 &  majority\_vote &          0.86 &         0.93 &         0.83 &   0.29 &       1.0 \\
#              agreement &                               none &       uqs-0.55 &          0.84 &         0.93 &         0.81 &   0.25 &       1.0 \\
#              agreement &              pair-contradictions-2 &  majority\_vote &          0.84 &         0.93 &         0.81 &   0.27 &       1.0 \\
#              agreement &                               none &        uqs-0.5 &          0.84 &         0.93 &         0.81 &   0.25 &       1.0 \\
#              agreement &            pair-contradictions-1.5 &  majority\_vote &          0.84 &         0.93 &         0.81 &   0.28 &       1.0 \\
#              agreement &             batch-contradictions-1 &  majority\_vote &          0.84 &         0.91 &         0.81 &   0.28 &       1.0 \\
#              agreement &                     batch-ct\_wqs-2 &  majority\_vote &          0.83 &         0.93 &         0.80 &   0.25 &       1.0 \\
#              agreement &                   batch-ct\_wqs-1.5 &  majority\_vote &          0.83 &         0.93 &         0.80 &   0.25 &       1.0 \\
#              agreement &             batch-contradictions-2 &  majority\_vote &          0.83 &         0.93 &         0.80 &   0.27 &       1.0 \\
#              agreement &                               none &  majority\_vote &          0.83 &         0.93 &         0.80 &   0.25 &       1.0 \\
#              agreement &                   total-ct\_wqs-0.5 &  majority\_vote &          0.83 &         0.93 &         0.80 &   0.25 &       1.0 \\
#              agreement &                     total-ct\_wqs-1 &  majority\_vote &          0.83 &         0.93 &         0.80 &   0.25 &       1.0 \\
#              agreement &                   batch-ct\_wqs-0.5 &  majority\_vote &          0.83 &         0.93 &         0.80 &   0.25 &       1.0 \\
#              agreement &                     total-ct\_wqs-2 &  majority\_vote &          0.83 &         0.93 &         0.80 &   0.25 &       1.0 \\
#              agreement &  exclude\_contradictory\_annotations &  majority\_vote &          0.83 &         0.93 &         0.80 &   0.36 &       1.0 \\
#              agreement &                   total-ct\_wqs-1.5 &  majority\_vote &          0.83 &         0.93 &         0.80 &   0.25 &       1.0 \\
#              agreement &                     batch-ct\_wqs-1 &  majority\_vote &          0.83 &         0.93 &         0.80 &   0.25 &       1.0 \\
#              agreement &                      pair-ct\_wqs-2 &  majority\_vote &          0.83 &         0.93 &         0.80 &   0.25 &       1.0 \\
#              agreement &                    pair-ct\_wqs-0.5 &  majority\_vote &          0.83 &         0.93 &         0.80 &   0.25 &       1.0 \\
#              agreement &                    pair-ct\_wqs-1.5 &  majority\_vote &          0.83 &         0.93 &         0.80 &   0.25 &       1.0 \\
#              agreement &                      pair-ct\_wqs-1 &  majority\_vote &          0.83 &         0.93 &         0.80 &   0.25 &       1.0 \\
#              agreement &             total-contradictions-2 &  majority\_vote &          0.83 &         0.90 &         0.80 &   0.28 &       1.0 \\
#              agreement &                               none &          uqs-1 &          0.83 &         0.78 &         0.88 &   0.25 &       1.0 \\
#  possible disagreement &           batch-contradictions-0.5 &  majority\_vote &          0.81 &         0.82 &         0.80 &   0.13 &       1.0 \\
#  possible disagreement &             batch-contradictions-1 &  majority\_vote &          0.80 &         0.81 &         0.79 &   0.13 &       1.0 \\
#  possible disagreement &           batch-contradictions-1.5 &  majority\_vote &          0.79 &         0.81 &         0.78 &   0.14 &       1.0 \\
#              agreement &           total-contradictions-0.5 &       top\_vote &          0.78 &         0.85 &         0.75 &   0.34 &       1.0 \\
#  possible disagreement &           total-contradictions-1.5 &  majority\_vote &          0.78 &         0.79 &         0.78 &   0.14 &       1.0 \\
#  possible disagreement &             total-contradictions-2 &  majority\_vote &          0.77 &         0.78 &         0.77 &   0.14 &       1.0 \\
#  possible disagreement &             total-contradictions-1 &  majority\_vote &          0.77 &         0.78 &         0.77 &   0.15 &       1.0 \\
#  possible disagreement &              pair-contradictions-1 &  majority\_vote &          0.77 &         0.78 &         0.77 &   0.14 &       1.0 \\
#              agreement &             total-contradictions-2 &       top\_vote &          0.77 &         0.82 &         0.73 &   0.28 &       1.0 \\
#              agreement &           total-contradictions-1.5 &       top\_vote &          0.77 &         0.82 &         0.73 &   0.29 &       1.0 \\
#              agreement &             total-contradictions-1 &       top\_vote &          0.77 &         0.82 &         0.73 &   0.30 &       1.0 \\
#              agreement &             batch-contradictions-1 &       top\_vote &          0.77 &         0.82 &         0.73 &   0.28 &       1.0 \\
#  possible disagreement &           total-contradictions-0.5 &  majority\_vote &          0.76 &         0.76 &         0.76 &   0.15 &       1.0 \\
#  possible disagreement &             batch-contradictions-2 &  majority\_vote &          0.76 &         0.78 &         0.75 &   0.14 &       1.0 \\
#  possible disagreement &                               none &        uqs-0.5 &          0.76 &         0.77 &         0.75 &   0.14 &       1.0 \\
#              agreement &           batch-contradictions-0.5 &       top\_vote &          0.75 &         0.82 &         0.71 &   0.30 &       1.0 \\
#  possible disagreement &            pair-contradictions-1.5 &  majority\_vote &          0.75 &         0.76 &         0.75 &   0.13 &       1.0 \\
#  possible disagreement &                               none &       uqs-0.55 &          0.75 &         0.76 &         0.75 &   0.14 &       1.0 \\
#              agreement &            pair-contradictions-0.5 &       top\_vote &          0.75 &         0.86 &         0.69 &   0.32 &       1.0 \\
#  possible disagreement &                   batch-ct\_wqs-0.5 &  majority\_vote &          0.75 &         0.76 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &                     batch-ct\_wqs-2 &  majority\_vote &          0.75 &         0.76 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &                     total-ct\_wqs-1 &  majority\_vote &          0.75 &         0.76 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &                   total-ct\_wqs-1.5 &  majority\_vote &          0.75 &         0.76 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &                    pair-ct\_wqs-0.5 &  majority\_vote &          0.75 &         0.76 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &  exclude\_contradictory\_annotations &  majority\_vote &          0.75 &         0.76 &         0.74 &   0.29 &       1.0 \\
#  possible disagreement &                      pair-ct\_wqs-2 &  majority\_vote &          0.75 &         0.76 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &              pair-contradictions-2 &  majority\_vote &          0.75 &         0.76 &         0.74 &   0.13 &       1.0 \\
#  possible disagreement &                    pair-ct\_wqs-1.5 &  majority\_vote &          0.75 &         0.76 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &                   batch-ct\_wqs-1.5 &  majority\_vote &          0.75 &         0.76 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &                     total-ct\_wqs-2 &  majority\_vote &          0.75 &         0.76 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &                   total-ct\_wqs-0.5 &  majority\_vote &          0.75 &         0.76 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &                      pair-ct\_wqs-1 &  majority\_vote &          0.75 &         0.76 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &                     batch-ct\_wqs-1 &  majority\_vote &          0.75 &         0.76 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &                               none &  majority\_vote &          0.75 &         0.76 &         0.74 &   0.14 &       1.0 \\
#              agreement &                     batch-ct\_wqs-2 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.25 &       1.0 \\
#              agreement &                   total-ct\_wqs-1.5 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.25 &       1.0 \\
#              agreement &                     total-ct\_wqs-2 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.25 &       1.0 \\
#              agreement &                      pair-ct\_wqs-2 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.25 &       1.0 \\
#              agreement &  exclude\_contradictory\_annotations &       top\_vote &          0.74 &         0.82 &         0.69 &   0.36 &       1.0 \\
#              agreement &           batch-contradictions-1.5 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.27 &       1.0 \\
#              agreement &                               none &       top\_vote &          0.74 &         0.82 &         0.69 &   0.25 &       1.0 \\
#              agreement &              pair-contradictions-2 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.27 &       1.0 \\
#              agreement &                   total-ct\_wqs-0.5 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.25 &       1.0 \\
#              agreement &                   batch-ct\_wqs-0.5 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.25 &       1.0 \\
#              agreement &                    pair-ct\_wqs-1.5 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.25 &       1.0 \\
#              agreement &            pair-contradictions-1.5 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.28 &       1.0 \\
#              agreement &             batch-contradictions-2 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.27 &       1.0 \\
#              agreement &                      pair-ct\_wqs-1 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.25 &       1.0 \\
#              agreement &                     total-ct\_wqs-1 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.25 &       1.0 \\
#              agreement &              pair-contradictions-1 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.29 &       1.0 \\
#              agreement &                   batch-ct\_wqs-1.5 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.25 &       1.0 \\
#              agreement &                    pair-ct\_wqs-0.5 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.25 &       1.0 \\
#              agreement &                     batch-ct\_wqs-1 &       top\_vote &          0.74 &         0.82 &         0.69 &   0.25 &       1.0 \\
#  possible disagreement &           total-contradictions-1.5 &       top\_vote &          0.74 &         0.75 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &             total-contradictions-1 &       top\_vote &          0.74 &         0.75 &         0.74 &   0.15 &       1.0 \\
#  possible disagreement &              pair-contradictions-1 &       top\_vote &          0.73 &         0.73 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &           total-contradictions-0.5 &       top\_vote &          0.73 &         0.73 &         0.73 &   0.15 &       1.0 \\
#  possible disagreement &             total-contradictions-2 &       top\_vote &          0.73 &         0.73 &         0.73 &   0.14 &       1.0 \\
#  possible disagreement &           batch-contradictions-1.5 &       top\_vote &          0.73 &         0.73 &         0.73 &   0.14 &       1.0 \\
#  possible disagreement &             batch-contradictions-2 &       top\_vote &          0.73 &         0.73 &         0.73 &   0.14 &       1.0 \\
#  possible disagreement &              pair-contradictions-2 &       top\_vote &          0.72 &         0.72 &         0.73 &   0.13 &       1.0 \\
#  possible disagreement &            pair-contradictions-1.5 &       top\_vote &          0.72 &         0.72 &         0.73 &   0.13 &       1.0 \\
#  possible disagreement &                   total-ct\_wqs-0.5 &       top\_vote &          0.72 &         0.73 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &                     total-ct\_wqs-1 &       top\_vote &          0.72 &         0.73 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &                   total-ct\_wqs-1.5 &       top\_vote &          0.72 &         0.73 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &                     batch-ct\_wqs-2 &       top\_vote &          0.72 &         0.73 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &                     total-ct\_wqs-2 &       top\_vote &          0.72 &         0.73 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &                     batch-ct\_wqs-1 &       top\_vote &          0.72 &         0.73 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &  exclude\_contradictory\_annotations &       top\_vote &          0.72 &         0.73 &         0.72 &   0.29 &       1.0 \\
#  possible disagreement &                   batch-ct\_wqs-1.5 &       top\_vote &          0.72 &         0.73 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &                      pair-ct\_wqs-2 &       top\_vote &          0.72 &         0.73 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &                    pair-ct\_wqs-0.5 &       top\_vote &          0.72 &         0.73 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &                               none &       top\_vote &          0.72 &         0.73 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &                    pair-ct\_wqs-1.5 &       top\_vote &          0.72 &         0.73 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &                      pair-ct\_wqs-1 &       top\_vote &          0.72 &         0.73 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &                   batch-ct\_wqs-0.5 &       top\_vote &          0.72 &         0.73 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &                               none &        uqs-0.6 &          0.72 &         0.71 &         0.73 &   0.14 &       1.0 \\
#  possible disagreement &            pair-contradictions-0.5 &       top\_vote &          0.71 &         0.71 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &            pair-contradictions-0.5 &  majority\_vote &          0.71 &         0.71 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &           batch-contradictions-0.5 &       top\_vote &          0.71 &         0.73 &         0.69 &   0.13 &       1.0 \\
#  possible disagreement &             batch-contradictions-1 &       top\_vote &          0.71 &         0.73 &         0.69 &   0.13 &       1.0 \\
#  possible disagreement &                               none &       uqs-0.65 &          0.70 &         0.69 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &                               none &        uqs-0.7 &          0.67 &         0.65 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &                               none &       uqs-0.75 &          0.66 &         0.64 &         0.72 &   0.14 &       1.0 \\
#  possible disagreement &                               none &       uqs-0.85 &          0.66 &         0.64 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &                               none &        uqs-0.9 &          0.66 &         0.64 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &                               none &        uqs-0.8 &          0.66 &         0.64 &         0.74 &   0.14 &       1.0 \\
#  possible disagreement &                               none &          uqs-1 &          0.65 &         0.57 &         0.76 &   0.14 &       1.0 \\
# \bottomrule
# \end{tabular}

# %%
#print(df.to_latex(index=False))

# possible disagreement 



overview_dicts = evaluate_configs(gold_poss_disagree, crowd)
df =  pd.DataFrame(overview_dicts) 
df = df.sort_values(by=['relations-f1'], ascending=False)[['filtering',
                                                           'aggregation',
                                                      'relations-f1',
                                                      'levels-f1', 
                                                        'negative_relations-f1', 'alpha',
                                                           'coverage']]
df.round(2).to_csv('../analyses/evaluation_accuracy_poss_disagree.csv')
df
# Out:
# ----Label distribution----
# True: 15
# False 71
# ----------------------------
# 86 17917 926
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# clean all contradictory annotations
#                             filtering    aggregation  relations-f1  levels-f1  \
# 28           batch-contradictions-0.5  majority_vote      0.827984   0.712569
# 32             batch-contradictions-1  majority_vote      0.806482   0.690999
# 52           total-contradictions-1.5  majority_vote      0.803523   0.689535
# 16              pair-contradictions-1  majority_vote      0.803523   0.689535
# 56             total-contradictions-2  majority_vote      0.794241   0.668349
# 48             total-contradictions-1  majority_vote      0.794241   0.668349
# 44           total-contradictions-0.5  majority_vote      0.790819   0.665935
# 17              pair-contradictions-1       top_vote      0.786728   0.645183
# 45           total-contradictions-0.5       top_vote      0.784980   0.668349
# 57             total-contradictions-2       top_vote      0.784980   0.668349
# 53           total-contradictions-1.5       top_vote      0.784980   0.668349
# 36           batch-contradictions-1.5  majority_vote      0.784980   0.668349
# 49             total-contradictions-1       top_vote      0.784980   0.668349
# 21            pair-contradictions-1.5       top_vote      0.777751   0.645183
# 25              pair-contradictions-2       top_vote      0.777751   0.645183
# 3                                none       uqs-0.55      0.777751   0.661674
# 43                     batch-ct_wqs-2       top_vote      0.775727   0.668349
# 27                      pair-ct_wqs-2       top_vote      0.775727   0.668349
# 47                   total-ct_wqs-0.5       top_vote      0.775727   0.668349
# 39                   batch-ct_wqs-1.5       top_vote      0.775727   0.668349
# 51                     total-ct_wqs-1       top_vote      0.775727   0.668349
# 35                     batch-ct_wqs-1       top_vote      0.775727   0.668349
# 55                   total-ct_wqs-1.5       top_vote      0.775727   0.668349
# 1                                none       top_vote      0.775727   0.668349
# 59                     total-ct_wqs-2       top_vote      0.775727   0.668349
# 31                   batch-ct_wqs-0.5       top_vote      0.775727   0.668349
# 61  exclude_contradictory_annotations       top_vote      0.775727   0.668349
# 15                    pair-ct_wqs-0.5       top_vote      0.775727   0.668349
# 23                    pair-ct_wqs-1.5       top_vote      0.775727   0.668349
# 19                      pair-ct_wqs-1       top_vote      0.775727   0.668349
# ..                                ...            ...           ...        ...
# 37           batch-contradictions-1.5       top_vote      0.768800   0.645183
# 13            pair-contradictions-0.5       top_vote      0.768800   0.624129
# 41             batch-contradictions-2       top_vote      0.768800   0.645183
# 40             batch-contradictions-2  majority_vote      0.766473   0.646856
# 26                      pair-ct_wqs-2  majority_vote      0.763478   0.645183
# 60  exclude_contradictory_annotations  majority_vote      0.763478   0.645183
# 58                     total-ct_wqs-2  majority_vote      0.763478   0.645183
# 54                   total-ct_wqs-1.5  majority_vote      0.763478   0.645183
# 50                     total-ct_wqs-1  majority_vote      0.763478   0.645183
# 46                   total-ct_wqs-0.5  majority_vote      0.763478   0.645183
# 24              pair-contradictions-2  majority_vote      0.763478   0.645183
# 14                    pair-ct_wqs-0.5  majority_vote      0.763478   0.645183
# 42                     batch-ct_wqs-2  majority_vote      0.763478   0.645183
# 34                     batch-ct_wqs-1  majority_vote      0.763478   0.645183
# 30                   batch-ct_wqs-0.5  majority_vote      0.763478   0.645183
# 22                    pair-ct_wqs-1.5  majority_vote      0.763478   0.645183
# 18                      pair-ct_wqs-1  majority_vote      0.763478   0.645183
# 0                                none  majority_vote      0.763478   0.645183
# 38                   batch-ct_wqs-1.5  majority_vote      0.763478   0.645183
# 29           batch-contradictions-0.5       top_vote      0.747917   0.602704
# 11                               none          uqs-1      0.746704   0.604023
# 5                                none       uqs-0.65      0.743086   0.601973
# 12            pair-contradictions-0.5  majority_vote      0.741829   0.616564
# 7                                none       uqs-0.75      0.731360   0.582307
# 33             batch-contradictions-1       top_vote      0.729238   0.579923
# 10                               none        uqs-0.9      0.729085   0.568621
# 9                                none       uqs-0.85      0.729085   0.568621
# 8                                none        uqs-0.8      0.729085   0.568621
# 4                                none        uqs-0.6      0.728882   0.581395
# 6                                none        uqs-0.7      0.724391   0.567383
#
#     negative_relations-f1     alpha  coverage
# 28               0.796961  0.097433       1.0
# 32               0.769889  0.099448       1.0
# 52               0.766422  0.121144       1.0
# 16               0.766422  0.119505       1.0
# 56               0.754623  0.122368       1.0
# 48               0.754623  0.127916       1.0
# 44               0.750513  0.135779       1.0
# 17               0.750513  0.119505       1.0
# 45               0.757886  0.135779       1.0
# 57               0.757886  0.122368       1.0
# 53               0.757886  0.121144       1.0
# 36               0.742817  0.117966       1.0
# 49               0.757886  0.127916       1.0
# 21               0.738942  0.113296       1.0
# 25               0.738942  0.115952       1.0
# 3                0.734101  0.119937       1.0
# 43               0.745859  0.119937       1.0
# 27               0.745859  0.119937       1.0
# 47               0.745859  0.119937       1.0
# 39               0.745859  0.119937       1.0
# 51               0.745859  0.119937       1.0
# 35               0.745859  0.119937       1.0
# 55               0.745859  0.119937       1.0
# 1                0.745859  0.119937       1.0
# 59               0.745859  0.119937       1.0
# 31               0.745859  0.119937       1.0
# 61               0.745859  0.252311       1.0
# 15               0.745859  0.119937       1.0
# 23               0.745859  0.119937       1.0
# 19               0.745859  0.119937       1.0
# ..                    ...       ...       ...
# 37               0.727359  0.117966       1.0
# 13               0.727359  0.119989       1.0
# 41               0.727359  0.118045       1.0
# 40               0.719107  0.118045       1.0
# 26               0.715745  0.119937       1.0
# 60               0.715745  0.252311       1.0
# 58               0.715745  0.119937       1.0
# 54               0.715745  0.119937       1.0
# 50               0.715745  0.119937       1.0
# 46               0.715745  0.119937       1.0
# 24               0.715745  0.115952       1.0
# 14               0.715745  0.119937       1.0
# 42               0.715745  0.119937       1.0
# 34               0.715745  0.119937       1.0
# 30               0.715745  0.119937       1.0
# 22               0.715745  0.119937       1.0
# 18               0.715745  0.119937       1.0
# 0                0.715745  0.119937       1.0
# 38               0.715745  0.119937       1.0
# 29               0.733791  0.097433       1.0
# 11               0.707106  0.119937       1.0
# 5                0.700693  0.119937       1.0
# 12               0.706112  0.119989       1.0
# 7                0.686981  0.119937       1.0
# 33               0.709465  0.099448       1.0
# 10               0.685112  0.119937       1.0
# 9                0.685112  0.119937       1.0
# 8                0.685112  0.119937       1.0
# 4                0.691387  0.119937       1.0
# 6                0.678115  0.119937       1.0
#
# [62 rows x 7 columns]

# %%
# possible disagreement 

gold_disagree_all = []
gold_disagree_all.extend(gold_poss_disagree)
gold_disagree_all.extend(gold_disagree)
#gold_poss_disagree + gold_disagree

overview_dicts = evaluate_configs(gold_disagree_all, crowd)
df =  pd.DataFrame(overview_dicts) 
df = df.sort_values(by=['relations-f1'], ascending=False)[['filtering',
                                                           'aggregation',
                                                      'relations-f1',
                                                      'levels-f1', 
                                                        'negative_relations-f1', 'alpha',
                                                           'coverage']]
df.round(2).to_csv('../analyses/evaluation_accuracy_poss_disagree.csv')
df
# Out:
# ----Label distribution----
# True: 23
# False 72
# ----------------------------
# 95 17917 1029
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# clean all contradictory annotations
#                             filtering    aggregation  relations-f1  levels-f1  \
# 28           batch-contradictions-0.5  majority_vote      0.806207   0.760542
# 32             batch-contradictions-1  majority_vote      0.797043   0.739001
# 36           batch-contradictions-1.5  majority_vote      0.787898   0.717004
# 52           total-contradictions-1.5  majority_vote      0.783363   0.738272
# 48             total-contradictions-1  majority_vote      0.774376   0.717004
# 56             total-contradictions-2  majority_vote      0.774376   0.717004
# 16              pair-contradictions-1  majority_vote      0.771615   0.738272
# 44           total-contradictions-0.5  majority_vote      0.759624   0.715613
# 40             batch-contradictions-2  majority_vote      0.758652   0.695502
# 2                                none        uqs-0.5      0.756451   0.739001
# 20            pair-contradictions-1.5  majority_vote      0.753865   0.717004
# 3                                none       uqs-0.55      0.750852   0.759365
# 26                      pair-ct_wqs-2  majority_vote      0.745009   0.717004
# 24              pair-contradictions-2  majority_vote      0.745009   0.717004
# 42                     batch-ct_wqs-2  majority_vote      0.745009   0.717004
# 38                   batch-ct_wqs-1.5  majority_vote      0.745009   0.717004
# 34                     batch-ct_wqs-1  majority_vote      0.745009   0.717004
# 60  exclude_contradictory_annotations  majority_vote      0.745009   0.717004
# 30                   batch-ct_wqs-0.5  majority_vote      0.745009   0.717004
# 46                   total-ct_wqs-0.5  majority_vote      0.745009   0.717004
# 58                     total-ct_wqs-2  majority_vote      0.745009   0.717004
# 54                   total-ct_wqs-1.5  majority_vote      0.745009   0.717004
# 0                                none  majority_vote      0.745009   0.717004
# 14                    pair-ct_wqs-0.5  majority_vote      0.745009   0.717004
# 50                     total-ct_wqs-1  majority_vote      0.745009   0.717004
# 22                    pair-ct_wqs-1.5  majority_vote      0.745009   0.717004
# 18                      pair-ct_wqs-1  majority_vote      0.745009   0.717004
# 53           total-contradictions-1.5       top_vote      0.742098   0.651029
# 49             total-contradictions-1       top_vote      0.742098   0.651029
# 17              pair-contradictions-1       top_vote      0.730347   0.628110
# ..                                ...            ...           ...        ...
# 41             batch-contradictions-2       top_vote      0.726316   0.651029
# 37           batch-contradictions-1.5       top_vote      0.726316   0.651029
# 21            pair-contradictions-1.5       top_vote      0.721970   0.628110
# 25              pair-contradictions-2       top_vote      0.721970   0.628110
# 47                   total-ct_wqs-0.5       top_vote      0.721466   0.651029
# 55                   total-ct_wqs-1.5       top_vote      0.721466   0.651029
# 43                     batch-ct_wqs-2       top_vote      0.721466   0.651029
# 51                     total-ct_wqs-1       top_vote      0.721466   0.651029
# 59                     total-ct_wqs-2       top_vote      0.721466   0.651029
# 31                   batch-ct_wqs-0.5       top_vote      0.721466   0.651029
# 39                   batch-ct_wqs-1.5       top_vote      0.721466   0.651029
# 23                    pair-ct_wqs-1.5       top_vote      0.721466   0.651029
# 35                     batch-ct_wqs-1       top_vote      0.721466   0.651029
# 15                    pair-ct_wqs-0.5       top_vote      0.721466   0.651029
# 19                      pair-ct_wqs-1       top_vote      0.721466   0.651029
# 61  exclude_contradictory_annotations       top_vote      0.721466   0.651029
# 27                      pair-ct_wqs-2       top_vote      0.721466   0.651029
# 1                                none       top_vote      0.721466   0.651029
# 4                                none        uqs-0.6      0.716982   0.688889
# 13            pair-contradictions-0.5       top_vote      0.713612   0.607407
# 12            pair-contradictions-0.5  majority_vote      0.713612   0.668793
# 29           batch-contradictions-0.5       top_vote      0.707097   0.630199
# 33             batch-contradictions-1       top_vote      0.707097   0.630199
# 5                                none       uqs-0.65      0.704827   0.649030
# 6                                none        uqs-0.7      0.671575   0.589675
# 7                                none       uqs-0.75      0.660435   0.573682
# 10                               none        uqs-0.9      0.659587   0.568254
# 9                                none       uqs-0.85      0.659587   0.568254
# 8                                none        uqs-0.8      0.659587   0.568254
# 11                               none          uqs-1      0.653514   0.505105
#
#     negative_relations-f1     alpha  coverage
# 28               0.829820  0.126860       1.0
# 32               0.803639  0.126006       1.0
# 36               0.777457  0.141405       1.0
# 52               0.786892  0.138565       1.0
# 48               0.775002  0.146647       1.0
# 56               0.775002  0.142126       1.0
# 16               0.771998  0.136139       1.0
# 44               0.771998  0.154618       1.0
# 40               0.753466  0.136848       1.0
# 2                0.765466  0.136073       1.0
# 20               0.748532  0.131840       1.0
# 3                0.760254  0.136073       1.0
# 26               0.736817  0.136073       1.0
# 24               0.736817  0.134231       1.0
# 42               0.736817  0.136073       1.0
# 38               0.736817  0.136073       1.0
# 34               0.736817  0.136073       1.0
# 60               0.736817  0.292349       1.0
# 30               0.736817  0.136073       1.0
# 46               0.736817  0.136073       1.0
# 58               0.736817  0.136073       1.0
# 54               0.736817  0.136073       1.0
# 0                0.736817  0.136073       1.0
# 14               0.736817  0.136073       1.0
# 50               0.736817  0.136073       1.0
# 22               0.736817  0.136073       1.0
# 18               0.736817  0.136073       1.0
# 53               0.736817  0.138565       1.0
# 49               0.736817  0.146647       1.0
# 17               0.729730  0.136139       1.0
# ..                    ...       ...       ...
# 41               0.722062  0.136848       1.0
# 37               0.722062  0.141405       1.0
# 21               0.718351  0.131840       1.0
# 25               0.718351  0.134231       1.0
# 47               0.725094  0.136073       1.0
# 55               0.725094  0.136073       1.0
# 43               0.725094  0.136073       1.0
# 51               0.725094  0.136073       1.0
# 59               0.725094  0.136073       1.0
# 31               0.725094  0.136073       1.0
# 39               0.725094  0.136073       1.0
# 23               0.725094  0.136073       1.0
# 35               0.725094  0.136073       1.0
# 15               0.725094  0.136073       1.0
# 19               0.725094  0.136073       1.0
# 61               0.725094  0.292349       1.0
# 27               0.725094  0.136073       1.0
# 1                0.725094  0.136073       1.0
# 4                0.736304  0.136073       1.0
# 13               0.706977  0.135236       1.0
# 12               0.713880  0.135236       1.0
# 29               0.739407  0.126860       1.0
# 33               0.727515  0.126006       1.0
# 5                0.705266  0.136073       1.0
# 6                0.665750  0.136073       1.0
# 7                0.653861  0.136073       1.0
# 10               0.657076  0.136073       1.0
# 9                0.657076  0.136073       1.0
# 8                0.657076  0.136073       1.0
# 11               0.615709  0.136073       1.0
#
# [62 rows x 7 columns]

# %%
#disagree
overview_dicts = evaluate_configs(gold_disagree, crowd)
df =  pd.DataFrame(overview_dicts) 
df = df.sort_values(by=['relations-f1'], ascending=False)[['filtering',
                                                           'aggregation',
                                                      'relations-f1',
                                                      'levels-f1', 
                                                        'negative_relations-f1', 'alpha',
                                                           'coverage']]
df.round(2).to_csv('../analyses/evaluation_accuracy_disagree.csv')
df
# Out:
# ----Label distribution----
# True: 8
# False 1
# ----------------------------
# 9 17917 103
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# clean all contradictory annotations
#                             filtering    aggregation  relations-f1  levels-f1  \
# 36           batch-contradictions-1.5  majority_vote      0.903704   0.891026
# 40             batch-contradictions-2  majority_vote      0.817460   0.891026
# 32             batch-contradictions-1  majority_vote      0.817460   0.891026
# 31                   batch-ct_wqs-0.5       top_vote      0.777778   0.816667
# 27                      pair-ct_wqs-2       top_vote      0.777778   0.816667
# 29           batch-contradictions-0.5       top_vote      0.777778   0.816667
# 1                                none       top_vote      0.777778   0.816667
# 33             batch-contradictions-1       top_vote      0.777778   0.816667
# 35                     batch-ct_wqs-1       top_vote      0.777778   0.816667
# 37           batch-contradictions-1.5       top_vote      0.777778   0.816667
# 39                   batch-ct_wqs-1.5       top_vote      0.777778   0.816667
# 41             batch-contradictions-2       top_vote      0.777778   0.816667
# 23                    pair-ct_wqs-1.5       top_vote      0.777778   0.816667
# 43                     batch-ct_wqs-2       top_vote      0.777778   0.816667
# 45           total-contradictions-0.5       top_vote      0.777778   0.816667
# 47                   total-ct_wqs-0.5       top_vote      0.777778   0.816667
# 49             total-contradictions-1       top_vote      0.777778   0.816667
# 51                     total-ct_wqs-1       top_vote      0.777778   0.816667
# 53           total-contradictions-1.5       top_vote      0.777778   0.816667
# 55                   total-ct_wqs-1.5       top_vote      0.777778   0.816667
# 57             total-contradictions-2       top_vote      0.777778   0.816667
# 59                     total-ct_wqs-2       top_vote      0.777778   0.816667
# 25              pair-contradictions-2       top_vote      0.777778   0.816667
# 61  exclude_contradictory_annotations       top_vote      0.777778   0.816667
# 13            pair-contradictions-0.5       top_vote      0.777778   0.816667
# 21            pair-contradictions-1.5       top_vote      0.777778   0.816667
# 15                    pair-ct_wqs-0.5       top_vote      0.777778   0.816667
# 19                      pair-ct_wqs-1       top_vote      0.777778   0.816667
# 17              pair-contradictions-1       top_vote      0.777778   0.816667
# 24              pair-contradictions-2  majority_vote      0.728205   0.791667
# ..                                ...            ...           ...        ...
# 48             total-contradictions-1  majority_vote      0.728205   0.791667
# 50                     total-ct_wqs-1  majority_vote      0.728205   0.791667
# 54                   total-ct_wqs-1.5  majority_vote      0.728205   0.791667
# 42                     batch-ct_wqs-2  majority_vote      0.728205   0.791667
# 4                                none        uqs-0.6      0.728205   0.791667
# 56             total-contradictions-2  majority_vote      0.728205   0.791667
# 58                     total-ct_wqs-2  majority_vote      0.728205   0.791667
# 60  exclude_contradictory_annotations  majority_vote      0.728205   0.791667
# 22                    pair-ct_wqs-1.5  majority_vote      0.728205   0.791667
# 0                                none  majority_vote      0.728205   0.791667
# 34                     batch-ct_wqs-1  majority_vote      0.728205   0.791667
# 26                      pair-ct_wqs-2  majority_vote      0.728205   0.791667
# 38                   batch-ct_wqs-1.5  majority_vote      0.728205   0.791667
# 14                    pair-ct_wqs-0.5  majority_vote      0.728205   0.791667
# 28           batch-contradictions-0.5  majority_vote      0.728205   0.791667
# 18                      pair-ct_wqs-1  majority_vote      0.728205   0.791667
# 30                   batch-ct_wqs-0.5  majority_vote      0.728205   0.791667
# 20            pair-contradictions-1.5  majority_vote      0.728205   0.791667
# 2                                none        uqs-0.5      0.711111   0.750000
# 3                                none       uqs-0.55      0.634921   0.673077
# 44           total-contradictions-0.5  majority_vote      0.629630   0.686364
# 16              pair-contradictions-1  majority_vote      0.629630   0.686364
# 12            pair-contradictions-0.5  majority_vote      0.629630   0.686364
# 5                                none       uqs-0.65      0.516595   0.566667
# 6                                none        uqs-0.7      0.383333   0.424603
# 10                               none        uqs-0.9      0.222222   0.250000
# 7                                none       uqs-0.75      0.222222   0.250000
# 8                                none        uqs-0.8      0.222222   0.250000
# 9                                none       uqs-0.85      0.222222   0.250000
# 11                               none          uqs-1      0.022222   0.027778
#
#     negative_relations-f1     alpha  coverage
# 36               0.891026  0.237245       1.0
# 40               0.891026  0.217878       1.0
# 32               0.891026  0.254860       1.0
# 31               0.816667  0.224904       1.0
# 27               0.816667  0.224904       1.0
# 29               0.816667  0.286507       1.0
# 1                0.816667  0.224904       1.0
# 33               0.816667  0.254860       1.0
# 35               0.816667  0.224904       1.0
# 37               0.816667  0.237245       1.0
# 39               0.816667  0.224904       1.0
# 41               0.816667  0.217878       1.0
# 23               0.816667  0.224904       1.0
# 43               0.816667  0.224904       1.0
# 45               0.816667  0.236263       1.0
# 47               0.816667  0.224904       1.0
# 49               0.816667  0.229861       1.0
# 51               0.816667  0.224904       1.0
# 53               0.816667  0.216050       1.0
# 55               0.816667  0.224904       1.0
# 57               0.816667  0.225876       1.0
# 59               0.816667  0.224904       1.0
# 25               0.816667  0.230557       1.0
# 61               0.816667  0.300041       1.0
# 13               0.816667  0.200618       1.0
# 21               0.816667  0.224793       1.0
# 15               0.816667  0.224904       1.0
# 19               0.816667  0.224904       1.0
# 17               0.816667  0.219406       1.0
# 24               0.791667  0.230557       1.0
# ..                    ...       ...       ...
# 48               0.791667  0.229861       1.0
# 50               0.791667  0.224904       1.0
# 54               0.791667  0.224904       1.0
# 42               0.791667  0.224904       1.0
# 4                0.791667  0.224904       1.0
# 56               0.791667  0.225876       1.0
# 58               0.791667  0.224904       1.0
# 60               0.791667  0.300041       1.0
# 22               0.791667  0.224904       1.0
# 0                0.791667  0.224904       1.0
# 34               0.791667  0.224904       1.0
# 26               0.791667  0.224904       1.0
# 38               0.791667  0.224904       1.0
# 14               0.791667  0.224904       1.0
# 28               0.791667  0.286507       1.0
# 18               0.791667  0.224904       1.0
# 30               0.791667  0.224904       1.0
# 20               0.791667  0.224793       1.0
# 2                0.750000  0.224904       1.0
# 3                0.673077  0.224904       1.0
# 44               0.686364  0.236263       1.0
# 16               0.686364  0.219406       1.0
# 12               0.686364  0.200618       1.0
# 5                0.566667  0.224904       1.0
# 6                0.424603  0.224904       1.0
# 10               0.250000  0.224904       1.0
# 7                0.250000  0.224904       1.0
# 8                0.250000  0.224904       1.0
# 9                0.250000  0.224904       1.0
# 11               0.027778  0.224904       1.0
#
# [62 rows x 7 columns]
