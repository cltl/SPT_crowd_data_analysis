# %% [markdown]
# # Evaluation of different crowd analysis metrics
#
#
# (1) Dataset filtering:
#
# * Exclude workers based on:
#     - contradiction ration (absolut thresh, batch stdv, pair stdv, total stdv)
#     - worker quality score (thresholds)
#     - attention check fails
#
# (2) Label aggregation:
#
# * Majority vote
# * Top vote
# * CT unit-label score (tresholds)

# %%
from clean_annotations import clean_workers
from load_data import load_experiment_data, load_expert_data, load_gold_data
from aggregation import aggregate_binary_labels

from load_data import load_experiment_data
from calculate_iaa import get_agreement
from utils_analysis import sort_by_key
from utils_analysis import load_analysis, load_ct

from sklearn.metrics import precision_recall_fscore_support as p_r_f1
from collections import defaultdict


def iaa_dis_agreement(data_dict_list, expert_unit_agreement_dict):
    
    data_by_agreement = defaultdict(list)
    data_by_triple = sort_by_key(data_dict_list, ['relation', 'property', 'concept'])
    
    for t, gold_expect in expert_unit_agreement_dict.items():
        data = data_by_triple[t]
        data_by_agreement[gold_expect].extend(data)
        
    for exp, data in data_by_agreement.items():
        agreement = get_agreement(data, v=False)
        print(exp, agreement['Krippendorff'])
        

def get_expert_agreement_labels(expert_annotations):
    expert_annotations_by_unit = sort_by_key(expert_annotations, ['relation',
                                                              'property', 'concept'])
    unit_agreement_dict = dict()
    for unit, data in expert_annotations_by_unit.items():
        agreements = []
        for d in data:
            w = d['workerid']
            if not w.endswith('_test1'):
                for k in d.keys():
                    #print(k)
                    if k.startswith('disagreement_'):
                        agreements.append(k)
        n_agreement_annotations = len(agreements)
        n_agree = agreements.count('disagreement_agreement')
        prop_agreement = n_agree/n_agreement_annotations

        if prop_agreement == 1.0:
            unit_agreement_dict[unit] = 'agreement'
        elif 'disagreement_agreement' in agreements:
            unit_agreement_dict[unit] = 'possible_disagreement'
        else:
            unit_agreement_dict[unit] = 'disagreement'
    return unit_agreement_dict




def get_gold_dis_agreement(gold, agreement_labels):
    
    gold_agree = defaultdict(list)
    
    for d in gold:
        t = f"{d['relation']}-{d['property']}-{d['concept']}"
        label = agreement_labels[t]
        gold_agree[label].append(d)
    return gold_agree

# %% [markdown]
# # Total evaluation

# %%
from load_data import load_experiment_data, load_gold_data
from evaluation import evaluate_configs

import pandas as pd


# load gold
run = 4
group = '*'
n_q = '*'
batch = '*'
gold = load_gold_data(run, group, n_q, batch)
for d in gold:
    if 'answer' not in d:
        print(d)
print('number of gold instances: ', len(gold))

# load crowd:
run = '*'
group = 'experiment*'
n_q = '*'
batch = '*'
crowd = load_experiment_data(run, group, n_q, batch)

overview_dicts = evaluate_configs(gold, crowd)
df =  pd.DataFrame(overview_dicts) 
df = df.sort_values(by=['relations-f1'], ascending=False)[['config',
                                                      'relations-f1',
                                                      'levels-f1', 
                                                        'negative_relations-f1', 'alpha']]
df.round(2).to_csv('../analyses/evaluation_accuracy_full.csv')
df
# Out:
# number of gold instances:  90
# Discarded 655.0 annotations.
# ----Label distribution----
# True: 20
# False 70
# ----------------------------
# 90 17917 1073
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# clean all contradictory annotations
#                                                config  relations-f1  \
# 38        (batch, 0.5, contradictions, majority_vote)      0.874872
# 54        (total, 0.5, contradictions, majority_vote)      0.851107
# 58          (total, 1, contradictions, majority_vote)      0.841359
# 46        (batch, 1.5, contradictions, majority_vote)      0.835391
# 62        (total, 1.5, contradictions, majority_vote)      0.831650
# 22         (pair, 0.5, contradictions, majority_vote)      0.827689
# 5                                        ct_vote_0.65      0.824302
# 42          (batch, 1, contradictions, majority_vote)      0.823428
# 55             (total, 0.5, contradictions, top_vote)      0.818796
# 6                                         ct_vote_0.7      0.814173
# 2                                         ct_vote_0.5      0.813702
# 60              (total, 1, crowdtruth, majority_vote)      0.812308
# 26           (pair, 1, contradictions, majority_vote)      0.810606
# 23              (pair, 0.5, contradictions, top_vote)      0.809359
# 28               (pair, 1, crowdtruth, majority_vote)      0.802655
# 3                                        ct_vote_0.55      0.801025
# 47             (batch, 1.5, contradictions, top_vote)      0.800000
# 51               (batch, 2, contradictions, top_vote)      0.800000
# 43               (batch, 1, contradictions, top_vote)      0.796145
# 50          (batch, 2, contradictions, majority_vote)      0.795187
# 4                                         ct_vote_0.6      0.793942
# 48            (batch, 1.5, crowdtruth, majority_vote)      0.793002
# 52              (batch, 2, crowdtruth, majority_vote)      0.793002
# 30         (pair, 1.5, contradictions, majority_vote)      0.791453
# 66          (total, 2, contradictions, majority_vote)      0.791453
# 7                                        ct_vote_0.75      0.791145
# 8                                         ct_vote_0.8      0.791145
# 63             (total, 1.5, contradictions, top_vote)      0.782545
# 59               (total, 1, contradictions, top_vote)      0.782545
# 39             (batch, 0.5, contradictions, top_vote)      0.782545
# ..                                                ...           ...
# 18                                    top_vote_ct_0.8      0.773495
# 19                                   top_vote_ct_0.85      0.773495
# 20                                    top_vote_ct_0.9      0.773495
# 68              (total, 2, crowdtruth, majority_vote)      0.772302
# 70  (None, None, exclude_contradictory_annotations...      0.772302
# 64            (total, 1.5, crowdtruth, majority_vote)      0.772302
# 0                                       majority_vote      0.772302
# 9                                        ct_vote_0.85      0.763584
# 10                                        ct_vote_0.9      0.763584
# 49                 (batch, 1.5, crowdtruth, top_vote)      0.759655
# 33                  (pair, 1.5, crowdtruth, top_vote)      0.759655
# 69                   (total, 2, crowdtruth, top_vote)      0.759655
# 65                 (total, 1.5, crowdtruth, top_vote)      0.759655
# 27                (pair, 1, contradictions, top_vote)      0.759655
# 29                    (pair, 1, crowdtruth, top_vote)      0.759655
# 61                   (total, 1, crowdtruth, top_vote)      0.759655
# 31              (pair, 1.5, contradictions, top_vote)      0.759655
# 35                (pair, 2, contradictions, top_vote)      0.759655
# 1                                            top_vote      0.759655
# 37                    (pair, 2, crowdtruth, top_vote)      0.759655
# 53                   (batch, 2, crowdtruth, top_vote)      0.759655
# 71  (None, None, exclude_contradictory_annotations...      0.759655
# 45                   (batch, 1, crowdtruth, top_vote)      0.750844
# 57                 (total, 0.5, crowdtruth, top_vote)      0.746642
# 56            (total, 0.5, crowdtruth, majority_vote)      0.704363
# 11                                          ct_vote_1      0.680556
# 25                  (pair, 0.5, crowdtruth, top_vote)      0.680548
# 41                 (batch, 0.5, crowdtruth, top_vote)      0.680548
# 40            (batch, 0.5, crowdtruth, majority_vote)      0.632561
# 24             (pair, 0.5, crowdtruth, majority_vote)      0.603022
#
#     levels-f1  negative_relations-f1     alpha
# 38   0.925088               0.884019  0.190106
# 54   0.899408               0.856002  0.207026
# 58   0.899408               0.856002  0.185277
# 46   0.876306               0.833309  0.173638
# 62   0.875147               0.843644  0.174478
# 22   0.899408               0.840169  0.191624
# 5    0.866011               0.815663  0.149496
# 42   0.876306               0.832473  0.174412
# 55   0.725323               0.780059  0.207026
# 6    0.770940               0.775669  0.149496
# 2    0.900659               0.833309  0.149496
# 60   0.850989               0.793153  0.141628
# 26   0.850989               0.817585  0.170898
# 23   0.725323               0.768379  0.191624
# 28   0.826828               0.780926  0.149068
# 3    0.875147               0.819009  0.149496
# 47   0.777351               0.783784  0.173638
# 51   0.777351               0.783784  0.165746
# 43   0.801319               0.807552  0.174412
# 50   0.876306               0.795711  0.165746
# 4    0.873149               0.813531  0.149496
# 48   0.850989               0.768671  0.145972
# 52   0.850989               0.768671  0.142829
# 30   0.850989               0.793153  0.158369
# 66   0.850989               0.793153  0.167532
# 7    0.716484               0.748263  0.149496
# 8    0.716484               0.748263  0.149496
# 63   0.725323               0.747587  0.174478
# 59   0.725323               0.747587  0.185277
# 39   0.725323               0.764061  0.190106
# ..        ...                    ...       ...
# 18   0.801319               0.780059  0.149496
# 19   0.801319               0.780059  0.149496
# 20   0.801319               0.780059  0.149496
# 68   0.850989               0.768671  0.149496
# 70   0.850989               0.768671  0.262413
# 64   0.850989               0.768671  0.149496
# 0    0.850989               0.768671  0.149496
# 9    0.716484               0.715359  0.149496
# 10   0.716484               0.715359  0.149496
# 49   0.725323               0.736304  0.145972
# 33   0.725323               0.736304  0.144131
# 69   0.725323               0.736304  0.149496
# 65   0.725323               0.736304  0.149496
# 27   0.725323               0.736304  0.170898
# 29   0.725323               0.736304  0.149068
# 61   0.725323               0.736304  0.141628
# 31   0.725323               0.736304  0.158369
# 35   0.725323               0.736304  0.158497
# 1    0.725323               0.736304  0.149496
# 37   0.725323               0.736304  0.149913
# 53   0.725323               0.736304  0.142829
# 71   0.725323               0.736304  0.262413
# 45   0.652308               0.697582  0.137707
# 57   0.652308               0.691527  0.114452
# 56   0.728205               0.668289  0.114452
# 11   0.566434               0.615709  0.149496
# 25   0.555769               0.611056  0.137818
# 41   0.555769               0.611056  0.136478
# 40   0.654682               0.616957  0.136478
# 24   0.629371               0.578900  0.137818
#
# [72 rows x 5 columns]

# %%
#print(df.round(2).to_latex(index=False))

# %% [markdown]
#  # Evaluation with respect to expected worker behavior

# %%
# get agreement data

run = "4"
#group1 = 'reason_agreement_expert_inspection1'
group = 'reason_agreement*_expert_inspection*'
batch = '*'
n_q = '*'

#run4-group_reason_agreement_expert_inspection1
expert_annotations = load_expert_data(run, group, n_q, batch)
#expert_annotations2 = load_expert_data(run, group2, n_q, batch)
#expert_annotations = expert_annotations1 + expert_annotations2
expert_unit_agreement_dict = get_expert_agreement_labels(expert_annotations)
agreement_labels = get_expert_agreement_labels(expert_annotations)
gold_by_agreement = get_gold_dis_agreement(gold, agreement_labels)
print('\n--- agreement categories---')
for l in gold_by_agreement.keys():
    print(l)
# Out:
# run4-group_reason_agreement_expert_inspection2/qu40-s_qu40-batch1.csv
# no summary data
# run4-group_reason_agreement_False_expert_inspection1/qu30-s_qu30-batch1.csv
# no summary data
# run4-group_reason_agreement_expert_inspection3/qu40-s_qu40-batch1.csv
# no summary data
# run4-group_reason_agreement_False_expert_inspection2/qu40-s_qu40-batch1.csv
# no summary data
# run4-group_reason_agreement_expert_inspection1/qu30-s_qu30-batch1.csv
# no summary data
# run4-group_reason_agreement_False_expert_inspection3/qu40-s_qu40-batch1.csv
# no summary data
#
# --- agreement categories---
# agreement
# possible_disagreement
# disagreement

# %%
# evaluate agree category:
gold_agree = gold_by_agreement['agreement']
gold_poss_disagree = gold_by_agreement['possible_disagreement']
gold_disagree = gold_by_agreement['disagreement']
print(len(gold_agree))
print(len(gold_poss_disagree))
print(len(gold_disagree))
# Out:
# 40
# 45
# 5

# %%
# agree

overview_dicts = evaluate_configs(gold_agree, crowd)
df =  pd.DataFrame(overview_dicts) 
df = df.sort_values(by=['relations-f1'], ascending=False)[['config',
                                                      'relations-f1',
                                                      'levels-f1', 
                                                        'negative_relations-f1', 'alpha']]
df.round(2).to_csv('../analyses/evaluation_accuracy_agree.csv')
df
# Out:
# ----Label distribution----
# True: 7
# False 33
# ----------------------------
# 40 17917 513
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# clean all contradictory annotations
#                                                config  relations-f1  \
# 22         (pair, 0.5, contradictions, majority_vote)      0.929832
# 54        (total, 0.5, contradictions, majority_vote)      0.929832
# 58          (total, 1, contradictions, majority_vote)      0.929832
# 6                                         ct_vote_0.7      0.926923
# 8                                         ct_vote_0.8      0.922675
# 7                                        ct_vote_0.75      0.922675
# 62        (total, 1.5, contradictions, majority_vote)      0.907885
# 5                                        ct_vote_0.65      0.904687
# 28               (pair, 1, crowdtruth, majority_vote)      0.886324
# 60              (total, 1, crowdtruth, majority_vote)      0.886324
# 3                                        ct_vote_0.55      0.886324
# 2                                         ct_vote_0.5      0.886324
# 46        (batch, 1.5, contradictions, majority_vote)      0.886324
# 4                                         ct_vote_0.6      0.883053
# 9                                        ct_vote_0.85      0.882857
# 10                                        ct_vote_0.9      0.882857
# 48            (batch, 1.5, crowdtruth, majority_vote)      0.865000
# 34           (pair, 2, contradictions, majority_vote)      0.865000
# 38        (batch, 0.5, contradictions, majority_vote)      0.865000
# 42          (batch, 1, contradictions, majority_vote)      0.865000
# 44              (batch, 1, crowdtruth, majority_vote)      0.865000
# 0                                       majority_vote      0.865000
# 50          (batch, 2, contradictions, majority_vote)      0.865000
# 52              (batch, 2, crowdtruth, majority_vote)      0.865000
# 30         (pair, 1.5, contradictions, majority_vote)      0.865000
# 64            (total, 1.5, crowdtruth, majority_vote)      0.865000
# 66          (total, 2, contradictions, majority_vote)      0.865000
# 68              (total, 2, crowdtruth, majority_vote)      0.865000
# 70  (None, None, exclude_contradictory_annotations...      0.865000
# 32             (pair, 1.5, crowdtruth, majority_vote)      0.865000
# ..                                                ...           ...
# 21                                      top_vote_ct_1      0.795384
# 40            (batch, 0.5, crowdtruth, majority_vote)      0.779762
# 24             (pair, 0.5, crowdtruth, majority_vote)      0.758000
# 47             (batch, 1.5, contradictions, top_vote)      0.749914
# 55             (total, 0.5, contradictions, top_vote)      0.749914
# 59               (total, 1, contradictions, top_vote)      0.749914
# 63             (total, 1.5, contradictions, top_vote)      0.749914
# 43               (batch, 1, contradictions, top_vote)      0.749914
# 39             (batch, 0.5, contradictions, top_vote)      0.749914
# 27                (pair, 1, contradictions, top_vote)      0.749914
# 11                                          ct_vote_1      0.745890
# 61                   (total, 1, crowdtruth, top_vote)      0.733856
# 65                 (total, 1.5, crowdtruth, top_vote)      0.730000
# 67               (total, 2, contradictions, top_vote)      0.730000
# 69                   (total, 2, crowdtruth, top_vote)      0.730000
# 31              (pair, 1.5, contradictions, top_vote)      0.730000
# 71  (None, None, exclude_contradictory_annotations...      0.730000
# 53                   (batch, 2, crowdtruth, top_vote)      0.730000
# 45                   (batch, 1, crowdtruth, top_vote)      0.730000
# 37                    (pair, 2, crowdtruth, top_vote)      0.730000
# 1                                            top_vote      0.730000
# 35                (pair, 2, contradictions, top_vote)      0.730000
# 33                  (pair, 1.5, crowdtruth, top_vote)      0.730000
# 23              (pair, 0.5, contradictions, top_vote)      0.712929
# 57                 (total, 0.5, crowdtruth, top_vote)      0.709887
# 29                    (pair, 1, crowdtruth, top_vote)      0.709887
# 49                 (batch, 1.5, crowdtruth, top_vote)      0.709887
# 25                  (pair, 0.5, crowdtruth, top_vote)      0.709887
# 41                 (batch, 0.5, crowdtruth, top_vote)      0.709887
# 51               (batch, 2, contradictions, top_vote)      0.709887
#
#     levels-f1  negative_relations-f1     alpha
# 22   0.959664               0.919423  0.346069
# 54   0.921296               0.919423  0.370216
# 58   0.921296               0.919423  0.334021
# 6    0.916667               0.916364  0.267403
# 8    0.908333               0.911741  0.267403
# 7    0.908333               0.911741  0.267403
# 62   0.884066               0.894017  0.320205
# 5    0.916667               0.890741  0.267403
# 28   0.884066               0.868937  0.274504
# 60   0.884066               0.868937  0.258721
# 3    0.884066               0.868937  0.267403
# 2    0.884066               0.868937  0.267403
# 46   0.884066               0.868937  0.291660
# 4    0.878993               0.865705  0.267403
# 9    0.852787               0.866667  0.267403
# 10   0.852787               0.866667  0.267403
# 48   0.847339               0.844000  0.262344
# 34   0.847339               0.844000  0.286623
# 38   0.810606               0.844000  0.330673
# 42   0.847339               0.844000  0.298755
# 44   0.847339               0.844000  0.256494
# 0    0.847339               0.844000  0.267403
# 50   0.847339               0.844000  0.283695
# 52   0.847339               0.844000  0.257331
# 30   0.847339               0.844000  0.295424
# 64   0.847339               0.844000  0.267403
# 66   0.847339               0.844000  0.297640
# 68   0.847339               0.844000  0.267403
# 70   0.847339               0.844000  0.351077
# 32   0.847339               0.844000  0.257331
# ..        ...                    ...       ...
# 21   0.697917               0.764087  0.267403
# 40   0.773438               0.742754  0.264075
# 24   0.735452               0.716444  0.261274
# 47   0.697917               0.711662  0.291660
# 55   0.697917               0.735043  0.370216
# 59   0.697917               0.735043  0.334021
# 63   0.697917               0.735043  0.320205
# 43   0.659867               0.711662  0.298755
# 39   0.659867               0.711662  0.330673
# 27   0.697917               0.711662  0.307013
# 11   0.699612               0.711111  0.267403
# 61   0.659867               0.715646  0.258721
# 65   0.659867               0.688000  0.267403
# 67   0.659867               0.711662  0.297640
# 69   0.659867               0.688000  0.267403
# 31   0.659867               0.688000  0.295424
# 71   0.659867               0.688000  0.351077
# 53   0.659867               0.688000  0.257331
# 45   0.659867               0.688000  0.256494
# 37   0.659867               0.688000  0.267403
# 1    0.659867               0.688000  0.267403
# 35   0.659867               0.688000  0.286623
# 33   0.659867               0.688000  0.257331
# 23   0.620370               0.665680  0.346069
# 57   0.620370               0.663946  0.207059
# 29   0.659867               0.688000  0.274504
# 49   0.659867               0.688000  0.262344
# 25   0.659867               0.663946  0.261274
# 41   0.659867               0.663946  0.264075
# 51   0.659867               0.688000  0.283695
#
# [72 rows x 5 columns]

# %%
#print(df.to_latex(index=False))

# %%
# possible disagreement 

overview_dicts = evaluate_configs(gold_poss_disagree, crowd)
df =  pd.DataFrame(overview_dicts) 
df = df.sort_values(by=['relations-f1'], ascending=False)[['config',
                                                      'relations-f1',
                                                      'levels-f1', 
                                                        'negative_relations-f1', 'alpha']]
df.round(2).to_csv('../analyses/evaluation_accuracy_poss_disagree.csv')
df
# Out:
# ----Label distribution----
# True: 10
# False 35
# ----------------------------
# 45 17917 507
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# clean all contradictory annotations
#                                                config  relations-f1  \
# 38        (batch, 0.5, contradictions, majority_vote)      0.893648
# 26           (pair, 1, contradictions, majority_vote)      0.827689
# 46        (batch, 1.5, contradictions, majority_vote)      0.814815
# 58          (total, 1, contradictions, majority_vote)      0.808566
# 62        (total, 1.5, contradictions, majority_vote)      0.808566
# 42          (batch, 1, contradictions, majority_vote)      0.808566
# 54        (total, 0.5, contradictions, majority_vote)      0.808566
# 22         (pair, 0.5, contradictions, majority_vote)      0.803313
# 55             (total, 0.5, contradictions, top_vote)      0.793002
# 5                                        ct_vote_0.65      0.791145
# 60              (total, 1, crowdtruth, majority_vote)      0.789562
# 23              (pair, 0.5, contradictions, top_vote)      0.770598
# 48            (batch, 1.5, crowdtruth, majority_vote)      0.770598
# 52              (batch, 2, crowdtruth, majority_vote)      0.770598
# 28               (pair, 1, crowdtruth, majority_vote)      0.770598
# 2                                         ct_vote_0.5      0.770598
# 3                                        ct_vote_0.55      0.766025
# 66          (total, 2, contradictions, majority_vote)      0.766025
# 30         (pair, 1.5, contradictions, majority_vote)      0.766025
# 50          (batch, 2, contradictions, majority_vote)      0.754224
# 4                                         ct_vote_0.6      0.750844
# 47             (batch, 1.5, contradictions, top_vote)      0.747475
# 49                 (batch, 1.5, crowdtruth, top_vote)      0.747475
# 37                    (pair, 2, crowdtruth, top_vote)      0.747475
# 36               (pair, 2, crowdtruth, majority_vote)      0.747475
# 51               (batch, 2, contradictions, top_vote)      0.747475
# 53                   (batch, 2, crowdtruth, top_vote)      0.747475
# 35                (pair, 2, contradictions, top_vote)      0.747475
# 59               (total, 1, contradictions, top_vote)      0.747475
# 61                   (total, 1, crowdtruth, top_vote)      0.747475
# ..                                                ...           ...
# 16                                    top_vote_ct_0.7      0.747475
# 33                  (pair, 1.5, crowdtruth, top_vote)      0.747475
# 18                                    top_vote_ct_0.8      0.747475
# 19                                   top_vote_ct_0.85      0.747475
# 20                                    top_vote_ct_0.9      0.747475
# 17                                   top_vote_ct_0.75      0.747475
# 32             (pair, 1.5, crowdtruth, majority_vote)      0.747475
# 27                (pair, 1, contradictions, top_vote)      0.747475
# 31              (pair, 1.5, contradictions, top_vote)      0.747475
# 44              (batch, 1, crowdtruth, majority_vote)      0.732510
# 39             (batch, 0.5, contradictions, top_vote)      0.728889
# 70  (None, None, exclude_contradictory_annotations...      0.728889
# 68              (total, 2, crowdtruth, majority_vote)      0.728889
# 64            (total, 1.5, crowdtruth, majority_vote)      0.728889
# 0                                       majority_vote      0.728889
# 45                   (batch, 1, crowdtruth, top_vote)      0.728889
# 29                    (pair, 1, crowdtruth, top_vote)      0.728889
# 10                                        ct_vote_0.9      0.715100
# 9                                        ct_vote_0.85      0.715100
# 8                                         ct_vote_0.8      0.715100
# 7                                        ct_vote_0.75      0.715100
# 6                                         ct_vote_0.7      0.715100
# 43               (batch, 1, contradictions, top_vote)      0.710203
# 11                                          ct_vote_1      0.680556
# 56            (total, 0.5, crowdtruth, majority_vote)      0.654031
# 57                 (total, 0.5, crowdtruth, top_vote)      0.592593
# 40            (batch, 0.5, crowdtruth, majority_vote)      0.571321
# 24             (pair, 0.5, crowdtruth, majority_vote)      0.531924
# 41                 (batch, 0.5, crowdtruth, top_vote)      0.526749
# 25                  (pair, 0.5, crowdtruth, top_vote)      0.526749
#
#     levels-f1  negative_relations-f1     alpha
# 38   0.898190               0.925996  0.051811
# 26   0.830317               0.850400  0.051209
# 46   0.832859               0.806706  0.057680
# 58   0.798246               0.827323  0.049030
# 62   0.798246               0.827323  0.043946
# 42   0.832859               0.827323  0.048032
# 54   0.798246               0.827323  0.062219
# 22   0.830317               0.823212  0.064561
# 55   0.700000               0.758383  0.062219
# 5    0.803030               0.760531  0.045904
# 60   0.762443               0.755461  0.042238
# 23   0.700000               0.732850  0.064561
# 48   0.762443               0.732850  0.045581
# 52   0.762443               0.732850  0.043616
# 28   0.730994               0.732850  0.039847
# 2    0.798246               0.781422  0.045904
# 3    0.793750               0.777987  0.045904
# 66   0.766003               0.777987  0.047594
# 30   0.793750               0.777987  0.039627
# 50   0.800000               0.759707  0.057101
# 4    0.785714               0.765114  0.045904
# 47   0.700000               0.706553  0.057680
# 49   0.700000               0.706553  0.045581
# 37   0.700000               0.706553  0.047161
# 36   0.725000               0.706553  0.047161
# 51   0.700000               0.706553  0.057101
# 53   0.700000               0.706553  0.043616
# 35   0.700000               0.706553  0.044727
# 59   0.700000               0.706553  0.049030
# 61   0.700000               0.706553  0.042238
# ..        ...                    ...       ...
# 16   0.766667               0.755461  0.045904
# 33   0.700000               0.706553  0.045982
# 18   0.766667               0.755461  0.045904
# 19   0.766667               0.755461  0.045904
# 20   0.766667               0.755461  0.045904
# 17   0.766667               0.755461  0.045904
# 32   0.725000               0.706553  0.045982
# 27   0.700000               0.706553  0.051209
# 31   0.700000               0.706553  0.039627
# 44   0.730994               0.710059  0.038899
# 39   0.732620               0.732850  0.051811
# 70   0.762443               0.732850  0.183990
# 68   0.762443               0.732850  0.045904
# 64   0.762443               0.732850  0.045904
# 0    0.762443               0.732850  0.045904
# 45   0.665775               0.684277  0.038899
# 29   0.665775               0.684277  0.039847
# 10   0.693853               0.673660  0.045904
# 9    0.693853               0.673660  0.045904
# 8    0.693853               0.673660  0.045904
# 7    0.693853               0.673660  0.045904
# 6    0.693853               0.673660  0.045904
# 43   0.697628               0.710059  0.048032
# 11   0.642857               0.634238  0.045904
# 56   0.598930               0.615385  0.036461
# 57   0.532086               0.543676  0.036461
# 40   0.598930               0.567473  0.031994
# 24   0.563241               0.519231  0.037962
# 41   0.458333               0.494386  0.031994
# 25   0.458333               0.494386  0.037962
#
# [72 rows x 5 columns]

# %%
#disagree
overview_dicts = evaluate_configs(gold_disagree, crowd)
df =  pd.DataFrame(overview_dicts) 
df = df.sort_values(by=['relations-f1'], ascending=False)[['config',
                                                      'relations-f1',
                                                      'levels-f1', 
                                                        'negative_relations-f1', 'alpha']]
df.round(2).to_csv('../analyses/evaluation_accuracy_disagree.csv')
df
# Out:
# ----Label distribution----
# True: 3
# False 2
# ----------------------------
# 5 17917 53
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# clean all contradictory annotations
#                                                config  relations-f1  \
# 38        (batch, 0.5, contradictions, majority_vote)      0.780952
# 54        (total, 0.5, contradictions, majority_vote)      0.600000
# 6                                         ct_vote_0.7      0.566667
# 71  (None, None, exclude_contradictory_annotations...      0.450000
# 39             (batch, 0.5, contradictions, top_vote)      0.450000
# 29                    (pair, 1, crowdtruth, top_vote)      0.450000
# 59               (total, 1, contradictions, top_vote)      0.450000
# 31              (pair, 1.5, contradictions, top_vote)      0.450000
# 33                  (pair, 1.5, crowdtruth, top_vote)      0.450000
# 57                 (total, 0.5, crowdtruth, top_vote)      0.450000
# 35                (pair, 2, contradictions, top_vote)      0.450000
# 1                                            top_vote      0.450000
# 37                    (pair, 2, crowdtruth, top_vote)      0.450000
# 41                 (batch, 0.5, crowdtruth, top_vote)      0.450000
# 55             (total, 0.5, contradictions, top_vote)      0.450000
# 25                  (pair, 0.5, crowdtruth, top_vote)      0.450000
# 42          (batch, 1, contradictions, majority_vote)      0.450000
# 43               (batch, 1, contradictions, top_vote)      0.450000
# 45                   (batch, 1, crowdtruth, top_vote)      0.450000
# 46        (batch, 1.5, contradictions, majority_vote)      0.450000
# 47             (batch, 1.5, contradictions, top_vote)      0.450000
# 53                   (batch, 2, crowdtruth, top_vote)      0.450000
# 49                 (batch, 1.5, crowdtruth, top_vote)      0.450000
# 50          (batch, 2, contradictions, majority_vote)      0.450000
# 27                (pair, 1, contradictions, top_vote)      0.450000
# 61                   (total, 1, crowdtruth, top_vote)      0.450000
# 14                                    top_vote_ct_0.6      0.450000
# 17                                   top_vote_ct_0.75      0.450000
# 2                                         ct_vote_0.5      0.450000
# 69                   (total, 2, crowdtruth, top_vote)      0.450000
# ..                                                ...           ...
# 23              (pair, 0.5, contradictions, top_vote)      0.450000
# 5                                        ct_vote_0.65      0.400000
# 62        (total, 1.5, contradictions, majority_vote)      0.342857
# 58          (total, 1, contradictions, majority_vote)      0.342857
# 64            (total, 1.5, crowdtruth, majority_vote)      0.342857
# 66          (total, 2, contradictions, majority_vote)      0.342857
# 68              (total, 2, crowdtruth, majority_vote)      0.342857
# 70  (None, None, exclude_contradictory_annotations...      0.342857
# 60              (total, 1, crowdtruth, majority_vote)      0.342857
# 52              (batch, 2, crowdtruth, majority_vote)      0.342857
# 0                                       majority_vote      0.342857
# 48            (batch, 1.5, crowdtruth, majority_vote)      0.342857
# 30         (pair, 1.5, contradictions, majority_vote)      0.342857
# 3                                        ct_vote_0.55      0.342857
# 4                                         ct_vote_0.6      0.342857
# 44              (batch, 1, crowdtruth, majority_vote)      0.342857
# 28               (pair, 1, crowdtruth, majority_vote)      0.342857
# 36               (pair, 2, crowdtruth, majority_vote)      0.342857
# 32             (pair, 1.5, crowdtruth, majority_vote)      0.342857
# 34           (pair, 2, contradictions, majority_vote)      0.342857
# 11                                          ct_vote_1      0.228571
# 10                                        ct_vote_0.9      0.228571
# 9                                        ct_vote_0.85      0.228571
# 8                                         ct_vote_0.8      0.228571
# 7                                        ct_vote_0.75      0.228571
# 26           (pair, 1, contradictions, majority_vote)      0.200000
# 22         (pair, 0.5, contradictions, majority_vote)      0.200000
# 56            (total, 0.5, crowdtruth, majority_vote)      0.200000
# 40            (batch, 0.5, crowdtruth, majority_vote)      0.000000
# 24             (pair, 0.5, crowdtruth, majority_vote)      0.000000
#
#     levels-f1  negative_relations-f1     alpha
# 38   0.780952               0.780952 -0.079394
# 54   0.600000               0.600000 -0.059838
# 6    0.566667               0.566667 -0.085522
# 71   0.450000               0.450000  0.001299
# 39   0.450000               0.450000 -0.079394
# 29   0.450000               0.450000 -0.087568
# 59   0.450000               0.450000 -0.062309
# 31   0.450000               0.450000 -0.088757
# 33   0.450000               0.450000 -0.084635
# 57   0.450000               0.450000 -0.136601
# 35   0.450000               0.450000 -0.077106
# 1    0.450000               0.450000 -0.085522
# 37   0.450000               0.450000 -0.084635
# 41   0.450000               0.450000 -0.112741
# 55   0.450000               0.450000 -0.059838
# 25   0.450000               0.450000 -0.110417
# 42   0.450000               0.450000 -0.069231
# 43   0.450000               0.450000 -0.069231
# 45   0.450000               0.450000 -0.082759
# 46   0.450000               0.450000 -0.085137
# 47   0.450000               0.450000 -0.085137
# 53   0.450000               0.450000 -0.091276
# 49   0.450000               0.450000 -0.091276
# 50   0.450000               0.450000 -0.095960
# 27   0.450000               0.450000 -0.087094
# 61   0.450000               0.450000 -0.084635
# 14   0.450000               0.450000 -0.085522
# 17   0.450000               0.450000 -0.085522
# 2    0.450000               0.450000 -0.085522
# 69   0.450000               0.450000 -0.085522
# ..        ...                    ...       ...
# 23   0.450000               0.450000 -0.096199
# 5    0.400000               0.400000 -0.085522
# 62   0.342857               0.342857 -0.087272
# 58   0.342857               0.342857 -0.062309
# 64   0.342857               0.342857 -0.085522
# 66   0.342857               0.342857 -0.076871
# 68   0.342857               0.342857 -0.085522
# 70   0.342857               0.342857  0.001299
# 60   0.342857               0.342857 -0.084635
# 52   0.342857               0.342857 -0.091276
# 0    0.342857               0.342857 -0.085522
# 48   0.342857               0.342857 -0.091276
# 30   0.342857               0.342857 -0.088757
# 3    0.342857               0.342857 -0.085522
# 4    0.342857               0.342857 -0.085522
# 44   0.342857               0.342857 -0.082759
# 28   0.342857               0.342857 -0.087568
# 36   0.342857               0.342857 -0.084635
# 32   0.342857               0.342857 -0.084635
# 34   0.342857               0.342857 -0.077106
# 11   0.228571               0.228571 -0.085522
# 10   0.228571               0.228571 -0.085522
# 9    0.228571               0.228571 -0.085522
# 8    0.228571               0.228571 -0.085522
# 7    0.228571               0.228571 -0.085522
# 26   0.200000               0.200000 -0.087094
# 22   0.200000               0.200000 -0.096199
# 56   0.200000               0.200000 -0.136601
# 40   0.000000               0.000000 -0.112741
# 24   0.000000               0.000000 -0.110417
#
# [72 rows x 5 columns]
