# %% [markdown]
# # Annotation analysis
#
# This noteboook
#
# * illustrates the steps of the analysis currently implemented
# * is used to analyze and monitor workers batch by batch

# %%
from load_data import load_experiment_data
from analyze_workers import get_worker_analysis, get_worker_contradiction_outlier_analysis
from analyze_pairs import get_pair_analysis
from analyze_pairs import show_pairs_of_worker
from analyze_pairs import compare_runs
from calculate_iaa import get_agreement
from analyze_relations_and_examples import agreement_relations_across_runs
#from aggregate_labels import get_overview

# %% [markdown]
# # Analyze worker contradictions:
#
# * Workers with highest contradiction to annotations ratio appear on top
# * use the pandas dataframe sort method to sort on other values:
#
# `df.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')`

# %% [markdown]
# ### Current batch

# %%
run = 4
batch = 10
n_q = '*'
group = 'experiment2'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_worker_analysis(data_dict_list, name)
df.drop(['annotations'], axis = 1, inplace=True)
df[['workerid', 'contradiction_poss_contradiction_ratio', 'n_contradictions', 'n_fails', 'n_annotations']]
# Out:
# Discarded 0.0 annotations.
#                    workerid  contradiction_poss_contradiction_ratio  \
# 0  5c251fdd17d86a00017d3c96                                     0.0
# 1  5caa2e430adbf40001d85452                                     0.0
# 2  5d0a96518dad180019fad34d                                     0.0
# 3  5d206ec4a61f400016f9d3e1                                     0.0
# 4  5d7a9456f608ef0016ff7592                                     0.0
# 5  5deb1d80347765248791ba44                                     0.0
# 6  5e6758c4a8c7654cc553eb9f                                     0.0
# 7  5ea36adfa9f5802f73c05208                                     0.0
# 8  5ea6bed3221dd504658c85c7                                     0.0
# 9  5ea7175ee1fab30c110e59f8                                     0.0
#
#    n_contradictions  n_fails  n_annotations
# 0                 0        2             72
# 1                 0        2             72
# 2                 0        2             72
# 3                 0        2             72
# 4                 0        2             72
# 5                 0        2             72
# 6                 0        2             72
# 7                 0        2             72
# 8                 0        2             72
# 9                 0        2             72

# %% [markdown]
# ### All annotations
#
# * Workers with highest contradiction to annotations ratio appear on top
# * use the pandas dataframe sort method to sort on other values:
# * Check how the behavior of a specific worker with many contradictions compares to other workers
#
# `df.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')`

# %%
run = '*'
batch = '*'
n_q = '*'
group = 'experiment*'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df_total, filepath = get_worker_analysis(data_dict_list, name)
analysis_type = 'workers'
df_outliers = get_worker_contradiction_outlier_analysis(analysis_type, run, group, batch)
df_total.drop(['annotations'], axis = 1, inplace=True)
df_total[['workerid', 'contradiction_poss_contradiction_ratio', 'n_contradictions', 'n_fails']][:10]
# Out:
# Discarded 655.0 annotations.
# Results written to: ../analyses/workers-outliers/run-all--group_experiment-all--batch-all-.csv
#                       workerid  contradiction_poss_contradiction_ratio  \
# 270   5c2c7eae8a20f50001e9a8c0                                0.770115
# 702   5bfed16ca1f050000102693c                                0.712644
# 884   5d6ef000391fb4001a97337d                                0.696970
# 1060                       111                                0.650000
# 243   5e8115962b00617ffc1b04ad                                0.633333
# 656   5c91321c0375460001034cb8                                0.633333
# 1029  5d76a2dc2a476a0001ce6843                                0.625000
# 707   5e2f554c4c58fa515ad361d0                                0.600000
# 229   5e8cffa6f387850d0476f30a                                0.576923
# 802   5e87276d17cdf1028850af59                                0.529412
#
#       n_contradictions  n_fails
# 270                 67        0
# 702                 62        1
# 884                 69        1
# 1060                39        0
# 243                 57        0
# 656                 38        0
# 1029                45        1
# 707                  3        0
# 229                 45        0
# 802                 54        1

# %%
# Good workers
df_total[['workerid', 'contradiction_poss_contradiction_ratio', 'n_contradictions', 'n_fails']][-20:]
# Out:
#                      workerid  contradiction_poss_contradiction_ratio  \
# 329  5cb92adbe0e8ab000176f421                                     0.0
# 96   55a15444fdf99b04310c8c85                                     0.0
# 333  5cae54fbe5b99b0015a57a33                                     0.0
# 334  5d50fbe64e3713001a005a19                                     0.0
# 345  5dc6d78cac77c74d18692044                                     0.0
# 346  5e1103e212e922000bc4bdf9                                     0.0
# 81   5c9be64e7eead40016aebc0c                                     0.0
# 350  56e99d054111eb000c77885b                                     0.0
# 354  5c3fb75eca00d30001c5187d                                     0.0
# 923  5c922ee24faf8b00014ca145                                     0.0
# 655  5c665e1948985d0001f09675                                     0.0
# 653  5dc2ef762bdeaa2048421817                                     0.0
# 364  5ea0448e208a8a03174218a0                                     0.0
# 644  5de5a14236d82552feeaf5ee                                     0.0
# 917  598ee5e333481c000164d32e                                     0.0
# 367  5badd3d7de6f4900019e4148                                     0.0
# 920  5e33cc7c4e448c394a198acc                                     0.0
# 374  5c251fdd17d86a00017d3c96                                     0.0
# 922  5bd34b706546650001029bec                                     0.0
# 171  5c4082b3fe87360001a55874                                     0.0
#
#      n_contradictions  n_fails
# 329                 0        0
# 96                  0        0
# 333                 0        1
# 334                 0        2
# 345                 0        1
# 346                 0        0
# 81                  0        0
# 350                 0        0
# 354                 0        0
# 923                 0        0
# 655                 0        0
# 653                 0        0
# 364                 0        0
# 644                 0        0
# 917                 0        0
# 367                 0        0
# 920                 0        0
# 374                 0        1
# 922                 0        0
# 171                 0        0

# %% [markdown]
# ### Get all contradictions and fails of a particular worker
#
# * Check if a specfic worker continuously contradicts themselves (and fails checks)

# %%
# copy from above - worker with many disagreements in target batch
worker = '5d034f7733bb360017370b87'

# df.loc[df['column_name'] == some_value]
df_total.loc[df_total['workerid'] == worker]
# Out:
#     average_time_question  contradiction_annotation_ratio  \
# 31               6.160701                        0.013274
#
#     contradiction_poss_contradiction_ratio  contradictory_pairs_ratio  \
# 31                                0.011905                   0.066667
#
#     fail_annotation_ratio  n_annotations  n_contradictions  n_fails  \
# 31                0.00885            226                 3        2
#
#     n_possible_contradictions                  workerid  ...  \
# 31                        252  5d034f7733bb360017370b87  ...
#
#     (implied_category, rare)  (rare, typical_of_concept)  \
# 31                       NaN                         NaN
#
#     (typical_of_concept, unusual)  (affording_activity, rare)  \
# 31                            NaN                    0.003968
#
#     (implied_category, unusual)  (typical_of_property, unusual)  \
# 31                          NaN                             NaN
#
#     (afforded_usual, impossible)  (rare, typical_of_property)  \
# 31                           NaN                          NaN
#
#     (impossible, typical_of_property)  (impossible, typical_of_concept)
# 31                                NaN                               NaN
#
# [1 rows x 28 columns]

# %% [markdown]
# # Analyze pairs
#
# * compars number of annotator contradictions among pairs

# %% [markdown]
# ### Current batch:

# %%
run = '4'
batch = '136'
n_q = '*'
group = 'experiment2'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_pair_analysis(data_dict_list, name)
df.drop(['annotations_with_contradiction'], axis = 1, inplace=True)
#df
# Out:
# Discarded 0.0 annotations.

# %% [markdown]
# ### Get rows with pairs annotated by specific workers:
#
# * Check if a worker in the only one contradicting or if others also had issues with the pairs

# %%
worker = '5dc1f283fc1cda15c5015611'

show_pairs_of_worker(worker, df)
# Out:
# Worker 5dc1f283fc1cda15c5015611 contradicted themselves in the following pairs:

# %% [markdown]
# ### Compare to entire annotation set

# %%
run = '*'
batch = '*'
n_q = '*'
group = 'experiment*'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_pair_analysis(data_dict_list, name)
print(filepath)
df.drop(['annotations_with_contradiction'], axis = 1, inplace=True)
df[:10]
# Out:
# Discarded 655.0 annotations.
# ../analyses/pairs/run-all--group_experiment-all--batch-all-.csv
#       average_time_pair  contradiction_annotation_ratio  \
# 0            142.439417                             0.0
# 1277          97.290460                             0.0
# 1305          87.077370                             0.0
# 1304          87.077370                             0.0
# 1303          87.077370                             0.0
# 1302         217.693425                             0.0
# 1301          87.077370                             0.0
# 1300          87.077370                             0.0
# 1299         217.693425                             0.0
# 1298          87.077370                             0.0
#
#       contradiction_poss_contradiction_ratio  n_annotations  n_contradictions  \
# 0                                        0.0             36                 0
# 1277                                     0.0            100                 0
# 1305                                     0.0            100                 0
# 1304                                     0.0            100                 0
# 1303                                     0.0            100                 0
# 1302                                     0.0             40                 0
# 1301                                     0.0            100                 0
# 1300                                     0.0            100                 0
# 1299                                     0.0             40                 0
# 1298                                     0.0            100                 0
#
#       n_possible_contradictions  n_workers  n_workers_contradicting  \
# 0                             0          9                        0
# 1277                        120         10                        0
# 1305                        150         10                        0
# 1304                        120         10                        0
# 1303                        120         10                        0
# 1302                          0         10                        0
# 1301                        120         10                        0
# 1300                        120         10                        0
# 1299                          0         10                        0
# 1298                        120         10                        0
#
#                      pair  ratio_workers_contradicting workers_contradicting  \
# 0           yellow-radish                          0.0
# 1277         sweet-orange                          0.0
# 1305      lay_eggs-equine                          0.0
# 1304     square-cafeteria                          0.0
# 1303             hot-dish                          0.0
# 1302        wheels-vessel                          0.0
# 1301          black-cider                          0.0
# 1300         sweet-butter                          0.0
# 1299         yellow-miner                          0.0
# 1298  made_of_wood-fipple                          0.0
#
#                               workers_not_contradicting
# 0     5717864c94d4fc001297198d 5b02fe323bc9af0001909...
# 1277  56e0246fa3b147000ac579f3 57027b6768c641000e0c8...
# 1305  5aff2de2a415960001f26f36 5b7182ec8050b70001793...
# 1304  5aff2de2a415960001f26f36 5b7182ec8050b70001793...
# 1303  5aff2de2a415960001f26f36 5b7182ec8050b70001793...
# 1302  5aff2de2a415960001f26f36 5b7182ec8050b70001793...
# 1301  5aff2de2a415960001f26f36 5b7182ec8050b70001793...
# 1300  5aff2de2a415960001f26f36 5b7182ec8050b70001793...
# 1299  5aff2de2a415960001f26f36 5b7182ec8050b70001793...
# 1298  5aff2de2a415960001f26f36 5b7182ec8050b70001793...

# %%
# check specific pair:

pair = 'hot-chutney'
df.loc[df['pair'] == pair]
# Out:
#      average_time_pair  contradiction_annotation_ratio  \
# 691          98.697263                        0.009615
#
#      contradiction_poss_contradiction_ratio  n_annotations  n_contradictions  \
# 691                                0.008333            104                 1
#
#      n_possible_contradictions  n_workers  n_workers_contradicting  \
# 691                        120         10                        1
#
#             pair  ratio_workers_contradicting  ...  \
# 691  hot-chutney                          0.1  ...
#
#     (implied_category, unusual) (affording_activity, rare)  \
# 691                         NaN                        1.0
#
#      (afforded_unusual, unusual)  (afforded_usual, unusual)  \
# 691                          NaN                        NaN
#
#      (afforded_unusual, impossible)  (afforded_usual, impossible)  \
# 691                             NaN                           NaN
#
#      (impossible, typical_of_property)  (impossible, typical_of_concept)  \
# 691                                NaN                               NaN
#
#      (affording_activity, impossible)  (implied_category, impossible)
# 691                               NaN                             NaN
#
# [1 rows x 30 columns]

# %% [markdown]
# ### Compare contradictions between runs:

# %%
run = '3'
batch = '*'
n_q = '*'
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df1, filepath = get_pair_analysis(data_dict_list, name)
print(f'analysis can be found at: {filepath}')

run = '4'
batch = '*'
n_q = '*'
group = 'experiment2'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df2, filepath = get_pair_analysis(data_dict_list, name)
print(f'analysis can be found at: {filepath}')

name1 = '3'
name2 = '4'
compare_runs(name1, name2, df1, df2, comp = 'all')
#print()
#compare_runs(name1, name2, df1, df2, comp = 'pairs')
# Out:
# Discarded 655.0 annotations.
# analysis can be found at: ../analyses/pairs/run3-group_experiment1-batch-all-.csv
# Discarded 0.0 annotations.
# analysis can be found at: ../analyses/pairs/run4-group_experiment2-batch-all-.csv
# Set 3 as a contradiction ratio of 0.0
# Set 4 as a contradiction ratio of 0.0
# The ratio is based on the number of workers annotating a pair.
# A worker always annotates a full set.
# (0.0, 0.0)

# %% [markdown]
# # Inter-annotator agreement
#
# * Total agreement
# * Agreement by relations
# * agreement after removing annotators with many contradictions/annotators who fail checks/contradictory annotations

# %% [markdown]
# ## Total iaa:

# %%
run = '*'
batch = '*'
n_q = '*'
group = 'experiment*'
print(f"Run {run}, all experiment groups:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)

run = '*'
batch = '*'
n_q = '*'
group = 'experiment1'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)

run = '4'
batch = '*'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)

get_agreement(data_dict_list)
# Out:
# Run *, all experiment groups:
# Discarded 655.0 annotations.
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:576: RuntimeWarning: invalid value encountered in true_divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# Krippendorff's alpha: 0.3289481038379506
# Average Cohen's Kappa (pairwise): 0.3097663994197471
# Proportional agreement (pairwise): 0.672934497069301
#
# Run *:
# Discarded 655.0 annotations.
# Krippendorff's alpha: 0.23567624334318582
# Average Cohen's Kappa (pairwise): 0.2270603465915947
# Proportional agreement (pairwise): 0.6230672746100898
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.3759582015271209
# Average Cohen's Kappa (pairwise): 0.3663806617723511
# Proportional agreement (pairwise): 0.7063955928484047
# {'Krippendorff': 0.3759582015271209,
#  'Proportional': 0.7063955928484047,
#  'Av_Cohens_kappa': 0.3663806617723511}

# %%
# Run 4 see if selecting good workers helps agreement:

# no whitelist
run = '4'
batch = '20'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)

# Whitelist
run = '4'
batch = '27'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)
# Whitelist
run = '4'
batch = '28'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)
# Whitelist
run = '4'
batch = '29'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)
# Whitelist
run = '4'
batch = '40'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)
# Whitelist
run = '4'
batch = '41'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)
# Whitelist
run = '4'
batch = '42'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)
# Whitelist
run = '4'
batch = '43'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)
# Whitelist
run = '4'
batch = '44'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)
# Whitelist
run = '4'
batch = '45'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)

# Whitelist
run = '4'
batch = '46'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)

# Whitelist
run = '4'
batch = '47'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)
# Whitelist
run = '4'
batch = '48'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)

# Whitelist
run = '4'
batch = '165'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)

# Whitelist
run = '4'
batch = '166'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)

# Whitelist
run = '4'
batch = '167'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)
# Out:
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.1773467340972621
# Average Cohen's Kappa (pairwise): 0.15990402232445725
# Proportional agreement (pairwise): 0.5741741741741743
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.36094682230869035
# Average Cohen's Kappa (pairwise): 0.3567475052361654
# Proportional agreement (pairwise): 0.7078078078078076
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.38306989982331197
# Average Cohen's Kappa (pairwise): 0.38816630417456993
# Proportional agreement (pairwise): 0.732456140350877
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.27779308118876944
# Average Cohen's Kappa (pairwise): 0.28131746636047383
# Proportional agreement (pairwise): 0.6657407407407409
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.28576527457959255
# Average Cohen's Kappa (pairwise): 0.28760343265417626
# Proportional agreement (pairwise): 0.6632716049382716
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.2768403864897817
# Average Cohen's Kappa (pairwise): 0.2781291987090819
# Proportional agreement (pairwise): 0.6587719298245616
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.38854530410759147
# Average Cohen's Kappa (pairwise): 0.3887653218470611
# Proportional agreement (pairwise): 0.6987987987987986
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.3684756150950007
# Average Cohen's Kappa (pairwise): 0.3712649234833178
# Proportional agreement (pairwise): 0.7069069069069067
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.3045833639053982
# Average Cohen's Kappa (pairwise): 0.30512979568179693
# Proportional agreement (pairwise): 0.6672364672364673
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.3862504409171078
# Average Cohen's Kappa (pairwise): 0.39067801043143063
# Proportional agreement (pairwise): 0.7012345679012345
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.2779135225775543
# Average Cohen's Kappa (pairwise): 0.28428208100463187
# Proportional agreement (pairwise): 0.6545454545454547
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.3613558843684369
# Average Cohen's Kappa (pairwise): 0.36303578441868367
# Proportional agreement (pairwise): 0.7163580246913579
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.31568332789916853
# Average Cohen's Kappa (pairwise): 0.3168582159819614
# Proportional agreement (pairwise): 0.693732193732194
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.3950597081563101
# Average Cohen's Kappa (pairwise): 0.4011393457970816
# Proportional agreement (pairwise): 0.7695906432748538
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.28926309401903916
# Average Cohen's Kappa (pairwise): 0.2876107434083014
# Proportional agreement (pairwise): 0.7114197530864197
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.3870344075910749
# Average Cohen's Kappa (pairwise): 0.3853041292148929
# Proportional agreement (pairwise): 0.7339339339339338
# {'Krippendorff': 0.3870344075910749,
#  'Proportional': 0.7339339339339338,
#  'Av_Cohens_kappa': 0.3853041292148929}

# %% [markdown]
# ## IAA by relation

# %%
runs = ['4', '3', '1']
experiment_name = 'experiment*'
path, df = agreement_relations_across_runs(runs, experiment_name)
print(f'Results written to: {path}')
# Out:
# Discarded 0.0 annotations.
# Discarded 655.0 annotations.
# Discarded 0.0 annotations.
# Results written to: ../analyses/iaa/relations_runs4-3-1.csv

# %%
df[['relation','1_Krippendorff', '3_Krippendorff',\
    '4_Krippendorff']].sort_values('4_Krippendorff', ascending=False)
# Out:
#                      relation  1_Krippendorff  3_Krippendorff  4_Krippendorff
# 7                      _check        0.904637        0.607970        0.917567
# 1              afforded_usual        0.336767        0.178122        0.596207
# 14           implied_category        0.260459        0.259537        0.445370
# 13         typical_of_concept        0.367910        0.307788        0.433827
# 5                  test_false             NaN        0.258187        0.409750
# 3                  impossible        0.183925        0.133176        0.390432
# 12         affording_activity        0.149149        0.196397        0.384056
# 9         typical_of_property        0.326482        0.234555        0.328336
# 0                     unusual        0.120147        0.157012        0.306007
# 8                        rare             NaN        0.129970        0.283294
# 15        variability_limited        0.197795        0.103467        0.252497
# 4            variability_open        0.143751        0.215107        0.218539
# 6                    creative        0.040020        0.058862        0.160452
# 11           afforded_unusual        0.108460        0.067595        0.104033
# 2                   test_true             NaN        0.038257        0.006591
# 10  variability_subcategories        0.157270             NaN             NaN
