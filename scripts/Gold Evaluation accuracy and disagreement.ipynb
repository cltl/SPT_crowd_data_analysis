# %% [markdown]
# # Evaluation of different crowd analysis metrics
#
#
# (1) Dataset filtering:
#
# * Exclude workers based on:
#     - contradiction ration (absolut thresh, batch stdv, pair stdv, total stdv)
#     - worker quality score (thresholds)
#     - attention check fails
#
# (2) Label aggregation:
#
# * Majority vote
# * Top vote
# * CT unit-label score (tresholds)

# %%
from clean_annotations import clean_workers
from load_data import load_experiment_data, load_expert_data, load_gold_data
from aggregation import aggregate_binary_labels

from load_data import load_experiment_data
from calculate_iaa import get_agreement
from utils_analysis import sort_by_key
from utils_analysis import load_analysis, load_ct

from sklearn.metrics import precision_recall_fscore_support as p_r_f1
from collections import defaultdict


def iaa_dis_agreement(data_dict_list, expert_unit_agreement_dict):
    
    data_by_agreement = defaultdict(list)
    data_by_triple = sort_by_key(data_dict_list, ['relation', 'property', 'concept'])
    
    for t, gold_expect in expert_unit_agreement_dict.items():
        data = data_by_triple[t]
        data_by_agreement[gold_expect].extend(data)
        
    for exp, data in data_by_agreement.items():
        agreement = get_agreement(data, v=False)
        print(exp, agreement['Krippendorff'])
        

def get_expert_agreement_labels(expert_annotations):
    expert_annotations_by_unit = sort_by_key(expert_annotations, ['relation',
                                                              'property', 'concept'])
    unit_agreement_dict = dict()
    for unit, data in expert_annotations_by_unit.items():
        agreements = []
        for d in data:
            w = d['workerid']
            if not w.endswith('_test1'):
                for k in d.keys():
                    #print(k)
                    if k.startswith('disagreement_'):
                        agreements.append(k)
        n_agreement_annotations = len(agreements)
        n_agree = agreements.count('disagreement_agreement')
        prop_agreement = n_agree/n_agreement_annotations

        if prop_agreement == 1.0:
            unit_agreement_dict[unit] = 'agreement'
        elif 'disagreement_agreement' in agreements:
            unit_agreement_dict[unit] = 'possible_disagreement'
        else:
            unit_agreement_dict[unit] = 'disagreement'
    return unit_agreement_dict




def get_gold_dis_agreement(gold, agreement_labels):
    
    gold_agree = defaultdict(list)
    
    for d in gold:
        t = f"{d['relation']}-{d['property']}-{d['concept']}"
        label = agreement_labels[t]
        gold_agree[label].append(d)
    return gold_agree

# %% [markdown]
# # Total evaluation

# %%
from load_data import load_experiment_data, load_gold_data
from evaluation import evaluate_configs

import pandas as pd

# %%
# load gold
group = 'reason_agreement*_expert_inspection*'
run = 4
gold = load_gold_data(run, group)
for d in gold:
    if 'answer' not in d:
        print(d)
print('number of gold instances: ', len(gold))

# load crowd:
run = '*'
group = 'experiment*'
n_q = '*'
batch = '*'
crowd = load_experiment_data(run, group, n_q, batch)
# Out:
# number of gold instances:  154
# Discarded 655.0 annotations.

# %%
overview_dicts = evaluate_configs(gold, crowd)
df =  pd.DataFrame(overview_dicts) 
df = df.sort_values(by=['relations-f1'], ascending=False)[['config',
                                                      'relations-f1',
                                                      'levels-f1', 
                                                        'negative_relations-f1', 'alpha']]
df.round(2).to_csv('../analyses/evaluation_accuracy_full.csv')
df
# Out:
# number of gold instances:  154
# Discarded 655.0 annotations.
# ----Label distribution----
# True: 30
# False 124
# ----------------------------
# 154 17917 1743
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# clean all contradictory annotations
#                                                config  relations-f1  \
# 38        (batch, 0.5, contradictions, majority_vote)      0.829942
# 62        (total, 1.5, contradictions, majority_vote)      0.821906
# 58          (total, 1, contradictions, majority_vote)      0.821906
# 46        (batch, 1.5, contradictions, majority_vote)      0.813515
# 54        (total, 0.5, contradictions, majority_vote)      0.813407
# 42          (batch, 1, contradictions, majority_vote)      0.812352
# 26           (pair, 1, contradictions, majority_vote)      0.804241
# 60              (total, 1, crowdtruth, majority_vote)      0.800245
# 28               (pair, 1, crowdtruth, majority_vote)      0.794848
# 66          (total, 2, contradictions, majority_vote)      0.793501
# 2                                         ct_vote_0.5      0.789453
# 48            (batch, 1.5, crowdtruth, majority_vote)      0.789453
# 52              (batch, 2, crowdtruth, majority_vote)      0.789453
# 5                                        ct_vote_0.65      0.788171
# 30         (pair, 1.5, contradictions, majority_vote)      0.788139
# 3                                        ct_vote_0.55      0.786678
# 22         (pair, 0.5, contradictions, majority_vote)      0.786519
# 50          (batch, 2, contradictions, majority_vote)      0.785202
# 55             (total, 0.5, contradictions, top_vote)      0.784329
# 4                                         ct_vote_0.6      0.784310
# 34           (pair, 2, contradictions, majority_vote)      0.782780
# 32             (pair, 1.5, crowdtruth, majority_vote)      0.782780
# 36               (pair, 2, crowdtruth, majority_vote)      0.782780
# 51               (batch, 2, contradictions, top_vote)      0.781356
# 47             (batch, 1.5, contradictions, top_vote)      0.781356
# 64            (total, 1.5, crowdtruth, majority_vote)      0.777422
# 68              (total, 2, crowdtruth, majority_vote)      0.777422
# 70  (None, None, exclude_contradictory_annotations...      0.777422
# 0                                       majority_vote      0.777422
# 43               (batch, 1, contradictions, top_vote)      0.776747
# ..                                                ...           ...
# 49                 (batch, 1.5, crowdtruth, top_vote)      0.763138
# 71  (None, None, exclude_contradictory_annotations...      0.763138
# 33                  (pair, 1.5, crowdtruth, top_vote)      0.763138
# 1                                            top_vote      0.763138
# 37                    (pair, 2, crowdtruth, top_vote)      0.763138
# 39             (batch, 0.5, contradictions, top_vote)      0.761223
# 21                                      top_vote_ct_1      0.760838
# 14                                    top_vote_ct_0.6      0.760838
# 31              (pair, 1.5, contradictions, top_vote)      0.760838
# 35                (pair, 2, contradictions, top_vote)      0.760838
# 13                                   top_vote_ct_0.55      0.760838
# 12                                    top_vote_ct_0.5      0.760838
# 18                                    top_vote_ct_0.8      0.760838
# 27                (pair, 1, contradictions, top_vote)      0.760838
# 20                                    top_vote_ct_0.9      0.760838
# 19                                   top_vote_ct_0.85      0.760838
# 15                                   top_vote_ct_0.65      0.760838
# 17                                   top_vote_ct_0.75      0.760838
# 16                                    top_vote_ct_0.7      0.760838
# 8                                         ct_vote_0.8      0.759221
# 45                   (batch, 1, crowdtruth, top_vote)      0.758187
# 56            (total, 0.5, crowdtruth, majority_vote)      0.757047
# 7                                        ct_vote_0.75      0.756111
# 10                                        ct_vote_0.9      0.740523
# 9                                        ct_vote_0.85      0.740523
# 41                 (batch, 0.5, crowdtruth, top_vote)      0.727273
# 11                                          ct_vote_1      0.718303
# 25                  (pair, 0.5, crowdtruth, top_vote)      0.714286
# 40            (batch, 0.5, crowdtruth, majority_vote)      0.671949
# 24             (pair, 0.5, crowdtruth, majority_vote)      0.654774
#
#     levels-f1  negative_relations-f1     alpha
# 38   0.812390               0.838247  0.197202
# 62   0.796042               0.820254  0.199057
# 58   0.796042               0.820254  0.208858
# 46   0.766163               0.800347  0.195085
# 54   0.794204               0.818687  0.226988
# 42   0.782249               0.807437  0.189528
# 26   0.766163               0.797615  0.196745
# 60   0.751142               0.776627  0.176613
# 28   0.736035               0.769632  0.186099
# 66   0.766163               0.783620  0.196364
# 2    0.782249               0.786169  0.183774
# 48   0.751142               0.762631  0.178579
# 52   0.751142               0.762631  0.179795
# 5    0.765929               0.787254  0.183774
# 30   0.751142               0.776627  0.189510
# 3    0.781122               0.783620  0.183774
# 22   0.762543               0.785075  0.208847
# 50   0.751142               0.771969  0.190307
# 55   0.713479               0.786885  0.226988
# 4    0.777151               0.791942  0.183774
# 34   0.751142               0.769632  0.189027
# 32   0.751142               0.762631  0.177379
# 36   0.751142               0.762631  0.183853
# 51   0.730883               0.777180  0.190307
# 47   0.730883               0.777180  0.195085
# 64   0.751142               0.762631  0.183774
# 68   0.751142               0.762631  0.183774
# 70   0.751142               0.762631  0.361085
# 0    0.751142               0.762631  0.183774
# 43   0.733285               0.789557  0.189528
# ..        ...                    ...       ...
# 49   0.713479               0.760675  0.178579
# 71   0.713479               0.760675  0.361085
# 33   0.713479               0.760675  0.177379
# 1    0.713479               0.760675  0.183774
# 37   0.713479               0.760675  0.183853
# 39   0.716421               0.786885  0.197202
# 21   0.759743               0.770234  0.183774
# 14   0.759743               0.770234  0.183774
# 31   0.695675               0.753215  0.189510
# 35   0.695675               0.753215  0.189027
# 13   0.759743               0.770234  0.183774
# 12   0.759743               0.770234  0.183774
# 18   0.759743               0.770234  0.183774
# 27   0.695675               0.753215  0.196745
# 20   0.759743               0.770234  0.183774
# 19   0.759743               0.770234  0.183774
# 15   0.759743               0.770234  0.183774
# 17   0.759743               0.770234  0.183774
# 16   0.759743               0.770234  0.183774
# 8    0.684731               0.756421  0.183774
# 45   0.699222               0.747539  0.178276
# 56   0.720819               0.727436  0.159763
# 7    0.685499               0.750689  0.183774
# 10   0.684731               0.734353  0.183774
# 9    0.684731               0.734353  0.183774
# 41   0.653404               0.708618  0.191590
# 11   0.568049               0.681801  0.183774
# 25   0.653404               0.692430  0.187081
# 40   0.627378               0.647055  0.191590
# 24   0.611240               0.624718  0.187081
#
# [72 rows x 5 columns]

# %%
#print(df.round(2).to_latex(index=False))
#gold[0]

# %% [markdown]
#  # Evaluation with respect to expected worker behavior

# %%
from utils_analysis import sort_by_key

# get agreement data

run = "4"
#group1 = 'reason_agreement_expert_inspection1'
group = 'reason_agreement*_expert_inspection*'
batch = '*'
n_q = '*'

#run4-group_reason_agreement_expert_inspection1
#expert_annotations = load_expert_data(run, group, n_q, batch)
#expert_annotations2 = load_expert_data(run, group2, n_q, batch)
#expert_annotations = expert_annotations1 + expert_annotations2
#expert_unit_agreement_dict = get_expert_agreement_labels(expert_annotations)
#agreement_labels = get_expert_agreement_labels(expert_annotations)

gold_by_agreement = sort_by_key(gold, ['expected_agreement'])
print('\n--- agreement categories---')
for l in gold_by_agreement.keys():
    print(l)
# Out:
# possible_disagreement
# disagreement
# disagreement
#
# --- agreement categories---
# possible_disagreement
# disagreement
# agreement

# %%
# evaluate agree category:
gold_agree = gold_by_agreement['agreement']
gold_poss_disagree = gold_by_agreement['possible_disagreement']
gold_disagree = gold_by_agreement['disagreement']
print(len(gold_agree))
print(len(gold_poss_disagree))
print(len(gold_disagree))
# Out:
# 59
# 86
# 9

# %%
# agree

overview_dicts = evaluate_configs(gold_agree, crowd)
df =  pd.DataFrame(overview_dicts) 
df = df.sort_values(by=['relations-f1'], ascending=False)[['config',
                                                      'relations-f1',
                                                      'levels-f1', 
                                                        'negative_relations-f1', 'alpha']]
df.round(2).to_csv('../analyses/evaluation_accuracy_agree.csv')
df
# Out:
# ----Label distribution----
# True: 7
# False 52
# ----------------------------
# 59 17917 714
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# clean all contradictory annotations
#                                                config  relations-f1  \
# 5                                        ct_vote_0.65      0.907571
# 6                                         ct_vote_0.7      0.903664
# 8                                         ct_vote_0.8      0.898305
# 7                                        ct_vote_0.75      0.898305
# 22         (pair, 0.5, contradictions, majority_vote)      0.896849
# 54        (total, 0.5, contradictions, majority_vote)      0.896849
# 58          (total, 1, contradictions, majority_vote)      0.896849
# 4                                         ct_vote_0.6      0.883410
# 62        (total, 1.5, contradictions, majority_vote)      0.883410
# 38        (batch, 0.5, contradictions, majority_vote)      0.870077
# 9                                        ct_vote_0.85      0.866840
# 10                                        ct_vote_0.9      0.866840
# 26           (pair, 1, contradictions, majority_vote)      0.856804
# 46        (batch, 1.5, contradictions, majority_vote)      0.856804
# 28               (pair, 1, crowdtruth, majority_vote)      0.843550
# 34           (pair, 2, contradictions, majority_vote)      0.843550
# 60              (total, 1, crowdtruth, majority_vote)      0.843550
# 30         (pair, 1.5, contradictions, majority_vote)      0.843550
# 3                                        ct_vote_0.55      0.843550
# 2                                         ct_vote_0.5      0.843550
# 42          (batch, 1, contradictions, majority_vote)      0.841205
# 56            (total, 0.5, crowdtruth, majority_vote)      0.830282
# 52              (batch, 2, crowdtruth, majority_vote)      0.830282
# 50          (batch, 2, contradictions, majority_vote)      0.830282
# 48            (batch, 1.5, crowdtruth, majority_vote)      0.830282
# 32             (pair, 1.5, crowdtruth, majority_vote)      0.830282
# 64            (total, 1.5, crowdtruth, majority_vote)      0.830282
# 44              (batch, 1, crowdtruth, majority_vote)      0.830282
# 68              (total, 2, crowdtruth, majority_vote)      0.830282
# 70  (None, None, exclude_contradictory_annotations...      0.830282
# ..                                                ...           ...
# 18                                    top_vote_ct_0.8      0.783462
# 13                                   top_vote_ct_0.55      0.783462
# 12                                    top_vote_ct_0.5      0.783462
# 63             (total, 1.5, contradictions, top_vote)      0.766821
# 59               (total, 1, contradictions, top_vote)      0.766821
# 67               (total, 2, contradictions, top_vote)      0.766821
# 43               (batch, 1, contradictions, top_vote)      0.766821
# 39             (batch, 0.5, contradictions, top_vote)      0.754590
# 23              (pair, 0.5, contradictions, top_vote)      0.747458
# 61                   (total, 1, crowdtruth, top_vote)      0.742247
# 65                 (total, 1.5, crowdtruth, top_vote)      0.742247
# 57                 (total, 0.5, crowdtruth, top_vote)      0.742247
# 69                   (total, 2, crowdtruth, top_vote)      0.742247
# 31              (pair, 1.5, contradictions, top_vote)      0.742247
# 53                   (batch, 2, crowdtruth, top_vote)      0.742247
# 33                  (pair, 1.5, crowdtruth, top_vote)      0.742247
# 51               (batch, 2, contradictions, top_vote)      0.742247
# 49                 (batch, 1.5, crowdtruth, top_vote)      0.742247
# 47             (batch, 1.5, contradictions, top_vote)      0.742247
# 27                (pair, 1, contradictions, top_vote)      0.742247
# 37                    (pair, 2, crowdtruth, top_vote)      0.742247
# 1                                            top_vote      0.742247
# 35                (pair, 2, contradictions, top_vote)      0.742247
# 29                    (pair, 1, crowdtruth, top_vote)      0.742247
# 71  (None, None, exclude_contradictory_annotations...      0.742247
# 40            (batch, 0.5, crowdtruth, majority_vote)      0.734803
# 45                   (batch, 1, crowdtruth, top_vote)      0.729769
# 24             (pair, 0.5, crowdtruth, majority_vote)      0.720881
# 25                  (pair, 0.5, crowdtruth, top_vote)      0.676173
# 41                 (batch, 0.5, crowdtruth, top_vote)      0.676173
#
#     levels-f1  negative_relations-f1     alpha
# 5    0.945028               0.892624  0.253746
# 6    0.915001               0.888338  0.253746
# 8    0.907611               0.882353  0.253746
# 7    0.907611               0.882353  0.253746
# 22   0.894802               0.879690  0.323356
# 54   0.894802               0.879690  0.342014
# 58   0.894802               0.879690  0.302838
# 4    0.919539               0.863815  0.253746
# 62   0.870514               0.863815  0.291210
# 38   0.822376               0.848004  0.302973
# 9    0.869608               0.846291  0.253746
# 10   0.869608               0.846291  0.253746
# 26   0.822376               0.832202  0.287787
# 46   0.846437               0.832202  0.272882
# 28   0.846437               0.816359  0.248437
# 34   0.822376               0.816359  0.269930
# 60   0.846437               0.816359  0.244441
# 30   0.822376               0.816359  0.275389
# 3    0.846437               0.816359  0.253746
# 2    0.846437               0.816359  0.253746
# 42   0.822376               0.814227  0.281476
# 56   0.870514               0.800429  0.184442
# 52   0.822376               0.800429  0.247165
# 50   0.822376               0.800429  0.267163
# 48   0.822376               0.800429  0.251416
# 32   0.822376               0.800429  0.246395
# 64   0.822376               0.800429  0.253746
# 44   0.822376               0.800429  0.236812
# 68   0.822376               0.800429  0.253746
# 70   0.822376               0.800429  0.361322
# ..        ...                    ...       ...
# 18   0.698529               0.746674  0.253746
# 13   0.698529               0.746674  0.253746
# 12   0.698529               0.746674  0.253746
# 63   0.698529               0.727629  0.291210
# 59   0.698529               0.727629  0.302838
# 67   0.698529               0.727629  0.276696
# 43   0.698529               0.727629  0.281476
# 39   0.673044               0.712897  0.302973
# 23   0.646826               0.701908  0.323356
# 61   0.673044               0.697964  0.244441
# 65   0.673044               0.697964  0.253746
# 57   0.673044               0.697964  0.184442
# 69   0.673044               0.697964  0.253746
# 31   0.673044               0.697964  0.275389
# 53   0.673044               0.697964  0.247165
# 33   0.673044               0.697964  0.246395
# 51   0.673044               0.697964  0.267163
# 49   0.673044               0.697964  0.251416
# 47   0.673044               0.697964  0.272882
# 27   0.673044               0.697964  0.287787
# 37   0.673044               0.697964  0.253746
# 1    0.673044               0.697964  0.253746
# 35   0.673044               0.697964  0.269930
# 29   0.673044               0.697964  0.248437
# 71   0.673044               0.697964  0.361322
# 40   0.748775               0.701961  0.241626
# 45   0.646826               0.682801  0.236812
# 24   0.723345               0.685001  0.241672
# 25   0.569082               0.618504  0.241672
# 41   0.569082               0.618504  0.241626
#
# [72 rows x 5 columns]

# %%
#print(df.to_latex(index=False))

# %%
# possible disagreement 

overview_dicts = evaluate_configs(gold_poss_disagree, crowd)
df =  pd.DataFrame(overview_dicts) 
df = df.sort_values(by=['relations-f1'], ascending=False)[['config',
                                                      'relations-f1',
                                                      'levels-f1', 
                                                        'negative_relations-f1', 'alpha']]
df.round(2).to_csv('../analyses/evaluation_accuracy_poss_disagree.csv')
df
# Out:
# ----Label distribution----
# True: 15
# False 71
# ----------------------------
# 86 17917 926
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# clean all contradictory annotations
#                                                config  relations-f1  \
# 38        (batch, 0.5, contradictions, majority_vote)      0.827984
# 42          (batch, 1, contradictions, majority_vote)      0.806482
# 26           (pair, 1, contradictions, majority_vote)      0.803523
# 62        (total, 1.5, contradictions, majority_vote)      0.803523
# 66          (total, 2, contradictions, majority_vote)      0.794241
# 58          (total, 1, contradictions, majority_vote)      0.794241
# 54        (total, 0.5, contradictions, majority_vote)      0.790819
# 45                   (batch, 1, crowdtruth, top_vote)      0.787703
# 61                   (total, 1, crowdtruth, top_vote)      0.787703
# 16                                    top_vote_ct_0.7      0.786728
# 27                (pair, 1, contradictions, top_vote)      0.786728
# 21                                      top_vote_ct_1      0.786728
# 19                                   top_vote_ct_0.85      0.786728
# 18                                    top_vote_ct_0.8      0.786728
# 17                                   top_vote_ct_0.75      0.786728
# 20                                    top_vote_ct_0.9      0.786728
# 15                                   top_vote_ct_0.65      0.786728
# 14                                    top_vote_ct_0.6      0.786728
# 13                                   top_vote_ct_0.55      0.786728
# 12                                    top_vote_ct_0.5      0.786728
# 59               (total, 1, contradictions, top_vote)      0.784980
# 63             (total, 1.5, contradictions, top_vote)      0.784980
# 55             (total, 0.5, contradictions, top_vote)      0.784980
# 46        (batch, 1.5, contradictions, majority_vote)      0.784980
# 67               (total, 2, contradictions, top_vote)      0.784980
# 29                    (pair, 1, crowdtruth, top_vote)      0.784980
# 60              (total, 1, crowdtruth, majority_vote)      0.781692
# 31              (pair, 1.5, contradictions, top_vote)      0.777751
# 35                (pair, 2, contradictions, top_vote)      0.777751
# 3                                        ct_vote_0.55      0.777751
# ..                                                ...           ...
# 28               (pair, 1, crowdtruth, majority_vote)      0.772582
# 32             (pair, 1.5, crowdtruth, majority_vote)      0.772582
# 30         (pair, 1.5, contradictions, majority_vote)      0.772582
# 51               (batch, 2, contradictions, top_vote)      0.768800
# 23              (pair, 0.5, contradictions, top_vote)      0.768800
# 47             (batch, 1.5, contradictions, top_vote)      0.768800
# 50          (batch, 2, contradictions, majority_vote)      0.766473
# 68              (total, 2, crowdtruth, majority_vote)      0.763478
# 0                                       majority_vote      0.763478
# 64            (total, 1.5, crowdtruth, majority_vote)      0.763478
# 34           (pair, 2, contradictions, majority_vote)      0.763478
# 70  (None, None, exclude_contradictory_annotations...      0.763478
# 39             (batch, 0.5, contradictions, top_vote)      0.747917
# 11                                          ct_vote_1      0.746704
# 57                 (total, 0.5, crowdtruth, top_vote)      0.745243
# 5                                        ct_vote_0.65      0.743086
# 44              (batch, 1, crowdtruth, majority_vote)      0.741976
# 22         (pair, 0.5, contradictions, majority_vote)      0.741829
# 56            (total, 0.5, crowdtruth, majority_vote)      0.732417
# 7                                        ct_vote_0.75      0.731360
# 43               (batch, 1, contradictions, top_vote)      0.729238
# 9                                        ct_vote_0.85      0.729085
# 8                                         ct_vote_0.8      0.729085
# 10                                        ct_vote_0.9      0.729085
# 4                                         ct_vote_0.6      0.728882
# 6                                         ct_vote_0.7      0.724391
# 41                 (batch, 0.5, crowdtruth, top_vote)      0.702784
# 25                  (pair, 0.5, crowdtruth, top_vote)      0.681554
# 40            (batch, 0.5, crowdtruth, majority_vote)      0.659582
# 24             (pair, 0.5, crowdtruth, majority_vote)      0.638951
#
#     levels-f1  negative_relations-f1     alpha
# 38   0.712569               0.796961  0.097433
# 42   0.690999               0.769889  0.099448
# 26   0.689535               0.766422  0.119505
# 62   0.689535               0.766422  0.121144
# 66   0.668349               0.754623  0.122368
# 58   0.668349               0.754623  0.127916
# 54   0.665935               0.750513  0.135779
# 45   0.690999               0.748173  0.125144
# 61   0.690999               0.760412  0.114164
# 16   0.645183               0.750513  0.119937
# 27   0.645183               0.750513  0.119505
# 21   0.645183               0.750513  0.119937
# 19   0.645183               0.750513  0.119937
# 18   0.645183               0.750513  0.119937
# 17   0.645183               0.750513  0.119937
# 20   0.645183               0.750513  0.119937
# 15   0.645183               0.750513  0.119937
# 14   0.645183               0.750513  0.119937
# 13   0.645183               0.750513  0.119937
# 12   0.645183               0.750513  0.119937
# 59   0.668349               0.757886  0.127916
# 63   0.668349               0.757886  0.121144
# 55   0.668349               0.757886  0.135779
# 46   0.668349               0.742817  0.117966
# 67   0.668349               0.757886  0.122368
# 29   0.668349               0.745859  0.126582
# 60   0.665935               0.738942  0.114164
# 31   0.645183               0.738942  0.113296
# 35   0.645183               0.738942  0.115952
# 3    0.661674               0.734101  0.119937
# ..        ...                    ...       ...
# 28   0.645183               0.727359  0.126582
# 32   0.665935               0.727359  0.114517
# 30   0.645183               0.727359  0.113296
# 51   0.645183               0.727359  0.118045
# 23   0.624129               0.727359  0.119989
# 47   0.645183               0.727359  0.117966
# 50   0.646856               0.719107  0.118045
# 68   0.645183               0.715745  0.119937
# 0    0.645183               0.715745  0.119937
# 64   0.645183               0.715745  0.119937
# 34   0.645183               0.715745  0.115952
# 70   0.645183               0.715745  0.252311
# 39   0.602704               0.733791  0.097433
# 11   0.604023               0.707106  0.119937
# 57   0.624129               0.707170  0.140568
# 5    0.601973               0.700693  0.119937
# 44   0.621393               0.700095  0.125144
# 22   0.616564               0.706112  0.119989
# 56   0.624142               0.685813  0.140568
# 7    0.582307               0.686981  0.119937
# 43   0.579923               0.709465  0.099448
# 9    0.568621               0.685112  0.119937
# 8    0.568621               0.685112  0.119937
# 10   0.568621               0.685112  0.119937
# 4    0.581395               0.691387  0.119937
# 6    0.567383               0.678115  0.119937
# 41   0.580877               0.668649  0.155154
# 25   0.580877               0.642140  0.143710
# 40   0.602704               0.633448  0.155154
# 24   0.579923               0.607266  0.143710
#
# [72 rows x 5 columns]

# %%
#disagree
overview_dicts = evaluate_configs(gold_disagree, crowd)
df =  pd.DataFrame(overview_dicts) 
df = df.sort_values(by=['relations-f1'], ascending=False)[['config',
                                                      'relations-f1',
                                                      'levels-f1', 
                                                        'negative_relations-f1', 'alpha']]
df.round(2).to_csv('../analyses/evaluation_accuracy_disagree.csv')
df
# Out:
# ----Label distribution----
# True: 3
# False 2
# ----------------------------
# 5 17917 53
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# clean all contradictory annotations
#                                                config  relations-f1  \
# 38        (batch, 0.5, contradictions, majority_vote)      0.780952
# 54        (total, 0.5, contradictions, majority_vote)      0.600000
# 6                                         ct_vote_0.7      0.566667
# 71  (None, None, exclude_contradictory_annotations...      0.450000
# 39             (batch, 0.5, contradictions, top_vote)      0.450000
# 29                    (pair, 1, crowdtruth, top_vote)      0.450000
# 59               (total, 1, contradictions, top_vote)      0.450000
# 31              (pair, 1.5, contradictions, top_vote)      0.450000
# 33                  (pair, 1.5, crowdtruth, top_vote)      0.450000
# 57                 (total, 0.5, crowdtruth, top_vote)      0.450000
# 35                (pair, 2, contradictions, top_vote)      0.450000
# 1                                            top_vote      0.450000
# 37                    (pair, 2, crowdtruth, top_vote)      0.450000
# 41                 (batch, 0.5, crowdtruth, top_vote)      0.450000
# 55             (total, 0.5, contradictions, top_vote)      0.450000
# 25                  (pair, 0.5, crowdtruth, top_vote)      0.450000
# 42          (batch, 1, contradictions, majority_vote)      0.450000
# 43               (batch, 1, contradictions, top_vote)      0.450000
# 45                   (batch, 1, crowdtruth, top_vote)      0.450000
# 46        (batch, 1.5, contradictions, majority_vote)      0.450000
# 47             (batch, 1.5, contradictions, top_vote)      0.450000
# 53                   (batch, 2, crowdtruth, top_vote)      0.450000
# 49                 (batch, 1.5, crowdtruth, top_vote)      0.450000
# 50          (batch, 2, contradictions, majority_vote)      0.450000
# 27                (pair, 1, contradictions, top_vote)      0.450000
# 61                   (total, 1, crowdtruth, top_vote)      0.450000
# 14                                    top_vote_ct_0.6      0.450000
# 17                                   top_vote_ct_0.75      0.450000
# 2                                         ct_vote_0.5      0.450000
# 69                   (total, 2, crowdtruth, top_vote)      0.450000
# ..                                                ...           ...
# 23              (pair, 0.5, contradictions, top_vote)      0.450000
# 5                                        ct_vote_0.65      0.400000
# 62        (total, 1.5, contradictions, majority_vote)      0.342857
# 58          (total, 1, contradictions, majority_vote)      0.342857
# 64            (total, 1.5, crowdtruth, majority_vote)      0.342857
# 66          (total, 2, contradictions, majority_vote)      0.342857
# 68              (total, 2, crowdtruth, majority_vote)      0.342857
# 70  (None, None, exclude_contradictory_annotations...      0.342857
# 60              (total, 1, crowdtruth, majority_vote)      0.342857
# 52              (batch, 2, crowdtruth, majority_vote)      0.342857
# 0                                       majority_vote      0.342857
# 48            (batch, 1.5, crowdtruth, majority_vote)      0.342857
# 30         (pair, 1.5, contradictions, majority_vote)      0.342857
# 3                                        ct_vote_0.55      0.342857
# 4                                         ct_vote_0.6      0.342857
# 44              (batch, 1, crowdtruth, majority_vote)      0.342857
# 28               (pair, 1, crowdtruth, majority_vote)      0.342857
# 36               (pair, 2, crowdtruth, majority_vote)      0.342857
# 32             (pair, 1.5, crowdtruth, majority_vote)      0.342857
# 34           (pair, 2, contradictions, majority_vote)      0.342857
# 11                                          ct_vote_1      0.228571
# 10                                        ct_vote_0.9      0.228571
# 9                                        ct_vote_0.85      0.228571
# 8                                         ct_vote_0.8      0.228571
# 7                                        ct_vote_0.75      0.228571
# 26           (pair, 1, contradictions, majority_vote)      0.200000
# 22         (pair, 0.5, contradictions, majority_vote)      0.200000
# 56            (total, 0.5, crowdtruth, majority_vote)      0.200000
# 40            (batch, 0.5, crowdtruth, majority_vote)      0.000000
# 24             (pair, 0.5, crowdtruth, majority_vote)      0.000000
#
#     levels-f1  negative_relations-f1     alpha
# 38   0.780952               0.780952 -0.079394
# 54   0.600000               0.600000 -0.059838
# 6    0.566667               0.566667 -0.085522
# 71   0.450000               0.450000  0.001299
# 39   0.450000               0.450000 -0.079394
# 29   0.450000               0.450000 -0.087568
# 59   0.450000               0.450000 -0.062309
# 31   0.450000               0.450000 -0.088757
# 33   0.450000               0.450000 -0.084635
# 57   0.450000               0.450000 -0.136601
# 35   0.450000               0.450000 -0.077106
# 1    0.450000               0.450000 -0.085522
# 37   0.450000               0.450000 -0.084635
# 41   0.450000               0.450000 -0.112741
# 55   0.450000               0.450000 -0.059838
# 25   0.450000               0.450000 -0.110417
# 42   0.450000               0.450000 -0.069231
# 43   0.450000               0.450000 -0.069231
# 45   0.450000               0.450000 -0.082759
# 46   0.450000               0.450000 -0.085137
# 47   0.450000               0.450000 -0.085137
# 53   0.450000               0.450000 -0.091276
# 49   0.450000               0.450000 -0.091276
# 50   0.450000               0.450000 -0.095960
# 27   0.450000               0.450000 -0.087094
# 61   0.450000               0.450000 -0.084635
# 14   0.450000               0.450000 -0.085522
# 17   0.450000               0.450000 -0.085522
# 2    0.450000               0.450000 -0.085522
# 69   0.450000               0.450000 -0.085522
# ..        ...                    ...       ...
# 23   0.450000               0.450000 -0.096199
# 5    0.400000               0.400000 -0.085522
# 62   0.342857               0.342857 -0.087272
# 58   0.342857               0.342857 -0.062309
# 64   0.342857               0.342857 -0.085522
# 66   0.342857               0.342857 -0.076871
# 68   0.342857               0.342857 -0.085522
# 70   0.342857               0.342857  0.001299
# 60   0.342857               0.342857 -0.084635
# 52   0.342857               0.342857 -0.091276
# 0    0.342857               0.342857 -0.085522
# 48   0.342857               0.342857 -0.091276
# 30   0.342857               0.342857 -0.088757
# 3    0.342857               0.342857 -0.085522
# 4    0.342857               0.342857 -0.085522
# 44   0.342857               0.342857 -0.082759
# 28   0.342857               0.342857 -0.087568
# 36   0.342857               0.342857 -0.084635
# 32   0.342857               0.342857 -0.084635
# 34   0.342857               0.342857 -0.077106
# 11   0.228571               0.228571 -0.085522
# 10   0.228571               0.228571 -0.085522
# 9    0.228571               0.228571 -0.085522
# 8    0.228571               0.228571 -0.085522
# 7    0.228571               0.228571 -0.085522
# 26   0.200000               0.200000 -0.087094
# 22   0.200000               0.200000 -0.096199
# 56   0.200000               0.200000 -0.136601
# 40   0.000000               0.000000 -0.112741
# 24   0.000000               0.000000 -0.110417
#
# [72 rows x 5 columns]
