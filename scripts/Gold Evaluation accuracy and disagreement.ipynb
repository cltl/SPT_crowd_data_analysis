# %% [markdown]
# # Evaluation of different crowd analysis metrics
#
#
# (1) Dataset filtering:
#
# * Exclude workers based on:
#     - contradiction ration (absolut thresh, batch stdv, pair stdv, total stdv)
#     - worker quality score (thresholds)
#     - attention check fails
#
# (2) Label aggregation:
#
# * Majority vote
# * Top vote
# * CT unit-label score (tresholds)

# %%
from clean_annotations import clean_workers
from calculate_iaa import get_agreement
from aggregation import aggregate_binary_labels
from evaluation import evaluate_configs


from utils_data import load_experiment_data, load_expert_data, load_gold_data
from utils_analysis import sort_by_key
from utils_analysis import load_analysis, load_ct

from sklearn.metrics import precision_recall_fscore_support as p_r_f1
from collections import defaultdict
import pandas as pd


def iaa_dis_agreement(data_dict_list, expert_unit_agreement_dict):
    
    data_by_agreement = defaultdict(list)
    data_by_triple = sort_by_key(data_dict_list, ['relation', 'property', 'concept'])
    
    for t, gold_expect in expert_unit_agreement_dict.items():
        data = data_by_triple[t]
        data_by_agreement[gold_expect].extend(data)
        
    for exp, data in data_by_agreement.items():
        agreement = get_agreement(data, v=False)
        print(exp, agreement['Krippendorff'])
        

def get_expert_agreement_labels(expert_annotations):
    expert_annotations_by_unit = sort_by_key(expert_annotations, ['relation',
                                                              'property', 'concept'])
    unit_agreement_dict = dict()
    for unit, data in expert_annotations_by_unit.items():
        agreements = []
        for d in data:
            w = d['workerid']
            if not w.endswith('_test1'):
                for k in d.keys():
                    #print(k)
                    if k.startswith('disagreement_'):
                        agreements.append(k)
        n_agreement_annotations = len(agreements)
        n_agree = agreements.count('disagreement_agreement')
        prop_agreement = n_agree/n_agreement_annotations

        if prop_agreement == 1.0:
            unit_agreement_dict[unit] = 'agreement'
        elif 'disagreement_agreement' in agreements:
            unit_agreement_dict[unit] = 'possible_disagreement'
        else:
            unit_agreement_dict[unit] = 'disagreement'
    return unit_agreement_dict




def get_gold_dis_agreement(gold, agreement_labels):
    
    gold_agree = defaultdict(list)
    
    for d in gold:
        t = f"{d['relation']}-{d['property']}-{d['concept']}"
        label = agreement_labels[t]
        gold_agree[label].append(d)
    return gold_agree

# %% [markdown]
# # Total evaluation

# %%
# load gold

gold = load_gold_data()
print(len(gold))
# remove instances without gold
gold = [d for d in gold if d['answer'] != 'NOGOLD']
print(len(gold))
# Out:
# 154
# 131

# %%
# load crowd:
run = '*'
group = 'experiment*'
n_q = '*'
batch = '*'
crowd = load_experiment_data(run, group, n_q, batch)
# Out:
# Discarded 655.0 annotations.

# %%
ct_thresholds = [0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 1]
stds = [ 0.5, 1, 1.5, 2]
overview_dicts = evaluate_configs(gold, crowd, ct_thresholds, stds)
df =  pd.DataFrame(overview_dicts) 
df_total = df.sort_values(by=['relations-f1'], ascending=False)[['filtering',
                                                           'filtering_unit',
                                                           'n_stdv',
                                                           'aggregation',
                                                            'relations-f1',
                                                            'relations-p',
                                                           'relations-r',
                                                           'alpha', 'relations-coverage']]
df_total.round(2).to_csv('../analyses/evaluation_accuracy_full.csv')
df_total
# Out:
# ----Label distribution----
# True: 21
# False 110
# ----------------------------
# 131 17917 1491
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/piasommerauer/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# clean all contradictory annotations
#                             filtering filtering_unit n_stdv    aggregation  \
# 28                     contradictions          batch    0.5  majority_vote
# 48                     contradictions          total      1  majority_vote
# 60  exclude_contradictory_annotations              -      -  majority_vote
# 52                     contradictions          total    1.5  majority_vote
# 44                     contradictions          total    0.5  majority_vote
# 36                     contradictions          batch    1.5  majority_vote
# 32                     contradictions          batch      1  majority_vote
# 16                     contradictions           pair      1  majority_vote
# 12                     contradictions           pair    0.5  majority_vote
# 56                     contradictions          total      2  majority_vote
# 20                     contradictions           pair    1.5  majority_vote
# 40                     contradictions          batch      2  majority_vote
# 24                     contradictions           pair      2  majority_vote
# 26                             ct_wqs           pair      2  majority_vote
# 42                             ct_wqs          batch      2  majority_vote
# 22                             ct_wqs           pair    1.5  majority_vote
# 30                             ct_wqs          batch    0.5  majority_vote
# 38                             ct_wqs          batch    1.5  majority_vote
# 0                                   -              -      -  majority_vote
# 18                             ct_wqs           pair      1  majority_vote
# 14                             ct_wqs           pair    0.5  majority_vote
# 46                             ct_wqs          total    0.5  majority_vote
# 50                             ct_wqs          total      1  majority_vote
# 54                             ct_wqs          total    1.5  majority_vote
# 58                             ct_wqs          total      2  majority_vote
# 34                             ct_wqs          batch      1  majority_vote
# 13                     contradictions           pair    0.5       top_vote
# 45                     contradictions          total    0.5       top_vote
# 41                     contradictions          batch      2       top_vote
# 37                     contradictions          batch    1.5       top_vote
# ..                                ...            ...    ...            ...
# 61  exclude_contradictory_annotations              -      -       top_vote
# 17                     contradictions           pair      1       top_vote
# 25                     contradictions           pair      2       top_vote
# 21                     contradictions           pair    1.5       top_vote
# 57                     contradictions          total      2       top_vote
# 47                             ct_wqs          total    0.5       top_vote
# 59                             ct_wqs          total      2       top_vote
# 55                             ct_wqs          total    1.5       top_vote
# 51                             ct_wqs          total      1       top_vote
# 1                                   -              -      -       top_vote
# 15                             ct_wqs           pair    0.5       top_vote
# 31                             ct_wqs          batch    0.5       top_vote
# 43                             ct_wqs          batch      2       top_vote
# 39                             ct_wqs          batch    1.5       top_vote
# 35                             ct_wqs          batch      1       top_vote
# 23                             ct_wqs           pair    1.5       top_vote
# 27                             ct_wqs           pair      2       top_vote
# 19                             ct_wqs           pair      1       top_vote
# 29                     contradictions          batch    0.5       top_vote
# 33                     contradictions          batch      1       top_vote
# 7                                   -              -      -       uas-0.75
# 8                                   -              -      -        uas-0.8
# 5                                   -              -      -       uas-0.65
# 9                                   -              -      -       uas-0.85
# 4                                   -              -      -        uas-0.6
# 10                                  -              -      -        uas-0.9
# 3                                   -              -      -       uas-0.55
# 11                                  -              -      -          uas-1
# 2                                   -              -      -        uas-0.5
# 6                                   -              -      -        uas-0.7
#
#     relations-f1  relations-p  relations-r     alpha  relations-coverage
# 28      0.876159     0.917413     0.862595  0.205896                 1.0
# 48      0.859888     0.888003     0.847328  0.213531                 1.0
# 60      0.854730     0.866298     0.847328  0.337895                 1.0
# 52      0.853606     0.885221     0.839695  0.204368                 1.0
# 44      0.852112     0.877439     0.839695  0.232688                 1.0
# 36      0.849769     0.899538     0.832061  0.197188                 1.0
# 32      0.848639     0.890882     0.832061  0.191913                 1.0
# 16      0.839664     0.871849     0.824427  0.198477                 1.0
# 12      0.827994     0.845697     0.816794  0.212183                 1.0
# 56      0.827289     0.866747     0.809160  0.199709                 1.0
# 20      0.827289     0.866747     0.809160  0.190236                 1.0
# 40      0.823615     0.882083     0.801527  0.193461                 1.0
# 24      0.821119     0.864351     0.801527  0.189459                 1.0
# 26      0.814956     0.862047     0.793893  0.185651                 1.0
# 42      0.814956     0.862047     0.793893  0.185651                 1.0
# 22      0.814956     0.862047     0.793893  0.185651                 1.0
# 30      0.814956     0.862047     0.793893  0.185651                 1.0
# 38      0.814956     0.862047     0.793893  0.185651                 1.0
# 0       0.814956     0.862047     0.793893  0.185651                 1.0
# 18      0.814956     0.862047     0.793893  0.185651                 1.0
# 14      0.814956     0.862047     0.793893  0.185651                 1.0
# 46      0.814956     0.862047     0.793893  0.185651                 1.0
# 50      0.814956     0.862047     0.793893  0.185651                 1.0
# 54      0.814956     0.862047     0.793893  0.185651                 1.0
# 58      0.814956     0.862047     0.793893  0.185651                 1.0
# 34      0.814956     0.862047     0.793893  0.185651                 1.0
# 13      0.793438     0.815335     0.778626  0.212183                 1.0
# 45      0.790801     0.807270     0.778626  0.232688                 1.0
# 41      0.787560     0.812608     0.770992  0.193461                 1.0
# 37      0.787560     0.812608     0.770992  0.197188                 1.0
# ..           ...          ...          ...       ...                 ...
# 61      0.777959     0.815935     0.755725  0.337895                 1.0
# 17      0.776373     0.793393     0.763359  0.198477                 1.0
# 25      0.776373     0.793393     0.763359  0.189459                 1.0
# 21      0.776373     0.793393     0.763359  0.190236                 1.0
# 57      0.773194     0.785057     0.763359  0.199709                 1.0
# 47      0.770658     0.790657     0.755725  0.185651                 1.0
# 59      0.770658     0.790657     0.755725  0.185651                 1.0
# 55      0.770658     0.790657     0.755725  0.185651                 1.0
# 51      0.770658     0.790657     0.755725  0.185651                 1.0
# 1       0.770658     0.790657     0.755725  0.185651                 1.0
# 15      0.770658     0.790657     0.755725  0.185651                 1.0
# 31      0.770658     0.790657     0.755725  0.185651                 1.0
# 43      0.770658     0.790657     0.755725  0.185651                 1.0
# 39      0.770658     0.790657     0.755725  0.185651                 1.0
# 35      0.770658     0.790657     0.755725  0.185651                 1.0
# 23      0.770658     0.790657     0.755725  0.185651                 1.0
# 27      0.770658     0.790657     0.755725  0.185651                 1.0
# 19      0.770658     0.790657     0.755725  0.185651                 1.0
# 29      0.767604     0.796491     0.748092  0.205896                 1.0
# 33      0.750204     0.789281     0.725191  0.191913                 1.0
# 7       0.000000     0.000000     0.000000  0.185651                 1.0
# 8       0.000000     0.000000     0.000000  0.185651                 1.0
# 5       0.000000     0.000000     0.000000  0.185651                 1.0
# 9       0.000000     0.000000     0.000000  0.185651                 1.0
# 4       0.000000     0.000000     0.000000  0.185651                 1.0
# 10      0.000000     0.000000     0.000000  0.185651                 1.0
# 3       0.000000     0.000000     0.000000  0.185651                 1.0
# 11      0.000000     0.000000     0.000000  0.185651                 1.0
# 2       0.000000     0.000000     0.000000  0.185651                 1.0
# 6       0.000000     0.000000     0.000000  0.185651                 1.0
#
# [62 rows x 9 columns]

# %%
from collections import defaultdict
# Filter table for paper
from collections import Counter
# include: top thee

# top config of each filtering-voting combo
selected_rows = []
res_dicts = df_total.to_dict('records')

selected_rows.extend(res_dicts[:3])


top_dict = defaultdict(list)

for d in res_dicts:
    ag = d['aggregation']
    if ag.startswith('uas'):
        ag, thresh = ag.split('-')
    f_a = (d['filtering'], ag)
    f1 = d['relations-f1']
    top_dict[f_a].append((f1, d))


for f_a, rows in top_dict.items():
    f1s = [f1 for f1, d in rows]
    top = max(f1s)
    for f1, d in rows:
        if f1 == top:
            if d not in selected_rows:
                selected_rows.append(d)
           
df = pd.DataFrame(selected_rows).sort_values(by=['relations-f1'], ascending=False)[['filtering',
                                                           'filtering_unit',
                                                           'n_stdv',
                                                           'aggregation',
                                                            'relations-f1',
                                                            'relations-p',
                                                           'relations-r',
                                                           'alpha', 'relations-coverage']]
df
# Out:
#                             filtering filtering_unit n_stdv    aggregation  \
# 0                      contradictions          batch    0.5  majority_vote
# 1                      contradictions          total      1  majority_vote
# 2   exclude_contradictory_annotations              -      -  majority_vote
# 9                              ct_wqs           pair    0.5  majority_vote
# 15                                  -              -      -  majority_vote
# 14                             ct_wqs          batch      1  majority_vote
# 13                             ct_wqs          total      2  majority_vote
# 11                             ct_wqs          total      1  majority_vote
# 10                             ct_wqs          total    0.5  majority_vote
# 12                             ct_wqs          total    1.5  majority_vote
# 8                              ct_wqs           pair      1  majority_vote
# 7                              ct_wqs          batch    1.5  majority_vote
# 6                              ct_wqs          batch    0.5  majority_vote
# 5                              ct_wqs           pair    1.5  majority_vote
# 4                              ct_wqs          batch      2  majority_vote
# 3                              ct_wqs           pair      2  majority_vote
# 16                     contradictions           pair    0.5       top_vote
# 17  exclude_contradictory_annotations              -      -       top_vote
# 25                             ct_wqs          batch    1.5       top_vote
# 30                                  -              -      -       top_vote
# 29                             ct_wqs           pair      1       top_vote
# 28                             ct_wqs           pair      2       top_vote
# 27                             ct_wqs           pair    1.5       top_vote
# 26                             ct_wqs          batch      1       top_vote
# 20                             ct_wqs          total    1.5       top_vote
# 24                             ct_wqs          batch      2       top_vote
# 23                             ct_wqs          batch    0.5       top_vote
# 22                             ct_wqs           pair    0.5       top_vote
# 21                             ct_wqs          total      1       top_vote
# 19                             ct_wqs          total      2       top_vote
# 18                             ct_wqs          total    0.5       top_vote
# 31                                  -              -      -       uas-0.75
# 32                                  -              -      -        uas-0.8
# 33                                  -              -      -       uas-0.65
# 34                                  -              -      -       uas-0.85
# 35                                  -              -      -        uas-0.6
# 36                                  -              -      -        uas-0.9
# 37                                  -              -      -       uas-0.55
# 38                                  -              -      -          uas-1
# 39                                  -              -      -        uas-0.5
# 40                                  -              -      -        uas-0.7
#
#     relations-f1  relations-p  relations-r     alpha  relations-coverage
# 0       0.876159     0.917413     0.862595  0.205896                 1.0
# 1       0.859888     0.888003     0.847328  0.213531                 1.0
# 2       0.854730     0.866298     0.847328  0.337895                 1.0
# 9       0.814956     0.862047     0.793893  0.185651                 1.0
# 15      0.814956     0.862047     0.793893  0.185651                 1.0
# 14      0.814956     0.862047     0.793893  0.185651                 1.0
# 13      0.814956     0.862047     0.793893  0.185651                 1.0
# 11      0.814956     0.862047     0.793893  0.185651                 1.0
# 10      0.814956     0.862047     0.793893  0.185651                 1.0
# 12      0.814956     0.862047     0.793893  0.185651                 1.0
# 8       0.814956     0.862047     0.793893  0.185651                 1.0
# 7       0.814956     0.862047     0.793893  0.185651                 1.0
# 6       0.814956     0.862047     0.793893  0.185651                 1.0
# 5       0.814956     0.862047     0.793893  0.185651                 1.0
# 4       0.814956     0.862047     0.793893  0.185651                 1.0
# 3       0.814956     0.862047     0.793893  0.185651                 1.0
# 16      0.793438     0.815335     0.778626  0.212183                 1.0
# 17      0.777959     0.815935     0.755725  0.337895                 1.0
# 25      0.770658     0.790657     0.755725  0.185651                 1.0
# 30      0.770658     0.790657     0.755725  0.185651                 1.0
# 29      0.770658     0.790657     0.755725  0.185651                 1.0
# 28      0.770658     0.790657     0.755725  0.185651                 1.0
# 27      0.770658     0.790657     0.755725  0.185651                 1.0
# 26      0.770658     0.790657     0.755725  0.185651                 1.0
# 20      0.770658     0.790657     0.755725  0.185651                 1.0
# 24      0.770658     0.790657     0.755725  0.185651                 1.0
# 23      0.770658     0.790657     0.755725  0.185651                 1.0
# 22      0.770658     0.790657     0.755725  0.185651                 1.0
# 21      0.770658     0.790657     0.755725  0.185651                 1.0
# 19      0.770658     0.790657     0.755725  0.185651                 1.0
# 18      0.770658     0.790657     0.755725  0.185651                 1.0
# 31      0.000000     0.000000     0.000000  0.185651                 1.0
# 32      0.000000     0.000000     0.000000  0.185651                 1.0
# 33      0.000000     0.000000     0.000000  0.185651                 1.0
# 34      0.000000     0.000000     0.000000  0.185651                 1.0
# 35      0.000000     0.000000     0.000000  0.185651                 1.0
# 36      0.000000     0.000000     0.000000  0.185651                 1.0
# 37      0.000000     0.000000     0.000000  0.185651                 1.0
# 38      0.000000     0.000000     0.000000  0.185651                 1.0
# 39      0.000000     0.000000     0.000000  0.185651                 1.0
# 40      0.000000     0.000000     0.000000  0.185651                 1.0

# %%
#print(df.round(2).to_latex(index = False))

# %% [markdown]
#  # Evaluation with respect to expected worker behavior

# %%
from utils_analysis import sort_by_key

# get agreement data

run = "4"
#group1 = 'reason_agreement_expert_inspection1'
group = 'reason_agreement*_expert_inspection*'
batch = '*'
n_q = '*'

#run4-group_reason_agreement_expert_inspection1
#expert_annotations = load_expert_data(run, group, n_q, batch)
#expert_annotations2 = load_expert_data(run, group2, n_q, batch)
#expert_annotations = expert_annotations1 + expert_annotations2
#expert_unit_agreement_dict = get_expert_agreement_labels(expert_annotations)
#agreement_labels = get_expert_agreement_labels(expert_annotations)

gold_by_agreement = sort_by_key(gold, ['expected_agreement'])
print('\n--- agreement categories---')
for l, data in gold_by_agreement.items():
    print(l, len(data))
# Out:
# --- agreement categories---
# disagreement 34
# agreement 49
# possible_disagreement 48

# %%
# evaluate agree category:
gold_agree = gold_by_agreement['agreement']
gold_poss_disagree = gold_by_agreement['possible_disagreement']
gold_disagree = gold_by_agreement['disagreement']
print(len(gold_agree))
print(len(gold_poss_disagree))
print(len(gold_disagree))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d67ac4854e3a> in <module>
#       1 # evaluate agree category:
# ----> 2 gold_agree = gold_by_agreement['agreement']
#       3 gold_poss_disagree = gold_by_agreement['possible_disagreement']
#       4 gold_disagree = gold_by_agreement['disagreement']
#       5 print(len(gold_agree))
#
# NameError: name 'gold_by_agreement' is not defined

# %%
#for d in gold_agree:
 #   print(d['quid'], d['answer'])

# %%
for d in gold_poss_disagree:
    if d['quid'] == 'typical_of_concept-rhino-black':
        print(d['quid'], d['answer'])
        print(d.keys())
# Out:
# typical_of_concept-rhino-black false
# dict_keys(['answer', 'completionurl', 'concept', 'disagreement_cnt', 'expected_agreement', 'property', 'quid', 'relation', 'workerid'])

# %%
for d in gold_disagree:
    print(d['quid'], d['answer'])
# Out:
# impossible-shovel-roll false
# implied_category-freebooter-dangerous true
# rare-carrot-red true
# variability_limited-recliner-square false
# variability_open-recliner-square false
# implied_category-recliner-square false
# typical_of_concept-recliner-square false
# rare-recliner-square false
# impossible-leopard-yellow false
# variability_limited-pen-round true
# rare-washer-roll false
# unusual-washer-roll true
# rare-acaridae-dangerous true
# unusual-acaridae-dangerous true
# creative-acaridae-dangerous false
# implied_category-stock-fly false
# typical_of_property-stock-fly false
# typical_of_concept-stock-fly false
# afforded_unusual-stock-fly false
# afforded_usual-stock-fly false
# variability_limited-stock-fly false
# creative-cruiser-wheels false
# variability_open-cruiser-wheels false
# rare-cruiser-wheels false
# impossible-cruiser-wheels false
# creative-rhino-black false
# rare-rhino-black false
# creative-leopard-yellow false
# impossible-recliner-square false
# afforded_usual-plaice-lay_eggs true
# unusual-shovel-roll true
# impossible-carrot-red false
# affording_activity-buttercup-yellow false
# implied_category-tire-roll true

# %%
# disagree vs agree

overview_dicts_agree = evaluate_configs(gold_agree, crowd)
for d in overview_dicts_agree:
    d['behav.'] = 'agree'
    
gold_disagree_all = []
gold_disagree_all.extend(gold_poss_disagree)
gold_disagree_all.extend(gold_disagree)


overview_dicts_disagree_all = evaluate_configs(gold_disagree_all, crowd)
for d in overview_dicts_disagree_all:
    d['behav.'] = 'disagree'
    
#overview_dicts_disagree = evaluate_configs(gold_disagree, crowd)
#for d in overview_dicts_disagree:
 #   d['behav.'] = 'disagree'
    #overview_dicts_total.append(d)

df_agree = pd.DataFrame(overview_dicts_agree).sort_values(by=['relations-f1'], ascending=False)
dicts_agree = df_agree.to_dict("records")

df_disagree = pd.DataFrame(overview_dicts_disagree).sort_values(by=['relations-f1'], ascending=False)
dicts_disagree = df_disagree.to_dict("records")


#df_disagree = pd.DataFrame(overview_dicts_disagree).sort_values(by=['relations-f1'], ascending=False)
#dicts_disagree = df_disagree.to_dict("records")

#df_agree
# Out:
# ----Label distribution----
# True: 6
# False 43
# ----------------------------
# 49 17917 608
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# clean all contradictory annotations
# ----Label distribution----
# True: 15
# False 67
# ----------------------------
# 82 17917 883
# aggretation
# no filtering - different aggretation methods
# cleaning and aggregation
# clean all contradictory annotations

# %%
overview_dicts_total = []
overview_dicts_total.extend(overview_dicts_agree)
overview_dicts_total.extend(overview_dicts_disagree)
#overview_dicts_total.extend(overview_dicts_poss_disagree)

df =  pd.DataFrame(overview_dicts_total) 
df = df.sort_values(by=['relations-f1'], ascending=False)[['behav.', 'filtering',
                                                           'filtering_unit',
                                                           'n_stdv',
                                                           'aggregation',
                                                            'relations-f1',
                                                            'relations-p',
                                                           'relations-r',
                                                           'alpha']]
df.round(2).to_csv('../analyses/evaluation_accuracy_disagree.csv')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ee3e6bc1942f> in <module>
#       1 overview_dicts_total = []
# ----> 2 overview_dicts_total.extend(overview_dicts_agree)
#       3 overview_dicts_total.extend(overview_dicts_disagree)
#       4 #overview_dicts_total.extend(overview_dicts_poss_disagree)
#       5
#
# NameError: name 'overview_dicts_agree' is not defined

# %%
# Get df for paper


configs_to_keep = []
for d in selected_rows:
    config = (d['filtering'], d['filtering_unit'], d['aggregation'], d['n_stdv'])
    config = [c  if c is not None else '-' for c in config]
    #if x is not None else ''
    if d['filtering'] != 'ct_wqs' and d['aggregation'] != 'top_vote':
        #print(config)
        print(config)
        configs_to_keep.append(config)

# add top three
selected_rows_ag_dis = []
selected_rows_ag_dis.extend(dicts_agree[:3])
selected_rows_ag_dis.extend(dicts_disagree[:3])
#for d in overview_dicts_agree:

#configs_agree = [(d['filtering'], d['filtering_unit'], d['aggregation'], d['n_stdv'])
 #                  for d in dicts_agree]


for d in dicts_agree:
    config = (d['filtering'], d['filtering_unit'], d['aggregation'], d['n_stdv'])
    config = [c  if c is not None else '-' for c in config]
    if config in configs_to_keep:
        print('keeping', config)
        if d not in selected_rows_ag_dis :
            selected_rows_ag_dis.append(d)
        #else:
         #   print('already collected')
    #else:
     #   print(config, 'not found')
 
        
for d in dicts_disagree:
    config = (d['filtering'], d['filtering_unit'], d['aggregation'], d['n_stdv'])
    config = [c  if c is not None else '-' for c in config]
    if config in configs_to_keep and d not in selected_rows_ag_dis:
        selected_rows_ag_dis.append(d)
    

df = pd.DataFrame(selected_rows_ag_dis).sort_values(by=['relations-f1'], ascending=False)[[
                                                            'behav.',
                                                           'aggregation',
                                                            'filtering',
                                                            'filtering_unit',
                                                            'n_stdv',
                                                           'relations-f1',
                                                            'relations-p',
                                                           'relations-r', 'alpha']]
df
# Out:
# ['contradictions', 'batch', 'majority_vote', 0.5]
# ['contradictions', 'total', 'majority_vote', 1]
# ['exclude_contradictory_annotations', '-', 'majority_vote', '-']
# ['-', '-', 'uas-0.65', '-']
# ['-', '-', 'majority_vote', '-']
# keeping ['-', '-', 'uas-0.65', '-']
# keeping ['contradictions', 'total', 'majority_vote', 1]
# keeping ['contradictions', 'batch', 'majority_vote', 0.5]
# keeping ['exclude_contradictory_annotations', '-', 'majority_vote', '-']
# keeping ['-', '-', 'majority_vote', '-']
#       behav.    aggregation                          filtering filtering_unit  \
# 0      agree  majority_vote                     contradictions           pair
# 1      agree       uas-0.65                                  -              -
# 2      agree        uas-0.7                                  -              -
# 6      agree  majority_vote                     contradictions          total
# 3   disagree  majority_vote                     contradictions          batch
# 4   disagree  majority_vote                     contradictions          batch
# 5   disagree  majority_vote                     contradictions          batch
# 7      agree  majority_vote                     contradictions          batch
# 8      agree  majority_vote  exclude_contradictory_annotations              -
# 10  disagree  majority_vote                                  -              -
# 11  disagree  majority_vote                     contradictions          total
# 9      agree  majority_vote                                  -              -
# 12  disagree  majority_vote  exclude_contradictory_annotations              -
# 13  disagree       uas-0.65                                  -              -
#
#    n_stdv  relations-f1  relations-p  relations-r     alpha
# 0     0.5      0.909816     0.944341     0.897959  0.277441
# 1       -      0.906319     0.923639     0.897959  0.225307
# 2       -      0.901284     0.905734     0.897959  0.225307
# 6       1      0.893367     0.938776     0.877551  0.278331
# 3     1.5      0.885784     0.895838     0.882353  0.201318
# 4       1      0.885784     0.895838     0.882353  0.201797
# 5     0.5      0.885784     0.895838     0.882353  0.214447
# 7     0.5      0.861015     0.930029     0.836735  0.276553
# 8       -      0.861015     0.930029     0.836735  0.324119
# 10      -      0.855311     0.859314     0.852941  0.207792
# 11      1      0.855311     0.859314     0.852941  0.228711
# 9       -      0.828874     0.923469     0.795918  0.225307
# 12      -      0.828676     0.839805     0.823529  0.306871
# 13      -      0.696421     0.696078     0.735294  0.207792

# %%
print(df.round(2).to_latex(index = False))
# Out:
# \begin{tabular}{lllllrrrr}
# \toprule
#    behav. &    aggregation &                          filtering & filtering\_unit & n\_stdv &  relations-f1 &  relations-p &  relations-r &  alpha \\
# \midrule
#     agree &  majority\_vote &                     contradictions &           pair &    0.5 &          0.91 &         0.94 &         0.90 &   0.28 \\
#     agree &       uas-0.65 &                                  - &              - &      - &          0.91 &         0.92 &         0.90 &   0.23 \\
#     agree &        uas-0.7 &                                  - &              - &      - &          0.90 &         0.91 &         0.90 &   0.23 \\
#     agree &  majority\_vote &                     contradictions &          total &      1 &          0.89 &         0.94 &         0.88 &   0.28 \\
#  disagree &  majority\_vote &                     contradictions &          batch &    0.5 &          0.89 &         0.91 &         0.88 &   0.16 \\
#     agree &  majority\_vote &                     contradictions &          batch &    0.5 &          0.86 &         0.93 &         0.84 &   0.28 \\
#     agree &  majority\_vote &  exclude\_contradictory\_annotations &              - &      - &          0.86 &         0.93 &         0.84 &   0.32 \\
#  disagree &  majority\_vote &                     contradictions &          batch &      1 &          0.85 &         0.89 &         0.84 &   0.15 \\
#  disagree &  majority\_vote &                     contradictions &          batch &    1.5 &          0.84 &         0.88 &         0.83 &   0.16 \\
#  disagree &  majority\_vote &                     contradictions &          total &      1 &          0.84 &         0.86 &         0.83 &   0.17 \\
#  disagree &  majority\_vote &  exclude\_contradictory\_annotations &              - &      - &          0.83 &         0.84 &         0.83 &   0.31 \\
#     agree &  majority\_vote &                                  - &              - &      - &          0.83 &         0.92 &         0.80 &   0.23 \\
#  disagree &  majority\_vote &                                  - &              - &      - &          0.81 &         0.83 &         0.79 &   0.16 \\
#  disagree &       uas-0.65 &                                  - &              - &      - &          0.79 &         0.79 &         0.80 &   0.16 \\
# \bottomrule
# \end{tabular}
