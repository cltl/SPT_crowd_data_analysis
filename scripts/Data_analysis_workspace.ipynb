# %% [markdown]
# # Annotation analysis
#
# This noteboook
#
# * illustrates the steps of the analysis currently implemented
# * is used to analyze and monitor workers batch by batch

# %%
from load_data import load_experiment_data
from analyze_workers import get_worker_analysis
from analyze_pairs import get_pair_analysis
from analyze_pairs import show_pairs_of_worker
from analyze_pairs import compare_runs
from calculate_iaa import get_agreement
from clean_annotations import clean_annotations
from analyze_relations_and_examples import agreement_relations_across_runs

# %% [markdown]
# # Analyze worker contradictions:
#
# * Workers with highest contradiction to annotations ratio appear on top
# * use the pandas dataframe sort method to sort on other values:
#
# `df.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')`

# %% [markdown]
# ### Current batch

# %%
run = 4
batch = 6
n_q = '*'
group = 'experiment2'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_worker_analysis(data_dict_list, name)
df.drop(['annotations'], axis = 1, inplace=True)
df
# Out:
# creating file with uuid run4-group_experiment2/qu70-s_qu70-batch6.csv
# added unique ids - file can be found at: ../data/prolific_output_uuid/run4-group_experiment2/qu70-s_qu70-batch6.csv
# Discarded 0.0 annotations.
#                    workerid  n_annotations  n_contradictions  n_fails  \
# 9  5ea0cab850c77d0d40fa0768             72                21        2
# 3  5be0b3d439bd3f000110d652             72                14        1
# 4  5c3f73995353e90001e40d16             72                 5        0
# 1  59d71813e2762800015eb5d8             72                 4        0
# 7  5ea07ee6ddea230581c2e93b             72                 4        0
# 8  5ea0b664c2b7320a4aef95af             72                 4        0
# 0  58bfb1f692a88e0001658253             72                 2        0
# 2  5bae3351a91ee200011a4220             72                 0        0
# 5  5d6aeb25a6a4220015010bd6             72                 0        0
# 6  5e1b28d4d370f435a62cfbe2             72                 0        0
#
#    contradiction_annotation_ratio  n_possible_contradictions  \
# 9                        0.291667                         87
# 3                        0.194444                         87
# 4                        0.069444                         87
# 1                        0.055556                         87
# 7                        0.055556                         87
# 8                        0.055556                         87
# 0                        0.027778                         87
# 2                        0.000000                         87
# 5                        0.000000                         87
# 6                        0.000000                         87
#
#    contradiction_poss_contradiction_ratio  fail_annotation_ratio  \
# 9                                0.241379               0.027778
# 3                                0.160920               0.013889
# 4                                0.057471               0.000000
# 1                                0.045977               0.000000
# 7                                0.045977               0.000000
# 8                                0.045977               0.000000
# 0                                0.022989               0.000000
# 2                                0.000000               0.000000
# 5                                0.000000               0.000000
# 6                                0.000000               0.000000
#
#    contradictory_pairs_ratio  average_time_question  ...  \
# 9                   0.777778               5.428792  ...
# 3                   0.333333               5.673389  ...
# 4                   0.222222               8.688653  ...
# 1                   0.111111              11.588833  ...
# 7                   0.111111              10.344486  ...
# 8                   0.111111               6.671319  ...
# 0                   0.111111              13.211792  ...
# 2                   0.000000               9.695250  ...
# 5                   0.000000              24.647153  ...
# 6                   0.000000              10.154597  ...
#
#    (afforded_unusual, impossible)  (afforded_unusual, unusual)  \
# 9                             1.0                          NaN
# 3                             1.0                          1.0
# 4                             NaN                          NaN
# 1                             NaN                          NaN
# 7                             NaN                          NaN
# 8                             NaN                          NaN
# 0                             NaN                          NaN
# 2                             NaN                          NaN
# 5                             NaN                          NaN
# 6                             NaN                          NaN
#
#    (implied_category, rare)  (rare, typical_of_concept)  \
# 9                       1.0                         1.0
# 3                       2.0                         1.0
# 4                       NaN                         NaN
# 1                       NaN                         NaN
# 7                       NaN                         1.0
# 8                       1.0                         1.0
# 0                       NaN                         NaN
# 2                       NaN                         NaN
# 5                       NaN                         NaN
# 6                       NaN                         NaN
#
#    (rare, typical_of_property)  (affording_activity, impossible)  \
# 9                          NaN                               3.0
# 3                          1.0                               NaN
# 4                          NaN                               1.0
# 1                          NaN                               NaN
# 7                          NaN                               NaN
# 8                          1.0                               NaN
# 0                          NaN                               NaN
# 2                          NaN                               NaN
# 5                          NaN                               NaN
# 6                          NaN                               NaN
#
#    (impossible, typical_of_concept)  (afforded_usual, impossible)  \
# 9                               4.0                           1.0
# 3                               NaN                           NaN
# 4                               NaN                           NaN
# 1                               NaN                           NaN
# 7                               NaN                           NaN
# 8                               NaN                           NaN
# 0                               NaN                           NaN
# 2                               NaN                           NaN
# 5                               NaN                           NaN
# 6                               NaN                           NaN
#
#    (implied_category, impossible)  (impossible, typical_of_property)
# 9                             3.0                                1.0
# 3                             NaN                                NaN
# 4                             NaN                                NaN
# 1                             NaN                                NaN
# 7                             NaN                                NaN
# 8                             NaN                                NaN
# 0                             NaN                                NaN
# 2                             NaN                                NaN
# 5                             NaN                                NaN
# 6                             NaN                                NaN
#
# [10 rows x 25 columns]

# %% [markdown]
# ### All annotations
#
# * Workers with highest contradiction to annotations ratio appear on top
# * use the pandas dataframe sort method to sort on other values:
# * Check how the behavior of a specific worker with many contradictions compares to other workers
#
# `df.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')`

# %%
run = '*'
batch = '*'
n_q = '*'
group = 'experiment*'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df_total, filepath = get_worker_analysis(data_dict_list, name)
df_total.drop(['annotations'], axis = 1, inplace=True)
df_total[:20]
# Out:
# Discarded 655.0 annotations.
#                      workerid  n_annotations  n_contradictions  n_fails  \
# 356  5bfed16ca1f050000102693c             74                62        1
# 604  5d6ef000391fb4001a97337d            138                69        1
# 874                       111             48                39        0
# 299  5c91321c0375460001034cb8             71                38        0
# 832  5d76a2dc2a476a0001ce6843             72                45        1
# 362  5e2f554c4c58fa515ad361d0             17                 3        0
# 493  5e87276d17cdf1028850af59             72                54        1
# 251  5d4434c68225f9001642fcd3             71                30        0
# 572  5c042ba4bb85e60001c05c83             72                47        0
# 74   5dc0395f2a1dd64710661ccd             71                33        0
# 599  5dac6532ccaa330016e11e8f             51                15        1
# 546  5ca0ab3d073bc1001209fd58             64                33        1
# 246  5de8dc07f42a16000a301cd6             78                31        0
# 460  5e4e86b070e1ed2d6e4e3f62             72                42        1
# 465  5e7cbbbcf0a5a004b60b48f7             72                41        1
# 209                   banking             75                26        0
# 130  599aca876b939900012da2cd             71                27        0
# 445                IT Manager             72                44        2
# 169  5cd94cb10196990019dbcb09             78                25        0
# 421  5e85d88e1d6de805083b051f             78                35        0
#
#      contradiction_annotation_ratio  n_possible_contradictions  \
# 356                        0.837838                         87
# 604                        0.500000                         99
# 874                        0.812500                         60
# 299                        0.535211                         60
# 832                        0.625000                         72
# 362                        0.176471                          5
# 493                        0.750000                        102
# 251                        0.422535                         58
# 572                        0.652778                         93
# 74                         0.464789                         66
# 599                        0.294118                         30
# 546                        0.515625                         66
# 246                        0.397436                         62
# 460                        0.583333                         84
# 465                        0.569444                         84
# 209                        0.346667                         54
# 130                        0.380282                         58
# 445                        0.611111                         96
# 169                        0.320513                         56
# 421                        0.448718                         81
#
#      contradiction_poss_contradiction_ratio  fail_annotation_ratio  \
# 356                                0.712644               0.013514
# 604                                0.696970               0.007246
# 874                                0.650000               0.000000
# 299                                0.633333               0.000000
# 832                                0.625000               0.013889
# 362                                0.600000               0.000000
# 493                                0.529412               0.013889
# 251                                0.517241               0.000000
# 572                                0.505376               0.000000
# 74                                 0.500000               0.000000
# 599                                0.500000               0.019608
# 546                                0.500000               0.015625
# 246                                0.500000               0.000000
# 460                                0.500000               0.013889
# 465                                0.488095               0.013889
# 209                                0.481481               0.000000
# 130                                0.465517               0.000000
# 445                                0.458333               0.027778
# 169                                0.446429               0.000000
# 421                                0.432099               0.000000
#
#      contradictory_pairs_ratio  average_time_question  ...  \
# 356                   0.600000              14.382986  ...
# 604                   0.777778               4.301442  ...
# 874                   0.571429               0.000000  ...
# 299                   0.875000              12.942127  ...
# 832                   0.600000              16.482319  ...
# 362                   0.285714              24.201118  ...
# 493                   0.777778               2.828292  ...
# 251                   0.875000               5.209535  ...
# 572                   0.777778               7.812292  ...
# 74                    0.875000               3.745113  ...
# 599                   0.625000               0.000000  ...
# 546                   0.555556               3.446672  ...
# 246                   0.555556               4.965808  ...
# 460                   0.777778               4.293264  ...
# 465                   0.777778              11.482222  ...
# 209                   0.555556               0.000000  ...
# 130                   0.875000              19.589310  ...
# 445                   0.777778               0.000000  ...
# 169                   0.777778               5.271885  ...
# 421                   0.545455              21.625103  ...
#
#      (rare, typical_of_concept)  (rare, typical_of_property)  \
# 356                         4.0                          4.0
# 604                         4.0                          5.0
# 874                         1.0                          2.0
# 299                         NaN                          NaN
# 832                         5.0                          3.0
# 362                         NaN                          NaN
# 493                         2.0                          3.0
# 251                         NaN                          NaN
# 572                         4.0                          3.0
# 74                          NaN                          NaN
# 599                         3.0                          2.0
# 546                         2.0                          1.0
# 246                         NaN                          NaN
# 460                         4.0                          5.0
# 465                         4.0                          6.0
# 209                         NaN                          NaN
# 130                         NaN                          NaN
# 445                         1.0                          3.0
# 169                         NaN                          NaN
# 421                         1.0                          1.0
#
#      (affording_activity, impossible)  (impossible, typical_of_concept)  \
# 356                               NaN                               5.0
# 604                               2.0                               3.0
# 874                               NaN                               3.0
# 299                               1.0                               5.0
# 832                               2.0                               3.0
# 362                               NaN                               NaN
# 493                               NaN                               3.0
# 251                               3.0                               3.0
# 572                               1.0                               1.0
# 74                                1.0                               3.0
# 599                               1.0                               1.0
# 546                               2.0                               3.0
# 246                               1.0                               3.0
# 460                               1.0                               1.0
# 465                               4.0                               2.0
# 209                               NaN                               4.0
# 130                               NaN                               NaN
# 445                               1.0                               1.0
# 169                               NaN                               1.0
# 421                               NaN                               NaN
#
#      (afforded_usual, impossible)  (implied_category, impossible)  \
# 356                           5.0                             4.0
# 604                           2.0                             6.0
# 874                           3.0                             2.0
# 299                           NaN                             4.0
# 832                           NaN                             3.0
# 362                           NaN                             NaN
# 493                           2.0                             5.0
# 251                           NaN                             3.0
# 572                           2.0                             3.0
# 74                            1.0                             3.0
# 599                           NaN                             NaN
# 546                           1.0                             3.0
# 246                           1.0                             3.0
# 460                           NaN                             2.0
# 465                           NaN                             4.0
# 209                           3.0                             2.0
# 130                           NaN                             NaN
# 445                           2.0                             3.0
# 169                           NaN                             2.0
# 421                           1.0                             1.0
#
#      (impossible, typical_of_property)  (afforded_unusual, rare)  \
# 356                                5.0                       3.0
# 604                                4.0                       3.0
# 874                                4.0                       2.0
# 299                                5.0                       NaN
# 832                                2.0                       NaN
# 362                                NaN                       NaN
# 493                                3.0                       3.0
# 251                                3.0                       NaN
# 572                                2.0                       2.0
# 74                                 2.0                       NaN
# 599                                1.0                       NaN
# 546                                3.0                       1.0
# 246                                3.0                       NaN
# 460                                2.0                       NaN
# 465                                4.0                       NaN
# 209                                4.0                       NaN
# 130                                NaN                       NaN
# 445                                1.0                       4.0
# 169                                1.0                       NaN
# 421                                NaN                       3.0
#
#      (afforded_usual, rare)  (afforded_usual, unusual)
# 356                     4.0                        4.0
# 604                     3.0                        3.0
# 874                     1.0                        3.0
# 299                     NaN                        1.0
# 832                     NaN                        NaN
# 362                     NaN                        NaN
# 493                     3.0                        3.0
# 251                     NaN                        NaN
# 572                     2.0                        1.0
# 74                      NaN                        1.0
# 599                     NaN                        NaN
# 546                     1.0                        1.0
# 246                     NaN                        1.0
# 460                     NaN                        NaN
# 465                     NaN                        NaN
# 209                     NaN                        1.0
# 130                     NaN                        1.0
# 445                     3.0                        3.0
# 169                     NaN                        NaN
# 421                     2.0                        2.0
#
# [20 rows x 28 columns]

# %%
# Good workers
df_total[-20:]
# Out:
#                      workerid  n_annotations  n_contradictions  n_fails  \
# 71   5d430e89be616d0015f784e8             71                 0        0
# 741  5dee62c0770a434f62147de2             76                 0        0
# 147  5c036f34efea06000188cdba              8                 0        0
# 743  5c62a91524035400014b69dc             78                 0        0
# 148  5c3de869b3369c0001a9264a              8                 0        0
# 745  5cb62e72ebe8a50001a9b7c8             78                 0        1
# 149  5c8250c026a0940016b265da              8                 0        0
# 747  5dd7abaaaf16d3746667182c             78                 0        0
# 67   5ceac282ca3e100016373e3c             71                 0        0
# 64   5a22e6aabf56cc00017701ef             71                 0        0
# 150  5de93ba177443804fea65939              8                 0        0
# 751  597fa2d8fc90e000011c586d             68                 0        0
# 752  5b2838e8b1cd750001498ba9             68                 0        0
# 153  5a0feb37df3fa800015c432a             78                 0        0
# 754  5dd6ccc58cf2f966166c0399             68                 0        0
# 65   5c41f300b96aae0001e75848             71                 0        0
# 161  5dad7f29033d57001357a2b8             71                 0        0
# 164  5c5b333a2b7de10001b78759             78                 0        0
# 758  5e6c075b1689b01da3b62993             68                 0        0
# 340  5cd574ebf1dc7600185cc0a4             71                 0        0
#
#      contradiction_annotation_ratio  n_possible_contradictions  \
# 71                              0.0                         58
# 741                             0.0                         84
# 147                             0.0                          0
# 743                             0.0                         84
# 148                             0.0                          0
# 745                             0.0                         84
# 149                             0.0                          0
# 747                             0.0                         84
# 67                              0.0                         66
# 64                              0.0                         66
# 150                             0.0                          0
# 751                             0.0                         72
# 752                             0.0                         72
# 153                             0.0                         56
# 754                             0.0                         72
# 65                              0.0                         66
# 161                             0.0                         52
# 164                             0.0                         60
# 758                             0.0                         72
# 340                             0.0                         60
#
#      contradiction_poss_contradiction_ratio  fail_annotation_ratio  \
# 71                                      0.0               0.000000
# 741                                     0.0               0.000000
# 147                                     0.0               0.000000
# 743                                     0.0               0.000000
# 148                                     0.0               0.000000
# 745                                     0.0               0.012821
# 149                                     0.0               0.000000
# 747                                     0.0               0.000000
# 67                                      0.0               0.000000
# 64                                      0.0               0.000000
# 150                                     0.0               0.000000
# 751                                     0.0               0.000000
# 752                                     0.0               0.000000
# 153                                     0.0               0.000000
# 754                                     0.0               0.000000
# 65                                      0.0               0.000000
# 161                                     0.0               0.000000
# 164                                     0.0               0.000000
# 758                                     0.0               0.000000
# 340                                     0.0               0.000000
#
#      contradictory_pairs_ratio  average_time_question  ...  \
# 71                         0.0               8.678676  ...
# 741                        0.0               8.971500  ...
# 147                        0.0              10.544000  ...
# 743                        0.0               6.654244  ...
# 148                        0.0              22.931875  ...
# 745                        0.0               5.071128  ...
# 149                        0.0              83.982125  ...
# 747                        0.0               9.759564  ...
# 67                         0.0              10.510493  ...
# 64                         0.0               5.570915  ...
# 150                        0.0              10.269000  ...
# 751                        0.0               8.560044  ...
# 752                        0.0               6.909279  ...
# 153                        0.0              10.343346  ...
# 754                        0.0               5.710118  ...
# 65                         0.0              16.126155  ...
# 161                        0.0              11.930225  ...
# 164                        0.0              11.800962  ...
# 758                        0.0               9.027721  ...
# 340                        0.0              16.699577  ...
#
#      (rare, typical_of_concept)  (rare, typical_of_property)  \
# 71                          NaN                          NaN
# 741                         NaN                          NaN
# 147                         NaN                          NaN
# 743                         NaN                          NaN
# 148                         NaN                          NaN
# 745                         NaN                          NaN
# 149                         NaN                          NaN
# 747                         NaN                          NaN
# 67                          NaN                          NaN
# 64                          NaN                          NaN
# 150                         NaN                          NaN
# 751                         NaN                          NaN
# 752                         NaN                          NaN
# 153                         NaN                          NaN
# 754                         NaN                          NaN
# 65                          NaN                          NaN
# 161                         NaN                          NaN
# 164                         NaN                          NaN
# 758                         NaN                          NaN
# 340                         NaN                          NaN
#
#      (affording_activity, impossible)  (impossible, typical_of_concept)  \
# 71                                NaN                               NaN
# 741                               NaN                               NaN
# 147                               NaN                               NaN
# 743                               NaN                               NaN
# 148                               NaN                               NaN
# 745                               NaN                               NaN
# 149                               NaN                               NaN
# 747                               NaN                               NaN
# 67                                NaN                               NaN
# 64                                NaN                               NaN
# 150                               NaN                               NaN
# 751                               NaN                               NaN
# 752                               NaN                               NaN
# 153                               NaN                               NaN
# 754                               NaN                               NaN
# 65                                NaN                               NaN
# 161                               NaN                               NaN
# 164                               NaN                               NaN
# 758                               NaN                               NaN
# 340                               NaN                               NaN
#
#      (afforded_usual, impossible)  (implied_category, impossible)  \
# 71                            NaN                             NaN
# 741                           NaN                             NaN
# 147                           NaN                             NaN
# 743                           NaN                             NaN
# 148                           NaN                             NaN
# 745                           NaN                             NaN
# 149                           NaN                             NaN
# 747                           NaN                             NaN
# 67                            NaN                             NaN
# 64                            NaN                             NaN
# 150                           NaN                             NaN
# 751                           NaN                             NaN
# 752                           NaN                             NaN
# 153                           NaN                             NaN
# 754                           NaN                             NaN
# 65                            NaN                             NaN
# 161                           NaN                             NaN
# 164                           NaN                             NaN
# 758                           NaN                             NaN
# 340                           NaN                             NaN
#
#      (impossible, typical_of_property)  (afforded_unusual, rare)  \
# 71                                 NaN                       NaN
# 741                                NaN                       NaN
# 147                                NaN                       NaN
# 743                                NaN                       NaN
# 148                                NaN                       NaN
# 745                                NaN                       NaN
# 149                                NaN                       NaN
# 747                                NaN                       NaN
# 67                                 NaN                       NaN
# 64                                 NaN                       NaN
# 150                                NaN                       NaN
# 751                                NaN                       NaN
# 752                                NaN                       NaN
# 153                                NaN                       NaN
# 754                                NaN                       NaN
# 65                                 NaN                       NaN
# 161                                NaN                       NaN
# 164                                NaN                       NaN
# 758                                NaN                       NaN
# 340                                NaN                       NaN
#
#      (afforded_usual, rare)  (afforded_usual, unusual)
# 71                      NaN                        NaN
# 741                     NaN                        NaN
# 147                     NaN                        NaN
# 743                     NaN                        NaN
# 148                     NaN                        NaN
# 745                     NaN                        NaN
# 149                     NaN                        NaN
# 747                     NaN                        NaN
# 67                      NaN                        NaN
# 64                      NaN                        NaN
# 150                     NaN                        NaN
# 751                     NaN                        NaN
# 752                     NaN                        NaN
# 153                     NaN                        NaN
# 754                     NaN                        NaN
# 65                      NaN                        NaN
# 161                     NaN                        NaN
# 164                     NaN                        NaN
# 758                     NaN                        NaN
# 340                     NaN                        NaN
#
# [20 rows x 28 columns]

# %% [markdown]
# ### Get all contradictions and fails of a particular worker
#
# * Check if a specfic worker continuously contradicts themselves (and fails checks)

# %%
# copy from above - worker with many disagreements in target batch
worker = '5ea0cab850c77d0d40fa0768'


# df.loc[df['column_name'] == some_value]
df_total.loc[df_total['workerid'] == worker]
# Out:
#                    workerid  n_annotations  n_contradictions  n_fails  \
# 9  5ea0cab850c77d0d40fa0768             72                21        2
#
#    contradiction_annotation_ratio  n_possible_contradictions  \
# 9                        0.291667                         87
#
#    contradiction_poss_contradiction_ratio  fail_annotation_ratio  \
# 9                                0.241379               0.027778
#
#    contradictory_pairs_ratio  average_time_question  ...  \
# 9                   0.777778               5.428792  ...
#
#    (rare, typical_of_concept)  (rare, typical_of_property)  \
# 9                         1.0                          NaN
#
#    (affording_activity, impossible)  (impossible, typical_of_concept)  \
# 9                               3.0                               4.0
#
#    (afforded_usual, impossible)  (implied_category, impossible)  \
# 9                           1.0                             3.0
#
#    (impossible, typical_of_property)  (afforded_unusual, rare)  \
# 9                                1.0                       NaN
#
#    (afforded_usual, rare)  (afforded_usual, unusual)
# 9                     NaN                        NaN
#
# [1 rows x 28 columns]

# %% [markdown]
# # Analyze pairs
#
# * compars number of annotator contradictions among pairs

# %% [markdown]
# ### Current batch:

# %%
run = '4'
batch = '6'
n_q = '*'
group = 'experiment2'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_pair_analysis(data_dict_list, name)
df.drop(['annotations_with_contradiction'], axis = 1, inplace=True)
df
# Out:
# Discarded 0.0 annotations.
#                    pair  n_annotations  n_workers  n_contradictions  \
# 5         sweet-sultana            100         10                16
# 2     fly-phalacrocorax            100         10                 7
# 3  dangerous-reduviidae            100         10                10
# 0      made_of_wood-axe            100         10                 5
# 6          hot-kerosene            100         10                 7
# 1       black-mentzelia            100         10                 3
# 4            square-cds            100         10                 6
# 7       _check4-_check4             10         10                 0
# 8         _test1-_test1             10         10                 0
#
#    n_workers_contradicting  ratio_workers_contradicting  \
# 5                        4                          0.4
# 2                        3                          0.3
# 3                        3                          0.3
# 0                        2                          0.2
# 6                        2                          0.2
# 1                        1                          0.1
# 4                        1                          0.1
# 7                        0                          0.0
# 8                        0                          0.0
#
#    contradiction_annotation_ratio  n_possible_contradictions  \
# 5                            0.16                        120
# 2                            0.07                        150
# 3                            0.10                        120
# 0                            0.05                        120
# 6                            0.07                        120
# 1                            0.03                        120
# 4                            0.06                        120
# 7                            0.00                          0
# 8                            0.00                          0
#
#    contradiction_poss_contradiction_ratio  average_time_pair  ...  \
# 5                                0.133333           76.39507  ...
# 2                                0.046667           76.39507  ...
# 3                                0.083333           76.39507  ...
# 0                                0.041667           76.39507  ...
# 6                                0.058333           76.39507  ...
# 1                                0.025000           76.39507  ...
# 4                                0.050000           76.39507  ...
# 7                                0.000000          763.95070  ...
# 8                                0.000000          763.95070  ...
#
#   (afforded_unusual, unusual) (typical_of_concept, unusual)  \
# 5                         NaN                           1.0
# 2                         1.0                           1.0
# 3                         NaN                           1.0
# 0                         NaN                           NaN
# 6                         NaN                           1.0
# 1                         NaN                           NaN
# 4                         NaN                           1.0
# 7                         NaN                           NaN
# 8                         NaN                           NaN
#
#    (implied_category, unusual)  (afforded_usual, impossible)  \
# 5                          2.0                           NaN
# 2                          1.0                           1.0
# 3                          2.0                           NaN
# 0                          NaN                           NaN
# 6                          NaN                           NaN
# 1                          NaN                           NaN
# 4                          1.0                           NaN
# 7                          NaN                           NaN
# 8                          NaN                           NaN
#
#    (typical_of_property, unusual)  (implied_category, rare)  \
# 5                             1.0                       2.0
# 2                             NaN                       NaN
# 3                             1.0                       1.0
# 0                             NaN                       NaN
# 6                             NaN                       NaN
# 1                             NaN                       NaN
# 4                             NaN                       1.0
# 7                             NaN                       NaN
# 8                             NaN                       NaN
#
#    (implied_category, impossible)  (rare, typical_of_concept)  \
# 5                             NaN                         2.0
# 2                             NaN                         NaN
# 3                             1.0                         NaN
# 0                             NaN                         NaN
# 6                             1.0                         1.0
# 1                             NaN                         NaN
# 4                             1.0                         1.0
# 7                             NaN                         NaN
# 8                             NaN                         NaN
#
#    (rare, typical_of_property)  (impossible, typical_of_property)
# 5                          2.0                                NaN
# 2                          NaN                                NaN
# 3                          NaN                                NaN
# 0                          NaN                                NaN
# 6                          NaN                                1.0
# 1                          NaN                                NaN
# 4                          NaN                                NaN
# 7                          NaN                                NaN
# 8                          NaN                                NaN
#
# [9 rows x 27 columns]

# %% [markdown]
# ### Get rows with pairs annotated by specific workers:
#
# * Check if a worker in the only one contradicting or if others also had issues with the pairs

# %%
worker = '5ea0cab850c77d0d40fa0768'

show_pairs_of_worker(worker, df)
# Out:
# Worker 5ea0cab850c77d0d40fa0768 contradicted themselves in the following pairs:
#
# sweet-sultana 	 total workers contradicting themselves: 4
# fly-phalacrocorax 	 total workers contradicting themselves: 3
# dangerous-reduviidae 	 total workers contradicting themselves: 3
# made_of_wood-axe 	 total workers contradicting themselves: 2
# hot-kerosene 	 total workers contradicting themselves: 2
# black-mentzelia 	 total workers contradicting themselves: 1
# square-cds 	 total workers contradicting themselves: 1

# %% [markdown]
# ### Compare to entire annotation set

# %%
run = '4'
batch = '*'
n_q = '*'
group = 'experiment2'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_pair_analysis(data_dict_list, name)
df.drop(['annotations_with_contradiction'], axis = 1, inplace=True)
df
# Out:
# Discarded 0.0 annotations.
#                    pair  n_annotations  n_workers  n_contradictions  \
# 28       sweet-hazelnut            101         10                11
# 6    lay_eggs-whiteface            100         10                 9
# 15         wheels-stage            100         10                15
# 20  made_of_wood-ladder            100         10                13
# 34       black-pipefish            102         10                14
# 32       lay_eggs-eland            101         10                 9
# 30  made_of_wood-timber            101         10                10
# 3   dangerous-doodlebug            100         10                 8
# 19       wheels-carrier            100         10                11
# 22     lay_eggs-pointer            100         10                16
# 21         hot-barbecue            100         10                15
# 14           wheels-rig            100         10                 5
# 35         fly-nuthatch            100         10                12
# 29            hot-candy            100         10                 8
# 25      dangerous-raper            100         10                 7
# 24       sweet-shiitake            100         10                 8
# 23          fly-haddock            100         10                 9
# 0           fly-wheeler            100         10                 7
# 13     dangerous-opener            100         10                 5
# 12      dangerous-plane            100         10                 8
# 11       wheels-railcar            100         10                 7
# 10    dangerous-unction            100         10                10
# 2     wheels-snowmobile            100         10                 5
# 4         black-pelican            100         10                 4
# 1             sweet-jam            100         10                 4
# 16        dangerous-bar            100         10                 2
# 7      made_of_wood-rod            100         10                 3
# 5          yellow-flame             40         10                 0
# 33       yellow-vanilla             40         10                 0
# 31      wheels-carriage             60         10                 0
# 27         _test4-_test             20         20                 0
# 8       _check1-_check1             10         10                 0
# 17      _check3-_check3             20         19                 0
# 26      _check2-_check2             10         10                 0
# 9         _test2-_test2             10         10                 0
# 18         _test3-_test             10         10                 0
#
#     n_workers_contradicting  ratio_workers_contradicting  \
# 28                        4                          0.4
# 6                         4                          0.4
# 15                        4                          0.4
# 20                        4                          0.4
# 34                        4                          0.4
# 32                        3                          0.3
# 30                        3                          0.3
# 3                         3                          0.3
# 19                        3                          0.3
# 22                        3                          0.3
# 21                        3                          0.3
# 14                        3                          0.3
# 35                        3                          0.3
# 29                        2                          0.2
# 25                        2                          0.2
# 24                        2                          0.2
# 23                        2                          0.2
# 0                         2                          0.2
# 13                        2                          0.2
# 12                        2                          0.2
# 11                        2                          0.2
# 10                        2                          0.2
# 2                         2                          0.2
# 4                         2                          0.2
# 1                         1                          0.1
# 16                        1                          0.1
# 7                         1                          0.1
# 5                         0                          0.0
# 33                        0                          0.0
# 31                        0                          0.0
# 27                        0                          0.0
# 8                         0                          0.0
# 17                        0                          0.0
# 26                        0                          0.0
# 9                         0                          0.0
# 18                        0                          0.0
#
#     contradiction_annotation_ratio  n_possible_contradictions  \
# 28                        0.108911                        120
# 6                         0.090000                        150
# 15                        0.150000                        120
# 20                        0.130000                        120
# 34                        0.137255                        120
# 32                        0.089109                        150
# 30                        0.099010                        120
# 3                         0.080000                        120
# 19                        0.110000                        120
# 22                        0.160000                        150
# 21                        0.150000                        120
# 14                        0.050000                        120
# 35                        0.120000                        150
# 29                        0.080000                        120
# 25                        0.070000                        120
# 24                        0.080000                        120
# 23                        0.090000                        150
# 0                         0.070000                        150
# 13                        0.050000                        120
# 12                        0.080000                        120
# 11                        0.070000                        120
# 10                        0.100000                        120
# 2                         0.050000                        120
# 4                         0.040000                        120
# 1                         0.040000                        120
# 16                        0.020000                        120
# 7                         0.030000                        120
# 5                         0.000000                          0
# 33                        0.000000                          0
# 31                        0.000000                          0
# 27                        0.000000                          0
# 8                         0.000000                          0
# 17                        0.000000                          0
# 26                        0.000000                          0
# 9                         0.000000                          0
# 18                        0.000000                          0
#
#     contradiction_poss_contradiction_ratio  average_time_pair  ...  \
# 28                                0.091667         124.733665  ...
# 6                                 0.060000          91.739940  ...
# 15                                0.125000          83.539730  ...
# 20                                0.108333         109.697710  ...
# 34                                0.116667         123.943395  ...
# 32                                0.060000         124.733665  ...
# 30                                0.083333         124.733665  ...
# 3                                 0.066667          91.739940  ...
# 19                                0.091667         109.697710  ...
# 22                                0.106667         109.697710  ...
# 21                                0.125000         109.697710  ...
# 14                                0.041667          83.539730  ...
# 35                                0.080000         125.681990  ...
# 29                                0.066667         125.681990  ...
# 25                                0.058333         109.697710  ...
# 24                                0.066667         109.697710  ...
# 23                                0.060000         109.697710  ...
# 0                                 0.046667          91.739940  ...
# 13                                0.041667          83.539730  ...
# 12                                0.066667          83.539730  ...
# 11                                0.058333          83.539730  ...
# 10                                0.083333          83.539730  ...
# 2                                 0.041667          91.739940  ...
# 4                                 0.033333          91.739940  ...
# 1                                 0.033333          91.739940  ...
# 16                                0.016667          83.539730  ...
# 7                                 0.025000          91.739940  ...
# 5                                 0.000000         229.349850  ...
# 33                                0.000000         314.204975  ...
# 31                                0.000000         209.469983  ...
# 27                                0.000000        1176.898500  ...
# 8                                 0.000000         917.399400  ...
# 17                                0.000000        1066.441237  ...
# 26                                0.000000        1096.977100  ...
# 9                                 0.000000         917.399400  ...
# 18                                0.000000         835.397300  ...
#
#    (rare, typical_of_property) (affording_activity, impossible)  \
# 28                         NaN                              1.0
# 6                          NaN                              NaN
# 15                         1.0                              NaN
# 20                         1.0                              NaN
# 34                         2.0                              NaN
# 32                         2.0                              NaN
# 30                         1.0                              NaN
# 3                          1.0                              NaN
# 19                         1.0                              NaN
# 22                         NaN                              NaN
# 21                         NaN                              3.0
# 14                         NaN                              1.0
# 35                         NaN                              NaN
# 29                         NaN                              1.0
# 25                         2.0                              NaN
# 24                         1.0                              1.0
# 23                         1.0                              NaN
# 0                          NaN                              NaN
# 13                         NaN                              NaN
# 12                         NaN                              1.0
# 11                         NaN                              1.0
# 10                         NaN                              1.0
# 2                          NaN                              1.0
# 4                          1.0                              NaN
# 1                          1.0                              NaN
# 16                         NaN                              NaN
# 7                          1.0                              NaN
# 5                          NaN                              NaN
# 33                         NaN                              NaN
# 31                         NaN                              NaN
# 27                         NaN                              NaN
# 8                          NaN                              NaN
# 17                         NaN                              NaN
# 26                         NaN                              NaN
# 9                          NaN                              NaN
# 18                         NaN                              NaN
#
#     (affording_activity, unusual)  (typical_of_property, unusual)  \
# 28                            1.0                             NaN
# 6                             NaN                             NaN
# 15                            3.0                             1.0
# 20                            1.0                             2.0
# 34                            1.0                             2.0
# 32                            NaN                             1.0
# 30                            1.0                             1.0
# 3                             1.0                             1.0
# 19                            1.0                             1.0
# 22                            NaN                             NaN
# 21                            1.0                             1.0
# 14                            3.0                             NaN
# 35                            NaN                             1.0
# 29                            2.0                             NaN
# 25                            NaN                             NaN
# 24                            1.0                             1.0
# 23                            NaN                             NaN
# 0                             NaN                             NaN
# 13                            1.0                             1.0
# 12                            1.0                             NaN
# 11                            1.0                             NaN
# 10                            NaN                             NaN
# 2                             1.0                             NaN
# 4                             NaN                             NaN
# 1                             NaN                             NaN
# 16                            1.0                             NaN
# 7                             NaN                             1.0
# 5                             NaN                             NaN
# 33                            NaN                             NaN
# 31                            NaN                             NaN
# 27                            NaN                             NaN
# 8                             NaN                             NaN
# 17                            NaN                             NaN
# 26                            NaN                             NaN
# 9                             NaN                             NaN
# 18                            NaN                             NaN
#
#     (impossible, typical_of_concept)  (impossible, typical_of_property)  \
# 28                               1.0                                NaN
# 6                                1.0                                1.0
# 15                               NaN                                NaN
# 20                               NaN                                NaN
# 34                               NaN                                NaN
# 32                               NaN                                NaN
# 30                               NaN                                NaN
# 3                                NaN                                NaN
# 19                               NaN                                NaN
# 22                               NaN                                NaN
# 21                               2.0                                3.0
# 14                               NaN                                NaN
# 35                               1.0                                1.0
# 29                               1.0                                NaN
# 25                               NaN                                NaN
# 24                               NaN                                1.0
# 23                               NaN                                NaN
# 0                                NaN                                NaN
# 13                               NaN                                NaN
# 12                               NaN                                NaN
# 11                               1.0                                NaN
# 10                               2.0                                NaN
# 2                                NaN                                NaN
# 4                                NaN                                NaN
# 1                                NaN                                NaN
# 16                               NaN                                NaN
# 7                                NaN                                1.0
# 5                                NaN                                NaN
# 33                               NaN                                NaN
# 31                               NaN                                NaN
# 27                               NaN                                NaN
# 8                                NaN                                NaN
# 17                               NaN                                NaN
# 26                               NaN                                NaN
# 9                                NaN                                NaN
# 18                               NaN                                NaN
#
#     (afforded_usual, unusual)  (typical_of_concept, unusual)  \
# 28                        NaN                            1.0
# 6                         1.0                            NaN
# 15                        NaN                            1.0
# 20                        NaN                            1.0
# 34                        NaN                            1.0
# 32                        NaN                            NaN
# 30                        NaN                            1.0
# 3                         NaN                            NaN
# 19                        NaN                            2.0
# 22                        2.0                            1.0
# 21                        NaN                            1.0
# 14                        NaN                            NaN
# 35                        2.0                            1.0
# 29                        NaN                            1.0
# 25                        NaN                            NaN
# 24                        NaN                            NaN
# 23                        1.0                            NaN
# 0                         NaN                            NaN
# 13                        NaN                            1.0
# 12                        NaN                            NaN
# 11                        NaN                            1.0
# 10                        NaN                            1.0
# 2                         NaN                            NaN
# 4                         NaN                            NaN
# 1                         NaN                            NaN
# 16                        NaN                            NaN
# 7                         NaN                            NaN
# 5                         NaN                            NaN
# 33                        NaN                            NaN
# 31                        NaN                            NaN
# 27                        NaN                            NaN
# 8                         NaN                            NaN
# 17                        NaN                            NaN
# 26                        NaN                            NaN
# 9                         NaN                            NaN
# 18                        NaN                            NaN
#
#     (afforded_usual, rare)  (afforded_usual, impossible)
# 28                     NaN                           NaN
# 6                      NaN                           NaN
# 15                     NaN                           NaN
# 20                     NaN                           NaN
# 34                     NaN                           NaN
# 32                     1.0                           NaN
# 30                     NaN                           NaN
# 3                      NaN                           NaN
# 19                     NaN                           NaN
# 22                     1.0                           1.0
# 21                     NaN                           NaN
# 14                     NaN                           NaN
# 35                     1.0                           3.0
# 29                     NaN                           NaN
# 25                     NaN                           NaN
# 24                     NaN                           NaN
# 23                     1.0                           1.0
# 0                      NaN                           NaN
# 13                     NaN                           NaN
# 12                     NaN                           NaN
# 11                     NaN                           NaN
# 10                     NaN                           NaN
# 2                      NaN                           NaN
# 4                      NaN                           NaN
# 1                      NaN                           NaN
# 16                     NaN                           NaN
# 7                      NaN                           NaN
# 5                      NaN                           NaN
# 33                     NaN                           NaN
# 31                     NaN                           NaN
# 27                     NaN                           NaN
# 8                      NaN                           NaN
# 17                     NaN                           NaN
# 26                     NaN                           NaN
# 9                      NaN                           NaN
# 18                     NaN                           NaN
#
# [36 rows x 30 columns]

# %%
# check specific pair:

pair = 'red-lipstick'
df.loc[df['pair'] == pair]
# Out:
#              pair  n_annotations  n_workers  n_contradictions  \
# 305  red-lipstick             50          5                 7
#
#      n_workers_contradicting  ratio_workers_contradicting  \
# 305                        2                          0.4
#
#      contradiction_annotation_ratio  average_time_pair  \
# 305                            0.14             59.799
#
#                                  workers_contradicting  \
# 305  57617fdb1a5ecc0006fc3860 5ddc0d87d3ac2ad102aff2b9
#
#                              workers_not_contradicting  ...  \
# 305  59dc2e2016ecc200016fea95 5c544985be9cd80001156...  ...
#
#      (affording_activity, unusual)  (rare, typical_of_concept)  \
# 305                            1.0                         NaN
#
#      (rare, typical_of_property)  (implied_category, rare)  \
# 305                          NaN                       NaN
#
#      (implied_category, impossible)  (affording_activity, impossible)  \
# 305                             NaN                               NaN
#
#      (afforded_unusual, impossible)  (afforded_usual, rare)  \
# 305                             NaN                     NaN
#
#      (afforded_unusual, rare)  (afforded_usual, impossible)
# 305                       NaN                           NaN
#
# [1 rows x 28 columns]

# %% [markdown]
# ### Compare contradictions between runs:

# %%
run = '3'
batch = '*'
n_q = '*'
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df1, filepath = get_pair_analysis(data_dict_list, name)
print(f'analysis can be found at: {filepath}')

run = '4'
batch = '*'
n_q = '*'
group = 'experiment2'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df2, filepath = get_pair_analysis(data_dict_list, name)
print(f'analysis can be found at: {filepath}')

name1 = '3'
name2 = '4'
compare_runs(name1, name2, df1, df2, comp = 'all')
#print()
#compare_runs(name1, name2, df1, df2, comp = 'pairs')
# Out:
# Discarded 655.0 annotations.
# analysis can be found at: ../analyses/pairs/run3-group_experiment1-batch-all-.csv
# Discarded 0.0 annotations.
# analysis can be found at: ../analyses/pairs/run4-group_experiment2-batch-all-.csv
# Set 3 as a contradiction ratio of 0.2528971962616822
# Set 4 as a contradiction ratio of 0.17926186291739896
# The ratio is based on the number of workers annotating a pair.
# A worker always annotates a full set.
# (0.2528971962616822, 0.17926186291739896)

# %% [markdown]
# # Inter-annotator agreement
#
# * Total agreement
# * Agreement by relations
# * agreement after removing annotators with many contradictions/annotators who fail checks/contradictory annotations

# %% [markdown]
# ## Total iaa:

# %%
run = '*'
batch = '*'
n_q = '*'
group = 'experiment1'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)

run = '4'
batch = '*'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)

get_agreement(data_dict_list)
# Out:
# Run *:
# Discarded 655.0 annotations.
# Krippendorff's alpha: 0.23567624334318582
# Proportional agreement (pairwise): 0.6233819990832739
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.23892481653734177
# Proportional agreement (pairwise): 0.6412293299870081
# {'Krippendorff': 0.23892481653734177, 'Proportional': 0.6412293299870081}

# %% [markdown]
# ## IAA of collapsed relations

# %%
run = '*'
batch = '*'
n_q = '*'
group = 'experiment1'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)

collapse_relations = 'pos_neg'
print(f'collapsing {collapse_relations}')
get_agreement(data_dict_list, collapse_relations = collapse_relations)

collapse_relations = 'levels'
print(f'collapsing {collapse_relations}')
get_agreement(data_dict_list, collapse_relations = collapse_relations)

collapse_relations = 'similar_relations'
print(f'collapsing {collapse_relations}')
get_agreement(data_dict_list, collapse_relations = collapse_relations)


run = '4'
batch = '*'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)

collapse_relations = 'pos_neg'
print(f'collapsing {collapse_relations}')
get_agreement(data_dict_list, collapse_relations = collapse_relations)

collapse_relations = 'levels'
print(f'collapsing {collapse_relations}')
get_agreement(data_dict_list, collapse_relations = collapse_relations)

collapse_relations = 'similar_relations'
print(f'collapsing {collapse_relations}')
get_agreement(data_dict_list, collapse_relations = collapse_relations)
# Out:
# Run *:
# Discarded 655.0 annotations.
# Krippendorff's alpha: 0.23567624334318582
# Proportional agreement (pairwise): 0.6233819990832739
#
# collapsing pos_neg
# pos_neg
# Krippendorff's alpha: 0.3348903198600117
# Proportional agreement (pairwise): 0.7902502664705034
#
# collapsing levels
# levels
# Krippendorff's alpha: 0.3555916355102202
# Proportional agreement (pairwise): 0.7038679436637708
#
# collapsing similar_relations
# similar_relations
# Krippendorff's alpha: 0.37526324080891615
# Proportional agreement (pairwise): 0.6967938704580102
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.24217199868349115
# Proportional agreement (pairwise): 0.6459022163559383
#
# collapsing pos_neg
# pos_neg
# Krippendorff's alpha: 0.3443147721286992
# Proportional agreement (pairwise): 0.7284790176338635
#
# collapsing levels
# levels
# Krippendorff's alpha: 0.3749315715926481
# Proportional agreement (pairwise): 0.6915466169308861
#
# collapsing similar_relations
# similar_relations
# Krippendorff's alpha: 0.3732721346790516
# Proportional agreement (pairwise): 0.7266231889199777
# {'Krippendorff': 0.3732721346790516, 'Proportional': 0.7266231889199777}

# %% [markdown]
# ## IAA by relation

# %%
runs = ['3', '1']
experiment_name = 'experiment1'
path, df = agreement_relations_across_runs(runs, experiment_name)
print(f'Results written to: {path}')
df
# Out:
# Discarded 655.0 annotations.
# Discarded 0.0 annotations.
# Results written to: ../analyses/iaa/relations_runs3-1.csv
#                      relation  3_Krippendorff  3_Proportional  1_Krippendorff  \
# 0            implied_category        0.261604        0.648495        0.260459
# 1          affording_activity        0.196837        0.654605        0.149149
# 2   variability_subcategories             NaN             NaN        0.157270
# 3                  impossible        0.134907        0.658426        0.183925
# 4         variability_limited        0.103003        0.551718        0.197795
# 5              afforded_usual        0.172981        0.644417        0.336767
# 6         typical_of_property        0.231757        0.755240        0.326482
# 7                    creative        0.059688        0.544502        0.040020
# 8                        rare        0.132488        0.576444             NaN
# 9          typical_of_concept        0.311785        0.712881        0.367910
# 10           afforded_unusual        0.068180        0.544889        0.108460
# 11                  test_true        0.045786        0.794077             NaN
# 12                     _check        0.606292        0.884235        0.904637
# 13                 test_false        0.258187        0.702768             NaN
# 14                    unusual        0.159998        0.576699        0.120147
# 15           variability_open        0.214621        0.606366        0.143751
#
#     1_Proportional
# 0         0.629956
# 1         0.672259
# 2         0.579637
# 3         0.679565
# 4         0.599990
# 5         0.698580
# 6         0.682547
# 7         0.524894
# 8              NaN
# 9         0.689440
# 10        0.557623
# 11             NaN
# 12        0.964443
# 13             NaN
# 14        0.561644
# 15        0.580081

# %% [markdown]
# ## Agreement after removing workers or annotations:

# %%
run = '3'
batch = '*'
n_q = '*'
group = 'experiment1'

print('Total Agreement')
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)
print('-------')
print()

print('Removing pair annotations with many contradictions:')
category = 'pairs_contradictions'
print(f'analyze {category}')
annotations_clean, annotations_removed = clean_annotations(run, group, n_q, batch, category)
print('agreement clean')
get_agreement(annotations_clean)
#print('agreement rest')
#get_agreement(annotations_removed)


category = 'worker_contradictions'
print(f'analyze {category}')
annotations_clean, annotations_removed = clean_annotations(run, group, n_q, batch, category)
print('agreement clean')
get_agreement(annotations_clean)
#print('agreement rest')
#get_agreement(annotations_removed)
print()

category = 'worker_checks'
print(f'analyze {category}')
annotations_clean, annotations_removed = clean_annotations(run, group, n_q, batch, category)
print('agreement clean')
get_agreement(annotations_clean)
#print('agreement rest')
#get_agreement(annotations_removed)
# Out:
# Total Agreement
# Discarded 655.0 annotations.
# Krippendorff's alpha: 0.23336207839907597
# Proportional agreement (pairwise): 0.6304754199128316
#
# -------
#
# Removing pair annotations with many contradictions:
# analyze pairs_contradictions
# Discarded 655.0 annotations.
# Found 24827 clean annotations.
# Round 10212 to remove.
#
# agreement clean
# Krippendorff's alpha: 0.33405102479157067
# Proportional agreement (pairwise): 0.68651450192071
#
# analyze worker_contradictions
# Discarded 655.0 annotations.
# Found 24877 clean annotations.
# Round 10100 to remove.
#
# agreement clean
# Krippendorff's alpha: 0.24953378047207264
# Proportional agreement (pairwise): 0.6498735089301452
#
#
# analyze worker_checks
# Discarded 655.0 annotations.
# Found 32448 clean annotations.
# Round 2529 to remove.
#
# agreement clean
# Krippendorff's alpha: 0.25028983009201133
# Proportional agreement (pairwise): 0.639896601266422
# {'Krippendorff': 0.25028983009201133, 'Proportional': 0.639896601266422}
