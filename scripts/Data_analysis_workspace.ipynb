# %% [markdown]
# # Annotation analysis
#
# This noteboook
#
# * illustrates the steps of the analysis currently implemented
# * is used to analyze and monitor workers batch by batch

# %%
from load_data import load_experiment_data
from analyze_workers import get_worker_analysis
from analyze_pairs import get_pair_analysis
from analyze_pairs import show_pairs_of_worker
from analyze_pairs import compare_runs
from calculate_iaa import get_agreement
from clean_annotations import clean_annotations
from analyze_relations_and_examples import agreement_relations_across_runs

# %% [markdown]
# # Analyze worker contradictions:
#
# * Workers with highest contradiction to annotations ratio appear on top
# * use the pandas dataframe sort method to sort on other values:
#
# `df.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')`

# %% [markdown]
# ### Current batch

# %%
run = 4
batch = 2
n_q = '*'
group = 'experiment2'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_worker_analysis(data_dict_list, name)
df.drop(['annotations'], axis = 1, inplace=True)
df
# Out:
# Discarded 0.0 annotations.
#                    workerid  n_annotations  n_contradictions  n_fails  \
# 7  5e7d04851ae8680b7c88e7e4             72                24        1
# 2  5d977727646bb70012d6ea5b             72                14        1
# 5  5e66c749fd0e5b454700f10f             72                11        1
# 0  58ac3822890ea500014c665d             72                 7        1
# 4  5e1aed4331d8d93320bc6d4e             77                 3        1
# 3  5e196bcd49c6aa210ea6aaad             72                 2        1
# 9  5e9cfd9cee0aed225ed1c501             72                 2        1
# 1  59007be801efbd0001856baf             72                 0        1
# 6  5e6e35cac8f7653d80726811             72                 0        1
# 8  5e9b4d1efab83b050f3bd741             72                 0        0
#
#    contradiction_annotation_ratio  n_possible_contradictions  \
# 7                        0.333333                         72
# 2                        0.194444                         72
# 5                        0.152778                         72
# 0                        0.097222                         72
# 4                        0.038961                         72
# 3                        0.027778                         72
# 9                        0.027778                         72
# 1                        0.000000                         72
# 6                        0.000000                         72
# 8                        0.000000                         72
#
#    contradiction_poss_contradiction_ratio  fail_annotation_ratio  \
# 7                                0.333333               0.013889
# 2                                0.194444               0.013889
# 5                                0.152778               0.013889
# 0                                0.097222               0.013889
# 4                                0.041667               0.012987
# 3                                0.027778               0.013889
# 9                                0.027778               0.013889
# 1                                0.000000               0.013889
# 6                                0.000000               0.013889
# 8                                0.000000               0.000000
#
#    contradictory_pairs_ratio  average_time_question  ...  \
# 7                        0.4              13.606750  ...
# 2                        0.5               7.412889  ...
# 5                        0.3              10.719486  ...
# 0                        0.2              24.351819  ...
# 4                        0.2              13.547494  ...
# 3                        0.1              12.213319  ...
# 9                        0.1              32.265972  ...
# 1                        0.0              10.793125  ...
# 6                        0.0               9.578764  ...
# 8                        0.0              39.127903  ...
#
#    (afforded_usual, rare)  (afforded_usual, unusual)  \
# 7                     1.0                        1.0
# 2                     NaN                        NaN
# 5                     NaN                        NaN
# 0                     1.0                        1.0
# 4                     NaN                        NaN
# 3                     NaN                        NaN
# 9                     NaN                        NaN
# 1                     NaN                        NaN
# 6                     NaN                        NaN
# 8                     NaN                        NaN
#
#    (rare, typical_of_concept)  (typical_of_concept, unusual)  \
# 7                         3.0                            3.0
# 2                         1.0                            1.0
# 5                         3.0                            1.0
# 0                         NaN                            NaN
# 4                         NaN                            NaN
# 3                         NaN                            NaN
# 9                         NaN                            NaN
# 1                         NaN                            NaN
# 6                         NaN                            NaN
# 8                         NaN                            NaN
#
#    (typical_of_property, unusual)  (rare, typical_of_property)  \
# 7                             2.0                          2.0
# 2                             2.0                          1.0
# 5                             NaN                          1.0
# 0                             NaN                          NaN
# 4                             NaN                          NaN
# 3                             1.0                          1.0
# 9                             NaN                          NaN
# 1                             NaN                          NaN
# 6                             NaN                          NaN
# 8                             NaN                          NaN
#
#    (impossible, typical_of_concept)  (affording_activity, impossible)  \
# 7                               1.0                               NaN
# 2                               NaN                               NaN
# 5                               1.0                               1.0
# 0                               NaN                               NaN
# 4                               1.0                               1.0
# 3                               NaN                               NaN
# 9                               NaN                               NaN
# 1                               NaN                               NaN
# 6                               NaN                               NaN
# 8                               NaN                               NaN
#
#    (impossible, typical_of_property)  (implied_category, impossible)
# 7                                1.0                             1.0
# 2                                NaN                             NaN
# 5                                NaN                             NaN
# 0                                NaN                             NaN
# 4                                NaN                             NaN
# 3                                NaN                             NaN
# 9                                NaN                             NaN
# 1                                NaN                             NaN
# 6                                NaN                             NaN
# 8                                NaN                             NaN
#
# [10 rows x 25 columns]

# %% [markdown]
# ### All annotations
#
# * Workers with highest contradiction to annotations ratio appear on top
# * use the pandas dataframe sort method to sort on other values:
# * Check how the behavior of a specific worker with many contradictions compares to other workers
#
# `df.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')`

# %%
run = '*'
batch = '*'
n_q = '*'
group = 'experiment2'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df_total, filepath = get_worker_analysis(data_dict_list, name)
df_total.drop(['annotations'], axis = 1, inplace=True)
df_total[:10]
# Out:
# Discarded 0.0 annotations.
#                     workerid  n_annotations  n_contradictions  n_fails  \
# 16  5e7d04851ae8680b7c88e7e4             72                24        1
# 0   55b24072fdf99b2462d7d259             72                27        0
# 11  5d977727646bb70012d6ea5b             72                14        1
# 14  5e66c749fd0e5b454700f10f             72                11        1
# 10  58ac3822890ea500014c665d             72                 7        1
# 4   59a42dd68d2b1600011b407d             72                 8        0
# 7   5b872639a89e62000113cbb6             72                 6        0
# 9   5e23cce1233c6c674df6fb07             72                 4        0
# 13  5e1aed4331d8d93320bc6d4e             77                 3        1
# 3   59007be801efbd0001856baf            144                 6        1
#
#     contradiction_annotation_ratio  n_possible_contradictions  \
# 16                        0.333333                         72
# 0                         0.375000                         84
# 11                        0.194444                         72
# 14                        0.152778                         72
# 10                        0.097222                         72
# 4                         0.111111                         84
# 7                         0.083333                         84
# 9                         0.055556                         84
# 13                        0.038961                         72
# 3                         0.041667                        156
#
#     contradiction_poss_contradiction_ratio  fail_annotation_ratio  \
# 16                                0.333333               0.013889
# 0                                 0.321429               0.000000
# 11                                0.194444               0.013889
# 14                                0.152778               0.013889
# 10                                0.097222               0.013889
# 4                                 0.095238               0.000000
# 7                                 0.071429               0.000000
# 9                                 0.047619               0.000000
# 13                                0.041667               0.012987
# 3                                 0.038462               0.006944
#
#     contradictory_pairs_ratio  average_time_question  ...  \
# 16                   0.400000              13.606750  ...
# 0                    0.666667              12.016708  ...
# 11                   0.500000               7.412889  ...
# 14                   0.300000              10.719486  ...
# 10                   0.200000              24.351819  ...
# 4                    0.333333              15.128681  ...
# 7                    0.333333               7.642375  ...
# 9                    0.222222              18.718042  ...
# 13                   0.200000              13.547494  ...
# 3                    0.055556               9.163729  ...
#
#     (impossible, typical_of_concept)  (typical_of_concept, unusual)  \
# 16                               1.0                            3.0
# 0                                2.0                            3.0
# 11                               NaN                            1.0
# 14                               1.0                            1.0
# 10                               NaN                            NaN
# 4                                1.0                            1.0
# 7                                NaN                            NaN
# 9                                NaN                            NaN
# 13                               1.0                            NaN
# 3                                NaN                            NaN
#
#     (affording_activity, unusual)  (implied_category, unusual)  \
# 16                            1.0                          3.0
# 0                             5.0                          3.0
# 11                            1.0                          3.0
# 14                            1.0                          NaN
# 10                            1.0                          1.0
# 4                             NaN                          2.0
# 7                             1.0                          2.0
# 9                             2.0                          1.0
# 13                            NaN                          NaN
# 3                             1.0                          1.0
#
#     (typical_of_property, unusual)  (rare, typical_of_property)  \
# 16                             2.0                          2.0
# 0                              2.0                          1.0
# 11                             2.0                          1.0
# 14                             NaN                          1.0
# 10                             NaN                          NaN
# 4                              NaN                          NaN
# 7                              NaN                          NaN
# 9                              NaN                          NaN
# 13                             NaN                          NaN
# 3                              NaN                          NaN
#
#     (afforded_usual, impossible)  (afforded_usual, rare)  \
# 16                           1.0                     1.0
# 0                            NaN                     NaN
# 11                           NaN                     NaN
# 14                           NaN                     NaN
# 10                           1.0                     1.0
# 4                            NaN                     NaN
# 7                            NaN                     NaN
# 9                            NaN                     NaN
# 13                           1.0                     NaN
# 3                            NaN                     NaN
#
#     (afforded_usual, unusual)  (impossible, typical_of_property)
# 16                        1.0                                1.0
# 0                         NaN                                NaN
# 11                        NaN                                NaN
# 14                        NaN                                NaN
# 10                        1.0                                NaN
# 4                         NaN                                NaN
# 7                         NaN                                NaN
# 9                         NaN                                NaN
# 13                        NaN                                NaN
# 3                         NaN                                NaN
#
# [10 rows x 25 columns]

# %%
# Good workers
df_total[-20:]
# Out:
#                     workerid  n_annotations  n_contradictions  n_fails  \
# 16  5e7d04851ae8680b7c88e7e4             72                24        1
# 0   55b24072fdf99b2462d7d259             72                27        0
# 11  5d977727646bb70012d6ea5b             72                14        1
# 14  5e66c749fd0e5b454700f10f             72                11        1
# 10  58ac3822890ea500014c665d             72                 7        1
# 4   59a42dd68d2b1600011b407d             72                 8        0
# 7   5b872639a89e62000113cbb6             72                 6        0
# 9   5e23cce1233c6c674df6fb07             72                 4        0
# 13  5e1aed4331d8d93320bc6d4e             77                 3        1
# 3   59007be801efbd0001856baf            144                 6        1
# 12  5e196bcd49c6aa210ea6aaad             72                 2        1
# 18  5e9cfd9cee0aed225ed1c501             72                 2        1
# 1   55e7117841988f000d75ce09             72                 1        1
# 8   5c3fb75eca00d30001c5187d             72                 0        0
# 6   5aae93f5fb22320001baaaac             72                 0        0
# 5   5aae762bc4e8f200014b3f88             72                 0        0
# 15  5e6e35cac8f7653d80726811             72                 0        1
# 2   56e99d054111eb000c77885b             72                 0        0
# 17  5e9b4d1efab83b050f3bd741             72                 0        0
#
#     contradiction_annotation_ratio  n_possible_contradictions  \
# 16                        0.333333                         72
# 0                         0.375000                         84
# 11                        0.194444                         72
# 14                        0.152778                         72
# 10                        0.097222                         72
# 4                         0.111111                         84
# 7                         0.083333                         84
# 9                         0.055556                         84
# 13                        0.038961                         72
# 3                         0.041667                        156
# 12                        0.027778                         72
# 18                        0.027778                         72
# 1                         0.013889                         84
# 8                         0.000000                         84
# 6                         0.000000                         84
# 5                         0.000000                         84
# 15                        0.000000                         72
# 2                         0.000000                         84
# 17                        0.000000                         72
#
#     contradiction_poss_contradiction_ratio  fail_annotation_ratio  \
# 16                                0.333333               0.013889
# 0                                 0.321429               0.000000
# 11                                0.194444               0.013889
# 14                                0.152778               0.013889
# 10                                0.097222               0.013889
# 4                                 0.095238               0.000000
# 7                                 0.071429               0.000000
# 9                                 0.047619               0.000000
# 13                                0.041667               0.012987
# 3                                 0.038462               0.006944
# 12                                0.027778               0.013889
# 18                                0.027778               0.013889
# 1                                 0.011905               0.013889
# 8                                 0.000000               0.000000
# 6                                 0.000000               0.000000
# 5                                 0.000000               0.000000
# 15                                0.000000               0.013889
# 2                                 0.000000               0.000000
# 17                                0.000000               0.000000
#
#     contradictory_pairs_ratio  average_time_question  ...  \
# 16                   0.400000              13.606750  ...
# 0                    0.666667              12.016708  ...
# 11                   0.500000               7.412889  ...
# 14                   0.300000              10.719486  ...
# 10                   0.200000              24.351819  ...
# 4                    0.333333              15.128681  ...
# 7                    0.333333               7.642375  ...
# 9                    0.222222              18.718042  ...
# 13                   0.200000              13.547494  ...
# 3                    0.055556               9.163729  ...
# 12                   0.100000              12.213319  ...
# 18                   0.100000              32.265972  ...
# 1                    0.111111               4.525097  ...
# 8                    0.000000               9.645694  ...
# 6                    0.000000              11.753167  ...
# 5                    0.000000               9.914667  ...
# 15                   0.000000               9.578764  ...
# 2                    0.000000              19.148639  ...
# 17                   0.000000              39.127903  ...
#
#     (impossible, typical_of_concept)  (typical_of_concept, unusual)  \
# 16                               1.0                            3.0
# 0                                2.0                            3.0
# 11                               NaN                            1.0
# 14                               1.0                            1.0
# 10                               NaN                            NaN
# 4                                1.0                            1.0
# 7                                NaN                            NaN
# 9                                NaN                            NaN
# 13                               1.0                            NaN
# 3                                NaN                            NaN
# 12                               NaN                            NaN
# 18                               NaN                            NaN
# 1                                NaN                            NaN
# 8                                NaN                            NaN
# 6                                NaN                            NaN
# 5                                NaN                            NaN
# 15                               NaN                            NaN
# 2                                NaN                            NaN
# 17                               NaN                            NaN
#
#     (affording_activity, unusual)  (implied_category, unusual)  \
# 16                            1.0                          3.0
# 0                             5.0                          3.0
# 11                            1.0                          3.0
# 14                            1.0                          NaN
# 10                            1.0                          1.0
# 4                             NaN                          2.0
# 7                             1.0                          2.0
# 9                             2.0                          1.0
# 13                            NaN                          NaN
# 3                             1.0                          1.0
# 12                            NaN                          NaN
# 18                            1.0                          NaN
# 1                             1.0                          NaN
# 8                             NaN                          NaN
# 6                             NaN                          NaN
# 5                             NaN                          NaN
# 15                            NaN                          NaN
# 2                             NaN                          NaN
# 17                            NaN                          NaN
#
#     (typical_of_property, unusual)  (rare, typical_of_property)  \
# 16                             2.0                          2.0
# 0                              2.0                          1.0
# 11                             2.0                          1.0
# 14                             NaN                          1.0
# 10                             NaN                          NaN
# 4                              NaN                          NaN
# 7                              NaN                          NaN
# 9                              NaN                          NaN
# 13                             NaN                          NaN
# 3                              NaN                          NaN
# 12                             1.0                          1.0
# 18                             NaN                          NaN
# 1                              NaN                          NaN
# 8                              NaN                          NaN
# 6                              NaN                          NaN
# 5                              NaN                          NaN
# 15                             NaN                          NaN
# 2                              NaN                          NaN
# 17                             NaN                          NaN
#
#     (afforded_usual, impossible)  (afforded_usual, rare)  \
# 16                           1.0                     1.0
# 0                            NaN                     NaN
# 11                           NaN                     NaN
# 14                           NaN                     NaN
# 10                           1.0                     1.0
# 4                            NaN                     NaN
# 7                            NaN                     NaN
# 9                            NaN                     NaN
# 13                           1.0                     NaN
# 3                            NaN                     NaN
# 12                           NaN                     NaN
# 18                           NaN                     NaN
# 1                            NaN                     NaN
# 8                            NaN                     NaN
# 6                            NaN                     NaN
# 5                            NaN                     NaN
# 15                           NaN                     NaN
# 2                            NaN                     NaN
# 17                           NaN                     NaN
#
#     (afforded_usual, unusual)  (impossible, typical_of_property)
# 16                        1.0                                1.0
# 0                         NaN                                NaN
# 11                        NaN                                NaN
# 14                        NaN                                NaN
# 10                        1.0                                NaN
# 4                         NaN                                NaN
# 7                         NaN                                NaN
# 9                         NaN                                NaN
# 13                        NaN                                NaN
# 3                         NaN                                NaN
# 12                        NaN                                NaN
# 18                        NaN                                NaN
# 1                         NaN                                NaN
# 8                         NaN                                NaN
# 6                         NaN                                NaN
# 5                         NaN                                NaN
# 15                        NaN                                NaN
# 2                         NaN                                NaN
# 17                        NaN                                NaN
#
# [19 rows x 25 columns]

# %% [markdown]
# ### Get all contradictions and fails of a particular worker
#
# * Check if a specfic worker continuously contradicts themselves (and fails checks)

# %%
# copy from above - worker with many disagreements in target batch
worker = '5e7d04851ae8680b7c88e7e4'


# df.loc[df['column_name'] == some_value]
df_total.loc[df_total['workerid'] == worker]
# Out:
#                     workerid  n_annotations  n_contradictions  n_fails  \
# 16  5e7d04851ae8680b7c88e7e4             72                24        1
#
#     contradiction_annotation_ratio  n_possible_contradictions  \
# 16                        0.333333                         72
#
#     contradiction_poss_contradiction_ratio  fail_annotation_ratio  \
# 16                                0.333333               0.013889
#
#     contradictory_pairs_ratio  average_time_question  ...  \
# 16                        0.4               13.60675  ...
#
#     (impossible, typical_of_concept)  (typical_of_concept, unusual)  \
# 16                               1.0                            3.0
#
#     (affording_activity, unusual)  (implied_category, unusual)  \
# 16                            1.0                          3.0
#
#     (typical_of_property, unusual)  (rare, typical_of_property)  \
# 16                             2.0                          2.0
#
#     (afforded_usual, impossible)  (afforded_usual, rare)  \
# 16                           1.0                     1.0
#
#     (afforded_usual, unusual)  (impossible, typical_of_property)
# 16                        1.0                                1.0
#
# [1 rows x 25 columns]

# %% [markdown]
# # Analyze pairs
#
# * compars number of annotator contradictions among pairs

# %% [markdown]
# ### Current batch:

# %%
run = '4'
batch = '*'
n_q = '*'
group = 'experiment2'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_pair_analysis(data_dict_list, name)
df.drop(['annotations_with_contradiction'], axis = 1, inplace=True)
df
# Out:
# Discarded 0.0 annotations.
#                    pair  n_annotations  n_workers  n_contradictions  \
# 9        sweet-hazelnut            101         10                11
# 15       black-pipefish            102         10                14
# 5          wheels-stage            100         10                15
# 16         fly-nuthatch            100         10                12
# 4            wheels-rig            100         10                 5
# 11  made_of_wood-timber            101         10                10
# 1        wheels-railcar            100         10                 7
# 13       lay_eggs-eland            101         10                 8
# 10            hot-candy            100         10                 8
# 0     dangerous-unction            100         10                10
# 3      dangerous-opener            100         10                 5
# 2       dangerous-plane            100         10                 8
# 6         dangerous-bar            100         10                 2
# 8          _test3-_test             10         10                 0
# 7       _check3-_check3             20         19                 0
# 12      wheels-carriage             60         10                 0
# 14       yellow-vanilla             40         10                 0
# 17         _test4-_test             10         10                 0
#
#     n_workers_contradicting  ratio_workers_contradicting  \
# 9                         4                          0.4
# 15                        4                          0.4
# 5                         4                          0.4
# 16                        3                          0.3
# 4                         3                          0.3
# 11                        3                          0.3
# 1                         2                          0.2
# 13                        2                          0.2
# 10                        2                          0.2
# 0                         2                          0.2
# 3                         2                          0.2
# 2                         2                          0.2
# 6                         1                          0.1
# 8                         0                          0.0
# 7                         0                          0.0
# 12                        0                          0.0
# 14                        0                          0.0
# 17                        0                          0.0
#
#     contradiction_annotation_ratio  n_possible_contradictions  \
# 9                         0.108911                        120
# 15                        0.137255                        120
# 5                         0.150000                        120
# 16                        0.120000                        120
# 4                         0.050000                        120
# 11                        0.099010                        120
# 1                         0.070000                        120
# 13                        0.079208                        120
# 10                        0.080000                        120
# 0                         0.100000                        120
# 3                         0.050000                        120
# 2                         0.080000                        120
# 6                         0.020000                        120
# 8                         0.000000                          0
# 7                         0.000000                          0
# 12                        0.000000                          0
# 14                        0.000000                          0
# 17                        0.000000                          0
#
#     contradiction_poss_contradiction_ratio  average_time_pair  ...  \
# 9                                 0.091667         124.733665  ...
# 15                                0.116667         123.943395  ...
# 5                                 0.125000          83.539730  ...
# 16                                0.100000         125.681990  ...
# 4                                 0.041667          83.539730  ...
# 11                                0.083333         124.733665  ...
# 1                                 0.058333          83.539730  ...
# 13                                0.066667         124.733665  ...
# 10                                0.066667         125.681990  ...
# 0                                 0.083333          83.539730  ...
# 3                                 0.041667          83.539730  ...
# 2                                 0.066667          83.539730  ...
# 6                                 0.016667          83.539730  ...
# 8                                 0.000000         835.397300  ...
# 7                                 0.000000        1066.441237  ...
# 12                                0.000000         209.469983  ...
# 14                                0.000000         314.204975  ...
# 17                                0.000000        1256.819900  ...
#
#    (impossible, typical_of_concept) (implied_category, unusual)  \
# 9                               1.0                         1.0
# 15                              NaN                         2.0
# 5                               NaN                         2.0
# 16                              1.0                         1.0
# 4                               NaN                         1.0
# 11                              NaN                         2.0
# 1                               1.0                         1.0
# 13                              NaN                         1.0
# 10                              1.0                         NaN
# 0                               2.0                         1.0
# 3                               NaN                         1.0
# 2                               NaN                         2.0
# 6                               NaN                         1.0
# 8                               NaN                         NaN
# 7                               NaN                         NaN
# 12                              NaN                         NaN
# 14                              NaN                         NaN
# 17                              NaN                         NaN
#
#     (typical_of_concept, unusual)  (affording_activity, unusual)  \
# 9                             1.0                            1.0
# 15                            1.0                            1.0
# 5                             1.0                            3.0
# 16                            1.0                            NaN
# 4                             NaN                            3.0
# 11                            1.0                            1.0
# 1                             1.0                            1.0
# 13                            NaN                            NaN
# 10                            1.0                            2.0
# 0                             1.0                            NaN
# 3                             1.0                            1.0
# 2                             NaN                            1.0
# 6                             NaN                            1.0
# 8                             NaN                            NaN
# 7                             NaN                            NaN
# 12                            NaN                            NaN
# 14                            NaN                            NaN
# 17                            NaN                            NaN
#
#     (typical_of_property, unusual)  (rare, typical_of_property)  \
# 9                              NaN                          NaN
# 15                             2.0                          2.0
# 5                              1.0                          1.0
# 16                             1.0                          NaN
# 4                              NaN                          NaN
# 11                             1.0                          1.0
# 1                              NaN                          NaN
# 13                             1.0                          2.0
# 10                             NaN                          NaN
# 0                              NaN                          NaN
# 3                              1.0                          NaN
# 2                              NaN                          NaN
# 6                              NaN                          NaN
# 8                              NaN                          NaN
# 7                              NaN                          NaN
# 12                             NaN                          NaN
# 14                             NaN                          NaN
# 17                             NaN                          NaN
#
#     (afforded_usual, rare)  (afforded_usual, impossible)  \
# 9                      NaN                           NaN
# 15                     NaN                           NaN
# 5                      NaN                           NaN
# 16                     1.0                           3.0
# 4                      NaN                           NaN
# 11                     NaN                           NaN
# 1                      NaN                           NaN
# 13                     1.0                           NaN
# 10                     NaN                           NaN
# 0                      NaN                           NaN
# 3                      NaN                           NaN
# 2                      NaN                           NaN
# 6                      NaN                           NaN
# 8                      NaN                           NaN
# 7                      NaN                           NaN
# 12                     NaN                           NaN
# 14                     NaN                           NaN
# 17                     NaN                           NaN
#
#     (afforded_usual, unusual)  (impossible, typical_of_property)
# 9                         NaN                                NaN
# 15                        NaN                                NaN
# 5                         NaN                                NaN
# 16                        2.0                                1.0
# 4                         NaN                                NaN
# 11                        NaN                                NaN
# 1                         NaN                                NaN
# 13                        NaN                                NaN
# 10                        NaN                                NaN
# 0                         NaN                                NaN
# 3                         NaN                                NaN
# 2                         NaN                                NaN
# 6                         NaN                                NaN
# 8                         NaN                                NaN
# 7                         NaN                                NaN
# 12                        NaN                                NaN
# 14                        NaN                                NaN
# 17                        NaN                                NaN
#
# [18 rows x 27 columns]

# %% [markdown]
# ### Get rows with pairs annotated by specific workers:
#
# * Check if a worker in the only one contradicting or if others also had issues with the pairs

# %%
worker = '5e7d04851ae8680b7c88e7e4'

show_pairs_of_worker(worker, df)
# Out:
# Worker 5e7d04851ae8680b7c88e7e4 contradicted themselves in the following pairs:
#
# sweet-hazelnut 	 total workers contradicting themselves: 4
# black-pipefish 	 total workers contradicting themselves: 4
# fly-nuthatch 	 total workers contradicting themselves: 3
# lay_eggs-eland 	 total workers contradicting themselves: 2

# %% [markdown]
# ### Compare to entire annotation set

# %%
run = '4'
batch = '*'
n_q = '*'
group = 'experiment2'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_pair_analysis(data_dict_list, name)
df.drop(['annotations_with_contradiction'], axis = 1, inplace=True)
df
# Out:
# Discarded 0.0 annotations.
#                    pair  n_annotations  n_workers  n_contradictions  \
# 9        sweet-hazelnut            101         10                11
# 15       black-pipefish            102         10                14
# 5          wheels-stage            100         10                15
# 16         fly-nuthatch            100         10                12
# 4            wheels-rig            100         10                 5
# 11  made_of_wood-timber            101         10                10
# 1        wheels-railcar            100         10                 7
# 13       lay_eggs-eland            101         10                 8
# 10            hot-candy            100         10                 8
# 0     dangerous-unction            100         10                10
# 3      dangerous-opener            100         10                 5
# 2       dangerous-plane            100         10                 8
# 6         dangerous-bar            100         10                 2
# 8          _test3-_test             10         10                 0
# 7       _check3-_check3             20         19                 0
# 12      wheels-carriage             60         10                 0
# 14       yellow-vanilla             40         10                 0
# 17         _test4-_test             10         10                 0
#
#     n_workers_contradicting  ratio_workers_contradicting  \
# 9                         4                          0.4
# 15                        4                          0.4
# 5                         4                          0.4
# 16                        3                          0.3
# 4                         3                          0.3
# 11                        3                          0.3
# 1                         2                          0.2
# 13                        2                          0.2
# 10                        2                          0.2
# 0                         2                          0.2
# 3                         2                          0.2
# 2                         2                          0.2
# 6                         1                          0.1
# 8                         0                          0.0
# 7                         0                          0.0
# 12                        0                          0.0
# 14                        0                          0.0
# 17                        0                          0.0
#
#     contradiction_annotation_ratio  n_possible_contradictions  \
# 9                         0.108911                        120
# 15                        0.137255                        120
# 5                         0.150000                        120
# 16                        0.120000                        120
# 4                         0.050000                        120
# 11                        0.099010                        120
# 1                         0.070000                        120
# 13                        0.079208                        120
# 10                        0.080000                        120
# 0                         0.100000                        120
# 3                         0.050000                        120
# 2                         0.080000                        120
# 6                         0.020000                        120
# 8                         0.000000                          0
# 7                         0.000000                          0
# 12                        0.000000                          0
# 14                        0.000000                          0
# 17                        0.000000                          0
#
#     contradiction_poss_contradiction_ratio  average_time_pair  ...  \
# 9                                 0.091667         124.733665  ...
# 15                                0.116667         123.943395  ...
# 5                                 0.125000          83.539730  ...
# 16                                0.100000         125.681990  ...
# 4                                 0.041667          83.539730  ...
# 11                                0.083333         124.733665  ...
# 1                                 0.058333          83.539730  ...
# 13                                0.066667         124.733665  ...
# 10                                0.066667         125.681990  ...
# 0                                 0.083333          83.539730  ...
# 3                                 0.041667          83.539730  ...
# 2                                 0.066667          83.539730  ...
# 6                                 0.016667          83.539730  ...
# 8                                 0.000000         835.397300  ...
# 7                                 0.000000        1066.441237  ...
# 12                                0.000000         209.469983  ...
# 14                                0.000000         314.204975  ...
# 17                                0.000000        1256.819900  ...
#
#    (impossible, typical_of_concept) (implied_category, unusual)  \
# 9                               1.0                         1.0
# 15                              NaN                         2.0
# 5                               NaN                         2.0
# 16                              1.0                         1.0
# 4                               NaN                         1.0
# 11                              NaN                         2.0
# 1                               1.0                         1.0
# 13                              NaN                         1.0
# 10                              1.0                         NaN
# 0                               2.0                         1.0
# 3                               NaN                         1.0
# 2                               NaN                         2.0
# 6                               NaN                         1.0
# 8                               NaN                         NaN
# 7                               NaN                         NaN
# 12                              NaN                         NaN
# 14                              NaN                         NaN
# 17                              NaN                         NaN
#
#     (typical_of_concept, unusual)  (affording_activity, unusual)  \
# 9                             1.0                            1.0
# 15                            1.0                            1.0
# 5                             1.0                            3.0
# 16                            1.0                            NaN
# 4                             NaN                            3.0
# 11                            1.0                            1.0
# 1                             1.0                            1.0
# 13                            NaN                            NaN
# 10                            1.0                            2.0
# 0                             1.0                            NaN
# 3                             1.0                            1.0
# 2                             NaN                            1.0
# 6                             NaN                            1.0
# 8                             NaN                            NaN
# 7                             NaN                            NaN
# 12                            NaN                            NaN
# 14                            NaN                            NaN
# 17                            NaN                            NaN
#
#     (typical_of_property, unusual)  (rare, typical_of_property)  \
# 9                              NaN                          NaN
# 15                             2.0                          2.0
# 5                              1.0                          1.0
# 16                             1.0                          NaN
# 4                              NaN                          NaN
# 11                             1.0                          1.0
# 1                              NaN                          NaN
# 13                             1.0                          2.0
# 10                             NaN                          NaN
# 0                              NaN                          NaN
# 3                              1.0                          NaN
# 2                              NaN                          NaN
# 6                              NaN                          NaN
# 8                              NaN                          NaN
# 7                              NaN                          NaN
# 12                             NaN                          NaN
# 14                             NaN                          NaN
# 17                             NaN                          NaN
#
#     (afforded_usual, rare)  (afforded_usual, impossible)  \
# 9                      NaN                           NaN
# 15                     NaN                           NaN
# 5                      NaN                           NaN
# 16                     1.0                           3.0
# 4                      NaN                           NaN
# 11                     NaN                           NaN
# 1                      NaN                           NaN
# 13                     1.0                           NaN
# 10                     NaN                           NaN
# 0                      NaN                           NaN
# 3                      NaN                           NaN
# 2                      NaN                           NaN
# 6                      NaN                           NaN
# 8                      NaN                           NaN
# 7                      NaN                           NaN
# 12                     NaN                           NaN
# 14                     NaN                           NaN
# 17                     NaN                           NaN
#
#     (afforded_usual, unusual)  (impossible, typical_of_property)
# 9                         NaN                                NaN
# 15                        NaN                                NaN
# 5                         NaN                                NaN
# 16                        2.0                                1.0
# 4                         NaN                                NaN
# 11                        NaN                                NaN
# 1                         NaN                                NaN
# 13                        NaN                                NaN
# 10                        NaN                                NaN
# 0                         NaN                                NaN
# 3                         NaN                                NaN
# 2                         NaN                                NaN
# 6                         NaN                                NaN
# 8                         NaN                                NaN
# 7                         NaN                                NaN
# 12                        NaN                                NaN
# 14                        NaN                                NaN
# 17                        NaN                                NaN
#
# [18 rows x 27 columns]

# %%
# check specific pair:

pair = 'red-lipstick'
df.loc[df['pair'] == pair]
# Out:
#              pair  n_annotations  n_workers  n_contradictions  \
# 305  red-lipstick             50          5                 7
#
#      n_workers_contradicting  ratio_workers_contradicting  \
# 305                        2                          0.4
#
#      contradiction_annotation_ratio  average_time_pair  \
# 305                            0.14             59.799
#
#                                  workers_contradicting  \
# 305  57617fdb1a5ecc0006fc3860 5ddc0d87d3ac2ad102aff2b9
#
#                              workers_not_contradicting  ...  \
# 305  59dc2e2016ecc200016fea95 5c544985be9cd80001156...  ...
#
#      (affording_activity, unusual)  (rare, typical_of_concept)  \
# 305                            1.0                         NaN
#
#      (rare, typical_of_property)  (implied_category, rare)  \
# 305                          NaN                       NaN
#
#      (implied_category, impossible)  (affording_activity, impossible)  \
# 305                             NaN                               NaN
#
#      (afforded_unusual, impossible)  (afforded_usual, rare)  \
# 305                             NaN                     NaN
#
#      (afforded_unusual, rare)  (afforded_usual, impossible)
# 305                       NaN                           NaN
#
# [1 rows x 28 columns]

# %% [markdown]
# ### Compare contradictions between runs:

# %%
run = '3'
batch = '*'
n_q = '*'
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df1, filepath = get_pair_analysis(data_dict_list, name)
print(f'analysis can be found at: {filepath}')

run = '4'
batch = '*'
n_q = '*'
group = 'experiment2'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df2, filepath = get_pair_analysis(data_dict_list, name)
print(f'analysis can be found at: {filepath}')

name1 = '3'
name2 = '4'
compare_runs(name1, name2, df1, df2, comp = 'all')
#print()
#compare_runs(name1, name2, df1, df2, comp = 'pairs')
# Out:
# Discarded 655.0 annotations.
# analysis can be found at: ../analyses/pairs/run3-group_experiment1-batch-all-.csv
# Discarded 0.0 annotations.
# analysis can be found at: ../analyses/pairs/run4-group_experiment2-batch-all-.csv
# Set 3 as a contradiction ratio of 0.20542056074766354
# Set 4 as a contradiction ratio of 0.17989417989417988
# The ratio is based on the number of workers annotating a pair.
# A worker always annotates a full set.
# (0.20542056074766354, 0.17989417989417988)

# %% [markdown]
# # Inter-annotator agreement
#
# * Total agreement
# * Agreement by relations
# * agreement after removing annotators with many contradictions/annotators who fail checks/contradictory annotations

# %% [markdown]
# ## Total iaa:

# %%
run = '*'
batch = '*'
n_q = '*'
group = 'experiment1'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)

run = '4'
batch = '*'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)

get_agreement(data_dict_list)
# Out:
# Run *:
# Discarded 655.0 annotations.
# Krippendorff's alpha: 0.23567624334318582
# Proportional agreement (pairwise): 0.6233819990832739
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.2557092823160244
# Proportional agreement (pairwise): 0.6446280991735535
# {'Krippendorff': 0.2557092823160244, 'Proportional': 0.6446280991735535}

# %% [markdown]
# ## IAA of collapsed relations

# %%
run = '*'
batch = '*'
n_q = '*'
group = 'experiment1'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)

collapse_relations = 'pos_neg'
print(f'collapsing {collapse_relations}')
get_agreement(data_dict_list, collapse_relations = collapse_relations)

collapse_relations = 'levels'
print(f'collapsing {collapse_relations}')
get_agreement(data_dict_list, collapse_relations = collapse_relations)

collapse_relations = 'similar_relations'
print(f'collapsing {collapse_relations}')
get_agreement(data_dict_list, collapse_relations = collapse_relations)


run = '4'
batch = '*'
n_q = '*'
group = 'experiment2'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)

collapse_relations = 'pos_neg'
print(f'collapsing {collapse_relations}')
get_agreement(data_dict_list, collapse_relations = collapse_relations)

collapse_relations = 'levels'
print(f'collapsing {collapse_relations}')
get_agreement(data_dict_list, collapse_relations = collapse_relations)

collapse_relations = 'similar_relations'
print(f'collapsing {collapse_relations}')
get_agreement(data_dict_list, collapse_relations = collapse_relations)
# Out:
# Run *:
# Discarded 655.0 annotations.
# Krippendorff's alpha: 0.23567624334318582
# Proportional agreement (pairwise): 0.6233819990832739
#
# collapsing pos_neg
# pos_neg
# Krippendorff's alpha: 0.3348903198600117
# Proportional agreement (pairwise): 0.7902502664705034
#
# collapsing levels
# levels
# Krippendorff's alpha: 0.3555916355102202
# Proportional agreement (pairwise): 0.7038679436637708
#
# collapsing similar_relations
# similar_relations
# Krippendorff's alpha: 0.37526324080891615
# Proportional agreement (pairwise): 0.6967938704580102
#
# Run 4:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.2557092823160244
# Proportional agreement (pairwise): 0.6446280991735535
#
# collapsing pos_neg
# pos_neg
# Krippendorff's alpha: 0.34615384615384615
# Proportional agreement (pairwise): 0.7154610622352557
#
# collapsing levels
# levels
# Krippendorff's alpha: 0.4013903547010509
# Proportional agreement (pairwise): 0.7050020579307507
#
# collapsing similar_relations
# similar_relations
# Krippendorff's alpha: 0.3774123398935175
# Proportional agreement (pairwise): 0.741418442380525
# {'Krippendorff': 0.3774123398935175, 'Proportional': 0.741418442380525}

# %% [markdown]
# ## IAA by relation

# %%
runs = ['3', '1']
experiment_name = 'experiment1'
path, df = agreement_relations_across_runs(runs, experiment_name)
print(f'Results written to: {path}')
df
# Out:
# Discarded 655.0 annotations.
# Discarded 0.0 annotations.
# Results written to: ../analyses/iaa/relations_runs3-1.csv
#                      relation  3_Krippendorff  3_Proportional  1_Krippendorff  \
# 0            implied_category        0.261604        0.648495        0.260459
# 1          affording_activity        0.196837        0.654605        0.149149
# 2   variability_subcategories             NaN             NaN        0.157270
# 3                  impossible        0.134907        0.658426        0.183925
# 4         variability_limited        0.103003        0.551718        0.197795
# 5              afforded_usual        0.172981        0.644417        0.336767
# 6         typical_of_property        0.231757        0.755240        0.326482
# 7                    creative        0.059688        0.544502        0.040020
# 8                        rare        0.132488        0.576444             NaN
# 9          typical_of_concept        0.311785        0.712881        0.367910
# 10           afforded_unusual        0.068180        0.544889        0.108460
# 11                  test_true        0.045786        0.794077             NaN
# 12                     _check        0.606292        0.884235        0.904637
# 13                 test_false        0.258187        0.702768             NaN
# 14                    unusual        0.159998        0.576699        0.120147
# 15           variability_open        0.214621        0.606366        0.143751
#
#     1_Proportional
# 0         0.629956
# 1         0.672259
# 2         0.579637
# 3         0.679565
# 4         0.599990
# 5         0.698580
# 6         0.682547
# 7         0.524894
# 8              NaN
# 9         0.689440
# 10        0.557623
# 11             NaN
# 12        0.964443
# 13             NaN
# 14        0.561644
# 15        0.580081

# %% [markdown]
# ## Agreement after removing workers or annotations:

# %%
run = '3'
batch = '*'
n_q = '*'
group = 'experiment1'

print('Total Agreement')
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)
print('-------')
print()

print('Removing pair annotations with many contradictions:')
category = 'pairs_contradictions'
print(f'analyze {category}')
annotations_clean, annotations_removed = clean_annotations(run, group, n_q, batch, category)
print('agreement clean')
get_agreement(annotations_clean)
#print('agreement rest')
#get_agreement(annotations_removed)


category = 'worker_contradictions'
print(f'analyze {category}')
annotations_clean, annotations_removed = clean_annotations(run, group, n_q, batch, category)
print('agreement clean')
get_agreement(annotations_clean)
#print('agreement rest')
#get_agreement(annotations_removed)
print()

category = 'worker_checks'
print(f'analyze {category}')
annotations_clean, annotations_removed = clean_annotations(run, group, n_q, batch, category)
print('agreement clean')
get_agreement(annotations_clean)
#print('agreement rest')
#get_agreement(annotations_removed)
# Out:
# Total Agreement
# Discarded 655.0 annotations.
# Krippendorff's alpha: 0.23336207839907597
# Proportional agreement (pairwise): 0.6304754199128316
#
# -------
#
# Removing pair annotations with many contradictions:
# analyze pairs_contradictions
# Discarded 655.0 annotations.
# Found 24827 clean annotations.
# Round 10212 to remove.
#
# agreement clean
# Krippendorff's alpha: 0.33405102479157067
# Proportional agreement (pairwise): 0.68651450192071
#
# analyze worker_contradictions
# Discarded 655.0 annotations.
# Found 24877 clean annotations.
# Round 10100 to remove.
#
# agreement clean
# Krippendorff's alpha: 0.24953378047207264
# Proportional agreement (pairwise): 0.6498735089301452
#
#
# analyze worker_checks
# Discarded 655.0 annotations.
# Found 32448 clean annotations.
# Round 2529 to remove.
#
# agreement clean
# Krippendorff's alpha: 0.25028983009201133
# Proportional agreement (pairwise): 0.639896601266422
# {'Krippendorff': 0.25028983009201133, 'Proportional': 0.639896601266422}
