# %% [markdown]
# # Annotation analysis
#
# This noteboook
#
# * illustrates the steps of the analysis currently implemented
# * is used to analyze and monitor workers batch by batch

# %%
from load_data import load_experiment_data
from analyze_workers import get_worker_analysis
from analyze_pairs import get_pair_analysis
from analyze_pairs import show_pairs_of_worker
from analyze_pairs import compare_runs
from calculate_iaa import get_agreement
from clean_annotations import clean_annotations
from analyze_relations_and_examples import agreement_relations_across_runs

# %% [markdown]
# # Analyze worker contradictions:
#
# * Workers with highest contradiction to annotations ratio appear on top
# * use the pandas dataframe sort method to sort on other values:
#
# `df.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')`

# %% [markdown]
# ### Current batch

# %%
run = 3
batch = 41
n_q = 70
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_worker_analysis(data_dict_list, name)
df.drop(['annotations'], axis = 1, inplace=True)
df
# Out:
# creating file with uuid run3-group_experiment1/qu70-s_qu70-batch41.csv
# added unique ids - file can be found at: ../data/prolific_output_uuid/run3-group_experiment1/qu70-s_qu70-batch41.csv
# Discarded 0.0 annotations.
#                    workerid  n_annotations  n_contradictions  n_fails  \
# 4  5c91bad5be78b00016c8329e             72                15        0
# 7  5d683e0f4a933f0001ebca29             72                10        0
# 9  5e874ce2a6b352069eae0aa2             72                 9        0
# 3  5baf689c51dfa8000130f19f             72                 6        0
# 8  5e8523df36bc6310a69ab92b             72                 5        0
# 5  5cd2cfecf03d540016cbc0a9             72                 3        0
# 6  5d0109dda3e75f001786296c             72                 3        0
# 2  5b222aff59f9620001c109cb             72                 2        0
# 0  56b8dc21e1d0a2000c15d4b7             72                 0        0
# 1  5a82ca84000dab00018c85cf             72                 0        0
#
#    contradiction_annotation_ratio  fail_annotation_ratio  \
# 4                        0.208333                    0.0
# 7                        0.138889                    0.0
# 9                        0.125000                    0.0
# 3                        0.083333                    0.0
# 8                        0.069444                    0.0
# 5                        0.041667                    0.0
# 6                        0.041667                    0.0
# 2                        0.027778                    0.0
# 0                        0.000000                    0.0
# 1                        0.000000                    0.0
#
#    average_time_question  (afforded_unusual, unusual)  \
# 4               6.447722                          NaN
# 7               5.591986                          2.0
# 9              14.709069                          1.0
# 3               9.884681                          NaN
# 8              18.917458                          1.0
# 5              10.605208                          1.0
# 6               7.492306                          1.0
# 2              15.668403                          1.0
# 0               9.077514                          NaN
# 1              10.702028                          NaN
#
#    (afforded_unusual, rare)  (implied_category, unusual)  ...  \
# 4                       NaN                          3.0  ...
# 7                       2.0                          3.0  ...
# 9                       1.0                          2.0  ...
# 3                       1.0                          1.0  ...
# 8                       NaN                          2.0  ...
# 5                       1.0                          NaN  ...
# 6                       1.0                          NaN  ...
# 2                       1.0                          NaN  ...
# 0                       NaN                          NaN  ...
# 1                       NaN                          NaN  ...
#
#    (affording_activity, impossible)  (implied_category, impossible)  \
# 4                               NaN                             1.0
# 7                               NaN                             NaN
# 9                               NaN                             NaN
# 3                               1.0                             1.0
# 8                               NaN                             NaN
# 5                               NaN                             NaN
# 6                               NaN                             NaN
# 2                               NaN                             NaN
# 0                               NaN                             NaN
# 1                               NaN                             NaN
#
#    (afforded_usual, unusual)  (afforded_usual, rare)  \
# 4                        2.0                     1.0
# 7                        NaN                     NaN
# 9                        NaN                     NaN
# 3                        NaN                     NaN
# 8                        NaN                     NaN
# 5                        NaN                     NaN
# 6                        NaN                     NaN
# 2                        NaN                     NaN
# 0                        NaN                     NaN
# 1                        NaN                     NaN
#
#    (typical_of_property, unusual)  (typical_of_concept, unusual)  \
# 4                             2.0                            1.0
# 7                             NaN                            NaN
# 9                             1.0                            1.0
# 3                             NaN                            NaN
# 8                             NaN                            1.0
# 5                             NaN                            NaN
# 6                             NaN                            NaN
# 2                             NaN                            NaN
# 0                             NaN                            NaN
# 1                             NaN                            NaN
#
#    (rare, typical_of_property)  (rare, typical_of_concept)  \
# 4                          1.0                         1.0
# 7                          NaN                         NaN
# 9                          NaN                         NaN
# 3                          NaN                         NaN
# 8                          NaN                         NaN
# 5                          NaN                         NaN
# 6                          NaN                         NaN
# 2                          NaN                         NaN
# 0                          NaN                         NaN
# 1                          NaN                         NaN
#
#    (affording_activity, unusual)  (afforded_unusual, impossible)
# 4                            1.0                             NaN
# 7                            NaN                             NaN
# 9                            1.0                             1.0
# 3                            NaN                             NaN
# 8                            NaN                             NaN
# 5                            NaN                             NaN
# 6                            NaN                             1.0
# 2                            NaN                             NaN
# 0                            NaN                             NaN
# 1                            NaN                             NaN
#
# [10 rows x 21 columns]

# %% [markdown]
# ### All annotations
#
# * Workers with highest contradiction to annotations ratio appear on top
# * use the pandas dataframe sort method to sort on other values:
# * Check how the behavior of a specific worker with many contradictions compares to other workers
#
# `df.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')`

# %%
run = '*'
batch = '*'
n_q = '*'
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_worker_analysis(data_dict_list, name)
df.drop(['annotations'], axis = 1, inplace=True)
df[:10]
# Out:
# Discarded 655.0 annotations.
#                      workerid  n_annotations  n_contradictions  n_fails  \
# 400  5c042ba4bb85e60001c05c83             72                47        0
# 648  5d76a2dc2a476a0001ce6843             72                45        1
# 315  5e4e86b070e1ed2d6e4e3f62             72                42        1
# 320  5e7cbbbcf0a5a004b60b48f7             72                41        1
# 419  5c1f3a7c10677f0001da2157             72                39        0
# 241  5c91321c0375460001034cb8             71                38        0
# 364  5ddd128c961cb3c6780ff181             72                36        0
# 642  5e76ab49dec4562243b421f9             72                35        2
# 297  5c8831d20d005a00131367d3             72                35        0
# 341  5ba4f45c4286a00001ea457f             72                34        1
#
#      contradiction_annotation_ratio  fail_annotation_ratio  \
# 400                        0.652778               0.000000
# 648                        0.625000               0.013889
# 315                        0.583333               0.013889
# 320                        0.569444               0.013889
# 419                        0.541667               0.000000
# 241                        0.535211               0.000000
# 364                        0.500000               0.000000
# 642                        0.486111               0.027778
# 297                        0.486111               0.000000
# 341                        0.472222               0.013889
#
#      average_time_question  (afforded_unusual, unusual)  \
# 400               7.812292                          1.0
# 648              16.482319                          NaN
# 315               4.293264                          NaN
# 320              11.482222                          NaN
# 419               9.921528                          3.0
# 241              12.942127                          2.0
# 364               8.403056                          2.0
# 642              18.781028                          NaN
# 297              16.026153                          1.0
# 341               9.803042                          NaN
#
#      (typical_of_property, unusual)  (implied_category, unusual)  ...  \
# 400                             3.0                          5.0  ...
# 648                             3.0                          5.0  ...
# 315                             5.0                          5.0  ...
# 320                             2.0                          1.0  ...
# 419                             5.0                          5.0  ...
# 241                             6.0                          6.0  ...
# 364                             2.0                          5.0  ...
# 642                             3.0                          2.0  ...
# 297                             3.0                          4.0  ...
# 341                             4.0                          4.0  ...
#
#      (implied_category, impossible)  (affording_activity, impossible)  \
# 400                             3.0                               1.0
# 648                             3.0                               2.0
# 315                             2.0                               1.0
# 320                             4.0                               4.0
# 419                             1.0                               1.0
# 241                             4.0                               1.0
# 364                             3.0                               2.0
# 642                             2.0                               3.0
# 297                             2.0                               2.0
# 341                             2.0                               2.0
#
#      (afforded_unusual, impossible)  (afforded_usual, impossible)  \
# 400                             1.0                           2.0
# 648                             NaN                           NaN
# 315                             NaN                           NaN
# 320                             NaN                           NaN
# 419                             1.0                           1.0
# 241                             1.0                           NaN
# 364                             1.0                           NaN
# 642                             NaN                           NaN
# 297                             NaN                           NaN
# 341                             NaN                           NaN
#
#      (implied_category, rare)  (rare, typical_of_concept)  \
# 400                       6.0                         4.0
# 648                       5.0                         5.0
# 315                       5.0                         4.0
# 320                       5.0                         4.0
# 419                       3.0                         1.0
# 241                       NaN                         NaN
# 364                       4.0                         3.0
# 642                       2.0                         4.0
# 297                       4.0                         2.0
# 341                       3.0                         2.0
#
#      (rare, typical_of_property)  (afforded_usual, rare)  \
# 400                          3.0                     2.0
# 648                          3.0                     NaN
# 315                          5.0                     NaN
# 320                          6.0                     NaN
# 419                          4.0                     1.0
# 241                          NaN                     NaN
# 364                          1.0                     NaN
# 642                          3.0                     NaN
# 297                          2.0                     1.0
# 341                          3.0                     NaN
#
#      (afforded_unusual, rare)  (affording_activity, rare)
# 400                       2.0                         3.0
# 648                       NaN                         5.0
# 315                       NaN                         4.0
# 320                       NaN                         6.0
# 419                       2.0                         1.0
# 241                       NaN                         NaN
# 364                       2.0                         1.0
# 642                       NaN                         4.0
# 297                       1.0                         3.0
# 341                       NaN                         3.0
#
# [10 rows x 25 columns]

# %%
# Good workers
df[-200:-150:]
# Out:
#                       workerid  n_annotations  n_contradictions  n_fails  \
# 154   5ce4db1f65cce3000166882d             71                 1        0
# 259   5d8e45a7d89bf800136c78e1             71                 1        0
# 116   5b2e41eb1d2f710001fb32db            142                 2        0
# 299   5e15baff6887bcbb5425280d             72                 1        1
# 407   579fadcbc6144900014a41cc             72                 1        0
# 513   5cd15bacde09c80016cf3fb4             72                 1        0
# 347   5d20e6639825ad00188bd75e             72                 1        0
# 505   5bc11bbbc11e1200018dfa3b             72                 1        1
# 346   5d15f6ad8078020001aa614a             72                 1        0
# 451   5d593e9e44609300192e33d1             72                 1        0
# 40    56a80ddfc89737000b22bd61             72                 1        0
# 652  Shummana.2010@hotmail.com             72                 1        1
# 634   5bb5c54dc9fbd80001037ca2             72                 1        0
# 361   5bd056f9263e0a00016d20d3             72                 1        0
# 587   5d10ce3e4217c500197fff6a             72                 1        0
# 358   5e85fb2aea1691074a320cf7             72                 1        0
# 526   5d553d4e6416e9001aeaa8a9             72                 1        0
# 616   5cb72d295a63a200170af08f             74                 1        0
# 494   5e70bc96e121de000b95c20e             74                 1        0
# 499   5d0155a1d3e32c00187b729d             74                 1        0
# 522   5c67338e7d17f800013f6176            150                 2        0
# 558   5e701697bb8f8a0b89b86434             76                 1        0
# 178   5ad90f90dec767000128a5f4             77                 1        0
# 568                        0.000000               0.000000
# 619                        0.000000               0.000000
#
#      average_time_question  (afforded_unusual, unusual)  \
# 154               8.306775                          1.0
# 259              13.005620                          NaN
# 116               5.781275                          1.0
# 299              13.756500                          NaN
# 407               7.079236                          NaN
# 513               9.389569                          NaN
# 347              12.262417                          NaN
# 505              10.438681                          NaN
# 346               8.900528                          NaN
# 451              13.106069                          NaN
# 40                5.461458                          NaN
# 652               0.000000                          NaN
# 634              11.298139                          NaN
# 361              10.924306                          NaN
# 587               9.606847                          NaN
# 358              17.294444                          NaN
# 526               5.317083                          NaN
# 616               6.653608                          NaN
# 494              10.654581                          NaN
# 499               7.978122                          NaN
# 522               3.085215                          NaN
# 558              11.247645                          NaN
# 178              25.003052                          NaN
# 179               5.016870                          NaN
# 585               5.072487                          NaN
# 434              10.618077                          NaN
# 433               7.754744                          NaN
# 106              10.994436                          1.0
# 445              12.598026                          NaN
# 436              11.623615                          NaN
# 67               12.683205                          1.0
# 537              10.101603                          NaN
# 97                7.594167                          NaN
# 580              10.692513                          NaN
# 534               8.905397                          NaN
# 487              10.018641                          NaN
# 583              10.120769                          NaN
# 262               8.730060                          1.0
# 109               5.580731                          NaN
# 617              14.852932                          NaN
# 618               8.497500                          NaN
# 662               5.414868                          NaN
# 70               17.341169                          NaN
# 564              12.998513                          NaN
# 4                 9.466085                          NaN
# 242               6.242127                          NaN
# 5                 5.570915                          NaN
# 567               8.560044                          NaN
# 568               6.909279                          NaN
# 619              24.712176                          NaN
#
#      (typical_of_property, unusual)  (implied_category, unusual)  ...  \
# 154                             NaN                          NaN  ...
# 259                             NaN                          NaN  ...
# 116                             NaN                          NaN  ...
# 299                             NaN                          NaN  ...
# 407                             NaN                          NaN  ...
# 513                             NaN                          NaN  ...
# 347                             NaN                          NaN  ...
# 505                             NaN                          NaN  ...
# 346                             NaN                          NaN  ...
# 451                             NaN                          NaN  ...
# 40                              1.0                          NaN  ...
# 652                             NaN                          1.0  ...
# 634                             NaN                          NaN  ...
# 361                             NaN                          NaN  ...
# 587                             NaN                          NaN  ...
# 358                             NaN                          NaN  ...
# 526                             NaN                          1.0  ...
# 616                             1.0                          NaN  ...
# 494                             NaN                          NaN  ...
# 499                             NaN                          NaN  ...
# 522                             NaN                          NaN  ...
# 558                             NaN                          NaN  ...
# 178                             NaN                          NaN  ...
# 179                             NaN                          NaN  ...
# 585                             NaN                          1.0  ...
# 434                             NaN                          NaN  ...
# 433                             NaN                          NaN  ...
# 106                             NaN                          NaN  ...
# 445                             NaN                          NaN  ...
# 436                             NaN                          NaN  ...
# 67                              NaN                          NaN  ...
# 537                             NaN                          NaN  ...
# 97                              NaN                          NaN  ...
# 580                             NaN                          NaN  ...
# 534                             NaN                          NaN  ...
# 487                             NaN                          NaN  ...
# 583                             NaN                          NaN  ...
# 262                             NaN                          NaN  ...
# 109                             NaN                          1.0  ...
# 617                             NaN                          NaN  ...
# 618                             NaN                          NaN  ...
# 662                             NaN                          NaN  ...
# 70                              NaN                          NaN  ...
# 564                             NaN                          NaN  ...
# 4                               NaN                          NaN  ...
# 242                             NaN                          NaN  ...
# 5                               NaN                          NaN  ...
# 567                             NaN                          NaN  ...
# 568                             NaN                          NaN  ...
# 619                             NaN                          NaN  ...
#
#      (implied_category, impossible)  (affording_activity, impossible)  \
#
# 568                          NaN                     NaN
# 619                          NaN                     NaN
#
#      (afforded_unusual, rare)  (affording_activity, rare)
# 154                       NaN                         NaN
# 259                       NaN                         NaN
# 116                       NaN                         NaN
# 299                       1.0                         NaN
# 407                       NaN                         1.0
# 513                       NaN                         NaN
# 347                       NaN                         NaN
# 505                       NaN                         NaN
# 346                       NaN                         NaN
# 451                       NaN                         NaN
# 40                        NaN                         NaN
# 652                       NaN                         NaN
# 634                       NaN                         1.0
# 361                       1.0                         NaN
# 587                       NaN                         NaN
# 358                       NaN                         NaN
# 526                       NaN                         NaN
# 616                       NaN                         NaN
# 494                       NaN                         1.0
# 499                       NaN                         NaN
# 522                       NaN                         NaN
# 558                       NaN                         NaN
# 178                       NaN                         NaN
# 179                       NaN                         NaN
# 585                       NaN                         NaN
# 434                       NaN                         1.0
# 433                       NaN                         NaN
# 106                       NaN                         NaN
# 445                       NaN                         NaN
# 436                       NaN                         1.0
# 67                        NaN                         NaN
# 537                       NaN                         NaN
# 97                        NaN                         NaN
# 580                       NaN                         NaN
# 534                       NaN                         NaN
# 487                       NaN                         NaN
# 583                       NaN                         NaN
# 262                       NaN                         NaN
# 109                       NaN                         NaN
# 617                       NaN                         NaN
# 618                       NaN                         NaN
# 662                       NaN                         NaN
# 70                        NaN                         NaN
# 564                       NaN                         NaN
# 4                         NaN                         NaN
# 242                       NaN                         NaN
# 5                         NaN                         NaN
# 567                       NaN                         NaN
# 568                       NaN                         NaN
# 619                       NaN                         NaN
#
# [50 rows x 25 columns]

# %% [markdown]
# ### Get all contradictions and fails of a particular worker
#
# * Check if a specfic worker continuously contradicts themselves (and fails checks)

# %%
# copy from above - worker with many disagreements in target batch
worker = '5e61391b8f3f89033279a67a'

# df.loc[df['column_name'] == some_value]
df.loc[df['workerid'] == worker]
# Out:
#                      workerid  n_annotations  n_contradictions  n_fails  \
# 301  5e61391b8f3f89033279a67a             72                32        0
#
#      contradiction_annotation_ratio  fail_annotation_ratio  \
# 301                        0.444444                    0.0
#
#      average_time_question  (afforded_unusual, unusual)  \
# 301               7.211972                          2.0
#
#      (typical_of_property, unusual)  (implied_category, unusual)  ...  \
# 301                             NaN                          4.0  ...
#
#      (implied_category, impossible)  (affording_activity, impossible)  \
# 301                             2.0                               NaN
#
#      (afforded_unusual, impossible)  (afforded_usual, impossible)  \
# 301                             2.0                           1.0
#
#      (implied_category, rare)  (rare, typical_of_concept)  \
# 301                       5.0                         3.0
#
#      (rare, typical_of_property)  (afforded_usual, rare)  \
# 301                          1.0                     1.0
#
#      (afforded_unusual, rare)  (affording_activity, rare)
# 301                       2.0                         4.0
#
# [1 rows x 25 columns]

# %% [markdown]
# # Analyze pairs
#
# * compars number of annotator contradictions among pairs

# %% [markdown]
# ### Current batch:

# %%
run = '3'
batch = '38'
n_q = '*'
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_pair_analysis(data_dict_list, name)
df.drop(['annotations_with_contradiction'], axis = 1, inplace=True)
df
# Out:
# Discarded 0.0 annotations.
#                pair  n_annotations  n_workers  n_contradictions  \
# 5       roll-barrel             98         10                19
# 1      roll-chamfer            100         10                15
# 6        roll-chock             99         10                10
# 4         roll-axle             99         10                 6
# 3       red-shallot             97         10                 3
# 0       red-truffle             99         10                 3
# 2  round-watermelon            103         10                 3
# 7   _check2-_check2             11         10                 0
# 8     _test2-_test2             10         10                 0
#
#    n_workers_contradicting  ratio_workers_contradicting  \
# 5                        4                          0.4
# 1                        4                          0.4
# 6                        3                          0.3
# 4                        1                          0.1
# 3                        2                          0.2
# 0                        1                          0.1
# 2                        3                          0.3
# 7                        0                          0.0
# 8                        0                          0.0
#
#    contradiction_annotation_ratio  average_time_pair  \
# 5                        0.193878          94.054221
# 1                        0.150000          93.366130
# 6                        0.101010          93.169505
# 4                        0.060606          93.169505
# 3                        0.030928          95.115880
# 0                        0.030303          93.169505
# 2                        0.029126          90.483126
# 7                        0.000000         875.270050
# 8                        0.000000         933.661300
#
#                                workers_contradicting  \
# 5  5b222aff59f9620001c109cb 5bd04def8f94190001a99...
# 1  5c73477642a5070001a2f940 5e418df8a3b8cc01e3363...
# 6  599863d36c165e000113fadf 5c73477642a5070001a2f...
# 4                           5c73477642a5070001a2f940
# 3  5a4fcc9fe0cf3d000125d7e4 5e418df8a3b8cc01e3363110
# 0                           5e418df8a3b8cc01e3363110
# 2  599863d36c165e000113fadf 5a4fcc9fe0cf3d000125d...
# 7
# 8
#
#                            workers_not_contradicting  ...  \
# 5  599863d36c165e000113fadf 59bda1adab8d830001fe5...  ...
# 1  599863d36c165e000113fadf 59bda1adab8d830001fe5...  ...
# 6  59bda1adab8d830001fe5e4b 5b222aff59f9620001c10...  ...
# 4  599863d36c165e000113fadf 59bda1adab8d830001fe5...  ...
# 3  599863d36c165e000113fadf 59bda1adab8d830001fe5...  ...
# 0  599863d36c165e000113fadf 59bda1adab8d830001fe5...  ...
# 2  59bda1adab8d830001fe5e4b 5b222aff59f9620001c10...  ...
# 7  599863d36c165e000113fadf 59bda1adab8d830001fe5...  ...
# 8  599863d36c165e000113fadf 59bda1adab8d830001fe5...  ...
#
#    (afforded_usual, rare)  (implied_category, impossible)  \
# 5                     NaN                             NaN
# 1                     1.0                             1.0
# 6                     1.0                             NaN
# 4                     NaN                             NaN
# 3                     NaN                             NaN
# 0                     NaN                             NaN
# 2                     NaN                             NaN
# 7                     NaN                             NaN
# 8                     NaN                             NaN
#
#    (afforded_usual, impossible)  (implied_category, unusual)  \
# 5                           NaN                          3.0
# 1                           1.0                          1.0
# 6                           NaN                          1.0
# 4                           NaN                          1.0
# 3                           NaN                          1.0
# 0                           NaN                          NaN
# 2                           NaN                          2.0
# 7                           NaN                          NaN
# 8                           NaN                          NaN
#
#    (afforded_usual, unusual)  (afforded_unusual, unusual)  \
# 5                        1.0                          4.0
# 1                        1.0                          2.0
# 6                        1.0                          3.0
# 4                        NaN                          1.0
# 3                        NaN                          NaN
# 0                        NaN                          NaN
# 2                        NaN                          NaN
# 7                        NaN                          NaN
# 8                        NaN                          NaN
#
#    (affording_activity, rare)  (affording_activity, unusual)  \
# 5                         NaN                            NaN
# 1                         NaN                            NaN
# 6                         NaN                            NaN
# 4                         NaN                            NaN
# 3                         1.0                            1.0
# 0                         NaN                            NaN
# 2                         NaN                            NaN
# 7                         NaN                            NaN
# 8                         NaN                            NaN
#
#    (typical_of_property, unusual)  (rare, typical_of_property)
# 5                             2.0                          1.0
# 1                             NaN                          NaN
# 6                             NaN                          NaN
# 4                             NaN                          NaN
# 3                             NaN                          NaN
# 0                             NaN                          NaN
# 2                             NaN                          NaN
# 7                             NaN                          NaN
# 8                             NaN                          NaN
#
# [9 rows x 26 columns]

# %% [markdown]
# ### Get rows with pairs annotated by specific workers:
#
# * Check if a worker in the only one contradicting or if others also had issues with the pairs

# %%
worker = '5c73477642a5070001a2f940'

show_pairs_of_worker(worker, df)
# Out:
# Worker 5c73477642a5070001a2f940 contradicted themselves in the following pairs:
#
# roll-barrel 	 total workers contradicting themselves: 4
# roll-chamfer 	 total workers contradicting themselves: 4
# roll-chock 	 total workers contradicting themselves: 3
# roll-axle 	 total workers contradicting themselves: 1

# %% [markdown]
# ### Compare to entire annotation set

# %%
run = '*'
batch = '*'
n_q = '*'
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df, filepath = get_pair_analysis(data_dict_list, name)
df.drop(['annotations_with_contradiction'], axis = 1, inplace=True)
df
# Out:
# Discarded 655.0 annotations.
#               pair  n_annotations  n_workers  n_contradictions  \
# 26    roll-spindle             50          5                22
# 227      roll-lamp             50          5                17
# 96   red-mentzelia             50          5                16
# 275    roll-hammer             50          5                16
# 39        roll-nut             50          5                16
# ..             ...            ...        ...               ...
# 371     red-tomato             95         15                 0
# 370  round-biscuit             90         15                 0
# 245       red-beet             95         15                 0
# 246       red-fear             15          5                 0
# 60     round-apple             95         15                 0
#
#      n_workers_contradicting  ratio_workers_contradicting  \
# 26                         4                          0.8
# 227                        4                          0.8
# 96                         4                          0.8
# 275                        5                          1.0
# 39                         5                          1.0
# ..                       ...                          ...
# 371                        0                          0.0
# 370                        0                          0.0
# 245                        0                          0.0
# 246                        0                          0.0
# 60                         0                          0.0
#
#      contradiction_annotation_ratio  average_time_pair  \
# 26                             0.44          57.711660
# 227                            0.34          85.335380
# 96                             0.32          72.657960
# 275                            0.32          52.465380
# 39                             0.32          53.847560
# ..                              ...                ...
# 371                            0.00         122.189322
# 370                            0.00         128.782233
# 245                            0.00         116.628067
# 246                            0.00         217.923067
# 60                             0.00         119.094798
#
#                                  workers_contradicting  \
# 26   5dc0395f2a1dd64710661ccd 5ddc56fbf290e7bbfa964...
# 227  5acb5910e1546900019c413a 5d3f14f66a8a4e0018c17...
# 96   5b994a6d700b020001c572e2 5d134f52f1341200164f9...
# 275  57e131b80cb6700001dd7e5c 5d14abad4d38750001435...
# 39   5a4bf85dac413f0001e6076a 5bfa79fdb8a4c50001b8a...
# ..                                                 ...
# 371
# 370
# 245
# 246
# 60
#
#                              workers_not_contradicting  ...  \
# 26                            5de6be6912bcf6041b3276ba  ...
# 227                           5c5758e9efe1550001dc31b6  ...
# 96                            5bce0e9e48473300014cafca  ...
# 275                                                     ...
# 39                                                      ...
# ..                                                 ...  ...
# 371  591d7a33e4b20e00016c2798 5a473bda7aebf70001153...  ...
# 370  591d7a33e4b20e00016c2798 5a473bda7aebf70001153...  ...
# 245  5c8abb61e1b6910001b30615 5d8b0fb691f3e600016e6...  ...
# 246  5c8abb61e1b6910001b30615 5d8b0fb691f3e600016e6...  ...
# 60   56a80ddfc89737000b22bd61 5b7ebb54ff1109000172a...  ...
#
#      (affording_activity, rare)  (implied_category, rare)  \
# 26                          NaN                       NaN
# 227                         NaN                       NaN
# 96                          NaN                       NaN
# 275                         NaN                       NaN
# 39                          NaN                       NaN
# ..                          ...                       ...
# 371                         NaN                       NaN
# 370                         NaN                       NaN
# 245                         NaN                       NaN
# 246                         NaN                       NaN
# 60                          NaN                       NaN
#
#      (rare, typical_of_property)  (implied_category, impossible)  \
# 26                           NaN                             2.0
# 227                          NaN                             1.0
# 96                           NaN                             1.0
# 275                          NaN                             1.0
# 39                           NaN                             NaN
# ..                           ...                             ...
# 371                          NaN                             NaN
# 370                          NaN                             NaN
# 245                          NaN                             NaN
# 246                          NaN                             NaN
# 60                           NaN                             NaN
#
#      (rare, typical_of_concept)  (affording_activity, impossible)  \
# 26                          NaN                               NaN
# 227                         NaN                               NaN
# 96                          NaN                               1.0
# 275                         NaN                               NaN
# 39                          NaN                               NaN
# ..                          ...                               ...
# 371                         NaN                               NaN
# 370                         NaN                               NaN
# 245                         NaN                               NaN
# 246                         NaN                               NaN
# 60                          NaN                               NaN
#
#      (afforded_unusual, impossible)  (afforded_usual, rare)  \
# 26                              2.0                     NaN
# 227                             2.0                     NaN
# 96                              NaN                     NaN
# 275                             2.0                     NaN
# 39                              NaN                     NaN
# ..                              ...                     ...
# 371                             NaN                     NaN
# 370                             NaN                     NaN
# 245                             NaN                     NaN
# 246                             NaN                     NaN
# 60                              NaN                     NaN
#
#      (afforded_unusual, rare)  (afforded_usual, impossible)
# 26                        NaN                           2.0
# 227                       NaN                           1.0
# 96                        NaN                           NaN
# 275                       NaN                           1.0
# 39                        NaN                           NaN
# ..                        ...                           ...
# 371                       NaN                           NaN
# 370                       NaN                           NaN
# 245                       NaN                           NaN
# 246                       NaN                           NaN
# 60                        NaN                           NaN
#
# [440 rows x 28 columns]

# %% [markdown]
# ### Compare contradictions between runs:

# %%
run = '1'
batch = '*'
n_q = '*'
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df1, filepath = get_pair_analysis(data_dict_list, name)
print(f'analysis can be found at: {filepath}')

run = '3'
batch = '*'
n_q = '*'
group = 'experiment1'

data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
name = f'run{run}-group_{group}-batch{batch}'.replace('*', '-all-')
df2, filepath = get_pair_analysis(data_dict_list, name)
print(f'analysis can be found at: {filepath}')

name1 = '1'
name2 = '3'
compare_runs(name1, name2, df1, df2, comp = 'all')
print()
compare_runs(name1, name2, df1, df2, comp = 'pairs')
# Out:
# Discarded 0.0 annotations.
# analysis can be found at: ../analyses/pairs/run1-group_experiment1-batch-all-.csv
# Discarded 655.0 annotations.
# analysis can be found at: ../analyses/pairs/run3-group_experiment1-batch-all-.csv
# Set 1 as a contradiction ratio of 0.26912294753704447
# Set 3 as a contradiction ratio of 0.2091286307053942
# The ratio is based on the number of workers annotating a pair.
# A worker always annotates a full set.
#
# Set 1 as a contradiction ratio of 0.23765786452353616
# Set 3 as a contradiction ratio of 0.23180256169946892
# The ratio is based on the number of workers annotating a pair.
# A worker always annotates a full set.
# This analysis only includes pairs annotated in run 1 and run 3.
# (0.23765786452353616, 0.23180256169946892)

# %% [markdown]
# # Inter-annotator agreement
#
# * Total agreement
# * Agreement by relations
# * agreement after removing annotators with many contradictions/annotators who fail checks/contradictory annotations

# %% [markdown]
# ## Total iaa:

# %%
run = '3'
batch = '*'
n_q = '*'
group = 'experiment1'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)

run = '1'
batch = '*'
n_q = '*'
group = 'experiment1'
print(f"Run {run}:")
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)

get_agreement(data_dict_list)
# Out:
# Run 3:
# Discarded 655.0 annotations.
# Krippendorff's alpha: 0.2463725697540442
# Proportional agreement (pairwise): 0.6385114873424212
#
# Run 1:
# Discarded 0.0 annotations.
# Krippendorff's alpha: 0.2413329996998821
# Proportional agreement (pairwise): 0.6204625909422005
# {'Krippendorff': 0.2413329996998821, 'Proportional': 0.6204625909422005}

# %% [markdown]
# ## IAA by relation

# %%
runs = ['3', '1']
experiment_name = 'experiment1'
path, df = agreement_relations_across_runs(runs, experiment_name)
print(f'Results written to: {path}')
df
# Out:
# Discarded 655.0 annotations.
# Discarded 0.0 annotations.
# Results written to: ../analyses/iaa/relations_runs3-1.csv
#                      relation  3_Krippendorff  3_Proportional  1_Krippendorff  \
# 0                        rare        0.162885        0.596243             NaN
# 1                      _check        0.643894        0.894828        0.904637
# 2                  impossible        0.143642        0.675566        0.183925
# 3            afforded_unusual        0.035775        0.525967        0.108460
# 4              afforded_usual        0.181940        0.660557        0.336767
# 5                   test_true        0.080396        0.813115             NaN
# 6                  test_false        0.106607        0.767095             NaN
# 7                    creative        0.065253        0.557281        0.040020
# 8   variability_subcategories             NaN             NaN        0.157270
# 9                     unusual        0.171452        0.584685        0.120147
# 10        typical_of_property        0.252850        0.770219        0.326482
# 11           variability_open        0.216772        0.607166        0.143751
# 12           implied_category        0.273568        0.659212        0.260459
# 13        variability_limited        0.120893        0.562074        0.197795
# 14         affording_activity        0.194360        0.653146        0.149149
# 15         typical_of_concept        0.332461        0.716034        0.367910
#
#     1_Proportional
# 0              NaN
# 1         0.964443
# 2         0.679565
# 3         0.557623
# 4         0.698580
# 5              NaN
# 6              NaN
# 7         0.524894
# 8         0.579637
# 9         0.561644
# 10        0.682547
# 11        0.580081
# 12        0.629956
# 13        0.599990
# 14        0.672259
# 15        0.689440

# %% [markdown]
# ## Agreement after removing workers or annotations:

# %%
run = '3'
batch = '*'
n_q = '*'
group = 'experiment1'

print('Total Agreement')
data_dict_list = load_experiment_data(run, group, n_q, batch, remove_not_val = True)
get_agreement(data_dict_list)
print('-------')
print()

print('Removing pairs with many contradictions:')
category = 'pairs_contradictions'
print(f'analyze {category}')
annotations_clean, annotations_removed = clean_annotations(run, group, n_q, batch, category)
print('agreement clean')
get_agreement(annotations_clean)
#print('agreement rest')
#get_agreement(annotations_removed)


category = 'worker_contradictions'
print(f'analyze {category}')
annotations_clean, annotations_removed = clean_annotations(run, group, n_q, batch, category)
print('agreement clean')
get_agreement(annotations_clean)
#print('agreement rest')
#get_agreement(annotations_removed)
print()

category = 'worker_checks'
print(f'analyze {category}')
annotations_clean, annotations_removed = clean_annotations(run, group, n_q, batch, category)
print('agreement clean')
get_agreement(annotations_clean)
#print('agreement rest')
#get_agreement(annotations_removed)
# Out:
# Total Agreement
# Discarded 655.0 annotations.
# Krippendorff's alpha: 0.2463725697540442
# Proportional agreement (pairwise): 0.6385114873424212
#
# -------
#
# Removing pairs with many contradictions:
# analyze pairs_contradictions
# Discarded 655.0 annotations.
# Found 21467 clean annotations.
# Round 7670 to remove.
#
# agreement clean
# Krippendorff's alpha: 0.34022524272587773
# Proportional agreement (pairwise): 0.6873914995739058
#
# analyze worker_contradictions
# Discarded 655.0 annotations.
# Found 18983 clean annotations.
# Round 10100 to remove.
#
# agreement clean
# Krippendorff's alpha: 0.2736523689712784
# Proportional agreement (pairwise): 0.6619245304424161
#
#
# analyze worker_checks
# Discarded 655.0 annotations.
# Found 26554 clean annotations.
# Round 2529 to remove.
#
# agreement clean
# Krippendorff's alpha: 0.26865514911812405
# Proportional agreement (pairwise): 0.6499509093252589
# {'Krippendorff': 0.26865514911812405, 'Proportional': 0.6499509093252589}
